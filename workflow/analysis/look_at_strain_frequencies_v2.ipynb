# %%
import pandas as pd
import numpy as np

from snp_analysis_tools_sherlock import *

import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from coalescence_analysis_tools import * 

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='fba6fb95-1baa-46d8-a77c-3086ce681187'>
#   <div id="ff0b4c21-567b-4455-8424-5a10595131f7" data-root-id="fba6fb95-1baa-46d8-a77c-3086ce681187" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7f5eb270-7fde-42ee-8261-f057e0c8bd82":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"fba6fb95-1baa-46d8-a77c-3086ce681187"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"9473fa5b-44a5-4b1d-bffe-88fb87ad9a66","attributes":{"plot_id":"fba6fb95-1baa-46d8-a77c-3086ce681187","comm_id":"ef1d7d73136c46b1b00bb73d1b4d8871","client_comm_id":"735ba3706935443faaa78470dce953b3"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"7f5eb270-7fde-42ee-8261-f057e0c8bd82","roots":{"fba6fb95-1baa-46d8-a77c-3086ce681187":"ff0b4c21-567b-4455-8424-5a10595131f7"},"root_ids":["fba6fb95-1baa-46d8-a77c-3086ce681187"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#df_metadata.head()
def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata = transform_df(df_metadata)
df_metadata['species_id'] = df_metadata['species_id'].astype(str)
df_metadata = df_metadata.set_index('species_id').astype(str)

# %%
def get_inoculumn_sort(x):
    subjects = list(np.sort(x.split('-')[:-1]))
    media =  x.split('-')[-1]
    return '-'.join(subjects + [media])




def get_in(x):
    #print('yay',x)
    if x in list(in_dict.keys()):
     
        return in_dict[x]
    else:
        return ''
#df_info['inoculumn'] = df_info['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:-1]))
e003_metadata = pd.read_csv('e003_metadata_cultures_round2.csv') #.drop(columns = 'Unnamed: 0')
e003_metadata['type_meso'] = e003_metadata['type_mesocosm']
#e003_metadata['inoculumn'] = e003_metadata['inoculumn'].transform(get_inoculumn_sort)

in_df = e003_metadata.loc[e003_metadata['is_inoculumn'],:].set_index('inoculumn').copy()

in_series = in_df['sample']
in_dict = in_series.to_dict()

# %%
def analyze_diversity(diversity_df1,minor_strain, minor_strain_subject, separate_plots_per_mesocosm=True):
  #  minor_strain = 

   # p = bokeh.plotting.figure(width = 600, height = 400)

   # if separate_plots_per_mesocosm:
    #plots = []
    p2 = bokeh.plotting.figure(width = 500, height = 300)
    palette = bokeh.palettes.Set2[8]
    for i, type_meso in enumerate(diversity_df1['type_meso'].unique()):
        mesos = diversity_df1.loc[diversity_df1['type_meso'] ==type_meso, 'mesocosm'].unique()
        
     #   p3 = bokeh.plotting.figure(width = 300, height = 200)
        df_type_meso = diversity_df1.loc[diversity_df1['type_meso'] == type_meso,:]
        color = palette[0]
        if type_meso.split('-')[-1] == 'mBHI':
            color = palette[1]
        p2.circle(df_type_meso['passage'].values,
                   df_type_meso[minor_strain].values,color = color, legend_label = type_meso, size = 5)
        for mesocosm in mesos:
            print(mesocosm)
            
            df_meso = diversity_df1.loc[diversity_df1['mesocosm'] == mesocosm,:]
            in_sample = df_meso['inoculumn_sample'].unique()[0]
            #print(type_meso, in_sample)
            if in_sample in df_info.index.values:
                df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
           # df_meso = pd.concat([df_meso, diversity_df1.loc[diversity_df1['sample'] == in_sample,:]])
            df_meso = df_meso.sort_values(by = 'passage')
          #  p.line(df_meso['passage'].values,
           #        df_meso[minor_strain].values, legend_label)

                #print(np.max(df_meso['passage'].values))
               # print(len(df_meso))
                
            p2.line(df_meso['passage'].values,
                   df_meso[minor_strain].values,color=color)
                

              
    p2.yaxis.axis_label = 'Minor strain abundance'
    p2.xaxis.axis_label = 'Passage'
    inoculumn_stuff = '-'.join(type_meso.split('-')[:-1])
    p2.title.text = f'{minor_strain_subject} in {inoculumn_stuff}'
    p2.y_range = bokeh.models.Range1d(-.005,1.005)
    p2.x_range = bokeh.models.Range1d(-.5,7.5)

      #  plots.append(p2)

            

  #  if separate_plots_per_mesocosm:
    return p2

# %%
def analyze_fitness(diversity_df1,minor_strain, major_strain,
                               minor_strain_subject, major_strain_subject):
    new_df = []
    for i, type_meso in enumerate(diversity_df1['type_meso'].unique()):
        mesos = diversity_df1.loc[diversity_df1['type_meso'] ==type_meso, 'mesocosm'].unique()
        df_type_meso = diversity_df1.loc[diversity_df1['type_meso'] == type_meso,:]
        for mesocosm in mesos:
            
            df_meso = diversity_df1.loc[diversity_df1['mesocosm'] == mesocosm,:]
            in_sample = df_meso['inoculumn_sample'].unique()[0]
            df_meso['shift_from_inoculumn'] = np.nan
           # df_meso[f'shift {minor_strain_subject}'] = np.nan
            df_meso[f'opp_strain_shift_from_inoculumn'] = np.nan
            if in_sample in df_info.index.values:
                df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
                df_meso['shift_from_inoculumn'] = df_meso[minor_strain] - df_info.loc[in_sample,minor_strain]
            #    df_meso[f'shift {minor_strain_subject}'] = df_meso[minor_strain] - df_info.loc[in_sample,minor_strain]
                df_meso[f'opp_strain_shift_from_inoculumn'] = df_meso[major_strain] - df_info.loc[in_sample,major_strain]
                
        
            df_meso = df_meso.sort_values(by = 'passage')
            new_df.append(df_meso)
            
    
    return pd.concat(new_df)

# %%
species_fnames = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2/*')
species_names = [fname.split('/')[-1] for fname in species_fnames]

#species_names

# %%
def analyze_diversity(diversity_df1,minor_strain, minor_strain_subject, separate_plots_per_mesocosm=True,
                     color = bokeh.palettes.Set2[8][1], p2 = None):
  #  minor_strain = 

   # p = bokeh.plotting.figure(width = 600, height = 400)

   # if separate_plots_per_mesocosm:
    #plots = []
    if p2 == None:
        p2 = bokeh.plotting.figure(width = 500, height = 300)
    palette = bokeh.palettes.Set2[8]
    for i, type_meso in enumerate(diversity_df1['type_meso'].unique()):
        mesos = diversity_df1.loc[diversity_df1['type_meso'] ==type_meso, 'mesocosm'].unique()
        
     #   p3 = bokeh.plotting.figure(width = 300, height = 200)
        df_type_meso = diversity_df1.loc[diversity_df1['type_meso'] == type_meso,:]
        color = palette[i]

        
        for mesocosm in mesos:
            print(mesocosm)
           # if mesocosm != 'G5-AE-AF-mBHI-mBHI':
            #    continue
            
            df_meso = diversity_df1.loc[diversity_df1['mesocosm'] == mesocosm,:]
            
            in_sample = df_meso['inoculumn_sample'].unique()[0]
            #print(type_meso, in_sample)
            if in_sample in df_info.index.values:
                df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
           # df_meso = pd.concat([df_meso, diversity_df1.loc[diversity_df1['sample'] == in_sample,:]])
            df_meso = df_meso.sort_values(by = 'passage')
          #  p.line(df_meso['passage'].values,
           #        df_meso[minor_strain].values, legend_label)

                #print(np.max(df_meso['passage'].values))
               # print(len(df_meso))
                
            p2.line(df_meso['passage'].values,
                   df_meso[minor_strain].values,color=color)
            p2.circle(df_meso['passage'].values,
                   df_meso[minor_strain].values,color = color, legend_label = type_meso, size = 5)
                

              
    p2.yaxis.axis_label = 'Minor strain abundance'
    p2.xaxis.axis_label = 'Passage'
    inoculumn_stuff = '-'.join(type_meso.split('-')[:-1])
    p2.title.text = f'{minor_strain_subject} in {inoculumn_stuff}'
    p2.y_range = bokeh.models.Range1d(-.005,1.005)
    p2.x_range = bokeh.models.Range1d(-.5,7.5)

      #  plots.append(p2)

            

  #  if separate_plots_per_mesocosm:
    return p2

# %%
def analyze_diversity(diversity_df1,minor_strain, minor_strain_subject, separate_plots_per_mesocosm=True,
                     real_species = ''):
  #  minor_strain = 

   # p = bokeh.plotting.figure(width = 600, height = 400)

   # if separate_plots_per_mesocosm:
    #plots = []
    p2 = bokeh.plotting.figure(width = 500, height = 300)
    palette = bokeh.palettes.Set2[8]
    for i, type_meso in enumerate(diversity_df1['type_meso'].unique()):
        mesos = diversity_df1.loc[diversity_df1['type_meso'] ==type_meso, 'mesocosm'].unique()
        
     #   p3 = bokeh.plotting.figure(width = 300, height = 200)
        df_type_meso = diversity_df1.loc[diversity_df1['type_meso'] == type_meso,:]
        color = palette[0]
        if type_meso.split('-')[-1] == 'mBHI':
            color = palette[1]
        p2.circle(df_type_meso['passage'].values,
                   df_type_meso[minor_strain].values,color = color, legend_label = type_meso, size = 5)
        for mesocosm in mesos:
            print(mesocosm)
            
            df_meso = diversity_df1.loc[diversity_df1['mesocosm'] == mesocosm,:]
            in_sample = df_meso['inoculumn_sample'].unique()[0]
            #print(type_meso, in_sample)
            if in_sample in df_info.index.values:
                df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
           # df_meso = pd.concat([df_meso, diversity_df1.loc[diversity_df1['sample'] == in_sample,:]])
            df_meso = df_meso.sort_values(by = 'passage')
          #  p.line(df_meso['passage'].values,
           #        df_meso[minor_strain].values, legend_label)

                #print(np.max(df_meso['passage'].values))
               # print(len(df_meso))
                
            p2.line(df_meso['passage'].values,
                   df_meso[minor_strain].values,color=color)
                

              
    p2.yaxis.axis_label = 'Minor strain abundance'
    p2.xaxis.axis_label = 'Passage'
    inoculumn_stuff = '-'.join(type_meso.split('-')[:-1])
    p2.title.text = f'{real_species} {minor_strain_subject} in {inoculumn_stuff}'
    p2.y_range = bokeh.models.Range1d(-.005,1.005)
    p2.x_range = bokeh.models.Range1d(-.5,7.5)

      #  plots.append(p2)

            

  #  if separate_plots_per_mesocosm:
    return p2

# %%
#species_names = glob.glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snps/*')
#species = '102320'
fnames = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/dir_selectionavg/*')
dfs = []
for fname in fnames:
    df = pd.read_csv(fname) #.set_index(sample)
    species = fname.split('/')[-1].split('_shifts.csv')[0]
    #df_abundance_sp = df_abundance_melted.loc[df_abundance_melted['species_id'] == int(species),:].set_index('sample')

    df['species_id'] = species
  #  df['species_abundance']= df['sample'].transform(lambda x: df_abundance_sp.loc[x, 'relative_abundance'])
   # df['Lineage'] = df_abundance_sp['Lineage'].values[0]
    #df['species'] = df_abundance_sp['species'].values[0]
    dfs.append(df)

full_df = pd.concat(dfs)
species = full_df['species_id'].unique()
for species in species_names:
    fnames = glob(f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsavg/{species}/*_parent_freqs.csv')
    print(species)
    real_species = df_metadata.loc[species,'species']
    print(real_species)
    plots_all = []
    for info_fname in np.sort(fnames): 
       # print(info_fname)
       # fname = f'~/git/coalescence-pilot-mgx/workflow/report/track_snps/{species}/AA-AE-mGAM_parent_freqs.csv'
        df = pd.read_csv(info_fname).rename(columns = {'Unnamed: 0': 'sample'})
       # print(df)
        if len(df) ==0:
            continue

        medium_df = df.set_index('sample').median()
        minor_strain = medium_df.index.values[0]
       # strains = df.columns.values[1:]
      #  subjects = [e003_metadata.loc[e003_metadata['sample'] == strain,'parent_subjects'].values[0].split('-')[0] for strain in strains]
       # print(subjects)

        df_info = pd.concat([df.set_index('sample'), 
                             e003_metadata.loc[e003_metadata['sample'].isin(df['sample'].unique()),:].set_index('sample')],axis=1)
        df_info['inoculumn_sample'] = df_info['inoculumn'].transform(get_in)
        #print(minor_strain)
        minor_strain_subject =  e003_metadata.loc[e003_metadata['sample'] == minor_strain,'parent_subjects'].values[0].split('-')[0]
        print(minor_strain_subject)
       # print(minor_strain)
        p2 = analyze_diversity(df_info, minor_strain, 
                               e003_metadata.loc[e003_metadata['sample'] == minor_strain,'parent_subjects'].values[0].split('-')[0],
                              real_species = real_species )
        p2.legend.visible = False
        bokeh.io.show(p2)
        plots_all.append(p2)
    if len(plots_all)>0:
        bokeh.io.export_png(bokeh.layouts.gridplot(plots_all,ncols=2),filename=f'{species}_minor_strain_abundance_avg.png')
# Out:
# 100296
# s__Peptostreptococcus anaerobius
# 100254
# s__Odoribacter splanchnicus
# 100059
# s__Lawsonibacter sp900066645
# 100238
# s__Enterococcus_D casseliflavus
# 100035
# s__Blautia_A hydrogenotrophica
# 100032
# s__Hungatella effluvii
# 103681
# s__Bacteroides stercoris
# 101380
# s__Faecalicatena gnavus
# 102353
# s__Enterococcus_B faecium
# 100255
# s__CAG-81 sp900066055
# 101345
# s__Bacteroides xylanisolvens
# 101547
# s__Emergencia timonensis
# 100146
# s__Dorea formicigenerans
# AA
# A3-AA-AC/PP-mBHI-mBHI
# B2-AA-AC/PP-mBHI-mBHI
# A3-AA-AC/PP-mBHI-mGAM
# B2-AA-AC/PP-mBHI-mGAM
# E3-AA-AC/PP-mBHI-mGAM
# F2-AA-AC/PP-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="dabce67e-76cd-437a-bf93-2ddd991de1e8" data-root-id="011c83fd-4a07-4bf6-8f34-d2fe3eca79df" style="display: contents;"></div>
# AA
# A3-AA-AC/PP-mGAM-mGAM
# A9-AA-AC/PP-mGAM-mGAM
# B2-AA-AC/PP-mGAM-mGAM
# B8-AA-AC/PP-mGAM-mGAM
# E9-AA-AC/PP-mGAM-mGAM
# F8-AA-AC/PP-mGAM-mGAM
# A9-AA-AC/PP-mGAM-mBHI
# B8-AA-AC/PP-mGAM-mBHI
# E9-AA-AC/PP-mGAM-mBHI
# F8-AA-AC/PP-mGAM-mBHI
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="b48c69ee-255f-47c2-b3f4-1741d5f7eb37" data-root-id="5e674560-6035-4283-8794-bc9ae9272393" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# AA
# A10-AA-AE-mGAM-mBHI
# C8-AA-AE-mGAM-mBHI
# E10-AA-AE-mGAM-mBHI
# G8-AA-AE-mGAM-mBHI
# A10-AA-AE-mGAM-mGAM
# A4-AA-AE-mGAM-mGAM
# C2-AA-AE-mGAM-mGAM
# C8-AA-AE-mGAM-mGAM
# E10-AA-AE-mGAM-mGAM
# G8-AA-AE-mGAM-mGAM
#   <div id="bb9e4f69-0851-4d46-82f4-60a41a7a8ee8" data-root-id="b644d551-729b-4130-9688-3aa329bb5d86" style="display: contents;"></div>
# AA
# A5-AA-AF-mBHI-mBHI
# D2-AA-AF-mBHI-mBHI
# H2-AA-AF-mBHI-mBHI
# A5-AA-AF-mBHI-mGAM
# D2-AA-AF-mBHI-mGAM
# E5-AA-AF-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# H2-AA-AF-mBHI-mGAM
#   <div id="eee11302-95fa-456a-82bf-80a82ff14002" data-root-id="e1d0678f-0af2-4e8b-8731-2a910decc179" style="display: contents;"></div>
# AA
# A11-AA-AF-mGAM-mBHI
# D8-AA-AF-mGAM-mBHI
# E11-AA-AF-mGAM-mBHI
# H8-AA-AF-mGAM-mBHI
# A11-AA-AF-mGAM-mGAM
# A5-AA-AF-mGAM-mGAM
# D2-AA-AF-mGAM-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# D8-AA-AF-mGAM-mGAM
# E11-AA-AF-mGAM-mGAM
# H8-AA-AF-mGAM-mGAM
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="be3ac4f4-a853-434d-94b8-b5a0ed5038a1" data-root-id="abf31f53-59cf-4880-afd1-317ea225587b" style="display: contents;"></div>
# AC/PP
# B10-AC/PP-AE-mGAM-mBHI
# C9-AC/PP-AE-mGAM-mBHI
# F10-AC/PP-AE-mGAM-mBHI
# G9-AC/PP-AE-mGAM-mBHI
# B10-AC/PP-AE-mGAM-mGAM
# B4-AC/PP-AE-mGAM-mGAM
# C3-AC/PP-AE-mGAM-mGAM
# C9-AC/PP-AE-mGAM-mGAM
# F10-AC/PP-AE-mGAM-mGAM
# G9-AC/PP-AE-mGAM-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="af7e1b12-25fa-416e-930a-539d854f8d33" data-root-id="aca1aba8-253e-4b71-b05b-a1a05dd1cafa" style="display: contents;"></div>
# AC/PP
# B5-AC/PP-AF-mBHI-mBHI
# D3-AC/PP-AF-mBHI-mBHI
# F5-AC/PP-AF-mBHI-mBHI
# H3-AC/PP-AF-mBHI-mBHI
# B5-AC/PP-AF-mBHI-mGAM
# D3-AC/PP-AF-mBHI-mGAM
# F5-AC/PP-AF-mBHI-mGAM
# H3-AC/PP-AF-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="f8996efc-7f05-4a72-a8d2-6db4fd266f26" data-root-id="215db02b-e42f-4b57-acf1-cc65818d8fec" style="display: contents;"></div>
# AC/PP
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# B11-AC/PP-AF-mGAM-mBHI
# D9-AC/PP-AF-mGAM-mBHI
# F11-AC/PP-AF-mGAM-mBHI
# H9-AC/PP-AF-mGAM-mBHI
# B11-AC/PP-AF-mGAM-mGAM
# B5-AC/PP-AF-mGAM-mGAM
# D3-AC/PP-AF-mGAM-mGAM
# D9-AC/PP-AF-mGAM-mGAM
# F11-AC/PP-AF-mGAM-mGAM
# H9-AC/PP-AF-mGAM-mGAM
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="e9ab510e-3928-4dc9-91f1-3c50bb4de69b" data-root-id="e39e3003-446f-47d2-9c88-344189cb2001" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# AE
# C11-AE-AF-mGAM-mBHI
# D10-AE-AF-mGAM-mBHI
# G11-AE-AF-mGAM-mBHI
# H10-AE-AF-mGAM-mBHI
# C11-AE-AF-mGAM-mGAM
# C5-AE-AF-mGAM-mGAM
# D10-AE-AF-mGAM-mGAM
# D4-AE-AF-mGAM-mGAM
# G11-AE-AF-mGAM-mGAM
#   <div id="b285643b-f032-4719-b73e-2e0c706743e8" data-root-id="d1573666-677f-4d00-9728-27d0d5d4b98c" style="display: contents;"></div>
# The geckodriver version (0.35.0) detected in PATH at /Users/sophiewalton/miniconda3/envs/bokeh_update/bin/geckodriver might not be compatible with the detected firefox version (134.0); currently, geckodriver 0.36.0 is recommended for firefox 134.*, so it is advised to delete the driver in PATH and retry
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)
# 101060
# s__Dialister sp900343095
# 102281
# s__Bacteroides faecis
# 103166
# s__
# 102272
# s__Faecalibacterium prausnitzii_D
# 100177
# s__Anaerotignum sp000436415
# 101638
# s__
# 100123
# s__Blautia sp001304935
# 102470
# s__Bacteroides intestinalis
# 101433
# s__Bacteroides salyersiae
# 102619
# s__Faecalibacterium prausnitzii_J
# 101059
# s__Porphyromonas somerae
# AA
# A5-AA-AF-mBHI-mBHI
# D2-AA-AF-mBHI-mBHI
# E5-AA-AF-mBHI-mBHI
# H2-AA-AF-mBHI-mBHI
# A5-AA-AF-mBHI-mGAM
# D2-AA-AF-mBHI-mGAM
# E5-AA-AF-mBHI-mGAM
# H2-AA-AF-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="ac5a7572-850e-46b7-aeef-a96fe529f757" data-root-id="bd49d07b-10a3-4c0d-b26e-83ce4b1354ce" style="display: contents;"></div>
# 103937
# s__Gemmiger sp003476825
# 100910
# s__Flavonifractor sp900199495
# AA
# A3-AA-AC/PP-mBHI-mBHI
# B2-AA-AC/PP-mBHI-mBHI
# E3-AA-AC/PP-mBHI-mBHI
# F2-AA-AC/PP-mBHI-mBHI
# E3-AA-AC/PP-mBHI-mGAM
# F2-AA-AC/PP-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="ae5ee268-8dd2-441d-a5e3-33046ac6528e" data-root-id="32ba3c9d-7f66-43c3-b84c-fae383742dc7" style="display: contents;"></div>
# AA
# A4-AA-AE-mBHI-mBHI
# C2-AA-AE-mBHI-mBHI
# E4-AA-AE-mBHI-mBHI
# G2-AA-AE-mBHI-mBHI
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# C2-AA-AE-mBHI-mGAM
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="f9c851ca-a65b-4469-b5a3-99fae4adf951" data-root-id="9cb39153-66aa-45d4-8449-b73ed173449f" style="display: contents;"></div>
# AC/PP
# B4-AC/PP-AE-mBHI-mBHI
# C3-AC/PP-AE-mBHI-mBHI
# F4-AC/PP-AE-mBHI-mBHI
# G3-AC/PP-AE-mBHI-mBHI
# C3-AC/PP-AE-mBHI-mGAM
# F4-AC/PP-AE-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="d5f523b0-fcdc-4e3e-a8ec-dfba5ad8be73" data-root-id="71db31c3-5d1b-432d-b71e-e65cadb6aa6b" style="display: contents;"></div>
# 100113
# s__Streptococcus salivarius
# 103796
# s__Peptoniphilus_B sp000478985
# 102478
# s__Bacteroides_B dorei
# AA
# A3-AA-AC/PP-mBHI-mBHI
# B2-AA-AC/PP-mBHI-mBHI
# E3-AA-AC/PP-mBHI-mBHI
# F2-AA-AC/PP-mBHI-mBHI
# A3-AA-AC/PP-mBHI-mGAM
# B2-AA-AC/PP-mBHI-mGAM
# E3-AA-AC/PP-mBHI-mGAM
# F2-AA-AC/PP-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="af1f201c-1b5a-4836-863e-643d60c17f99" data-root-id="4b4b75a8-e248-41d8-9c00-af3e7a1d0211" style="display: contents;"></div>
# AA
# A3-AA-AC/PP-mGAM-mGAM
# A9-AA-AC/PP-mGAM-mGAM
# B2-AA-AC/PP-mGAM-mGAM
# B8-AA-AC/PP-mGAM-mGAM
# E9-AA-AC/PP-mGAM-mGAM
# F8-AA-AC/PP-mGAM-mGAM
# A9-AA-AC/PP-mGAM-mBHI
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="fab12772-e768-4c6b-b804-4edbfd7d363e" data-root-id="bc1b55ca-0178-4667-bec5-6f4f1dc03286" style="display: contents;"></div>
# 102945
# s__Bariatricus massiliensis
# AC/PP
# B4-AC/PP-AE-mBHI-mBHI
# C3-AC/PP-AE-mBHI-mBHI
# F4-AC/PP-AE-mBHI-mBHI
# G3-AC/PP-AE-mBHI-mBHI
# B4-AC/PP-AE-mBHI-mGAM
# C3-AC/PP-AE-mBHI-mGAM
# F4-AC/PP-AE-mBHI-mGAM
# G3-AC/PP-AE-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="dd52bb62-b98f-41ea-9d06-14fdae9839bd" data-root-id="0d128989-50fe-4883-9684-ae2a2dd5fec9" style="display: contents;"></div>
# 100078
# s__Lachnospira rogosae
# 101362
# s__Streptococcus anginosus
# 100243
# s__Bacteroides_B massiliensis
# 100217
# s__Acetatifactor sp900066565
# 100022
# s__Faecalibacterium prausnitzii_C
# 102327
# s__Oscillibacter sp900066435
# AA
# A3-AA-AC/PP-mBHI-mBHI
# B2-AA-AC/PP-mBHI-mBHI
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="f3369001-ddca-41c9-8c2b-ff3a050b3221" data-root-id="457883da-4ca0-46a2-8b22-2db04b8c49ed" style="display: contents;"></div>
# AA
# A5-AA-AF-mBHI-mBHI
# D2-AA-AF-mBHI-mBHI
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="f3184e22-1650-4e1d-9a81-72cc895447b0" data-root-id="fce7d95b-9e74-4d0b-99f6-e24eb2f49f95" style="display: contents;"></div>
# AC/PP
# B5-AC/PP-AF-mBHI-mBHI
# D3-AC/PP-AF-mBHI-mBHI
# F5-AC/PP-AF-mBHI-mBHI
# H3-AC/PP-AF-mBHI-mBHI
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="fd0a553e-bf37-4e43-bea5-7486196b6d08" data-root-id="97f9b669-bbbf-4f2a-814a-eeadda77e44c" style="display: contents;"></div>
# 101300
# s__Faecalibacterium prausnitzii_K
# 100013
# s__
# AA
# A3-AA-AC/PP-mBHI-mBHI
# B2-AA-AC/PP-mBHI-mBHI
# E3-AA-AC/PP-mBHI-mBHI
# F2-AA-AC/PP-mBHI-mBHI
# A3-AA-AC/PP-mBHI-mGAM
# B2-AA-AC/PP-mBHI-mGAM
# E3-AA-AC/PP-mBHI-mGAM
# F2-AA-AC/PP-mBHI-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="e438243d-c5ae-42c3-ac38-885bbed402a2" data-root-id="ba1ffc4b-26a4-46dc-8658-628dc5566fa8" style="display: contents;"></div>
# 102320
# s__Enterococcus_B faecium_B
# AC/PP
# B11-AC/PP-AF-mGAM-mBHI
# D9-AC/PP-AF-mGAM-mBHI
# F11-AC/PP-AF-mGAM-mBHI
# H9-AC/PP-AF-mGAM-mBHI
# B11-AC/PP-AF-mGAM-mGAM
# B5-AC/PP-AF-mGAM-mGAM
# D3-AC/PP-AF-mGAM-mGAM
# D9-AC/PP-AF-mGAM-mGAM
# F11-AC/PP-AF-mGAM-mGAM
# H9-AC/PP-AF-mGAM-mGAM
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_80262/1562628832.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
#   <div id="a8947769-eeef-4f9b-86e9-0b356e30b198" data-root-id="7d58718a-b391-497b-a6f7-3728f39903a5" style="display: contents;"></div>
# 101338
# s__Blautia_A wexlerae
# 102549
# s__Bacteroides caccae

# %%
df_alive = pd.read_csv('alive.csv').drop(columns = 'Unnamed: 0')
#df_infogood = df_info.loc[df_info['type_meso'].isin()

# %%
df_ingood = df_info.loc[df_info['type_meso'].isin(df_sp['type_meso'].unique()),:]

# %%
fname = '~/git/coalescence-pilot-mgx/midas2_output/mergev2/species/species_relative_abundance.tsv'
df_abundance = pd.read_csv(fname, delimiter = '\t')
df_abundance
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_abundance_melted = pd.melt(df_abundance, 
                                  var_name = 'sample', 
                                  id_vars='species_id',
                                  value_name = 'relative_abundance')


df_abundance_melted = transform_df(df_abundance_melted)
#df_abundance_melted['speciesid']# -sample'] = df_abundance_melted['species_id'] + '-' + df_abundance_melted['sample']
df_abundance_melted.head()
# Out:
#    species_id                       sample  relative_abundance  \
# 0      102506  C12-e003Coalescence-mBHI-p3               0.187
# 1      102320  C12-e003Coalescence-mBHI-p3               0.121
# 2      100099  C12-e003Coalescence-mBHI-p3               0.119
# 3      100196  C12-e003Coalescence-mBHI-p3               0.123
# 4      101346  C12-e003Coalescence-mBHI-p3               0.038
#
#                                              Lineage  \
# 0  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 1  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# 3  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 4  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                            species              genus                 family  \
# 0            s__Escherichia coli_D     g__Escherichia  f__Enterobacteriaceae
# 1      s__Enterococcus_B faecium_B  g__Enterococcus_B     f__Enterococcaceae
# 2        s__Flavonifractor plautii  g__Flavonifractor    f__Oscillospiraceae
# 3  s__Bacteroides thetaiotaomicron     g__Bacteroides      f__Bacteroidaceae
# 4         s__Bacteroides uniformis     g__Bacteroides      f__Bacteroidaceae
#
#                phyla
# 0  p__Proteobacteria
# 1      p__Firmicutes
# 2    p__Firmicutes_A
# 3    p__Bacteroidota
# 4    p__Bacteroidota

# %%
def plot_species_abundance(diversity_df1, real_species = real_species):
    p2 = bokeh.plotting.figure(width = 500, height = 200)
    palette = bokeh.palettes.Set2[8]
    for i, type_meso in enumerate(diversity_df1['type_meso'].unique()):
        mesos = diversity_df1.loc[diversity_df1['type_meso'] ==type_meso, 'mesocosm'].unique()
        
     #   p3 = bokeh.plotting.figure(width = 300, height = 200)
        df_type_meso = diversity_df1.loc[diversity_df1['type_meso'] == type_meso,:]
        color = palette[0]
        if type_meso.split('-')[-1] == 'mBHI':
            color = palette[1]
        p2.circle(df_type_meso['passage'].values,
                   df_type_meso['species_abundance'].values,color = color, legend_label = type_meso, size = 5)
        for mesocosm in mesos:
            print(mesocosm)
            
            df_meso = diversity_df1.loc[diversity_df1['mesocosm'] == mesocosm,:]
            in_sample = df_meso['inoculumn_sample'].unique()[0]
            #print(type_meso, in_sample)
            if in_sample in df_info.index.values:
                df_meso.loc[in_sample,:] = df_info.loc[in_sample,:]
           # df_meso = pd.concat([df_meso, diversity_df1.loc[diversity_df1['sample'] == in_sample,:]])
            df_meso = df_meso.sort_values(by = 'passage')
          #  p.line(df_meso['passage'].values,
           #        df_meso[minor_strain].values, legend_label)

                #print(np.max(df_meso['passage'].values))
               # print(len(df_meso))
                
            p2.line(df_meso['passage'].values,
                   df_meso['species_abundance'].values,color=color)
                

              
    p2.yaxis.axis_label = 'Specices Abundance'
    p2.xaxis.axis_label = 'Passage'
    inoculumn_stuff = '-'.join(type_meso.split('-')[:-1])
    p2.title.text = f'{real_species} {minor_strain_subject} in {inoculumn_stuff}'
    p2.y_range = bokeh.models.Range1d(-.005,1.005)
    p2.x_range = bokeh.models.Range1d(-.5,7.5)

      #  plots.append(p2)

            

  #  if separate_plots_per_mesocosm:
    return p2

# %%
df_alive = pd.read_csv('dead.csv').drop(columns = 'Unnamed: 0')
plots_all = []
plots_all = []
for species in df_alive['species_id'].unique():
    df_sp = df_alive.loc[df_alive['species_id'] == species,:]
    #species_names = glob.glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snps/*')
#species = '102320'
    fnames = glob(f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2/{species}/*_parent_freqs.csv')
    print(species)
  #  real_species = df_metadata.loc[str(species),'species']
  # species = fname.split('/')[-1].split('_shifts.csv')[0]
    df_abundance_sp = df_abundance_melted.loc[df_abundance_melted['species_id'] == int(species),:].set_index('sample')


    
    for info_fname in np.sort(fnames): 
        df = pd.read_csv(info_fname).rename(columns = {'Unnamed: 0': 'sample'})
        df['species_id'] = species
        df['species_abundance']= df['sample'].transform(lambda x: df_abundance_sp.loc[x, 'relative_abundance'])
        df['Lineage'] = df_abundance_sp['Lineage'].values[0]
        df['species'] = df_abundance_sp['species'].values[0]
        real_species = df_abundance_sp['species'].values[0]
        if len(df) ==0:
            continue

        medium_df = df.set_index('sample').median()
        minor_strain = medium_df.index.values[0]

        df_info = pd.concat([df.set_index('sample'), 
                             e003_metadata.loc[e003_metadata['sample'].isin(df['sample'].unique()),:].set_index('sample')],axis=1)
        df_info['inoculumn_sample'] = df_info['inoculumn'].transform(get_in)
        
       # print(df_info['inoculumn'])
        if df_info['inoculumn'].unique()[0] in df_sp['inoculumn'].values:
            
            minor_strain_subject =  e003_metadata.loc[e003_metadata['sample'] == minor_strain,'parent_subjects'].values[0].split('-')[0]
            print(minor_strain_subject)
            df_ingood = df_info.loc[~df_info['is_inoculumn'],:]
            df_ingood = df_ingood.loc[df_ingood['type_meso'].isin(df_sp['type_meso'].unique()),:]
            df_ingood = pd.concat([df_ingood, df_info.loc[df_info['is_inoculumn'],:]])
          #  df_info_good = df_info.loc[df_info['type_meso'].isin(df_sp['type_meso'].unique()),:]
         #   df_info_good = pd.concat([df_info_good, df_info.loc[df_info['is_inoculumn'],:]])
            p1 = plot_species_abundance(df_ingood, real_species = real_species)
            p2 = analyze_diversity(df_ingood, minor_strain, 
                                   e003_metadata.loc[e003_metadata['sample'] == minor_strain,'parent_subjects'].values[0].split('-')[0],
                                  
                                   real_species = real_species )
            p2.legend.visible = False
            p1.legend.visible = False
            bokeh.io.show(bokeh.layouts.gridplot([p1,p2],ncols = 1))
            plots_all.append(bokeh.layouts.gridplot([p1,p2],ncols = 1))
if len(plots_all)>0:
    bokeh.io.export_png(bokeh.layouts.gridplot(plots_all,ncols=2),filename=f'dead_plots.png')
# Out:
# 100013
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 12
#       9   print(species)
#      10 #  real_species = df_metadata.loc[str(species),'species']
#      11 # species = fname.split('/')[-1].split('_shifts.csv')[0]
# ---> 12   df_abundance_sp = df_abundance_melted.loc[df_abundance_melted['species_id'] == int(species),:].set_index('sample')
#      16   for info_fname in np.sort(fnames):
#      17       df = pd.read_csv(info_fname).rename(columns = {'Unnamed: 0': 'sample'})
#
# NameError: name 'df_abundance_melted' is not defined

# %%
species = '102528'
fnames = glob(f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snps/{species}/*_parent_freqs.csv')
plots_all = []
for info_fname in np.sort(fnames): 
    print(info_fname)
   # fname = f'~/git/coalescence-pilot-mgx/workflow/report/track_snps/{species}/AA-AE-mGAM_parent_freqs.csv'
    df = pd.read_csv(info_fname).rename(columns = {'Unnamed: 0': 'sample'})

    medium_df = df.set_index('sample').median()
    if len(medium_df) < 1:
        continue
    minor_strain = medium_df.index.values[0]
   # strains = df.columns.values[1:]
  #  subjects = [e003_metadata.loc[e003_metadata['sample'] == strain,'parent_subjects'].values[0].split('-')[0] for strain in strains]
   # print(subjects)
    
    df_info = pd.concat([df.set_index('sample'), e003_metadata.loc[e003_metadata['sample'].isin(df['sample'].unique()),:].set_index('sample')],axis=1)
    df_info['inoculumn_sample'] = df_info['inoculumn'].transform(get_in)
    #print(minor_strain)
    minor_strain_subject =  e003_metadata.loc[e003_metadata['sample'] == minor_strain,'parent_subjects'].values[0].split('-')[0]
   # print(minor_strain_subject)
    p2 = analyze_diversity(df_info, minor_strain, 
                           e003_metadata.loc[e003_metadata['sample'] == minor_strain,'parent_subjects'].values[0].split('-')[0])
    bokeh.io.show(p2)
    plots_all.append(p2)
bokeh.io.export_png(bokeh.layouts.gridplot(plots_all,ncols=2),filename=f'{species}_minor_strain_abundance.png')

# %%
species = '101346'
fnames = glob(f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snps/{species}/*_parent_freqs.csv')
plots_all = []
for info_fname in np.sort(fnames): 
    print(info_fname)
   # fname = f'~/git/coalescence-pilot-mgx/workflow/report/track_snps/{species}/AA-AE-mGAM_parent_freqs.csv'
    df = pd.read_csv(info_fname).rename(columns = {'Unnamed: 0': 'sample'})

    medium_df = df.set_index('sample').median()
    if len(medium_df) < 1:
        continue
    minor_strain = medium_df.index.values[0]
   # strains = df.columns.values[1:]
  #  subjects = [e003_metadata.loc[e003_metadata['sample'] == strain,'parent_subjects'].values[0].split('-')[0] for strain in strains]
   # print(subjects)
    
    df_info = pd.concat([df.set_index('sample'), e003_metadata.loc[e003_metadata['sample'].isin(df['sample'].unique()),:].set_index('sample')],axis=1)
    df_info['inoculumn_sample'] = df_info['inoculumn'].transform(get_in)
    #print(minor_strain)
    minor_strain_subject =  e003_metadata.loc[e003_metadata['sample'] == minor_strain,'parent_subjects'].values[0].split('-')[0]
   # print(minor_strain_subject)
    p2 = analyze_diversity(df_info, minor_strain, 
                           e003_metadata.loc[e003_metadata['sample'] == minor_strain,'parent_subjects'].values[0].split('-')[0])
    bokeh.io.show(p2)
    plots_all.append(p2)
bokeh.io.export_png(bokeh.layouts.gridplot(plots_all,ncols=2),filename=f'{species}_minor_strain_abundance.png')
