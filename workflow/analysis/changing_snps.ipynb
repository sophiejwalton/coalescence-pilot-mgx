# %%
import pandas as pd
import numpy as np
import iqplot
import glob


from plot_tools import *
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9dc63a3e-1d47-47c6-8e40-178cf2b3c4c4'>
#   <div id="b128b228-d856-4949-a471-ec8deebdb7af" data-root-id="9dc63a3e-1d47-47c6-8e40-178cf2b3c4c4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
e003_metadata['AC']=e003_metadata['parent_subjects'].transform(lambda x: 'AC' in x)
e003_metadata= e003_metadata.loc[~e003_metadata['AC'],:]
e003_metadata.loc['A2-e003Coalescence-Inoculumn-mBHI',:]
e003_metadatap7 = e003_metadata.loc[e003_metadata['passage']==7,:]
e003_metadatap7.loc[e003_metadata['type_mesocosm']=='AA-AA-mGAM-mGAM',:]
e003_metadatap7_columns_dic = {}
for sample in e003_metadatap7.index.values:
    e003_metadatap7_columns_dic[sample]=e003_metadatap7.loc[sample,'mesocosm']

# %%
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
e003_metadata['AC']=e003_metadata['parent_subjects'].transform(lambda x: 'AC' in x)
e003_metadata= e003_metadata.loc[~e003_metadata['AC'],:]
e003_metadatap0 = e003_metadata.loc[e003_metadata['passage']==0,:]
e003_metadatap0=e003_metadatap0.loc[e003_metadatap0['parent_subjects'].isin(['AA-AA',
                                                                             'AE-AE',
                                                                             'AF-AF']),:]
e003_metadata=e003_metadata.loc[e003_metadata['inoculumn'].isin(['AA-AE-mBHI','AE-AA-mBHI']),:]
e003_metadatap7 = e003_metadata.loc[e003_metadata['passage']==7,:]
e003_metadatap7
samples = ['A4-e003Coalescence-mBHI-p7',
           'C2-e003Coalescence-mGAM-p7',
           'C2-e003Coalescence-mBHI-p7',]
e003_metadatap7
# Out:
#                                 comm comm-media   inoculumn  \
# sample
# A4-e003Coalescence-mBHI-p7        A4    A4-mBHI  AA-AE-mBHI
# C2-e003Coalescence-mGAM-p7        C2    C2-mGAM  AA-AE-mBHI
# C2-e003Coalescence-mBHI-p7        C2    C2-mBHI  AA-AE-mBHI
# G2-e003Coalescence-mBHI-p7_S121   G2    G2-mBHI  AA-AE-mBHI
# E4-e003Coalescence-mGAM-p7_S147   E4    E4-mGAM  AA-AE-mBHI
# E4-e003Coalescence-mBHI-p7_S99    E4    E4-mBHI  AA-AE-mBHI
#
#                                                        inoculumn_sample  \
# sample
# A4-e003Coalescence-mBHI-p7       A4-e003Coalescence-mBHI-inoculumn-redo
# C2-e003Coalescence-mGAM-p7       C2-e003Coalescence-mBHI-inoculumn-redo
# C2-e003Coalescence-mBHI-p7       C2-e003Coalescence-mBHI-inoculumn-redo
# G2-e003Coalescence-mBHI-p7_S121  C2-e003Coalescence-mBHI-inoculumn-redo
# E4-e003Coalescence-mGAM-p7_S147  A4-e003Coalescence-mBHI-inoculumn-redo
# E4-e003Coalescence-mBHI-p7_S99   A4-e003Coalescence-mBHI-inoculumn-redo
#
# ...

# %%
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
e003_metadatap0 = e003_metadata.loc[e003_metadata['passage']==0,:]
e003_metadata
# Out:
#                                             comm comm-media      inoculumn  \
# sample
# A_A1_A2_AA_AA_mBHI_mBHI_2_S1                  A2    A2-mBHI     AA-AA-mBHI
# A_A2_A3_ACPP_AA_mBHI_mBHI_2_S2                A3    A3-mBHI  AA-AC/PP-mBHI
# A_A3_A4_AE_AA_mBHI_mBHI_2_S3                  A4    A4-mBHI     AA-AE-mBHI
# A_A4_A5_AF_AA_mBHI_mBHI_2_S4                  A5    A5-mBHI     AA-AF-mBHI
# A_A5_A8_AA_AA_mGAM_mBHI_2_S5                  A8    A8-mBHI     AA-AA-mGAM
# ...                                          ...        ...            ...
# Coalescence-F3-E11-AA-AF-mGAM-mGAM-3_S682    E11   E11-mGAM     AA-AF-mGAM
# Coalescence-B7-E3-AA-ACPP-mBHI-mBHI-7_S638    E3    E3-mBHI  AA-AC/PP-mBHI
# Coalescence-C5-A3-AA-ACPP-mBHI-mGAM-5_S648    A3    A3-mGAM  AA-AC/PP-mBHI
# Coalescence-F9-C8-AA-AE-mGAM-mGAM-3_S688      C8    C8-mGAM     AA-AE-mGAM
# Coalescence-E11-D3-ACPP-AF-mBHI-mBHI-3_S678   D3    D3-mBHI  AC/PP-AF-mBHI
#
# ...

# %%
e003_metadatap0 = e003_metadata.loc[e003_metadata['passage']==0,:].reset_index()
e003_metadatap0['read1_file']= e003_metadatap0['sample'].transform(lambda x: f'workflow/out/concat/{x}-filtered.1.fastq.gz')
e003_metadatap0['read2_file']= e003_metadatap0['sample'].transform(lambda x: f'workflow/out/concat/{x}-filtered.2.fastq.gz')
e003_metadatap0['read1_file'] = '/oak/stanford/groups/dpetrov/swalton/coalescence-pilot-mgx/' + e003_metadatap0['read1_file']
e003_metadatap0['read2_file'] = '/oak/stanford/groups/dpetrov/swalton/coalescence-pilot-mgx/' + e003_metadatap0['read2_file']
e003_metadatap0['sample_name']=e003_metadatap0['sample']
e003_metadatap0_info = e003_metadatap0[['sample_name','read1_file','read2_file']]
e003_metadatap0_info.to_csv('~/git/coalescence-phanta/samples_phanta.tsv',sep='\t',index=False,header=False)

# %%
#df = pd.read_csv('~/git/coalescence-pilot-mgx/workflow/report/evolution/100196/AA-AA-mGAM_freqs_changing.csv').set_index('site_id')-inter
df = pd.read_csv('~/git/coalescence-pilot-mgx/workflow/report/evolution/102438/AA-AA-mGAM_freqs_changing.csv').set_index('site_id')
df = df.rename(columns=e003_metadatap7_columns_dic)
#df[['A2-e003Coalescence-Inoculumn-mBHI','A2-e003Coalescence-mGAM-p7','E2-e003Coalescence-mGAM-p7_S145']]
dfnan = df.isna()
good = dfnan.sum(axis=1)
good = good[good<len(df.columns.values)*.2]
good
df = df.loc[good.index.values,:]
df#[['A2-e003Coalescence-mGAM-p7','E2-e003Coalescence-mGAM-p7_S145']]
# Out:
#                                    A2-e003Coalescence-Inoculumn-mGAM  \
# site_id
# gnl|Prokka|UHGG143131_1|1092782|C                              1.000
# gnl|Prokka|UHGG143131_1|1204080|C                              1.000
# gnl|Prokka|UHGG143131_1|1204081|G                              1.000
# gnl|Prokka|UHGG143131_1|1843567|C                              1.000
# gnl|Prokka|UHGG143131_1|1843568|G                              1.000
# gnl|Prokka|UHGG143131_1|211021|T                               1.000
# gnl|Prokka|UHGG143131_1|211022|C                               1.000
# gnl|Prokka|UHGG143131_1|2156201|C                              1.000
# gnl|Prokka|UHGG143131_1|2229820|G                              1.000
# gnl|Prokka|UHGG143131_1|2270636|T                              0.881
# gnl|Prokka|UHGG143131_1|2270637|C                              0.898
# gnl|Prokka|UHGG143131_1|2270639|T                              0.906
# ...

# %%
len(df.columns.values)
# Out:
# 20

# %%
e003_metadata.loc[df.columns.values,:].groupby(['type_mesocosm']).sum(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 e003_metadata.loc[df.columns.values,:].groupby(['type_mesocosm']).sum(numeric_only=True)
#
# File ~/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/pandas/core/indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...
