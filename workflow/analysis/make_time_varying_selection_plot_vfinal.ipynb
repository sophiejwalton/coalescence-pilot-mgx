# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control
#from bokeh.models import FixedTicker, FuncTickFormatter 
from scipy.stats import chi2

#from bokeh.io import output_notebook

from snp_analysis_tools_sherlock import *
from plot_tools import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='502d11e8-cb1d-48b2-a09b-3c9d6e2e942f'>
#   <div id="a635b687-e4bc-41ee-8682-36a9f9352120" data-root-id="502d11e8-cb1d-48b2-a09b-3c9d6e2e942f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9c25013c-89e9-4327-a7ef-52a1a2464e70":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"502d11e8-cb1d-48b2-a09b-3c9d6e2e942f"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6ba37bc9-b7c9-470a-ac31-659fc8d2bfde","attributes":{"plot_id":"502d11e8-cb1d-48b2-a09b-3c9d6e2e942f","comm_id":"9a1fbc90b8f049c3a9c6352d1f268aef","client_comm_id":"3b7c65be5cb94c23b2b639461d8e4ed9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"9c25013c-89e9-4327-a7ef-52a1a2464e70","roots":{"502d11e8-cb1d-48b2-a09b-3c9d6e2e942f":"a635b687-e4bc-41ee-8682-36a9f9352120"},"root_ids":["502d11e8-cb1d-48b2-a09b-3c9d6e2e942f"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_metadata  =transform_df(df_metadata)
df_metadata.loc[df_metadata['species_id']==101349,:]
# Out:
#       species_id    representative MGnify_accession  species_closest  \
# 1348      101349  GUT_GENOME096096  MGYG-HGUT-01349         102640.0
#
#       ani_closest  gtpro_kmer_counts  phyeco_marker_counts  phyeco_pass_ratio  \
# 1348      94.0625            55924.0                  15.0                1.0
#
#       pangene_counts  genome_counts  ...     N50  GC_content  Completeness  \
# 1348          100370            789  ...  257597       38.67         100.0
#
#       Contamination                                            Lineage  \
# 1348            0.0  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o...
#
#       Continent                   species           genus              family  \
# 1348        NaN  s__Veillonella parvula_A  g__Veillonella  f__Veillonellaceae
#
#                 phyla
# 1348  p__Firmicutes_C
#
# [1 rows x 23 columns]

# %%
def get_pred_sel(ts,sel_coeff, start_value,):
    pred=np.exp(ts*sel_coeff)
    pred = pred*start_value/(1 - start_value + start_value*pred)
    return pred

# %%
def get_preds_for_plottingv2(sp,ino,type_meso, t0,t1):

    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
#    print(fname1)
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    freq1 = pd.read_csv(fname1)
    df_both = pd.read_csv(fname1).set_index('sample')
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
 
    df_both=df_both.loc[df_both['shifts_med']<.1,:]
  #  print(len(df_both),'oo')
    

    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()


   # print('bef',np.max(df_both_meta_good['actual_med1']- df_both_meta_good['boot_med1']))
    df_both_meta_good.loc[df_both_meta_good['boot_med']<1e-3,'boot_med']=1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med']>1-1e-3,'boot_med']=1-1e-3
   # df_both_meta_good.loc[df_both_meta_good['boot_med2']<1e-3,'boot_med2']=1e-3
    #df_both_meta_good.loc[df_both_meta_good['boot_med1']>1-1e-3,'boot_med1']=1-1e-3
    
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med']#/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med']#/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])
   # print(df_both_meta_good['boot_med1'])
    df_both_meta_good.loc[df_both_meta_good['boot_med1']<1e-3,'boot_med1']=1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med1']>1-1e-3,'boot_med1']=1-1e-3

    sel_stuff['type_mesocosm']=sel_stuff['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:]))
    sel_stuff['species']=sp
    sel_stuff['inoculumn']=ino
    sel_stuff = sel_stuff.loc[sel_stuff['type_mesocosm']==type_meso,:]
    
    sel_stuff['start_val']=np.nan
    sel_stuff['t1_val']=np.nan
    
    if len(sel_stuff)==0:
        print(type_meso, 'bad',len(sel_stuff))
        return [],[],[],[]
    good_mesos = []
    for meso in sel_stuff['mesocosm'].unique():
    
        sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'late_sel_med']
        start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1']
        if len(start_val)>0:
            sel_stuff.loc[sel_stuff['mesocosm']==meso,'start_val'] = start_val.values[0]
        passages = list(df_both_meta_good.loc[df_both_meta_good['mesocosm']==meso,'passage'].values)
        if len(np.intersect1d([1,2,6,7],passages))==4:
            good_mesos.append(meso)
    ts=np.arange(9)
    #print(start_values)
    sel_stuff=sel_stuff.loc[~sel_stuff['start_val'].isna(),:]
    sel_stuff = sel_stuff.loc[sel_stuff['mesocosm'].isin(good_mesos),:]
    if len(sel_stuff)==0:
        print(type_meso, 'bad',len(sel_stuff))
        return [],[],[],[]
    sel_stuff_med = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).median(numeric_only=True)
    
   #print(sel_stuff_med)
    pred_values = get_pred_sel(ts-t1,sel_stuff_med['early_sel_med'].values[0], sel_stuff_med['start_val'].values[0])
    pred_values_logit = np.log(pred_values/(1-pred_values))
    sel_coeffs = sel_stuff['early_sel_med'].values
  #  print(len(sel_stuff))
    start_values = sel_stuff['start_val'].values
   # print('starts',start_values)
   # print(sel_coeffs)
    pred_values_t7=get_pred_sel(7-t1,sel_coeffs, start_values,)
    argmax_7 =np.argmax(pred_values_t7) 
    argmin_7 =np.argmin(pred_values_t7) 

    ts=np.arange(9)
    pred_valuesmax = get_pred_sel(ts-t1,sel_coeffs[argmax_7], start_values[argmax_7],)
    pred_values_logitmax = np.log(pred_valuesmax/(1-pred_valuesmax))

    pred_valuesmin = get_pred_sel(ts-t1,sel_coeffs[argmin_7], start_values[argmin_7],)
    pred_values_logitmin = np.log(pred_valuesmin/(1-pred_valuesmin))
  #  print('potatoes',sel_stuff_meso.loc[(sel_stuff_meso['passage1']==t0)*(sel_stuff_meso['passage2']==t1),'start_value1'].values)
    
        
    return ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax

# %%
import os
inos=['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]

#inos = ['AA-AF-mGAM']
1#inos = ['AE-AF-mBHI']
species = [102438,100196, 100099, 100146, 101346, 102506, 102478]
species = [102438,100196, 100099, 100146, 101346, 102506, 102478,102358,101294]
species = [102438]
species = ['100146', '101059', '100910', '102478', '102438', '100196',
       '103117', '103656', '102544', '102506', '101346', '100099',
       '101400', '101294']

species
t0=1
t1=2
inos = ['AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI','AE-AF-mGAM',]
#inos = ['AE-AF-mBHI',]
#species = [102438]
name_dic = {'100099':'Flavonifractor plautii',
            '100146':'Dorea formicigenerans',
            '100196': 'Bacteroides thetaiotaomicron',
            '101294': 'Parasutterella excrementihominis',
            '101346': 'Bacteroides uniformis',
            '102438': 'Parabacteroides distasonis',
            '102478': 'Bacteroides dorei',
            '102506': 'Escherichia coli',
            '103656': 'Acutalibacteraceae sp'}
#polgood = pol.loc[~pol['max_early_sel_med'].isna(),:]
allcomps=0

           
for sp in [100099, 102478,102438]:
    plots_all=[]
    for ino in inos:
        print(ino)
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
        if f'{sp}-{ino}' in bad_inos:
            continue
        if not os.path.isfile(fname):
            print('oo')
            continue
        psstrain,type_mesos = make_logit_plot(sp, ino,strain1=True,
                                       colorby='const',logit=True,
                                        )
      #  print(psstrain)
        print('yay',type_mesos)
        for i in range(len(psstrain)):
        #    if f'{sp}-{type_mesos[i]}' not in df_ttest['sp_mesos'].values:
         #       continue
        #    print('yay',f'{sp}-{type_mesos[i]}',df_ttest.loc[df_ttest['sp_mesos']==f'{sp}-{type_mesos[i]}','qvals'])
            allcomps=allcomps+1
            p1 = psstrain[i]
            meso = type_mesos[i]
            
            med1=meso.split('-')[-2]
            med2 = meso.split('-')[-1]
            ino1 = f'{sp}-{med1}-{med2}'
            p1.legend.visible=False
            ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax = get_preds_for_plottingv2(sp,ino,meso, t0,t1)
            print('mes',meso, 'ino',ino,t0,t1)
            if len(pred_values_logit)>0:
                print('good',meso)
                p1.line(ts,pred_values_logit,color='grey')
                p1.line(ts,pred_values_logitmin,color='grey',line_dash='dashed')
                p1.line(ts,pred_values_logitmax,color='grey',line_dash='dashed')
            p1.yaxis.axis_label_text_font_style = 'normal'
            p1.xaxis.axis_label_text_font_style = 'normal'
            p1.width=500
            p1.height=250
            p1.xaxis.axis_label_text_font_size='22px'
            p1.yaxis.axis_label_text_font_size='22px'
            p1.xaxis.major_label_text_font_size='15px'
            p1.yaxis.major_label_text_font_size='15px'
                #p1.ray(y=np.log(99e-2/(1-99e-2)),x=0)
              # p1.ray(y=np.log(1e-2/(1-1e-2)),x=0)
            bokeh.io.show(p1)
            p1.output_backend='svg'
          #  p1.title.text = name_dic[str(sp)]
           # p1.title.text_font_style='italic'
           # p1.title.text_font_size='22px'
            export_plot_pdf(p1,f'plots_time_varying/time_varying_plotv2_{sp}_{ino}-{med2}-{t0}_{t1}')
# Out:
# AA-AF-mGAM
# yay ['AA-AF-mGAM-mBHI', 'AA-AF-mGAM-mGAM']
# mes AA-AF-mGAM-mBHI ino AA-AF-mGAM 1 2
# good AA-AF-mGAM-mBHI
#   <div id="e07da246-afd3-477c-aa5b-4d4f4e792b08" data-root-id="45c43859-a3a8-497d-b7dd-3cf9dc93a9e3" style="display: contents;"></div>
# mes AA-AF-mGAM-mGAM ino AA-AF-mGAM 1 2
# good AA-AF-mGAM-mGAM
#   <div id="c711ae01-cd4a-4120-8db6-5b4d1fedb5f1" data-root-id="95768217-a241-49fa-81a3-4aafce553772" style="display: contents;"></div>
# AA-AE-mGAM
# yay ['AA-AE-mGAM-mBHI', 'AA-AE-mGAM-mGAM']
# mes AA-AE-mGAM-mBHI ino AA-AE-mGAM 1 2
# good AA-AE-mGAM-mBHI
#   <div id="c453c176-c78f-4a99-8604-db5ec9dc07cf" data-root-id="e0693dd6-f64f-4a7f-9dd6-179603a39d23" style="display: contents;"></div>
# mes AA-AE-mGAM-mGAM ino AA-AE-mGAM 1 2
# good AA-AE-mGAM-mGAM
#   <div id="d1c9306d-b12d-4260-9469-1bdcf5572151" data-root-id="cf27cfc0-32f4-4301-81af-f90c8ce4b392" style="display: contents;"></div>
# AE-AF-mBHI
# yay ['AE-AF-mBHI-mBHI', 'AE-AF-mBHI-mGAM']
# mes AE-AF-mBHI-mBHI ino AE-AF-mBHI 1 2
# good AE-AF-mBHI-mBHI
#   <div id="f05fa702-5644-4a75-b8a1-51cc04dca3d7" data-root-id="4a090eb0-30e6-4264-b8a3-98fab0a883ef" style="display: contents;"></div>
# mes AE-AF-mBHI-mGAM ino AE-AF-mBHI 1 2
# good AE-AF-mBHI-mGAM
#   <div id="f4b27a8b-bc57-4c26-b367-4dcc169fa11a" data-root-id="14a9ac97-922e-4a05-b402-0cef46acf57f" style="display: contents;"></div>
# AA-AF-mBHI
# yay ['AA-AF-mBHI-mBHI', 'AA-AF-mBHI-mGAM']
# mes AA-AF-mBHI-mBHI ino AA-AF-mBHI 1 2
# good AA-AF-mBHI-mBHI
#   <div id="d48a61a5-ef35-4815-9fe9-f7a0239a6bd2" data-root-id="8e476730-3788-4902-9b51-03e1381f37f5" style="display: contents;"></div>
# mes AA-AF-mBHI-mGAM ino AA-AF-mBHI 1 2
# good AA-AF-mBHI-mGAM
#   <div id="f63bcf61-0dee-4157-a0b5-56e6494e5a21" data-root-id="ba1c857d-d120-441f-8280-94d0ea1e3923" style="display: contents;"></div>
# AA-AE-mBHI
# yay ['AA-AE-mBHI-mBHI', 'AA-AE-mBHI-mGAM']
# mes AA-AE-mBHI-mBHI ino AA-AE-mBHI 1 2
# good AA-AE-mBHI-mBHI
#   <div id="b966a7b4-4d35-4d2b-9cdb-0e3a468d8336" data-root-id="b62c6273-0f78-4b81-9723-889ad3035bb2" style="display: contents;"></div>
# mes AA-AE-mBHI-mGAM ino AA-AE-mBHI 1 2
# good AA-AE-mBHI-mGAM
#   <div id="c5338027-0551-4099-9c59-e3b7d9e906ce" data-root-id="e517ebc0-4513-49b4-b562-146ca105622d" style="display: contents;"></div>
# AE-AF-mGAM
# yay ['AE-AF-mGAM-mBHI', 'AE-AF-mGAM-mGAM']
# mes AE-AF-mGAM-mBHI ino AE-AF-mGAM 1 2
# good AE-AF-mGAM-mBHI
#   <div id="f6de3ce1-55e8-4234-91de-770aa746f917" data-root-id="cbc1125a-5bc6-4018-a753-618a25b87ac7" style="display: contents;"></div>
# mes AE-AF-mGAM-mGAM ino AE-AF-mGAM 1 2
# good AE-AF-mGAM-mGAM
#   <div id="edb508cf-7f50-4ba1-b474-4c93f32daa07" data-root-id="9b45d9f6-3766-4277-8648-621f192664ff" style="display: contents;"></div>
# AA-AF-mGAM
# yay ['AA-AF-mGAM-mBHI', 'AA-AF-mGAM-mGAM']
# AA-AF-mGAM-mBHI bad 0
# mes AA-AF-mGAM-mBHI ino AA-AF-mGAM 1 2
#   <div id="add4a9c6-9a2a-4377-81f0-d370ee5b17ec" data-root-id="0a7358c6-01b8-419d-847a-ca73aa9738c6" style="display: contents;"></div>
# mes AA-AF-mGAM-mGAM ino AA-AF-mGAM 1 2
# good AA-AF-mGAM-mGAM
#   <div id="d3778a15-d8d5-4f34-ba4d-435e6395737f" data-root-id="149f0360-1beb-47e8-9ff3-8323ac9ee188" style="display: contents;"></div>
# AA-AE-mGAM
# oo
# AE-AF-mBHI
# AA-AF-mBHI
# AA-AE-mBHI
# oo
# AE-AF-mGAM
# oo
# AA-AF-mGAM
# yay ['AA-AF-mGAM-mBHI', 'AA-AF-mGAM-mGAM']
# mes AA-AF-mGAM-mBHI ino AA-AF-mGAM 1 2
# good AA-AF-mGAM-mBHI
#   <div id="cff42e7e-9d2d-43f6-a85f-e0eec7ccf48b" data-root-id="fb2ca5fb-35e7-403e-bb48-595ce79ce88e" style="display: contents;"></div>
# mes AA-AF-mGAM-mGAM ino AA-AF-mGAM 1 2
# good AA-AF-mGAM-mGAM
#   <div id="f0a55712-d2bc-40fc-8c3e-6ae7897a423e" data-root-id="5f1a013d-5124-4818-b878-74771528e361" style="display: contents;"></div>
# AA-AE-mGAM
# yay ['AA-AE-mGAM-mBHI', 'AA-AE-mGAM-mGAM']
# mes AA-AE-mGAM-mBHI ino AA-AE-mGAM 1 2
# good AA-AE-mGAM-mBHI
#   <div id="e835faa9-a9f7-4dff-b252-5d5c19dce749" data-root-id="ebeb52c8-9333-482f-96ab-39b3d6a1eef0" style="display: contents;"></div>
# mes AA-AE-mGAM-mGAM ino AA-AE-mGAM 1 2
# good AA-AE-mGAM-mGAM
#   <div id="c8a10f3f-725f-477b-bd33-59cb2efcc6f5" data-root-id="d9626594-bc13-46a7-a3be-f1f0d1afafc9" style="display: contents;"></div>
# AE-AF-mBHI
# yay ['AE-AF-mBHI-mBHI', 'AE-AF-mBHI-mGAM']
# mes AE-AF-mBHI-mBHI ino AE-AF-mBHI 1 2
# good AE-AF-mBHI-mBHI
#   <div id="c602638f-9067-4c42-a15e-4c7136eba6ab" data-root-id="495aa9dd-441b-4d0e-9673-b8e9b401f3ca" style="display: contents;"></div>
# mes AE-AF-mBHI-mGAM ino AE-AF-mBHI 1 2
# good AE-AF-mBHI-mGAM
#   <div id="dbd4da4c-3a42-4186-bad2-cf2a795421f6" data-root-id="5ed6d32c-33ac-4d0e-b61b-a317026de611" style="display: contents;"></div>
# AA-AF-mBHI
# yay ['AA-AF-mBHI-mBHI', 'AA-AF-mBHI-mGAM']
# mes AA-AF-mBHI-mBHI ino AA-AF-mBHI 1 2
# good AA-AF-mBHI-mBHI
#   <div id="b338de77-a21a-4cd7-b0ae-953c0ed9508b" data-root-id="116025ab-fde7-48bb-a4ca-4faef0b4de8a" style="display: contents;"></div>
# mes AA-AF-mBHI-mGAM ino AA-AF-mBHI 1 2
# good AA-AF-mBHI-mGAM
#   <div id="f498f7bb-a543-472e-ad4d-06f3c0d7551a" data-root-id="7e02f856-4fd9-49e4-be85-776b4c8ab0c2" style="display: contents;"></div>
# AA-AE-mBHI
# yay ['AA-AE-mBHI-mBHI', 'AA-AE-mBHI-mGAM']
# AA-AE-mBHI-mBHI bad 0
# mes AA-AE-mBHI-mBHI ino AA-AE-mBHI 1 2
#   <div id="def1c8d7-b6f1-44e7-a165-0805b4c67f9a" data-root-id="bf3450df-2343-4a1e-84bf-b83a2802aa53" style="display: contents;"></div>
# mes AA-AE-mBHI-mGAM ino AA-AE-mBHI 1 2
# good AA-AE-mBHI-mGAM
#   <div id="bd6fefec-8947-41ab-aece-c18acb471a5d" data-root-id="6f513581-a73f-4d32-8ab9-3605ff2ebcc2" style="display: contents;"></div>
# AE-AF-mGAM
# yay ['AE-AF-mGAM-mBHI', 'AE-AF-mGAM-mGAM']
# mes AE-AF-mGAM-mBHI ino AE-AF-mGAM 1 2
# good AE-AF-mGAM-mBHI
#   <div id="db52d7d7-12a6-44a0-9d4a-8ab7f16cf49c" data-root-id="8a035570-77ea-473e-a8a7-27271a360ee9" style="display: contents;"></div>
# mes AE-AF-mGAM-mGAM ino AE-AF-mGAM 1 2
# good AE-AF-mGAM-mGAM
#   <div id="d00ec7e8-59e2-48b0-94af-c2d0e15bb2b1" data-root-id="68192cd6-ed05-4691-b318-2fcc85f825d0" style="display: contents;"></div>

# %%
def get_selection_stuff_time_vary(species,inoculumn,t0,t1,thresh=1e-3):
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
 #   print(fname1)
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    freq1 = pd.read_csv(fname1)
    df_both = pd.read_csv(fname1).set_index('sample')
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['shifts_med']<.1,:]
    

    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()


   # print('bef',np.max(df_both_meta_good['actual_med1']- df_both_meta_good['boot_med1']))
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med']#/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med']#/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])
    sel_stuff['type_mesocosm']=sel_stuff['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:]))
    sel_stuff['species']=species
    sel_stuff['inoculumn']=inoculumn
   # sel_stuff = sel_stuff.loc[sel_stuff['type_mesocosm']==type_meso,:]
    sel_stuff['start_val']=np.nan
    sel_stuff['t1_val']=np.nan
    
    if len(sel_stuff)==0:
        return [],[]
    good_mesos = []
    for meso in sel_stuff['mesocosm'].unique():
    
        sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'early_sel_med']
        start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1']
        if len(start_val)>0:
            sel_stuff.loc[sel_stuff['mesocosm']==meso,'start_val'] = start_val.values[0]
        passages = list(df_both_meta_good.loc[df_both_meta_good['mesocosm']==meso,'passage'].values)
        if len(np.intersect1d([1,2,6,7],passages))==4:
            good_mesos.append(meso)
    ts=np.arange(9)
    
    #print(start_values)
    sel_stuff=sel_stuff.loc[~sel_stuff['start_val'].isna(),:]
    sel_stuff = sel_stuff.loc[sel_stuff['mesocosm'].isin(good_mesos),:]
    sel_stuff.loc[sel_stuff['start_val']<=1e-3,'late_sel_med']=sel_stuff.loc[sel_stuff['start_val']<=1e-3,'early_sel_med']
    sel_stuff.loc[sel_stuff['start_val']>=1-1e-3,'late_sel_med']=sel_stuff.loc[sel_stuff['start_val']>=1-1e-3,'early_sel_med']
    if len(sel_stuff)==0:
        return [],[]
    sel_stuff_meso_meds = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).median(numeric_only=True)
    sel_stuff_meso_maxs= sel_stuff.groupby(['type_mesocosm','species','inoculumn']).max(numeric_only=True)
    
    sel_stuff_meso_mins = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).min(numeric_only=True)
   # print(species, sel_stuff_meso_meds.columns.values)
    for column in ['early_sel_med','act_7_med','pred7_med','late_sel_med']:
        sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'max_{column}']=sel_stuff_meso_maxs.loc[sel_stuff_meso_meds.index.values,column]
        sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'min_{column}']=sel_stuff_meso_mins.loc[sel_stuff_meso_meds.index.values,column]
    return sel_stuff_meso_meds,sel_stuff

# %%
def get_pred_sel(ts,sel_coeff, start_value,):
    pred=np.exp(ts*sel_coeff)
  #  print(pred)
    pred = pred*start_value/(1 - start_value + start_value*pred)
    
    return pred

# %%
def get_selection_stuff_time_vary_all_times(species,inoculumn,t0,t1,thresh=1e-3):
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
   # fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
 #   print(fname1)
   # fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parentboth_info.csv'
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    df_both = pd.read_csv(fname1).set_index('sample')
    #df_both = get_both_dfs(fname1)
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['shifts_med']<.1,:]


    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med']#/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med']#/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])
    
    sel_stuff['type_mesocosm']=sel_stuff['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:]))
 
    sel_stuff['species']=species
    sel_stuff['inoculumn']=inoculumn
   # sel_stuff = sel_stuff.loc[sel_stuff['type_mesocosm']==type_meso,:]
    sel_stuff['start_val']=np.nan
    sel_stuff['t1_val']=np.nan
    df_both_meta_good['pred_val_sel_12']=np.nan
    df_both_meta_good['sel_12']=np.nan
    
    if len(sel_stuff)==0:
        return [],[]
    big_dfs = []
    for sample in df_both_meta_good['sample'].unique():
        meso = df_both_meta_good.loc[df_both_meta_good['sample']==sample,'mesocosm'].values[0]
        passage = df_both_meta_good.loc[df_both_meta_good['sample']==sample,'passage'].values[0]
     #   print(sel_stuff['mesocosm'])
      #  print(meso)
        sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'early_sel_med']
        if len(sel_coeff)>0:
            sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'early_sel_med'].values[0]
        start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1']
        
        if len(start_val)>0:
            start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1'].values[0]
        t = passage-t1
        
        
        pred = get_pred_sel(t,sel_coeff, start_val)
       # print('passage',start_val)
      #  print('pred',pred)
    #    print(pred,sel_coeff,start_val,passage, t)
       # print('pred',pred)
        df_both_meta_good.loc[df_both_meta_good['sample']==sample,'pred_val_sel_12']=pred
        df_both_meta_good.loc[df_both_meta_good['sample']==sample,'sel_12']=sel_coeff
    ts=np.arange(9)
    
    return sel_stuff,df_both_meta_good

# %%
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
len(np.unique(species_list))
# Out:
# 137

# %%
all_dfs=[]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
t0 = 1
t1 = 2
big_dfs = []


for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
        if f'{sp}-{ino}' in bad_inos:
            continue 
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
        if os.path.exists(fname):
          #  print(fname)
        fname2=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
            if not os.path.exists(fname2):
                continue
           # df,_= get_selection_stuff_time_vary(sp,ino,t0,t1,thresh=1e-3)
            df,df2=get_selection_stuff_time_vary_all_times(sp,ino,t0,t1,thresh=1e-3)
          #  df2['species_id']==sp
            
            if len(df)>0:
                df2['species_id']=sp
                big_dfs.append(df2.reset_index())
            
big_df=pd.concat(big_dfs).reset_index()
len(big_df['species_id'].unique())
big_df['species-type_meso']=big_df['species_id'].astype(str)+'-'+big_df['type_mesocosm'].astype(str)
big_df['species-mesocosm']=big_df['species_id'].astype(str)+'-'+big_df['mesocosm'].astype(str)
big_df = big_df.loc[~big_df['pred_val_sel_12'].isna(),:]
big_df_good=big_df.loc[(big_df['pred_val_sel_12']>1e-2)*(big_df['pred_val_sel_12']<1-1e-2),:]
#big_df = big_df.set_index('species-type_meso')
len(big_df['species_id'].unique())
big_df_p7 = big_df.loc[big_df['passage']==7,:]

# %%
len(big_df_p7)
# Out:
# 123

# %%
big_df_p7['sel_12_gen']=big_df_p7['sel_12']*1/np.log2(200)
def ecdf_transform(data):
    return 1- data.rank(method="first") / len(data)

big_df_p7.loc[:, "sel_12 ECDF"] = big_df_p7[
    "sel_12"
].transform(ecdf_transform)

# %%
big_df_p7['species-type_meso'].unique()
# Out:
# array(['100146-AA-AE-mGAM-mBHI', '100146-AA-AF-mGAM-mBHI',
#        '100146-AA-AF-mGAM-mGAM', '100146-AE-AF-mGAM-mBHI',
#        '101059-AA-AF-mBHI-mBHI', '101059-AA-AF-mBHI-mGAM',
#        '100910-AA-AE-mBHI-mBHI', '100910-AA-AE-mBHI-mGAM',
#        '102478-AA-AF-mGAM-mBHI', '102478-AA-AF-mGAM-mGAM',
#        '102438-AA-AE-mBHI-mGAM', '102438-AA-AF-mBHI-mBHI',
#        '102438-AA-AF-mBHI-mGAM', '102438-AE-AF-mBHI-mBHI',
#        '102438-AE-AF-mBHI-mGAM', '102438-AA-AE-mGAM-mBHI',
#        '102438-AA-AE-mGAM-mGAM', '102438-AA-AF-mGAM-mBHI',
#        '102438-AA-AF-mGAM-mGAM', '102438-AE-AF-mGAM-mGAM',
#        '102438-AE-AF-mGAM-mBHI', '100196-AA-AE-mBHI-mGAM',
#        '100196-AA-AF-mGAM-mGAM', '103656-AA-AE-mGAM-mGAM',
#        '103656-AA-AF-mGAM-mGAM', '103656-AE-AF-mGAM-mGAM',
#        '102506-AA-AF-mGAM-mBHI', '102506-AA-AF-mGAM-mGAM',
#        '101346-AA-AF-mGAM-mGAM', '100099-AA-AE-mBHI-mBHI',
#        '100099-AA-AE-mBHI-mGAM', '100099-AA-AF-mBHI-mBHI',
#        '100099-AA-AF-mBHI-mGAM', '100099-AE-AF-mBHI-mBHI',
#        '100099-AE-AF-mBHI-mGAM', '100099-AA-AE-mGAM-mBHI',
#        '100099-AA-AE-mGAM-mGAM', '100099-AA-AF-mGAM-mBHI',
#        '100099-AA-AF-mGAM-mGAM', '100099-AE-AF-mGAM-mGAM',
#        '100099-AE-AF-mGAM-mBHI', '101400-AA-AF-mBHI-mBHI',
#        '101294-AE-AF-mBHI-mGAM', '101294-AA-AE-mGAM-mGAM',
#        '101294-AA-AF-mGAM-mGAM', '101294-AE-AF-mGAM-mGAM',
#        '101294-AE-AF-mGAM-mBHI'], dtype=object)

# %%
big_df_p7_gr=big_df_p7.groupby(['species-type_meso']).median(numeric_only=True).reset_index()
big_df_p7_gr['to_pol']=big_df_p7_gr['sel_12_gen']<0 #'species-type-mesocosm'].values
to_pol = big_df_p7_gr.loc[big_df_p7_gr['to_pol'],'species-type_meso'].values
big_df_p7_gr['sel_12_gen_pol']=big_df_p7_gr['sel_12_gen'].copy()
big_df_p7_gr.loc[big_df_p7_gr['to_pol'],'sel_12_gen_pol']=-big_df_p7_gr.loc[big_df_p7_gr['to_pol'],'sel_12_gen_pol']
big_df_p7_gr=big_df_p7_gr.sort_values(by='sel_12_gen_pol', ascending=False)

p = hv.Points(big_df_p7_gr, vdims=['sel_12_gen_pol'],kdims=['species-type_meso','sel_12_gen_pol'], label='mGAM',).opts(width=350,
                                                                                                     size=5,
                                                                                                color=bokeh.palettes.Set2[3][-1],
                                                                                               line_color='black',
                                                                                                 xrotation=60)




print('w00',len(big_df_p7_gr))
big_df_p7['sel_12_gen_pol']=big_df_p7['sel_12_gen'].copy()
big_df_p7.loc[big_df_p7['species-type_meso'].isin(to_pol),'sel_12_gen_pol']=-big_df_p7.loc[big_df_p7['species-type_meso'].isin(to_pol),'sel_12_gen_pol']

p3 = hv.Points(big_df_p7, vdims=['sel_12_gen_pol'],kdims=['species-type_meso','sel_12_gen_pol'],).opts(width=450,
                                                                                                    size=5,
                                                                                    color=bokeh.palettes.Set2[3][-1],
                                                                                          alpha=.5,
                                                                                                xrotation=60)

p=hv.render(p*p3*p)
p.yaxis.axis_label='Sel Coeff'
p.xaxis.axis_label='Competition'
#p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p.ray(x=0,y=0,angle=0,color='black')
p.output_backend = "svg"
p.legend.visible=False
test_name='bloh'

bokeh.io.export_svgs(p, filename = test_name + '.svg')
export_plot_pdf(p,'sel12_stuff')
bokeh.io.show(p)
# Out:
# w00 47
#   <div id="f77d95ed-0261-4af7-a63e-553cb03c0bc6" data-root-id="5e54f233-7dae-4d8d-bc8b-b3ad54bcc07e" style="display: contents;"></div>

# %%
big_df_p7['species_id'].unique()
# Out:
# array(['100146', '101059', '100910', '102478', '102438', '100196',
#        '103656', '102506', '101346', '100099', '101400', '101294'],
#       dtype=object)

# %%
print(np.percentile(big_df_p7_gr['sel_12_gen_pol'].values,25))
print(np.percentile(big_df_p7_gr['sel_12_gen_pol'].values,75))
# Out:
# 0.11837113065069976
# 0.33767257772196063

# %%
70/111
# Out:
# 0.6306306306306306

# %%
# t test 
import scipy.stats
from scipy import stats
import numpy as np
from scipy.stats import false_discovery_control

sp_mesos = []
pvals = []
effect_size = []
for sp_type_meso in big_df_p7['species-type_meso'].unique():
    big_df_sp_type_meso = big_df_p7.loc[big_df_p7['species-type_meso']==sp_type_meso,:]
    sp_mesos.append(sp_type_meso)
    preds = big_df_sp_type_meso['pred_val_sel_12'].values
    acts = big_df_sp_type_meso['boot_med1'].values
    t_statistic, p_value = stats.ttest_ind(preds,acts)
    pvals.append(p_value)
    effect_size.append(np.mean(preds)-np.mean(acts))
df_ttest = pd.DataFrame(data={'sp_mesos':sp_mesos,'pvals':pvals,'effect_size':effect_size})
df_ttest=df_ttest.loc[~df_ttest['pvals'].isna(),:]
print(len(df_ttest))
df_ttest = df_ttest.loc[df_ttest['effect_size'].abs()>1e-2,:]
df_ttest = df_ttest.sort_values(by='pvals')
df_ttest['qvals']=false_discovery_control(df_ttest['pvals'])
len(df_ttest.loc[df_ttest['qvals']<.05,:])
df_ttest_good = df_ttest.loc[df_ttest['qvals']<.05,:]
sp_type_meso
# Out:
# 36
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6316: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:579: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# '101294-AE-AF-mGAM-mBHI'

# %%
#polgood.loc[df_ttest_good['sp_mesos'].values,['min_late_sel_med','max_late_sel_med']]

# %%
sels = big_df['sel_12'].abs().values
np.median(sels)
np.percentile(sels,25)
# Out:
# np.float64(0.7712573530129789)

# %%
thresh=1e-3
passage=6
big_df2 = big_df.loc[big_df['sel_12'].abs()<np.percentile(sels,75),:]
big_df2 = big_df2.loc[big_df2['sel_12'].abs()>np.percentile(sels,25),:]
len(big_df2.loc[(big_df2['passage']==passage)*((big_df2['pred_val_sel_12']>=thresh)*(big_df2['pred_val_sel_12']<=1-thresh)),:])/len(big_df2.loc[big_df2['passage']==passage,:])
# Out:
# 0.2545454545454545

# %%
def get_pred_sel(ts,sel_coeff, start_value,):
    pred=np.exp(ts*sel_coeff)
  #  print(pred)
    pred = pred*start_value/(1 - start_value + start_value*pred)
    
    return pred

# %%
big_df = big_df.loc[~big_df['pred_val_sel_12'].isna(),:]
thresh=1e-2
big_df_good=big_df.loc[(big_df['pred_val_sel_12']>=thresh)*(big_df['pred_val_sel_12']<=1-thresh),:]
big_df_good=big_df_good.loc[big_df_good['passage']>2,:]
#print(len(big_df_good))

big_df_good['counts']=1
print('good',len(big_df_good))
big_df_good['het_pred']=big_df_good['pred_val_sel_12']*(1-big_df_good['pred_val_sel_12'])
big_df_good['het_act']=big_df_good['boot_med1']*(1-big_df_good['boot_med1'])
big_df_good_pol = big_df_good#.groupby(['species-type_meso','passage']).median(numeric_only=True).copy().reset_index()
big_df_good_polmax = big_df_good#.groupby(['species-type_meso','passage']).max(numeric_only=True).copy().reset_index()
big_df_good_polmin = big_df_good#.groupby(['species-type_meso','passage']).min(numeric_only=True).copy().reset_index()
#print(big_df_good_pol['sel_12']>0,)
#big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.0,'pred_val_sel_12']
big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'boot_med1']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'boot_med1']
big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']

#big_df_good_pol.loc[big_df_good_pol['sel_12']>0,'boot_med1']=1-big_df_good_pol.loc[big_df_good_pol['sel_12']>.0,'boot_med1']
#big_df_good_pol.loc[big_df_good_pol['sel_12']>0,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['sel_12']>0,'pred_val_sel_12']


print(len(big_df_good_pol))
b=big_df_good.groupby(['species-mesocosm']).median(numeric_only=True)
len(b)
# Out:
# good 171
# 171
# 61

# %%
sp_mesos=[]

passages=[]
preds=[]
acts=[]
max_het_act = []
max_het_pred = []
min_het_act = []
min_het_pred  = []
column='species-mesocosm'
for sp_meso in big_df_good_pol[column].unique():
    sp_thing=big_df_good_pol.loc[big_df_good_pol[column]==sp_meso,:]
    
    max_passage = sp_thing['passage'].max()
    sp_thing = sp_thing.loc[sp_thing['passage']==max_passage,:]
    pred_val = sp_thing['pred_val_sel_12'].values[0]
    act_val = sp_thing['boot_med1'].values[0]
    
    sp_mesos.append(sp_meso)
    passages.append(max_passage)
    preds.append(pred_val)
    acts.append(act_val)
    max_val_df = big_df_good_polmax.loc[(big_df_good_polmax[column]==sp_meso)*(big_df_good_polmax['passage']==max_passage),:]
    min_val_df = big_df_good_polmin.loc[(big_df_good_polmin[column]==sp_meso)*(big_df_good_polmin['passage']==max_passage),:]
    max_het_act.append(max_val_df['het_act'].values[0])
    min_het_act.append(min_val_df['het_act'].values[0])
    max_het_pred.append(max_val_df['het_pred'].values[0])
    min_het_pred.append(min_val_df['het_act'].values[0])
df = pd.DataFrame(data={'sp_mesos':sp_mesos,'passage':passages,'pred':preds,'act':acts,
                       'max_het_act':max_het_act,'min_het_act':min_het_act,'max_het_pred':max_het_pred,'min_het_pred':min_het_pred})
#df

# %%
df['het_act']=df['act']*(1.-df['act'])
df['het_pred']=df['pred']*(1.-df['pred'])
df['passage']=df['passage'].astype(str)
df=df.sort_values(by='passage')
p = hv.Points(df,vdims=['het_act',hv.Dimension('passage',values=['3','4','5','6','7',])],kdims = ['het_pred','het_act']).opts(size=10,color='passage',line_color='black',
                                                                                                                              cmap = [bokeh.palettes.Pastel1[5][0],
                                                                                                                                      bokeh.palettes.Pastel1[5][-1],
                                                                                                                                      bokeh.palettes.Pastel1[5][2],
                                                                                                                                      bokeh.palettes.Pastel1[5][1],
                                                                                                                                       bokeh.palettes.Pastel1[5][3],],
                                                                                                                              legend_position='right',
                                                                                                                              colorbar=True,width=300,
                                                                                                                              height=250,
                                                                     )

p = hv.render(p)
points = np.linspace(-1,2)
p.x_range=bokeh.models.Range1d(-.005,.255)
p.y_range=bokeh.models.Range1d(-.005,.255)
p.legend.location='right'
p.line(points,points,color='grey',line_width=2)
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p.legend.visible=False
export_plot_pdf(p,'het')
bokeh.io.show(p)
# Out:
#   <div id="e2a5bc97-490a-4bb0-b1ea-8a17ea007fc0" data-root-id="45d431cf-c19b-4e31-985d-aa0ee3a43887" style="display: contents;"></div>

# %%
len(df.loc[df['het_pred']<df['het_act'],:])
# Out:
# 46

# %%
len(df)
# Out:
# 27

# %%
p = np.random.choice([0,1],size=(len(df),100000))
b=p.sum(axis=0)
print(np.percentile(b,97.5))
# Out:
# 19.0

# %%
big_df_good_pol = big_df_good.copy()
#print(big_df_good_pol['sel_12']>0,)
#big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>0,'pred_val_sel_12']
big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'boot_med1']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'boot_med1']
big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']

print(len(big_df_good_pol))
b=big_df_good_pol.groupby(['species-type_meso']).median(numeric_only=True)

p = hv.Points(big_df_good_pol,vdims=['boot_med1'],kdims = ['pred_val_sel_12','boot_med1'])

p = hv.render(p)
points = np.linspace(-1,2)
p.line(points,points)
bokeh.io.show(p)
# Out:
# 171
#   <div id="efc3ec59-eab7-412d-80cb-5f6dee8a123f" data-root-id="878f7442-9e2b-404e-be52-109814988611" style="display: contents;"></div>

# %%
def make_big_plot(meds,logit_scale=False,sel_range = (-.5,.5),line=True,width=400):
    if logit_scale:
        meds = meds.copy()
        for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med','pred7_med']:
            meds[freq_column]=np.log(meds[freq_column]/(1-meds[freq_column]))

         #   'early_sel_med','act_7_med','pred7_med','late_sel_med'
    scatter = hv.Scatter(meds, kdims =  'pred7_med', vdims=['act_7_med',hv.Dimension('early_sel_med',range=sel_range)]).opts(#size=4, 
                                                                                        alpha = 1.0, color = 'early_sel_med',#height=700,
                                                                                           width = width,line_color='black',
                                                                                                      
                                                                                      cmap = 'Magma',
                                                                                                            colorbar=True, 
                                                                                                  # logx=True, logy=True,
                                                                                                    legend_position='right',
                                                                                                        size=10,
                                                                                         )
    seg = hv.Segments(meds, ['pred7_med', 
                             'min_act_7_med', 
                             'pred7_med', 'max_act_7_med', ]).opts(color='black',alpha=.2)
    
    seg2 = hv.Segments(meds, ['min_pred7_med', 
                             'act_7_med', 
                             'max_pred7_med', 'act_7_med', ]).opts(color='black',alpha=.2)

    exps_adjust = np.array([.001,.01,.1,.5,.9,.99,.999])
    lins_adjust = np.log(exps_adjust/(1-exps_adjust))
    #exps_adjust = exps_adjust[::2]
   # lins_adjust = lins_adjust[::2]
    if logit_scale:
        scatter.opts(xticks=[(lins_adjust[i], exps_adjust[i]) for i in range(len(lins_adjust))],
                 yticks=[(lins_adjust[i], exps_adjust[i]) for i in range(len(lins_adjust))]
                )
    
    ticks = np.linspace(sel_range[0],sel_range[1],6)
    labels = [str(tick) for tick in ticks]
   # if sel_range[0]!=0:
    labels[0] = '<' + labels[0]
   # if sel_range[-1]!= 0:
    labels[-1] = '>' + labels[-1]

    #labels[-1] = '>' + labels[-1]
    print(labels)
  #  labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    
    # Apply colorbar customization
    scatter.opts(
        colorbar=True,
        colorbar_opts={
            'major_label_overrides': dict(zip(ticks, labels))
        }
    )

    scatter = hv.render(scatter*seg*seg2)
    if line:
        if logit_scale:
            scatter.line(np.linspace(-8,8), np.linspace(-8,8),color = 'black', )
        else:
            scatter.line(np.linspace(1e-20,1), np.linspace(1e-20,1),color = 'black', )
        
    scatter.legend.visible = True
    scatter.xaxis.axis_label = 'Predicted final frequency'
    scatter.yaxis.axis_label = 'Actual final frequency'
    #bokeh.io.show(scatter)
    return scatter,meds

# %%
def polarize(df,positive=False):
    to_polarize = df.loc[df['pred7_med']>.5,:].index.values
    if positive:
        to_polarize = df.loc[df['pred7_med']<.5,:].index.values
    print(to_polarize)
    for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med',]:
        df.loc[to_polarize,freq_column]= 1- df.loc[to_polarize,freq_column]
    for sel_column in ['early_sel_med','max_early_sel_med','min_early_sel_med',
                      'late_sel_med','max_late_sel_med','min_late_sel_med',]:
        df.loc[to_polarize,sel_column]= -df.loc[to_polarize,sel_column]
    print(df.loc[to_polarize,'pred7_med'])
    df.loc[to_polarize,'pred7_med']=1-df.loc[to_polarize,'pred7_med']
    return df


def adjust(df,thresh=1e-3):
   # to_polarize = df.loc[df['pred_p7s']>.5,:].index.values
    for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med','pred7_med']:
        df.loc[df[freq_column]>1-thresh,freq_column]= 1-thresh
        df.loc[df[freq_column]<thresh,freq_column]= thresh
    return df

# %%
all_dfs=[]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
t0 = 1
t1 = 2
big_dfs = []

big_dfs_all = []
for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
        if f'{sp}-{ino}' in bad_inos:
            continue 
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
        if os.path.exists(fname):
            fname2=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
            if not os.path.exists(fname2):
                continue
            df,df2= get_selection_stuff_time_vary(sp,ino,t0,t1,thresh=1e-3)
            #df,df2=get_selection_stuff_time_vary_all_times(sp,ino,t0,t1,thresh=1e-3)
                        
            if len(df)>0:
                df['species_id']=sp
                big_dfs.append(df.reset_index())
                df2['species_id']=sp
                big_dfs_all.append(df2)
            
big_df=pd.concat(big_dfs).reset_index()
big_df_all=pd.concat(big_dfs_all).reset_index()

len(big_df['species_id'].unique())
big_df['species-type_meso']=big_df['species_id'].astype(str)+'-'+big_df['type_mesocosm'].astype(str)
#big_df['species-mesocosm']=big_df['species_id'].astype(str)+'-'+big_df['mesocosm'].astype(str)
#big_df = big_df.loc[~big_df['pred_val_sel_12'].isna(),:]
#big_df_good=big_df.loc[(big_df['pred_val_sel_12']>1e-2)*(big_df['pred_val_sel_12']<1-1e-2),:]
#big_df = big_df.set_index('species-type_meso')
len(big_df['species_id'].unique())
# Out:
# 11

# %%
big_df_all
# Out:
#      index  Unnamed: 0             mesocosm  diff7_med  diff7_lower  \
# 0        0           0   C8-AA-AE-mGAM-mBHI  -0.297174    -0.306626
# 1        1           1  E10-AA-AE-mGAM-mBHI  -0.794501    -0.804328
# 2        2           2  A10-AA-AE-mGAM-mBHI  -0.499000    -0.499000
# 3        3           3   G8-AA-AE-mGAM-mBHI  -0.583200    -0.590420
# 4        1           1   D8-AA-AF-mGAM-mGAM  -0.004680    -0.005808
# ..     ...         ...                  ...        ...          ...
# 106      1           1   D8-AA-AF-mGAM-mGAM  -0.068246    -0.072589
# 107      2           2  E11-AA-AF-mGAM-mGAM  -0.049040    -0.053170
# 108      3           3   H8-AA-AF-mGAM-mGAM  -0.091914    -0.106029
# 109      0           0  C11-AE-AF-mGAM-mGAM   0.052241     0.004426
# 110      1           1  H10-AE-AF-mGAM-mBHI   0.001771     0.000988
#
#      diff7_upper  pred_7_upper  pred_7_lower     pred7_med  as_extreme7  ...  \
# 0      -0.289061  4.270346e-10  6.754690e-11  1.746664e-10         1000  ...
# 1      -0.790661  6.934626e-09  3.840333e-09  5.140876e-09         1000  ...
# 2      -0.484067  8.371745e-06  5.695312e-06  6.780512e-06         1000  ...
# 3      -0.575708  8.562705e-05  2.485503e-05  3.458236e-05         1000  ...
# 4      -0.003702  1.522294e-14  1.397497e-15  4.881343e-15         1000  ...
# ..           ...           ...           ...           ...          ...  ...
# 106    -0.064923  1.546188e-04  4.647356e-05  8.804787e-05         1000  ...
# 107    -0.044198  5.849594e-03  2.746290e-03  4.096832e-03         1000  ...
# 108    -0.073887  6.259081e-02  3.090108e-02  4.443251e-02         1000  ...
# 109     0.124583  9.446323e-01  8.253647e-01  8.706614e-01           17  ...
# 110     0.002711  9.999952e-01  9.999888e-01  9.999925e-01            0  ...
#
#      sample_early1  sample_early2  sample_late1  sample_late2  \
# 0                1              2             6             7
# 1                1              2             6             7
# 2                1              2             6             7
# 3                1              2             6             7
# 4                1              2             6             7
# ..             ...            ...           ...           ...
# 106              1              2             6             7
# 107              1              2             6             7
# 108              1              2             6             7
# 109              1              2             6             7
# 110              1              2             6             7
#
#        type_mesocosm  species   inoculumn  start_val  t1_val  species_id
# 0    AA-AE-mGAM-mBHI   100146  AA-AE-mGAM   0.039553     NaN      100146
# 1    AA-AE-mGAM-mBHI   100146  AA-AE-mGAM   0.123732     NaN      100146
# 2    AA-AE-mGAM-mBHI   100146  AA-AE-mGAM   0.170191     NaN      100146
# 3    AA-AE-mGAM-mBHI   100146  AA-AE-mGAM   0.172699     NaN      100146
# 4    AA-AF-mGAM-mGAM   100146  AA-AF-mGAM   0.004810     NaN      100146
# ..               ...      ...         ...        ...     ...         ...
# 106  AA-AF-mGAM-mGAM   101294  AA-AF-mGAM   0.053862     NaN      101294
# 107  AA-AF-mGAM-mGAM   101294  AA-AF-mGAM   0.094416     NaN      101294
# 108  AA-AF-mGAM-mGAM   101294  AA-AF-mGAM   0.145030     NaN      101294
# 109  AE-AF-mGAM-mGAM   101294  AE-AF-mGAM   0.599790     NaN      101294
# 110  AE-AF-mGAM-mBHI   101294  AE-AF-mGAM   0.904374     NaN      101294
#
# [111 rows x 29 columns]

# %%
            
big_df=pd.concat(big_dfs).reset_index()
len(big_df['species_id'].unique())
big_df['species-type_meso']=big_df['species_id'].astype(str)+'-'+big_df['type_mesocosm'].astype(str)
big_df = big_df.set_index('species-type_meso')
big_df.head()
pol = polarize(big_df,positive=True)
pol = adjust(pol)
# Out:
# ['100146-AA-AE-mGAM-mBHI' '100146-AA-AF-mGAM-mGAM'
#  '101059-AA-AF-mBHI-mGAM' '102438-AA-AE-mBHI-mGAM'
#  '102438-AA-AF-mBHI-mBHI' '102438-AA-AF-mBHI-mGAM'
#  '102438-AE-AF-mBHI-mBHI' '102438-AA-AE-mGAM-mBHI'
#  '102438-AA-AE-mGAM-mGAM' '102438-AA-AF-mGAM-mBHI'
#  '102438-AA-AF-mGAM-mGAM' '102438-AE-AF-mGAM-mBHI'
#  '100196-AA-AE-mBHI-mGAM' '100196-AA-AF-mGAM-mGAM'
#  '103656-AA-AF-mGAM-mGAM' '102506-AA-AF-mGAM-mBHI'
#  '102506-AA-AF-mGAM-mGAM' '101346-AA-AF-mGAM-mGAM'
#  '100099-AA-AE-mBHI-mBHI' '100099-AA-AE-mBHI-mGAM'
#  '100099-AA-AF-mBHI-mBHI' '100099-AA-AF-mBHI-mGAM'
#  '100099-AE-AF-mBHI-mBHI' '100099-AE-AF-mBHI-mGAM'
#  '100099-AA-AE-mGAM-mGAM' '100099-AA-AF-mGAM-mBHI'
#  '100099-AA-AF-mGAM-mGAM' '100099-AE-AF-mGAM-mBHI'
#  '101294-AE-AF-mBHI-mGAM' '101294-AA-AE-mGAM-mGAM'
#  '101294-AA-AF-mGAM-mGAM']
# species-type_meso
# 100146-AA-AE-mGAM-mBHI    3.392826e-06
# 100146-AA-AF-mGAM-mGAM    4.881343e-15
# 101059-AA-AF-mBHI-mGAM    4.842226e-01
# 102438-AA-AE-mBHI-mGAM    1.591619e-10
# 102438-AA-AF-mBHI-mBHI    1.263791e-06
# 102438-AA-AF-mBHI-mGAM    4.065061e-08
# 102438-AE-AF-mBHI-mBHI    1.103148e-02
# 102438-AA-AE-mGAM-mBHI    2.223953e-02
# 102438-AA-AE-mGAM-mGAM    7.116606e-07
# 102438-AA-AF-mGAM-mBHI    3.720995e-08
# 102438-AA-AF-mGAM-mGAM    2.949577e-07
# 102438-AE-AF-mGAM-mBHI    4.985084e-01
# 100196-AA-AE-mBHI-mGAM    8.861110e-04
# 100196-AA-AF-mGAM-mGAM    3.226409e-07
# 103656-AA-AF-mGAM-mGAM    4.892561e-15
# 102506-AA-AF-mGAM-mBHI    6.159110e-04
# 102506-AA-AF-mGAM-mGAM    7.143977e-05
# 101346-AA-AF-mGAM-mGAM    3.098858e-07
# 100099-AA-AE-mBHI-mBHI    2.334749e-07
# 100099-AA-AE-mBHI-mGAM    7.750429e-07
# 100099-AA-AF-mBHI-mBHI    7.299593e-04
# 100099-AA-AF-mBHI-mGAM    1.563034e-06
# 100099-AE-AF-mBHI-mBHI    3.228213e-05
# 100099-AE-AF-mBHI-mGAM    5.925187e-05
# 100099-AA-AE-mGAM-mGAM    2.488562e-04
# 100099-AA-AF-mGAM-mBHI    2.647757e-12
# 100099-AA-AF-mGAM-mGAM    1.286096e-06
# 100099-AE-AF-mGAM-mBHI    6.382418e-07
# 101294-AE-AF-mBHI-mGAM    5.107743e-02
# 101294-AA-AE-mGAM-mGAM    1.136840e-09
# 101294-AA-AF-mGAM-mGAM    2.113908e-03
# Name: pred7_med, dtype: float64

# %%
pol.loc[pol['species_id']=='103656',:]
# Out:
#                         index    type_mesocosm species   inoculumn  \
# species-type_meso
# 103656-AA-AE-mGAM-mGAM      0  AA-AE-mGAM-mGAM  103656  AA-AE-mGAM
# 103656-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  103656  AA-AF-mGAM
#
#                         Unnamed: 0     diff7_med   diff7_lower  diff7_upper  \
# species-type_meso
# 103656-AA-AE-mGAM-mGAM         0.5  1.570314e-01  1.529944e-01     0.160789
# 103656-AA-AF-mGAM-mGAM         1.0 -1.439673e-07 -3.526288e-07     0.000000
#
#                         pred_7_upper  pred_7_lower  ...  t1_val  \
# species-type_meso                                   ...
# 103656-AA-AE-mGAM-mGAM  9.999999e-01  9.999997e-01  ...     NaN
# 103656-AA-AF-mGAM-mGAM  9.725535e-15  2.453399e-15  ...     NaN
#
#                         max_early_sel_med  min_early_sel_med  max_act_7_med  \
# species-type_meso
# 103656-AA-AE-mGAM-mGAM           3.531825           3.106734       0.973998
# 103656-AA-AF-mGAM-mGAM           4.252618           6.307898       0.998828
#
#                         min_act_7_med  max_pred7_med  min_pred7_med  \
# species-type_meso
# 103656-AA-AE-mGAM-mGAM       0.709939          0.999          0.999
# 103656-AA-AF-mGAM-mGAM       0.999000          0.999          0.999
#
#                         max_late_sel_med  min_late_sel_med  species_id
# species-type_meso
# 103656-AA-AE-mGAM-mGAM          1.439444          0.895089      103656
# 103656-AA-AF-mGAM-mGAM         -0.000000          0.576636      103656
#
# [2 rows x 36 columns]

# %%
polgood = pol.loc[~pol['max_early_sel_med'].isna(),:]
def get_median(array1,array2):
    return np.median(array1)-np.median(array2)

test = scipy.stats.permutation_test((polgood['early_sel_med'].abs(),polgood['late_sel_med'].abs()),get_median )
0.0002<1e-3
print(np.percentile(polgood['early_sel_med'].abs(),25))
print(np.percentile(polgood['early_sel_med'].abs(),75))
print(np.percentile(polgood['late_sel_med'].abs(),25))
print(np.percentile(polgood['late_sel_med'].abs(),75))
# Out:
# 0.9404821514170919
# 2.65764176664647
# 0.17481140469465767
# 0.6846728475716094

# %%
test = scipy.stats.permutation_test((polgood['early_sel_med'].abs(),polgood['late_sel_med'].abs()),get_median )
test
# Out:
# PermutationTestResult(statistic=np.float64(1.4762308150430117), pvalue=np.float64(0.0002), null_distribution=array([-0.08018537,  0.32691181, -0.11579409, ...,  0.27461973,
#        -0.32833976, -0.52120192], shape=(9999,)))

# %%
from holoviews.operation import histogram
def make_big_plot_sel(meds,line=True,width=400,by_gen=True):
    if by_gen:
        meds = meds.copy()
        meds[['early_sel_med','min_late_sel_med', 'max_late_sel_med', 'min_early_sel_med', 'max_early_sel_med','late_sel_med']]=\
        meds[['early_sel_med','min_late_sel_med', 'max_late_sel_med', 'min_early_sel_med', 'max_early_sel_med','late_sel_med']]*1/np.log2(200)
        
    
    scatter = hv.Scatter(meds.sort_values(by='act_7_med'), kdims =  'early_sel_med', vdims=['late_sel_med',hv.Dimension('act_7_med',range=(0,1))]).opts(#size=4, 
                                                                                        alpha = 1.0,  height=300,width=300,
                                                                                           line_color='black',color=bokeh.palettes.Set2[3][-1],
                                                                                                      
                                                                                     # cmap = 'Magma',
                                                                                                          #  colorbar=True, 
                                                                                                  # logx=True, logy=True,
                                                                                                    legend_position='right',
                                                                                                        size=10,
        
                                                                                         )
    seg = hv.Segments(meds, ['early_sel_med', 
                             'min_late_sel_med', 
                             'early_sel_med', 'max_late_sel_med', ]).opts(color='black',alpha=.2,)#backend_opts={'plot.output_backend':'svg'})
    
    seg2 = hv.Segments(meds, ['min_early_sel_med', 
                             'late_sel_med', 
                             'max_early_sel_med', 'late_sel_med', ]).opts(color='black',alpha=.2,)#backend_opts={'plot.output_backend':'svg'})
    
    ticks = np.linspace(0,1,6)
    labels = [str(tick) for tick in ticks]
   # if sel_range[0]!=0:
    labels[0] = '<' + labels[0]
   # if sel_range[-1]!= 0:
    labels[-1] = '>' + labels[-1]

    #labels[-1] = '>' + labels[-1]
    print(labels)
  #  labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    
    # Apply colorbar customization
    scatter.opts(
        colorbar=True,
        #\colorbar_opts={
      #      'major_label_overrides': dict(zip(ticks, labels))
      #  }
    )
  #  [(i,i) for i in np.linspace(-10,10)]
    p = hv.Curve([(i,i) for i in np.linspace(-7,7)]).opts(line_color='grey',xlim=(-.1,1),
                                                         ylim=(-1,1), )#backend_opts={'plot.output_backend':'svg'})

    scatter=scatter#.hist(dimension=['early_sel_med','late_sel_med'],).opts(opts.Histogram(color=bokeh.palettes.Set2[3][-1]),)
                                                                         # backend_opts={'plot.output_backend':'svg'})
    scatter = scatter*seg*seg2*p
 #   scatter = (scatter) << yhist.opts(width=300) << xhist.opts(height=300)
   # scatter = hv.render(scatter*seg*seg2*p, kwargs=dict(fmt='svg'))
#    scatter.line(np.linspace(-10,10), np.linspace(-10,10),color = 'black', )
        
   # scatter.legend.visible = True
 #   scatter.yaxis.axis_label = 'Sel 6-7'
    #bokeh.io.show(scatter)
    return scatter

# %%
def ecdf_transform(data):
    return data.rank(method="first") / len(data)

# %%
p = make_big_plot_sel(pol,)
pol['deltas']=-pol['late_sel_med']*1/np.log2(200)+pol['early_sel_med']*1/np.log2(200)
pol.loc[:, "deltas ECDF"] = pol[
    "deltas"
].transform(ecdf_transform)

p2 = hv.Scatter(
    data=pol,
    kdims='deltas',
    vdims=['deltas ECDF'],
).opts(cmap = [bokeh.palettes.Bright[6][1],bokeh.palettes.Bright[6][4],bokeh.palettes.Vibrant[7][-1]],
       width=250,height=200,xlabel='S_late - s_early',#legend_position='right',
      ylabel='CDF',xlim=(-1.,.5))
p3 = hv.Scatter(
    data=pol,
    kdims='deltas',
    vdims=['deltas ECDF'],
).opts(color =bokeh.palettes.Set2[3][-1],
       width=250,height=200,xlabel='S_late - s_early',#legend_position='right',
      ylabel='1-CDF',xlim=(-.2,1),size=5)
print(len(pol.loc[pol['deltas']<-.01,:])/len(pol))
p3= hv.render(p3)
#p3.ray(x=-.01,y=-1,color='red',angle=np.pi/2)
p3.xaxis.major_label_text_font_size='15px'
p3.yaxis.major_label_text_font_size='15px'
p3.output_backend='svg'
#p3.width=300
bokeh.io.show(p3)
export_plot_pdf(p3,'1_2_ecdf1')
bokeh.io.show(p3)
p= p
p= hv.render(p)
p.output_backend='svg'
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p.y_range = bokeh.models.Range1d(-.5,.5)
p.height=200
p.width=300
bokeh.io.show(p)
export_plot_pdf(p,'1_2_scatter')
# Out:
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
# 0.09523809523809523
#   <div id="f849b59f-b866-4bef-bd4d-dd9dc22a5da7" data-root-id="6816dac2-9178-4fe0-b445-c5321d822cea" style="display: contents;"></div>
#   <div id="bffe5f2b-a420-42d0-b076-b7737786003f" data-root-id="6816dac2-9178-4fe0-b445-c5321d822cea" style="display: contents;"></div>
#   <div id="d5946da7-3346-46fb-847a-240d8cdd83e8" data-root-id="8462058d-30a3-4ff4-9c3b-3af171bd1b2e" style="display: contents;"></div>

# %%
polgood = pol.loc[~pol['max_early_sel_med'].isna(),:]
def get_median(array1,array2):
    return np.median(array1)-np.median(array2)

test = scipy.stats.permutation_test((polgood['early_sel_med'].abs(),polgood['late_sel_med'].abs()),get_median )
0.0002<1e-3
print(np.percentile(polgood['early_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood['early_sel_med'].abs()*1/np.log2(200),75))
print(np.percentile(polgood['late_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood['late_sel_med'].abs()*1/np.log2(200),75))
# Out:
# 0.12303765639588901
# 0.34768338135424737
# 0.022869530817247047
# 0.089571654747705

# %%
len(polgood )
# Out:
# 42

# %%
polgood5 = polgood.copy()
thresh=5e-3
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'min_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']

polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'max_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']
p = make_big_plot_sel(polgood5,)

polgood5['deltas']=-polgood5['late_sel_med']*1/np.log2(200) + polgood5['early_sel_med']*1/np.log2(200)
polgood5.loc[:, "deltas ECDF"] = polgood5[
    "deltas"
].transform(ecdf_transform)

polgood5b = polgood5.loc[((polgood5['act_7_med']<1-thresh)*(polgood5['act_7_med']>thresh)),:]
test = scipy.stats.permutation_test((polgood5b['early_sel_med'].abs(),polgood5b['late_sel_med'].abs()),get_median )
print(test.pvalue)
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),75))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),75))

p3 = hv.Scatter(
    data=polgood5,
    kdims='deltas',
    vdims=['deltas ECDF'],
).opts(cmap = [bokeh.palettes.Bright[6][1],bokeh.palettes.Bright[6][4],bokeh.palettes.Vibrant[7][-1]],
       width=250,height=200,xlabel='S_late - s_early',#legend_position='right',
      ylabel='1-CDF',xlim=(-1.,.5))
print(len(polgood5.loc[polgood5['deltas']<-.01,:])/len(polgood5))
p3 = hv.render(p3)
p3.ray(x=-.01,y=-1,color='red',angle=np.pi/2)
bokeh.io.show(p3)
p = make_big_plot_sel(polgood5,)
p= p
p= hv.render(p)
p.output_backend='svg'
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
test = scipy.stats.permutation_test((polgood5b['early_sel_med'].values,polgood5b['late_sel_med'].values),get_median )
print('pval',test.pvalue)
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),75))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),75))

p3 = hv.Scatter(
    data=polgood5,
    kdims='deltas',
    vdims=['deltas ECDF'],
).opts(color =bokeh.palettes.Set2[3][-1],
       width=250,height=200,xlabel='S_late - s_early',#legend_position='right',
      ylabel='1-CDF',xlim=(-.2,1),size=5)
print(len(polgood5.loc[polgood5['deltas']<-.01,:])/len(polgood5))
p3 = hv.render(p3)
#p3.ray(x=-.01,y=-1,color='red',angle=np.pi/2)
#bokeh.io.show(p3)
p = make_big_plot_sel(polgood5,)
p= p
p= hv.render(p)
p.output_backend='svg'
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p3.xaxis.major_label_text_font_size='15px'
p3.yaxis.major_label_text_font_size='15px'
p3.output_backend='svg'
#p3.width=300
bokeh.io.show(p3)
export_plot_pdf(p3,'1_2_ecdf5')
p.y_range = bokeh.models.Range1d(-.5,.5)
p.height=200
#p.width=300
bokeh.io.show(p)
export_plot_pdf(p,'1_2_scatter5')
# Out:
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
# 0.0002
# 0.11541436271699004
# 0.3304593840810643
# 0.03188039648615857
# 0.11605994643265458
# 0.07142857142857142
#   <div id="de9b7a38-db2f-4353-90b7-7cf319d647c3" data-root-id="cb0c2682-e71b-4165-8a93-ee4bfaaefe2c" style="display: contents;"></div>
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
# pval 0.0002
# 0.11541436271699004
# 0.3304593840810643
# 0.03188039648615857
# 0.11605994643265458
# 0.07142857142857142
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
#   <div id="ac71a979-694b-4d56-b6a7-0d3f80502014" data-root-id="353968d9-1c50-4d93-b7c7-dc88207490b5" style="display: contents;"></div>
#   <div id="cdf151b3-fd4b-4c46-ac03-12e4a8166ca4" data-root-id="5ec4d292-a915-4e83-81ca-3c0433768ec7" style="display: contents;"></div>

# %%
polgood5 = polgood.copy()
thresh=1e-2
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'min_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']

polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'max_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']

polgood5['deltas']=-polgood5['late_sel_med']*1/np.log2(200)+polgood5['early_sel_med']*1/np.log2(200)
polgood5.loc[:, "deltas ECDF"] = polgood5[
    "deltas"
].transform(ecdf_transform)
polgood5 = polgood5.loc[~polgood5['max_early_sel_med'].isna(),:]
def get_median(array1,array2):
    return np.median(array1)-np.median(array2)
polgood5b = polgood5.loc[((polgood5['act_7_med']<1-thresh)*(polgood5['act_7_med']>thresh)),:]
polgood5b = polgood5.loc[((polgood5['act_7_med']<1-thresh)*(polgood5['act_7_med']>thresh)),:]
test = scipy.stats.permutation_test((polgood5b['early_sel_med'].abs(),polgood5b['late_sel_med'].abs()),get_median )
print(test.pvalue)
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),75))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),75))

p3 = hv.Scatter(
    data=polgood5,
    kdims='deltas',
    vdims=['deltas ECDF'],
).opts(cmap = [bokeh.palettes.Bright[6][1],bokeh.palettes.Bright[6][4],bokeh.palettes.Vibrant[7][-1]],
       width=250,height=200,xlabel='S_late - s_early',#legend_position='right',
      ylabel='1-CDF',xlim=(-1.,.5))
print(len(polgood5.loc[polgood5['deltas']<-.01,:])/len(polgood5))
p3 = hv.render(p3)
p3.ray(x=-.01,y=-1,color='red',angle=np.pi/2)
bokeh.io.show(p3)
p = make_big_plot_sel(polgood5,)
p= p
p= hv.render(p)
p.output_backend='svg'
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
test = scipy.stats.permutation_test((polgood5b['early_sel_med'].values,polgood5b['late_sel_med'].values),get_median )
print('pval',test.pvalue)
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),75))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),75))

p3 = hv.Scatter(
    data=polgood5,
    kdims='deltas',
    vdims=['deltas ECDF'],
).opts(color =bokeh.palettes.Set2[3][-1],
       width=250,height=200,xlabel='S_late - s_early',#legend_position='right',
      ylabel='1-CDF',xlim=(-.2,1),size=5)
print(len(polgood5.loc[polgood5['deltas']<-.01,:])/len(polgood5))
p3 = hv.render(p3)
#p3.ray(x=-.01,y=-1,color='red',angle=np.pi/2)
bokeh.io.show(p3)
p = make_big_plot_sel(polgood5,)
p= p
p= hv.render(p)
p.output_backend='svg'
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p3.xaxis.major_label_text_font_size='15px'
p3.yaxis.major_label_text_font_size='15px'
p3.output_backend='svg'
export_plot_pdf(p3,'1_2_ecdf10')
p.y_range = bokeh.models.Range1d(-.5,.5)
p.height=200
p.width=300
bokeh.io.show(p)
export_plot_pdf(p,'1_2_scatter10')
# Out:
# 0.0002
# 0.12186385360290489
# 0.32338767621654846
# 0.02868219110194868
# 0.09325840460751539
# 0.023809523809523808
#   <div id="fe10163f-b306-4f96-999f-1af7df267459" data-root-id="d278191b-ca44-4015-8555-5e4f88ec8bca" style="display: contents;"></div>
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
# pval 0.0002
# 0.12186385360290489
# 0.32338767621654846
# 0.02868219110194868
# 0.09325840460751539
# 0.023809523809523808
#   <div id="aa1ec6c7-1fcb-4f30-8e11-a9e629e72368" data-root-id="ff22e536-1801-490e-b3c0-3c0cef5c5d0b" style="display: contents;"></div>
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
#   <div id="cfcdde08-b183-45ff-8cf4-6709a1f3b7e1" data-root-id="80e494a6-8345-416e-a332-11a8437dfd6e" style="display: contents;"></div>

# %%
polgood5 = polgood.copy()
thresh=5e-2
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'min_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']

polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'max_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']

polgood5['deltas']=-polgood5['late_sel_med']*1/np.log2(200)+polgood5['early_sel_med']*1/np.log2(200)
polgood5.loc[:, "deltas ECDF"] = polgood5[
    "deltas"
].transform(ecdf_transform)
polgood5 = polgood5.loc[~polgood5['max_early_sel_med'].isna(),:]
def get_median(array1,array2):
    return np.median(array1)-np.median(array2)
polgood5b = polgood5.loc[((polgood5['act_7_med']<1-thresh)*(polgood5['act_7_med']>thresh)),:]
test = scipy.stats.permutation_test((polgood5b['early_sel_med'].values,polgood5b['late_sel_med'].values),get_median )
print('pval',test.pvalue)
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['early_sel_med'].abs()*1/np.log2(200),75))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),25))
print(np.percentile(polgood5b['late_sel_med'].abs()*1/np.log2(200),75))

p3 = hv.Scatter(
    data=polgood5,
    kdims='deltas',
    vdims=['deltas ECDF'],
).opts(color =bokeh.palettes.Set2[3][-1],
       width=250,height=200,xlabel='S_late - s_early',#legend_position='right',
      ylabel='1-CDF',xlim=(-.2,1.),size=5)
print(len(polgood5.loc[polgood5['deltas']<-.01,:])/len(polgood5))
p3 = hv.render(p3)
#p3.ray(x=-.01,y=-1,color='red',angle=np.pi/2)
bokeh.io.show(p3)
p = make_big_plot_sel(polgood5,)
p= p
p= hv.render(p)
p.output_backend='svg'
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p3.xaxis.major_label_text_font_size='15px'
p3.yaxis.major_label_text_font_size='15px'
p3.output_backend='svg'
export_plot_pdf(p3,'1_2_ecdf50')
p.y_range = bokeh.models.Range1d(-.5,.5)
p.height=200
#p.width=300
bokeh.io.show(p)
export_plot_pdf(p,'1_2_scatter50')
# Out:
# pval 0.0002
# 0.12239980862140032
# 0.31631596835203263
# 0.025483985717738793
# 0.04755704002410481
# 0.0
#   <div id="a2d1f4da-6a95-46b3-bcd8-7105881700fd" data-root-id="54387b67-4423-46eb-8823-18909efd0cc7" style="display: contents;"></div>
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
#   <div id="a1a590bc-064f-438c-a3cc-19118f75e530" data-root-id="12982741-b4ce-4d7e-bfab-189e69e1a92b" style="display: contents;"></div>

# %%
#pol.loc[pol[
p = make_big_plot_sel(pol,)
p= p
p= hv.render(p)
p.output_backend='svg'
bokeh.io.show(p)
export_plot_pdf(p,'1_2_scatter')
# Out:
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
#   <div id="a5a3c12c-74db-4c66-898b-cdbcf909d6dd" data-root-id="00f426c2-75a6-4af0-8119-1556f507bb87" style="display: contents;"></div>

# %%
#big_df_p6=big_df.loc[big_df['passage']==6,:]
sp_mesos = []
pvals = []
big_df_all['species-type_meso']=big_df_all['species_id'].astype(str)+'-'+big_df_all['type_mesocosm']
polgood5 = polgood.copy()
thresh=1e-2
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'min_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']

polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'max_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']


effect_size = []
for sp_type_meso in polgood5.loc[((polgood5['act_7_med']<1-thresh)*(polgood5['act_7_med']>thresh)),:].index.values:
    good = big_df#.loc[big_df['passage']==7,:]
    p7s =big_df_all.loc[big_df_all['species-type_meso'] == sp_type_meso,'early_sel_med'].values
    p7s = p7s[~np.isnan(p7s)]
    p6s = big_df_all.loc[big_df_all['species-type_meso'] == sp_type_meso,'late_sel_med'].values
    p6s = p6s[~np.isnan(p6s)]
    sp_mesos.append(sp_type_meso)
    t_statistic, p_value = stats.ttest_ind(p7s,p6s)
    pvals.append(p_value)
    effect_size.append(np.mean(p7s)-np.mean(p6s))
df_ttest_p6 = pd.DataFrame(data={'sp_mesos':sp_mesos,'pvals':pvals,'effect_size':effect_size})
df_ttest_p6=df_ttest_p6.loc[~df_ttest_p6['pvals'].isna(),:]
print(len(df_ttest_p6))
#df_ttest_p = df_ttest.loc[df_ttest['effect_size'].abs()>1e-2,:]
df_ttest_p6 = df_ttest_p6.sort_values(by='pvals')
df_ttest_p6['qvals']=false_discovery_control(df_ttest_p6['pvals'])
df_ttest_p6.reset_index()
# Out:
# 21
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6316: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#     index                sp_mesos     pvals  effect_size     qvals
# 0       7  102438-AA-AF-mGAM-mGAM  0.000078    -2.783630  0.001636
# 1      15  100099-AE-AF-mBHI-mGAM  0.001176    -1.630176  0.009314
# 2      18  100099-AA-AF-mGAM-mGAM  0.001331    -1.981712  0.009314
# 3       0  100146-AA-AE-mGAM-mBHI  0.001977    -3.004262  0.010380
# 4       6  102438-AA-AF-mGAM-mBHI  0.012159    -2.742951  0.051068
# 5      11  103656-AA-AE-mGAM-mGAM  0.024797     2.152014  0.079392
# 6      13  101346-AA-AF-mGAM-mGAM  0.028194    -2.172970  0.079392
# 7      17  100099-AA-AE-mGAM-mGAM  0.030244    -0.825007  0.079392
# 8       5  102438-AE-AF-mBHI-mGAM  0.042028     1.177418  0.098065
# 9      12  102506-AA-AF-mGAM-mBHI  0.051355    -1.606341  0.107845
# 10     16  100099-AA-AE-mGAM-mBHI  0.057035     0.630825  0.108885
# 11     21  101294-AA-AF-mGAM-mGAM  0.071589    -0.587214  0.125115
# 12     14  100099-AA-AF-mBHI-mBHI  0.085150    -1.871703  0.125115
# 13     20  100099-AE-AF-mGAM-mGAM  0.086351     0.602796  0.125115
# 14      1  100146-AE-AF-mGAM-mBHI  0.089368     2.172091  0.125115
# 15     19  100099-AE-AF-mGAM-mBHI  0.132732    -1.696719  0.164026
# 16      2  101059-AA-AF-mBHI-mBHI  0.132783     1.063853  0.164026
# 17     10  100196-AA-AF-mGAM-mGAM  0.151658    -3.417111  0.176935
# 18      9  102438-AE-AF-mGAM-mGAM  0.166824    -0.821838  0.184385
# 19      4  102438-AE-AF-mBHI-mBHI  0.191535    -1.043723  0.201112
# 20      8  102438-AE-AF-mGAM-mBHI  0.540436    -0.747707  0.540436

# %%
big_df_all.columns.values
# Out:
# array(['index', 'Unnamed: 0', 'mesocosm', 'diff7_med', 'diff7_lower',
#        'diff7_upper', 'pred_7_upper', 'pred_7_lower', 'pred7_med',
#        'as_extreme7', 'act7_upper', 'act_7_lower', 'act_7_med',
#        'early_sel_upper', 'early_sel_lower', 'early_sel_med',
#        'late_sel_upper', 'late_sel_lower', 'late_sel_med',
#        'sample_early1', 'sample_early2', 'sample_late1', 'sample_late2',
#        'type_mesocosm', 'species', 'inoculumn', 'start_val', 't1_val',
#        'species_id', 'species-type_meso'], dtype=object)

# %%
#big_df_p6=big_df.loc[big_df['passage']==6,:]
sp_mesos = []
pvals = []
big_df_all['species-type_meso']=big_df_all['species_id'].astype(str)+'-'+big_df_all['type_mesocosm']
polgood5 = polgood.copy()
thresh=1e-2
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']
polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'min_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']

polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<thresh)),'max_late_sel_med']= \
        polgood5.loc[((polgood5['act_7_med']>1-thresh)+(polgood5['act_7_med']<-thresh)),'early_sel_med']


effect_size = []
for sp_type_meso in big_df_all['species-type_meso'].unique():
    good = big_df#.loc[big_df['passage']==7,:]
    p7s =big_df_all.loc[big_df_all['species-type_meso'] == sp_type_meso,'act_7_med'].values
    p7s = p7s[~np.isnan(p7s)]
    p7s[p7s>1-1e-3]=1-1e-3
    p7s[p7s<1e-3]=1e-3
    p6s = big_df_all.loc[big_df_all['species-type_meso'] == sp_type_meso,'pred7_med'].values
    p6s = p6s[~np.isnan(p6s)]
    p6s[p6s>1-1e-3]=1-1e-3
    p6s[p6s<1e-3]=1e-3
    sp_mesos.append(sp_type_meso)
    t_statistic, p_value = stats.ttest_ind(p7s,p6s)
    pvals.append(p_value)
    effect_size.append(np.mean(p7s)-np.mean(p6s))
df_ttest_p6 = pd.DataFrame(data={'sp_mesos':sp_mesos,'pvals':pvals,'effect_size':effect_size})
df_ttest_p6=df_ttest_p6.loc[~df_ttest_p6['pvals'].isna(),:]
print(len(df_ttest_p6))
#df_ttest_p = df_ttest.loc[df_ttest['effect_size'].abs()>1e-2,:]
df_ttest_p6 = df_ttest_p6.sort_values(by='pvals')
df_ttest_p6['qvals']=false_discovery_control(df_ttest_p6['pvals'])
df_ttest_p6.reset_index()
# Out:
# 32
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:579: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6316: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#     index                sp_mesos     pvals   effect_size     qvals
# 0      32  100099-AA-AE-mGAM-mGAM  0.000018  7.415693e-02  0.000568
# 1      14  102438-AA-AF-mGAM-mGAM  0.000266  8.570987e-02  0.003585
# 2      11  102438-AE-AF-mBHI-mGAM  0.000336 -5.480511e-01  0.003585
# 3      31  100099-AA-AE-mGAM-mBHI  0.001112 -4.935552e-01  0.008110
# 4      33  100099-AA-AF-mGAM-mGAM  0.001267  6.730229e-02  0.008110
# 5       0  100146-AA-AE-mGAM-mBHI  0.001869  5.434688e-01  0.009968
# 6       2  100146-AE-AF-mGAM-mBHI  0.002956 -3.004857e-01  0.013515
# 7      39  101294-AA-AF-mGAM-mGAM  0.014889  7.093239e-02  0.059556
# 8      15  102438-AA-AF-mGAM-mBHI  0.049676  6.968437e-02  0.176625
# 9      30  100099-AE-AF-mBHI-mGAM  0.058005  8.561875e-02  0.182232
# 10     10  102438-AE-AF-mBHI-mBHI  0.062642  4.354467e-01  0.182232
# 11     24  101346-AA-AF-mGAM-mGAM  0.099385  2.748174e-02  0.262342
# 12     22  102506-AA-AF-mGAM-mGAM  0.108531  4.238906e-04  0.262342
# 13      1  100146-AA-AF-mGAM-mGAM  0.118950  3.408023e-03  0.262342
# 14     36  100099-AE-AF-mGAM-mGAM  0.122973 -2.824933e-01  0.262342
# 15     23  102506-AA-AF-mGAM-mBHI  0.170574  1.531482e-02  0.341147
# 16      3  101059-AA-AF-mBHI-mBHI  0.184394 -1.637259e-02  0.342190
# 17      6  102478-AA-AF-mGAM-mGAM  0.192482 -2.431436e-03  0.342190
# 18     37  101294-AE-AF-mBHI-mGAM  0.211471 -1.429435e-01  0.356161
# 19     27  100099-AA-AF-mBHI-mBHI  0.253808  2.913044e-02  0.406092
# 20     29  100099-AE-AF-mBHI-mBHI  0.287702  6.473345e-03  0.438404
# 21     12  102438-AA-AE-mGAM-mBHI  0.348795 -1.294476e-01  0.466372
# 22     13  102438-AA-AE-mGAM-mGAM  0.355918  2.502503e-07  0.466372
# 23     20  103656-AA-AE-mGAM-mGAM  0.356355 -1.570314e-01  0.466372
# 24     21  103656-AA-AF-mGAM-mGAM  0.373363  5.748092e-05  0.466372
# 25     19  100196-AA-AF-mGAM-mGAM  0.422460  1.316865e-01  0.466372
# 26     18  100196-AA-AE-mBHI-mGAM  0.422650  5.493896e-05  0.466372
# 27     34  100099-AA-AF-mGAM-mBHI  0.422650  6.535176e-03  0.466372
# 28     38  101294-AA-AE-mGAM-mGAM  0.422650  2.603822e-07  0.466372
# 29     35  100099-AE-AF-mGAM-mBHI  0.457075 -1.078476e-01  0.487546
# 30     17  102438-AE-AF-mGAM-mGAM  0.753467 -8.037440e-02  0.777772
# 31     16  102438-AE-AF-mGAM-mBHI  0.972183 -2.165102e-02  0.972183

# %%
big_df_all['sig']=False
big_df_all['pred7_med']
big_df_all.loc[big_df_all['as_extreme7']>975,'sig']=True
big_df_all.loc[big_df_all['as_extreme7']<25,'sig']=True
big_df_all.loc[((big_df_all['act_7_med'] - big_df_all['pred7_med']).abs() <1e-2),'sig']=False
#big_df_all.loc[big_df_all['act_7_med']>1-1e-2,'sig']=False

big_df_all['p']=big_df_all['as_extreme7']/1e3
big_df_all.loc[big_df_all['p']>.5,'p']=1-big_df_all.loc[big_df_all['p']>.5,'p']
big_df_all['q'] = stats.false_discovery_control(big_df_all['p'], method='bh')
big_df_allg = big_df_all.loc[big_df_all['diff7_med'].abs()>.01,:]
big_df_allg['q'] = stats.false_discovery_control(big_df_allg['q'], method='bh')
big_df_all.loc[((big_df_all['act_7_med'] - big_df_all['pred7_med']).abs() <1e-2),'q']=1.
len(big_df_allg.loc[big_df_allg['q']<.05,:])
# Out:
# 70

# %%
len(big_df_allg)
# Out:
# 70

# %%
big_df_allpol = big_df_all.copy()
big_df_allpol.loc[big_df_allpol['pred7_med']>.5,'act_7_med']= 1 - big_df_allpol.loc[big_df_allpol['pred7_med']>.5,'act_7_med']
big_df_allpol.loc[big_df_allpol['pred7_med']>.5,'pred7_med']= 1 - big_df_allpol.loc[big_df_allpol['pred7_med']>.5,'pred7_med']
p3 = hv.Points(big_df_allpol, kdims = ['pred7_med','act_7_med', ],vdims = [ 'pred7_med','act_7_med',]).opts(size=10,
                                                                                                        height=300,width=300,
                                                                                           line_color='black',alpha=.5,
                                                                                                        color=bokeh.palettes.Set2[3][-1],
                                                                                                       )
p3 = hv.render(p3)
p3.xaxis.major_label_text_font_size='15px'
p3.yaxis.major_label_text_font_size='15px'
p3.output_backend='svg'
export_plot_pdf(p3,'pred_act_all_reps')

# %%
big_df_allpol = big_df_all.copy()
big_df_allpol['early_sel_med']=big_df_allpol['early_sel_med']*1/np.log2(200)
big_df_allpol['late_sel_med']=big_df_allpol['late_sel_med']*1/np.log2(200)
big_df_allpol.loc[big_df_allpol['early_sel_med']<0,'late_sel_med']=  -big_df_allpol.loc[big_df_allpol['early_sel_med']<0,'late_sel_med']
big_df_allpol.loc[big_df_allpol['early_sel_med']<0,'early_sel_med']=  -big_df_allpol.loc[big_df_allpol['early_sel_med']<0,'early_sel_med']
p = hv.Points(big_df_allpol, kdims = ['early_sel_med','late_sel_med', ],vdims = [ 'early_sel_med','late_sel_med',]).opts(size=10,
                                                                                                        height=300,width=300,
                                                                                           line_color='black',alpha=.5,
                                                                                                        color=bokeh.palettes.Set2[3][-1],
                                                                                                       )
p1 = hv.Curve([(i,i) for i in np.linspace(-7,7)]).opts(line_color='grey',xlim=(-.1,1),
                                                         ylim=(-1,1), )
p=hv.render(p*p1)
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p.output_backend='svg'
export_plot_pdf(p,'early_late')
bokeh.io.show(p)
# Out:
#   <div id="a0042d05-b262-4847-b4ef-454ddb26a38d" data-root-id="bdd60519-f80f-4e55-ab18-abf429d398a6" style="display: contents;"></div>
