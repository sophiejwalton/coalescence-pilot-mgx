# %%
import pandas as pd

# %%
fname = 'all_dfs_div.csv'
df = pd.read_csv(fname, delimiter = '\t')
df.head()
# Out:
#   ,sample,species_id,relative_abundance,experiment,sub_experiment,comm,parent_subjects,is_inoculumn,parent_media,media,passage,mesocosm,single-subject,inoculumn,diversity,inoculumn_sample,species,species_name
# 0  0,A3-e003Coalescence-mBHI-inoculumn-redo,10029...
# 1  1,A2-e003Coalescence-mBHI-p7,100296,0.139,e003...
# 2  2,B3-e003Coalescence-mBHI-p5,100296,0.006,e003...
# 3  3,D2-e003Coalescence-mBHI-p5,100296,0.138,e003...
# 4  4,B2-e003Coalescence-mBHI-p3,100296,0.145,e003...

# %%
df = df.reset_index()

# %%
#df = df.set_index('sample')

#df.to_csv('new_csv.tsv', sep = '\t')
