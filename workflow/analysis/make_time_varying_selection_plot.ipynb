# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control
#from bokeh.models import FixedTicker, FuncTickFormatter 
from scipy.stats import chi2

#from bokeh.io import output_notebook

from snp_analysis_tools_sherlock import *
from plot_tools import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a30651be-adab-4813-bc2d-600646231de1'>
#   <div id="c18d1bbb-1dff-451d-bb44-49b84e363ff3" data-root-id="a30651be-adab-4813-bc2d-600646231de1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"daa4767e-a78b-4421-8fd8-bcc422db546f":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a30651be-adab-4813-bc2d-600646231de1"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6715a0e8-ada1-4b89-a5b0-31cca4deafc3","attributes":{"plot_id":"a30651be-adab-4813-bc2d-600646231de1","comm_id":"9c6a76e88aac4a9791ac2445477fb72e","client_comm_id":"5e7af65d66934569b3b36fc15f6176c0"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"daa4767e-a78b-4421-8fd8-bcc422db546f","roots":{"a30651be-adab-4813-bc2d-600646231de1":"c18d1bbb-1dff-451d-bb44-49b84e363ff3"},"root_ids":["a30651be-adab-4813-bc2d-600646231de1"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_metadata  =transform_df(df_metadata)
df_metadata.loc[df_metadata['species_id']==101349,:]
# Out:
#       species_id    representative MGnify_accession  species_closest  \
# 1348      101349  GUT_GENOME096096  MGYG-HGUT-01349         102640.0
#
#       ani_closest  gtpro_kmer_counts  phyeco_marker_counts  phyeco_pass_ratio  \
# 1348      94.0625            55924.0                  15.0                1.0
#
#       pangene_counts  genome_counts  ...     N50  GC_content  Completeness  \
# 1348          100370            789  ...  257597       38.67         100.0
#
#       Contamination                                            Lineage  \
# 1348            0.0  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o...
#
#       Continent                   species           genus              family  \
# 1348        NaN  s__Veillonella parvula_A  g__Veillonella  f__Veillonellaceae
#
#                 phyla
# 1348  p__Firmicutes_C
#
# [1 rows x 23 columns]

# %%
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',

            
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
            
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
            
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',

            
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
            
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
            
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
            
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
            
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',

            
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']

# %%
def get_pred_sel(ts,sel_coeff, start_value,):
    pred=np.exp(ts*sel_coeff)
    pred = pred*start_value/(1 - start_value + start_value*pred)
    return pred

# %%
def get_preds_for_plotting(species, inoculumn,good_meso, t0,t1):
    sel_stuff, df_both_meta_good = get_selection_stuff_both(species,inoculumn)
    print(np.max(df_both_meta_good['actual_med1']-df_both_meta_good['boot_med1']))
    sel_stuff_t0t1 = sel_stuff.loc[(sel_stuff['passage1']==t0)*(sel_stuff['passage2']==t1),:]

    df_both_meta_good_meso= df_both_meta_good.loc[(df_both_meta_good['type_mesocosm'] == good_meso)+(df_both_meta_good['is_inoculumn']),:]
    sel_stuff_meso=sel_stuff_t0t1.loc[sel_stuff_t0t1['type_mesocosm']==good_meso,:]
    sel_stuff_meso=sel_stuff_meso.set_index('sample2')
        
    df_both_meta_good_meso=df_both_meta_good_meso.set_index('sample')
    sel_stuff_meso['start_value']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
        
    sel_stuff_meso=sel_stuff_meso.reset_index()
    sel_stuff_meso=sel_stuff_meso.set_index('sample1')
    sel_stuff_meso['start_value1']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
        
    sel_stuff_meso=sel_stuff_meso.reset_index()
    df_both_meta_good_meso=df_both_meta_good_meso.reset_index()
    sel_stuff_meso_meds = sel_stuff_meso.groupby(['passage1','passage2','type_mesocosm']).median(numeric_only=True).reset_index()
      
    sel_coeff = sel_stuff_meso_meds.loc[(sel_stuff_meso_meds['passage1']==t0)*(sel_stuff_meso_meds['passage2']==t1),'sel_med']
    start_value = df_both_meta_good_meso.loc[df_both_meta_good_meso['passage']==t1,'boot_med1'].median()
    
       
    sel_coeffs = sel_stuff_meso.loc[(sel_stuff_meso['passage1']==t0)*(sel_stuff_meso['passage2']==t1),'sel_med'].values
    if len(sel_coeffs)==0:
        return [],[],[],[]
    b=sel_stuff_meso.loc[(sel_stuff_meso['passage1']==t0)*(sel_stuff_meso['passage2']==t1),'sample2'].values
    start_values=sel_stuff_meso.loc[(sel_stuff_meso['passage1']==t0)*(sel_stuff_meso['passage2']==t1),'start_value'].values
    ts=np.arange(9)
    print(start_values)
    pred_values = get_pred_sel(ts-t1,sel_coeff.values[0], start_value)
    pred_values_logit = np.log(pred_values/(1-pred_values))
    pred_values_t7=get_pred_sel(7-t1,sel_coeffs, start_values,)
    argmax_7 =np.argmax(pred_values_t7) 
    argmin_7 =np.argmin(pred_values_t7) 

    ts=np.arange(9)
    pred_valuesmax = get_pred_sel(ts-t1,sel_coeffs[argmax_7], start_values[argmax_7],)
    pred_values_logitmax = np.log(pred_valuesmax/(1-pred_valuesmax))

    pred_valuesmin = get_pred_sel(ts-t1,sel_coeffs[argmin_7], start_values[argmin_7],)
    pred_values_logitmin = np.log(pred_valuesmin/(1-pred_valuesmin))
    print('potatoes',sel_stuff_meso.loc[(sel_stuff_meso['passage1']==t0)*(sel_stuff_meso['passage2']==t1),'start_value1'].values)
    return ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax

# %%
import os
inos=['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]

#inos = ['AA-AF-mGAM']
1#inos = ['AE-AF-mBHI']
species = [102438,100196, 100099, 100146, 101346, 102506, 102478]
species = [102438,100196, 100099, 100146, 101346, 102506, 102478,102358,101294]
species = [102438]
species = ['100146', '101059', '100910', '102478', '102438', '100196',
       '103117', '103656', '102544', '102506', '101346', '100099',
       '101400', '101294']

species
t0=1
t1=2
inos = ['AE-AF-mGAM','AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
species = [102478]
for sp in species:
    plots_all=[]
    for ino in inos:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{sp}/{ino}_parent1_info.csv'
        if f'{sp}-{ino}' in bad_inos:
            continue
        if not os.path.isfile(fname):
            print('oo')
            continue
        psstrain,type_mesos = make_logit_plot(sp, ino,
                                       colorby='const',logit=True,
                                        )
      #  print(psstrain)
        for i in range(len(psstrain)):
            p1 = psstrain[i]
            meso = type_mesos[i]
            med1=meso.split('-')[-2]
            med2 = meso.split('-')[-1]
            ino1 = f'{sp}-{med1}-{med2}'
            p1.legend.visible=False
            ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax = get_preds_for_plotting(sp,ino,meso, t0,t1)
            if len(pred_values_logit)>0:
                p1.line(ts,pred_values_logit,color='grey')
                p1.line(ts,pred_values_logitmin,color='grey',line_dash='dashed')
                p1.line(ts,pred_values_logitmax,color='grey',line_dash='dashed')
                p1.yaxis.axis_label_text_font_style = 'normal'
                p1.xaxis.axis_label_text_font_style = 'normal'
                bokeh.io.show(p1)
                p1.output_backend='svg'
                export_plot_pdf(p1,f'time_varying_plot_{sp}_{ino}-{med2}-{t0}_{t1}')
# Out:
# bef 0.004079085214987788
# aft 0.0031705958966372627
# bef 0.004079085214987788
# aft 0.0031705958966372627
# 0.0031705958966372627
# [0.001]
# potatoes [0.04214291]
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
#   <div id="ef90fd12-9f62-4006-9355-40fea4118ca4" data-root-id="9dd1854b-9092-42cf-a155-e3e7ea5cd5f8" style="display: contents;"></div>
# bef 0.004079085214987788
# aft 0.0031705958966372627
# 0.0031705958966372627
# bef 2.3168310577803553e-06
# aft 0.0009150683625287481
# bef 2.3168310577803553e-06
# aft 0.0009150683625287481
# 0.0009150683625287481
# [0.77160494 0.76753927]
# potatoes [0.68267223 0.65240084]
#   <div id="ce3aa874-9f51-4b47-bdd5-ff55156f4e54" data-root-id="8397ab5e-3e90-4155-b9a4-b5da38787ea1" style="display: contents;"></div>
# bef 2.3168310577803553e-06
# aft 0.0009150683625287481
# 0.0009150683625287481
# [0.98669688 0.9880251  0.99854653 0.99673592]
# potatoes [0.87270876 0.83706721 0.85395538 0.82790224]
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_60042/3481213613.py:40: RuntimeWarning: divide by zero encountered in divide
#   pred_values_logitmax = np.log(pred_valuesmax/(1-pred_valuesmax))
#   <div id="d1145694-885e-4411-accd-a6c3432ea96d" data-root-id="0b06cbf0-8b0c-4a26-aa89-25ed2d571797" style="display: contents;"></div>
# bef 2.6385900458225642e-05
# aft 0.0010000000000000009
# bef 2.6385900458225642e-05
# aft 0.0010000000000000009
# 0.0010000000000000009
# [0.999 0.999]
# potatoes [0.96903404 0.9489023 ]
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
#   <div id="d9083284-0525-406e-a8dd-183f3d1f0f75" data-root-id="7e462d8f-99fc-4417-b3c1-5cb90303f26e" style="display: contents;"></div>
# bef 2.6385900458225642e-05
# aft 0.0010000000000000009
# 0.0010000000000000009
# [0.98768655 0.99107825 0.999      0.999     ]
# potatoes [0.98918706 0.99060882 0.999      0.98905295]
#   <div id="a38155c5-c73c-4f92-ad0b-e2bd2fb5fac7" data-root-id="ec380734-93f3-4830-96ea-53732ae0ff46" style="display: contents;"></div>
# oo

# %%
def get_big_df_time_varying_sel(sp,ino,t0,t1,thresh=1e-3):
    sel_stuff, df_both_meta_good = get_selection_stuff_both(sp,ino)
    sel_stuff_t0t1 = sel_stuff.loc[(sel_stuff['passage1']==t0)*(sel_stuff['passage2']==t1),:]
    sel_stuff_67 = sel_stuff.loc[(sel_stuff['passage1']==6)*(sel_stuff['passage2']==7),:]
    dfs = []
    for good_meso in sel_stuff['type_mesocosm'].unique():
        df_both_meta_good_meso= df_both_meta_good.loc[(df_both_meta_good['type_mesocosm'] == good_meso)+(df_both_meta_good['is_inoculumn']),:]
        sel_stuff_meso=sel_stuff_t0t1.loc[sel_stuff_t0t1['type_mesocosm']==good_meso,:]
        sel_stuff_meso67=sel_stuff_67.loc[sel_stuff_67['type_mesocosm']==good_meso,:]
        sel_stuff_meso=sel_stuff_meso.set_index('sample2')
                    
        df_both_meta_good_meso=df_both_meta_good_meso.set_index('sample')
        sel_stuff_meso['start_value']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
            
        sel_stuff_meso=sel_stuff_meso.reset_index()
        sel_stuff_meso=sel_stuff_meso.set_index('sample1')
        sel_stuff_meso['start_value1']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
        sel_stuff_meso=sel_stuff_meso.reset_index()
        sel_stuff_meso = sel_stuff_meso.set_index('mesocosm')
        df_both_meta_good_meso=df_both_meta_good_meso.reset_index()
        sel_stuff_meso['actual_p7']= np.nan
        #sel_stuff_meso['actual_p6']= np.nan
        if len(sel_stuff_meso)==0:
            continue 
        p7_df = df_both_meta_good_meso.loc[(df_both_meta_good_meso['passage']==7)*(df_both_meta_good_meso['type_mesocosm']==good_meso),:].set_index('mesocosm')
        p6_df = df_both_meta_good_meso.loc[(df_both_meta_good_meso['passage']==6)*(df_both_meta_good_meso['type_mesocosm']==good_meso),:].set_index('mesocosm')
        p7_mesos = np.intersect1d(sel_stuff_meso.index.values,p7_df.index.values)
        sel_stuff_meso67 = sel_stuff_meso67.set_index('mesocosm')
        p67_mesos = np.intersect1d(sel_stuff_meso.index.values,sel_stuff_meso67.index.values)
        
        #print(sel_stuff_meso.index.values, p7_df.index.values)
        sel_stuff_meso.loc[p7_mesos,'actual_p7']= p7_df.loc[p7_mesos,'boot_med1']
        sel_stuff_meso.loc[p67_mesos,'actual_p6']= p6_df.loc[p67_mesos,'boot_med1']
        sel_stuff_meso.loc[p67_mesos,'sel_med67']= sel_stuff_meso67.loc[p67_mesos,'sel_med']
        sel_stuff_meso['p7_preds'] = get_pred_sel(7-t1,sel_stuff_meso['sel_med'].values, sel_stuff_meso['start_value'].values)
        sel_stuff_meso.loc[sel_stuff_meso['actual_p6']<=thresh,'sel_med67']=sel_stuff_meso.loc[sel_stuff_meso['actual_p6']<=thresh,'sel_med']
        sel_stuff_meso.loc[sel_stuff_meso['actual_p6']>=1-thresh,'sel_med67']=sel_stuff_meso.loc[sel_stuff_meso['actual_p6']>=1-thresh,'sel_med']
        
        sel_stuff_meso_meds = sel_stuff_meso.groupby(['passage1','passage2','type_mesocosm']).median(numeric_only=True).reset_index().set_index('type_mesocosm')
        sel_stuff_meso_maxs = sel_stuff_meso.groupby(['passage1','passage2','type_mesocosm']).max(numeric_only=True).reset_index().set_index('type_mesocosm')
        sel_stuff_meso_mins = sel_stuff_meso.groupby(['passage1','passage2','type_mesocosm']).min(numeric_only=True).reset_index().set_index('type_mesocosm')

        for column in ['sel_med','actual_p7','p7_preds','sel_med67']:
            sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'max_{column}']=sel_stuff_meso_maxs.loc[sel_stuff_meso_meds.index.values,column]
            sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'min_{column}']=sel_stuff_meso_mins.loc[sel_stuff_meso_meds.index.values,column]
        dfs.append(sel_stuff_meso_meds.reset_index())
    if len(dfs)>0:
        dfs = pd.concat(dfs,axis=0)
    return dfs

# %%
all_dfs=[]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
t0 = 1
t1 = 2
big_df = []
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']
for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
        if f'{sp}-{ino}' in bad_inos:
            continue 
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parent1_info.csv'
        if os.path.exists(fname):
            df = get_big_df_time_varying_sel(sp,ino,t0,t1)
            
            if len(df)>0:
                df['species_id']=sp
                big_df.append(df.reset_index())
            
big_df=pd.concat(big_df).reset_index()
len(big_df['species_id'].unique())
# Out:
# bef 2.1230881120299673e-05
# aft 0.0005148071271501575
# bef 4.0520465009900863e-05
# aft 3.921278033218803e-05
# bef 3.949788255350195e-05
# aft 3.916260597480736e-05
# bef 0.0010000000000000009
# aft 0.00043862110135040044
# bef 0.000500000000000056
# aft 0.0009676147336278307
# bef 2.6385900458225642e-05
# aft 0.0010000000000000009
# bef 2.3168310577803553e-06
# aft 0.0009150683625287481
# bef 0.004079085214987788
# aft 0.0031705958966372627
# bef 1.0078317107999751e-05
# aft 0.0005335592136541667
# bef 1.3182700219699535e-05
# aft 1.3176484522235861e-05
# bef 0.0
# aft 0.0
# bef 3.99948983332999e-05
# aft 3.966525558079647e-05
# bef 5.7049588119501005e-05
# aft 5.5845353300838785e-05
# bef 0.0004999999999999449
# aft 0.00017416409081638662
# bef 9.39850140299972e-06
# aft 1.0235870412296857e-05
# bef 2.960856708699843e-06
# aft 3.2200760903843863e-06
# bef 4.857059140489983e-05
# aft 4.857558066910343e-05
# bef 0.0010000000000000009
# aft 0.0006062628169656303
# bef 0.0040000000000000036
# aft 0.0018342332368019854
# bef 0.0010000000000000009
# aft 0.0004770204568388392
# bef 0.0009999999999998899
# aft 0.0002871689969877189
# bef 0.0001417645705389381
# aft 0.05519592513818983
# bef 0.0
# aft 0.0
# bef 0.00016516112037401331
# aft 0.0010000000000000009
# bef 6.524384766299924e-06
# aft 6.497288751239772e-06
# bef 0.0
# aft 0.0
# bef 0.0004999999999998894
# aft 0.00041578819385981736
# bef 0.000999999999999994
# aft 0.0009756807921945526
# bef 1.2598003517000009e-05
# aft 0.00018802773641080073
# bef 0.0
# aft 0.0
# bef 0.0005000000000000004
# aft 0.0003404808071650889
# bef 7.29043999758705e-06
# aft 0.00042215107159060405
# bef 1.4185147629630634e-05
# aft 0.0010000000000000009
# bef 0.00020827828465730391
# aft 0.001471995289615169
# bef 0.0001461214130698968
# aft 0.00014612629388511406
# bef 0.00011119639709100682
# aft 0.007565085771947588
# bef 6.901105772039173e-05
# aft 0.00042895672082698955
# 14

# %%
def make_big_plot(meds,logit_scale=False,sel_range = (-.5,.5),line=True,width=400):
    if logit_scale:
        meds = meds.copy()
        for freq_column in ['actual_p7', 'min_actual_p7',  'max_actual_p7', 'min_p7_preds','max_p7_preds','p7_preds']:
            meds[freq_column]=np.log(meds[freq_column]/(1-meds[freq_column]))
    scatter = hv.Scatter(meds, kdims =  'p7_preds', vdims=['actual_p7',hv.Dimension('sel_med',range=sel_range)]).opts(#size=4, 
                                                                                        alpha = 1.0, color = 'sel_med',#height=700,
                                                                                           width = width,line_color='black',
                                                                                                      
                                                                                      cmap = 'Magma',
                                                                                                            colorbar=True, 
                                                                                                  # logx=True, logy=True,
                                                                                                    legend_position='right',
                                                                                                        size=10,
                                                                                         )
    seg = hv.Segments(meds, ['p7_preds', 
                             'min_actual_p7', 
                             'p7_preds', 'max_actual_p7', ]).opts(color='black',alpha=.2)
    
    seg2 = hv.Segments(meds, ['min_p7_preds', 
                             'actual_p7', 
                             'max_p7_preds', 'actual_p7', ]).opts(color='black',alpha=.2)

    exps_adjust = np.array([.001,.01,.1,.5,.9,.99,.999])
    lins_adjust = np.log(exps_adjust/(1-exps_adjust))
    #exps_adjust = exps_adjust[::2]
   # lins_adjust = lins_adjust[::2]
    if logit_scale:
        scatter.opts(xticks=[(lins_adjust[i], exps_adjust[i]) for i in range(len(lins_adjust))],
                 yticks=[(lins_adjust[i], exps_adjust[i]) for i in range(len(lins_adjust))]
                )
    
    ticks = np.linspace(sel_range[0],sel_range[1],6)
    labels = [str(tick) for tick in ticks]
   # if sel_range[0]!=0:
    labels[0] = '<' + labels[0]
   # if sel_range[-1]!= 0:
    labels[-1] = '>' + labels[-1]

    #labels[-1] = '>' + labels[-1]
    print(labels)
  #  labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    
    # Apply colorbar customization
    scatter.opts(
        colorbar=True,
        colorbar_opts={
            'major_label_overrides': dict(zip(ticks, labels))
        }
    )

    scatter = hv.render(scatter*seg*seg2)
    if line:
        if logit_scale:
            scatter.line(np.linspace(-8,8), np.linspace(-8,8),color = 'black', )
        else:
            scatter.line(np.linspace(1e-20,1), np.linspace(1e-20,1),color = 'black', )
        
    scatter.legend.visible = True
    scatter.xaxis.axis_label = 'Predicted final frequency'
    scatter.yaxis.axis_label = 'Actual final frequency'
    #bokeh.io.show(scatter)
    return scatter,meds

# %%
def polarize(df):
    to_polarize = df.loc[df['p7_preds']>.5,:].index.values
    for freq_column in ['actual_p7', 'min_actual_p7',  'max_actual_p7', 'min_p7_preds','max_p7_preds',]:
        df.loc[to_polarize,freq_column]= 1- df.loc[to_polarize,freq_column]
    for sel_column in ['sel_med','max_sel_med','min_sel_med']:
        df.loc[to_polarize,sel_column]= - df.loc[to_polarize,sel_column]
    df.loc[to_polarize,'p7_preds']=1-df.loc[to_polarize,'p7_preds']
    return df


def adjust(df,thresh=1e-3):
   # to_polarize = df.loc[df['pred_p7s']>.5,:].index.values
    for freq_column in ['actual_p7', 'min_actual_p7',  'max_actual_p7', 'min_p7_preds','max_p7_preds','p7_preds']:
        df.loc[df[freq_column]>1-thresh,freq_column]= 1-thresh
        df.loc[df[freq_column]<thresh,freq_column]= thresh
    return df

# %%
pol = polarize(big_df)
pol = adjust(pol)

# %%
pol
# Out:
#     level_0  index    type_mesocosm  passage1  passage2  Unnamed: 0   sel_med  \
# 0         0      0  AA-AE-mGAM-mBHI         1         2        69.5 -2.746930
# 1         0      0  AA-AF-mGAM-mBHI         1         2        15.5 -1.961390
# 2         1      0  AA-AF-mGAM-mGAM         1         2        87.0 -7.089452
# 3         0      0  AE-AF-mGAM-mBHI         1         2        55.0 -1.375865
# 4         1      0  AE-AF-mGAM-mGAM         1         2       127.5 -0.188013
# 5         0      0  AA-AF-mBHI-mBHI         1         2        61.0 -0.512538
# 6         1      0  AA-AF-mBHI-mGAM         1         2        75.0 -0.635340
# 7         0      0  AA-AE-mBHI-mBHI         1         2        34.0 -2.013125
# 8         1      0  AA-AE-mBHI-mGAM         1         2        53.0 -0.000000
# 9         0      0  AA-AE-mGAM-mGAM         1         2       112.5 -0.000397
# 10        1      0  AA-AE-mGAM-mBHI         1         2        48.5 -1.048679
# 11        0      0  AA-AF-mGAM-mBHI         1         2        15.5 -0.501630
# 12        1      0  AA-AF-mGAM-mGAM         1         2        80.0 -4.938606
# 13        0      0  AE-AF-mGAM-mBHI         1         2        20.0 -1.058283
# 14        0      0  AA-AE-mBHI-mGAM         1         2        37.0 -1.399336
# 15        0      0  AA-AF-mBHI-mBHI         1         2        20.0 -3.542367
# 16        1      0  AA-AF-mBHI-mGAM         1         2        49.0 -1.944138
# 17        0      0  AE-AF-mBHI-mBHI         1         2        16.5 -1.185115
# 18        1      0  AE-AF-mBHI-mGAM         1         2        84.0 -0.926992
# 19        0      0  AA-AE-mGAM-mBHI         1         2        63.0 -0.291780
# 20        1      0  AA-AE-mGAM-mGAM         1         2       126.0 -1.764566
# 21        0      0  AA-AF-mGAM-mBHI         1         2        59.5 -3.067743
# 22        1      0  AA-AF-mGAM-mGAM         1         2       101.5 -2.418944
# 23        0      0  AE-AF-mGAM-mBHI         1         2        34.5 -0.383392
# 24        1      0  AE-AF-mGAM-mGAM         1         2       105.0 -0.024805
# 25        0      0  AA-AE-mBHI-mGAM         1         2        85.5 -0.026324
# 26        0      0  AA-AF-mGAM-mBHI         1         2        26.0 -1.806662
# 27        1      0  AA-AF-mGAM-mGAM         1         2       148.0 -3.843851
# 28        0      0  AA-AF-mGAM-mGAM         1         2        14.5 -0.431469
# 29        0      0  AA-AE-mGAM-mGAM         1         2        31.5 -4.375783
# 30        0      0  AA-AF-mGAM-mGAM         1         2        49.0 -7.106196
# 31        0      0  AE-AF-mGAM-mGAM         1         2        10.0 -4.380546
# 32        0      0  AA-AE-mBHI-mBHI         1         2        10.5 -0.239294
# 33        1      0  AA-AE-mBHI-mGAM         1         2        14.0 -0.197904
# 34        0      0  AA-AF-mGAM-mBHI         1         2        62.5 -0.797489
# 35        1      0  AA-AF-mGAM-mGAM         1         2       109.5 -1.365813
# 36        0      0  AA-AF-mGAM-mGAM         1         2        66.0 -2.702631
# 37        0      0  AA-AE-mBHI-mBHI         1         2        34.0 -2.344291
# 38        1      0  AA-AE-mBHI-mGAM         1         2       101.5 -3.816357
# 39        0      0  AA-AF-mBHI-mBHI         1         2        46.5 -0.783604
# 40        1      0  AA-AF-mBHI-mGAM         1         2        55.0 -2.605771
# 41        0      0  AE-AF-mBHI-mBHI         1         2        73.5 -1.776055
# 42        1      0  AE-AF-mBHI-mGAM         1         2       126.0 -1.571024
# 43        0      0  AA-AE-mGAM-mBHI         1         2        77.0 -0.879592
# 44        1      0  AA-AE-mGAM-mGAM         1         2       161.0 -1.085406
# 45        0      0  AA-AF-mGAM-mBHI         1         2        62.5 -4.843934
# 46        1      0  AA-AF-mGAM-mGAM         1         2       109.5 -2.175138
# 47        0      0  AE-AF-mGAM-mBHI         1         2        62.0 -2.526545
# 48        1      0  AE-AF-mGAM-mGAM         1         2       126.0 -1.066818
# 49        0      0  AA-AF-mBHI-mGAM         1         2        10.0 -0.265173
# 50        0      0  AE-AF-mBHI-mGAM         1         2        43.0 -0.646561
# 51        0      0  AA-AE-mGAM-mGAM         1         2        42.0 -2.886873
# 52        0      0  AA-AF-mGAM-mBHI         1         2         4.0 -0.876770
# 53        1      0  AA-AF-mGAM-mGAM         1         2        62.0 -0.944966
# 54        0      0  AE-AF-mGAM-mBHI         1         2        49.0 -1.895367
# 55        1      0  AE-AF-mGAM-mGAM         1         2        80.0 -0.380808
#
#     sel_lower  sel_upper      sel_med1  ...  p7_preds  max_sel_med  \
# 0   -2.772182  -2.722036 -2.707201e+00  ...  0.001000    -1.755387
# 1   -2.028102  -1.912622 -1.932799e+00  ...  0.001000    -1.408786
# 2   -7.108670  -7.071581 -7.038947e+00  ...  0.001000    -6.493607
# 3    1.302615   1.428355  1.257754e+00  ...  0.001198    -4.071997
# 4   -0.227433  -0.158151 -1.855210e-01  ...  0.043615    -0.051626
# 5    0.501797   0.522735  4.575145e-01  ...  0.007590    -0.833420
# 6   -0.674718  -0.626980 -6.032517e-01  ...  0.200217    -0.376686
# 7    1.995485   2.034438  1.960613e+00  ...  0.001000    -2.186609
# 8   -0.120233   0.104360 -2.220446e-16  ...  0.112576    -0.000000
# 9    0.000000   0.004514  3.825066e-02  ...  0.004943    -0.077988
# 10   0.032452   1.390362  1.623317e+00  ...  0.001000    -1.518255
# 11   0.457615   0.528329  4.805076e-01  ...  0.024739    -0.562127
# 12   4.802849   5.065335  5.305184e+00  ...  0.001000    -5.335922
# 13  -1.221683  -0.845431 -1.045304e+00  ...  0.001000    -1.058283
# 14  -3.368906  -1.284321 -1.401211e+00  ...  0.001000    -1.050367
# 15  -3.634956  -1.832581 -3.498551e+00  ...  0.001000    -1.366175
# 16  -1.991206  -1.943122 -1.927454e+00  ...  0.001000    -1.926971
# 17  -1.221409  -1.122043 -1.137179e+00  ...  0.010119    -0.682516
# 18   0.914743   0.940578  8.936707e-01  ...  0.004274    -1.110192
# 19  -0.342898  -0.225650 -2.856432e-01  ...  0.022812     0.340253
# 20  -1.765082  -1.723899 -1.760401e+00  ...  0.001000    -1.201105
# 21  -3.140086  -3.002900 -3.005202e+00  ...  0.001000    -2.094449
# 22  -2.443939  -2.391271 -2.361739e+00  ...  0.001000    -2.233255
# 23  -0.441706  -0.366739 -3.663570e-01  ...  0.498630     0.460953
# 24  -0.012022   0.066220  8.446211e-02  ...  0.059232    -0.607051
# 25  -0.028887  -0.025295  0.000000e+00  ...  0.001000     0.006322
# 26  -1.824086  -1.800525 -1.764346e+00  ...  0.001000    -1.806662
# 27  -3.862400  -3.821972 -3.778236e+00  ...  0.001000    -2.502992
# 28   0.411448   0.452042  4.049601e-01  ...  0.185725    -0.780798
# 29   4.274892   4.484179  4.362752e+00  ...  0.001000    -4.511332
# 30  -7.111716  -7.098789 -7.075152e+00  ...  0.001000    -6.212107
# 31  -4.402079  -4.331177 -4.366114e+00  ...  0.001000    -3.697908
# 32  -0.301340  -0.145536 -2.029966e-01  ...  0.341583    -0.156320
# 33   0.124080   0.266382  2.859323e-01  ...  0.250700    -0.197904
# 34  -0.825451  -0.782833 -7.869388e-01  ...  0.001488    -0.718383
# 35  -1.392820  -1.349221 -1.346000e+00  ...  0.001000    -1.132171
# 36  -2.717054  -2.687902 -2.478988e+00  ...  0.001000    -2.655888
# 37  -2.384409  -2.308165 -2.304645e+00  ...  0.001000    -1.637394
# 38  -3.851563  -3.752689 -3.793931e+00  ...  0.001000    -1.908134
# 39  -0.856219  -0.733799 -7.850259e-01  ...  0.001000    -0.529952
# 40  -2.857111  -2.458419 -2.612925e+00  ...  0.001000    -1.897163
# 41  -1.820082  -1.752113 -1.708451e+00  ...  0.001000    -1.377791
# 42  -1.605399  -1.560532 -1.525055e+00  ...  0.001000    -0.833341
# 43   0.873814   0.899076  8.711656e-01  ...  0.067425    -1.101899
# 44  -1.109304  -1.072848 -1.076965e+00  ...  0.001000    -0.802742
# 45  -4.847289  -4.834913 -4.829720e+00  ...  0.001000    -3.902144
# 46  -2.193664  -2.162645 -2.148917e+00  ...  0.001000    -2.076909
# 47  -2.537796  -2.514862 -2.479128e+00  ...  0.001000    -0.228213
# 48   1.049241   1.079890  1.040788e+00  ...  0.001000    -1.075956
# 49  -0.426469   0.882031  0.000000e+00  ...  0.001610    -0.265173
# 50  -0.695427  -0.580080 -6.155848e-01  ...  0.052021    -0.156153
# 51  -3.048337  -2.715869 -2.858100e+00  ...  0.001000    -2.771488
# 52   0.747392   0.917148  8.485840e-01  ...  0.003197    -0.876770
# 53  -0.989563  -0.842248 -9.470092e-01  ...  0.002088    -0.259282
# 54   1.876915   1.949934  1.809926e+00  ...  0.001000    -1.895367
# 55   0.349034   0.412422  3.290376e-01  ...  0.096796    -0.421596
#
#     min_sel_med  max_actual_p7  min_actual_p7  max_p7_preds  min_p7_preds  \
# 0     -5.593056       0.795501       0.298174      0.001000      0.001000
# 1     -2.513994       0.001727       0.001727      0.001000      0.001000
# 2     -7.553811       0.006600       0.001000      0.001000      0.001000
# 3     -1.053558       0.228395       0.386503      0.001000      0.007917
# 4     -0.324401            NaN            NaN      0.069342      0.017888
# 5     -0.241592       0.003006       0.042339      0.001000      0.029800
# 6     -0.775572       0.991984       0.991984      0.484282      0.084758
# 7     -1.959864       0.041577       0.071573      0.001000      0.001000
# 8     -0.000000       0.999000       0.999000      0.112576      0.112576
# 9     -0.000000       0.001000       0.014734      0.001000      0.012313
# 10    -0.579104       0.001000       0.001000      0.001000      0.001000
# 11    -0.441134       0.228395       0.228395      0.017896      0.031582
# 12    -4.430048       0.001000       0.008016      0.001000      0.001000
# 13    -1.058283       0.001000       0.001000      0.001000      0.001000
# 14    -3.536329       0.001000       0.001000      0.001000      0.001000
# 15    -4.008700       0.006630       0.002575      0.001000      0.001000
# 16    -2.413089       0.001300       0.001300      0.001000      0.001000
# 17    -1.687713       0.560901       0.333000      0.020182      0.001000
# 18    -0.104980       0.497710       0.710010      0.001090      0.242349
# 19    -0.295632       0.015235       0.005225      0.376633      0.010996
# 20    -3.400887       0.001000       0.001000      0.001000      0.001000
# 21    -4.133803       0.086912       0.054601      0.001000      0.001000
# 22    -3.006193       0.113035       0.058645      0.001000      0.001000
# 23    -1.227737       0.718266       0.235052      0.992923      0.004337
# 24     0.332061       0.004548       0.642343      0.002168      0.375156
# 25    -0.043997       0.001000       0.001000      0.001032      0.001000
# 26    -1.806662            NaN            NaN      0.001000      0.001000
# 27    -4.853288       0.264092       0.001000      0.001000      0.001000
# 28    -0.082139            NaN            NaN      0.008707      0.362743
# 29    -4.240233       0.026043       0.290061      0.001000      0.001000
# 30    -7.350441       0.001169       0.001000      0.001000      0.001000
# 31    -7.420687       0.003652       0.003652      0.001000      0.001000
# 32    -0.322268            NaN            NaN      0.451946      0.231219
# 33    -0.197904            NaN            NaN      0.250700      0.250700
# 34    -1.100175       0.023614       0.003658      0.002263      0.001000
# 35    -1.882866       0.001820       0.001000      0.001000      0.001000
# 36    -3.015781       0.054027       0.013145      0.001000      0.001000
# 37    -3.246750       0.002442       0.001000      0.001000      0.001000
# 38    -5.321955       0.001000       0.001000      0.001000      0.001000
# 39    -1.211222       0.048913       0.011934      0.004694      0.001000
# 40    -4.203015       0.001242       0.001242      0.001000      0.001000
# 41    -3.039111       0.024072       0.001097      0.001000      0.001000
# 42    -1.698723       0.168517       0.018018      0.003577      0.001000
# 43    -0.604356       0.367617       0.670072      0.014133      0.208548
# 44    -1.359571       0.093023       0.066599      0.001370      0.001000
# 45    -5.478174       0.014070       0.001000      0.001000      0.001000
# 46    -2.960563       0.093939       0.046324      0.001000      0.001000
# 47    -2.560599       0.052261       0.003078      0.391134      0.001000
# 48    -0.915434       0.101112       0.570256      0.001000      0.001000
# 49    -0.265173            NaN            NaN      0.001610      0.001610
# 50    -0.694841       0.010391       0.001000      0.462283      0.036717
# 51    -3.002258       0.001000       0.001000      0.001000      0.001000
# 52    -0.876770            NaN            NaN      0.003197      0.003197
# 53    -1.291545       0.135853       0.053427      0.044440      0.001000
# 54    -1.895367       0.002791       0.002791      0.001000      0.001000
# 55    -0.288434       0.181726       0.181726      0.076798      0.135946
#
#     max_sel_med67  min_sel_med67  species_id
# 0        0.755413      -0.352053      100146
# 1             NaN            NaN      100146
# 2        0.000000      -7.553811      100146
# 3        0.239567      -0.348826      100146
# 4             NaN            NaN      100146
# 5        1.211033      -3.787962      101059
# 6        0.118794       0.118794      101059
# 7       -0.936769      -0.936769      100910
# 8             NaN            NaN      100910
# 9        0.077988       0.000000      102478
# 10       1.518255       0.579104      102478
# 11            NaN            NaN      102478
# 12       5.335922      -2.088491      102478
# 13      -1.058283      -1.058283      102478
# 14       0.000000       0.000000      102438
# 15      -2.496410      -2.496410      102438
# 16      -2.413089      -2.413089      102438
# 17       0.047130      -0.315977      102438
# 18       0.724751      -1.038364      102438
# 19       0.819153       0.000000      102438
# 20      -1.712931      -3.400887      102438
# 21      -0.144588      -0.242572      102438
# 22       0.963489      -0.111289      102438
# 23       0.939061      -0.218062      102438
# 24       2.969911       0.186311      102438
# 25       0.000000      -0.016581      100196
# 26            NaN            NaN      100196
# 27       1.591935      -0.028080      100196
# 28            NaN            NaN      103117
# 29       2.907465       0.895089      103656
# 30       0.000000      -7.350441      103656
# 31            NaN            NaN      103656
# 32            NaN            NaN      102544
# 33            NaN            NaN      102544
# 34       0.977450       0.254346      102506
# 35       0.000000      -2.101710      102506
# 36       0.564984      -1.630689      101346
# 37       0.000000       0.000000      100099
# 38       0.000000      -5.321955      100099
# 39       2.795813      -2.041976      100099
# 40      -1.897163      -1.897163      100099
# 41       3.204425       0.000000      100099
# 42       2.796443      -0.378781      100099
# 43       0.693175      -0.385311      100099
# 44       0.388224      -0.902868      100099
# 45      -5.370810      -5.478174      100099
# 46       0.464417      -0.813122      100099
# 47       0.836810      -1.946918      100099
# 48       0.917850       0.041843      100099
# 49            NaN            NaN      101400
# 50      -0.121603      -2.367009      101294
# 51       0.000000      -3.002258      101294
# 52            NaN            NaN      101294
# 53       0.041144      -0.424430      101294
# 54       0.000000       0.000000      101294
# 55      -0.059442      -0.059442      101294
#
# [56 rows x 30 columns]

# %%
p,_ = make_big_plot(pol,sel_range = (-.5,0))

p.x_range = bokeh.models.Range1d(-.02,.5)
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,'time_varying_01_freq')
# Out:
# ['<-0.5', '-0.4', '-0.3', '-0.19999999999999996', '-0.09999999999999998', '>0.0']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_60042/2460616001.py:59: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   scatter.legend.visible = True
#   <div id="cd68b2c0-b977-48f3-ae78-1c2e23de4883" data-root-id="c49a536b-7e96-486f-b089-a6274cd72e43" style="display: contents;"></div>

# %%
p,_ = make_big_plot(pol.loc[pol['p7_preds']<1e-1,:],sel_range = (-4.0,0),width=400,logit_scale=True)
p.x_range = bokeh.models.Range1d(-8.,-4)
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,'time_varying_01_freq_inset')
# Out:
# ['<-4.0', '-3.2', '-2.4', '-1.5999999999999996', '-0.7999999999999998', '>0.0']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_60042/2460616001.py:59: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   scatter.legend.visible = True
#   <div id="e9adacb8-db3c-4451-bfe3-3dbae8331bdd" data-root-id="5541a6a3-1d89-4263-9ce7-2496f94df310" style="display: contents;"></div>

# %%
def make_big_plot_sel(meds,line=True,width=400):
    scatter = hv.Scatter(meds, kdims =  'sel_med', vdims=['sel_med67',hv.Dimension('actual_p7',range=(0,1))]).opts(#size=4, 
                                                                                        alpha = 1.0, color = 'actual_p7',#height=700,
                                                                                           width = width,line_color='black',
                                                                                                      
                                                                                      cmap = 'Magma',
                                                                                                            colorbar=True, 
                                                                                                  # logx=True, logy=True,
                                                                                                    legend_position='right',
                                                                                                        size=10,
                                                                                         )
    seg = hv.Segments(meds, ['sel_med', 
                             'min_sel_med67', 
                             'sel_med', 'max_sel_med67', ]).opts(color='black',alpha=.2)
    
    seg2 = hv.Segments(meds, ['min_sel_med', 
                             'sel_med67', 
                             'max_sel_med', 'sel_med67', ]).opts(color='black',alpha=.2)
    
    ticks = np.linspace(0,1,6)
    labels = [str(tick) for tick in ticks]
   # if sel_range[0]!=0:
    labels[0] = '<' + labels[0]
   # if sel_range[-1]!= 0:
    labels[-1] = '>' + labels[-1]

    #labels[-1] = '>' + labels[-1]
    print(labels)
  #  labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    
    # Apply colorbar customization
    scatter.opts(
        colorbar=True,
        #\colorbar_opts={
      #      'major_label_overrides': dict(zip(ticks, labels))
      #  }
    )

    scatter = hv.render(scatter*seg*seg2)
    scatter.line(np.linspace(-10,10), np.linspace(-10,10),color = 'black', )
        
    scatter.legend.visible = True
    scatter.xaxis.axis_label = 'Sel 1-2'
    scatter.yaxis.axis_label = 'Sel 6-7'
    #bokeh.io.show(scatter)
    return scatter

# %%
p = make_big_plot_sel(pol,)

#p.x_range = bokeh.models.Range1d(-.02,.5)
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,'time_varying_12_sel')
# Out:
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_60042/2694824213.py:42: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   scatter.legend.visible = True
#   <div id="f66a8088-f0d2-489a-9936-3a0964a9a364" data-root-id="2499bf02-8ec8-473d-ac90-e48e8ee0cbcb" style="display: contents;"></div>

# %%
def get_big_df_time_varying_sel(sp,ino,t0,t1,thresh=1e-3):
    sel_stuff, df_both_meta_good = get_selection_stuff_both(sp,ino)
    sel_stuff_t0t1 = sel_stuff.loc[(sel_stuff['passage1']==t0)*(sel_stuff['passage2']==t1),:]
    sel_stuff_67 = sel_stuff.loc[(sel_stuff['passage1']==6)*(sel_stuff['passage2']==7),:]
    dfs = []
    for good_meso in sel_stuff['type_mesocosm'].unique():
        df_both_meta_good_meso= df_both_meta_good.loc[(df_both_meta_good['type_mesocosm'] == good_meso)+(df_both_meta_good['is_inoculumn']),:]
        sel_stuff_meso=sel_stuff_t0t1.loc[sel_stuff_t0t1['type_mesocosm']==good_meso,:]
        sel_stuff_meso67=sel_stuff_67.loc[sel_stuff_67['type_mesocosm']==good_meso,:]
        sel_stuff_meso=sel_stuff_meso.set_index('sample2')
                    
        df_both_meta_good_meso=df_both_meta_good_meso.set_index('sample')
        sel_stuff_meso['start_value']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
            
        sel_stuff_meso=sel_stuff_meso.reset_index()
        sel_stuff_meso=sel_stuff_meso.set_index('sample1')
        sel_stuff_meso['start_value1']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
        sel_stuff_meso=sel_stuff_meso.reset_index()
        sel_stuff_meso = sel_stuff_meso.set_index('mesocosm')
        df_both_meta_good_meso=df_both_meta_good_meso.reset_index()
        sel_stuff_meso['actual_p7']= np.nan
        #sel_stuff_meso['actual_p6']= np.nan
        if len(sel_stuff_meso)==0:
            continue 
        p7_df = df_both_meta_good_meso.loc[(df_both_meta_good_meso['passage']==7)*(df_both_meta_good_meso['type_mesocosm']==good_meso),:].set_index('mesocosm')
        p6_df = df_both_meta_good_meso.loc[(df_both_meta_good_meso['passage']==6)*(df_both_meta_good_meso['type_mesocosm']==good_meso),:].set_index('mesocosm')
        p7_mesos = np.intersect1d(sel_stuff_meso.index.values,p7_df.index.values)
        
        sel_stuff_meso67 = sel_stuff_meso67.set_index('mesocosm')
        p67_mesos = np.intersect1d(sel_stuff_meso.index.values,sel_stuff_meso67.index.values)
        
        #print(sel_stuff_meso.index.values, p7_df.index.values)
        p7_df['p7_preds']=np.nan
        p7_df['sel_med67']=np.nan
        p7_df['sel_med12']=np.nan
        p7_df.loc[p7_mesos,'p7_preds']=sel_stuff_meso.loc[p7_mesos,'p7_preds']
        p7_df.loc[p67_mesos,'sel_med67']=sel_stuff_meso67.loc[p67_mesos,'sel_med']
        p7_df.loc[p7_mesos,'sel_med12']=sel_stuff_meso.loc[p7_mesos,'sel_med']
        
        sel_stuff_meso.loc[p7_mesos,'actual_p7']= p7_df.loc[p7_mesos,'boot_med1']
        sel_stuff_meso.loc[p67_mesos,'actual_p6']= p6_df.loc[p67_mesos,'boot_med1']
        sel_stuff_meso.loc[p67_mesos,'sel_med67']= sel_stuff_meso67.loc[p67_mesos,'sel_med']
        sel_stuff_meso['p7_preds'] = get_pred_sel(7-t1,sel_stuff_meso['sel_med'].values, sel_stuff_meso['start_value'].values)
        sel_stuff_meso.loc[sel_stuff_meso['actual_p6']<=thresh,'sel_med67']=sel_stuff_meso.loc[sel_stuff_meso['actual_p6']<=thresh,'sel_med']
        sel_stuff_meso.loc[sel_stuff_meso['actual_p6']>=1-thresh,'sel_med67']=sel_stuff_meso.loc[sel_stuff_meso['actual_p6']>=1-thresh,'sel_med']
        
        sel_stuff_meso_meds = sel_stuff_meso.groupby(['passage1','passage2','type_mesocosm']).median(numeric_only=True).reset_index().set_index('type_mesocosm')
        sel_stuff_meso_maxs = sel_stuff_meso.groupby(['passage1','passage2','type_mesocosm']).max(numeric_only=True).reset_index().set_index('type_mesocosm')
        sel_stuff_meso_mins = sel_stuff_meso.groupby(['passage1','passage2','type_mesocosm']).min(numeric_only=True).reset_index().set_index('type_mesocosm')

        for column in ['sel_med','actual_p7','p7_preds','sel_med67']:
            sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'max_{column}']=sel_stuff_meso_maxs.loc[sel_stuff_meso_meds.index.values,column]
            sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'min_{column}']=sel_stuff_meso_mins.loc[sel_stuff_meso_meds.index.values,column]
        dfs.append(sel_stuff_meso_meds.reset_index())
    if len(dfs)>0:
        dfs = pd.concat(dfs,axis=0)
    return dfs

# %%
def get_big_df_time_varying_sel_by_meso(sp,ino,t0,t1,thresh=1e-3):
    sel_stuff, df_both_meta_good = get_selection_stuff_both(sp,ino)
    sel_stuff_t0t1 = sel_stuff.loc[(sel_stuff['passage1']==t0)*(sel_stuff['passage2']==t1),:]
    sel_stuff_67 = sel_stuff.loc[(sel_stuff['passage1']==6)*(sel_stuff['passage2']==7),:]
    dfs = []
    for good_meso in sel_stuff['mesocosm'].unique():
        
        df_both_meta_good_meso= df_both_meta_good.loc[(df_both_meta_good['mesocosm'] == good_meso)+(df_both_meta_good['is_inoculumn']),:]
        sel_stuff_meso=sel_stuff_t0t1.loc[sel_stuff_t0t1['mesocosm']==good_meso,:]
        sel_stuff_meso67=sel_stuff_67.loc[sel_stuff_67['mesocosm']==good_meso,:]
        sel_stuff_meso=sel_stuff_meso.set_index('sample2')  
        df_both_meta_good_meso=df_both_meta_good_meso.set_index('sample')
        
        sel_stuff_meso['start_value']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
            
        sel_stuff_meso=sel_stuff_meso.reset_index()
        sel_stuff_meso=sel_stuff_meso.set_index('sample1')
        df_both_meta_good_meso=df_both_meta_good_meso.reset_index()
        sel_stuff_meso['actual_p7']= np.nan
        #sel_stuff_meso['actual_p6']= np.nan
        if len(sel_stuff_meso)==0:
            continue 
        p7_df = df_both_meta_good_meso.loc[(df_both_meta_good_meso['passage']==7)*(df_both_meta_good_meso['type_mesocosm']==good_meso),:].set_index('mesocosm')
        p6_df = df_both_meta_good_meso.loc[(df_both_meta_good_meso['passage']==6)*(df_both_meta_good_meso['type_mesocosm']==good_meso),:].set_index('mesocosm')
        p7_mesos = np.intersect1d(sel_stuff_meso.index.values,p7_df.index.values)
        sel_stuff_meso67 = sel_stuff_meso67.set_index('mesocosm')
        p67_mesos = np.intersect1d(sel_stuff_meso.index.values,sel_stuff_meso67.index.values)
        
        #print(sel_stuff_meso.index.values, p7_df.index.values)
        sel_stuff_meso.loc[p7_mesos,'actual_p7']= p7_df.loc[p7_mesos,'boot_med1']
        sel_stuff_meso.loc[p67_mesos,'actual_p6']= p6_df.loc[p67_mesos,'boot_med1']
        sel_stuff_meso.loc[p67_mesos,'sel_med67']= sel_stuff_meso67.loc[p67_mesos,'sel_med']
        sel_stuff_meso['p7_preds'] = get_pred_sel(7-t1,sel_stuff_meso['sel_med'].values, sel_stuff_meso['start_value'].values)
        sel_stuff_meso.loc[sel_stuff_meso['actual_p6']<=thresh,'sel_med67']=sel_stuff_meso.loc[sel_stuff_meso['actual_p6']<=thresh,'sel_med']
        sel_stuff_meso.loc[sel_stuff_meso['actual_p6']>=1-thresh,'sel_med67']=sel_stuff_meso.loc[sel_stuff_meso['actual_p6']>=1-thresh,'sel_med']
        dfs.append(sel_stuff_meso_meds.reset_index())
    if len(dfs)>0:
        dfs = pd.concat(dfs,axis=0)
    return dfs

# %%
def get_big_df_time_varying_sel(sp,ino,t0,t1,thresh=1e-3):
    sel_stuff, df_both_meta_good = get_selection_stuff_both(sp,ino)
    sel_stuff_t0t1 = sel_stuff.loc[(sel_stuff['passage1']==t0)*(sel_stuff['passage2']==t1),:]
    sel_stuff_67 = sel_stuff.loc[(sel_stuff['passage1']==6)*(sel_stuff['passage2']==7),:]
    dfs = []
    for good_meso in sel_stuff['type_mesocosm'].unique():
        df_both_meta_good_meso= df_both_meta_good.loc[(df_both_meta_good['type_mesocosm'] == good_meso)+(df_both_meta_good['is_inoculumn']),:]
        sel_stuff_meso=sel_stuff_t0t1.loc[sel_stuff_t0t1['type_mesocosm']==good_meso,:]
        sel_stuff_meso67=sel_stuff_67.loc[sel_stuff_67['type_mesocosm']==good_meso,:]
        sel_stuff_meso=sel_stuff_meso.set_index('sample2')
                    
        df_both_meta_good_meso=df_both_meta_good_meso.set_index('sample')
        sel_stuff_meso['start_value']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
            
        sel_stuff_meso=sel_stuff_meso.reset_index()
        sel_stuff_meso=sel_stuff_meso.set_index('sample1')
        sel_stuff_meso['start_value1']=df_both_meta_good_meso.loc[sel_stuff_meso.index.values,'boot_med1']
        sel_stuff_meso=sel_stuff_meso.reset_index()
        sel_stuff_meso = sel_stuff_meso.set_index('mesocosm')
        df_both_meta_good_meso=df_both_meta_good_meso.reset_index()
        sel_stuff_meso['actual_p7']= np.nan
        #sel_stuff_meso['actual_p6']= np.nan
        if len(sel_stuff_meso)==0:
            continue 
        p7_df = df_both_meta_good_meso.loc[(df_both_meta_good_meso['passage']==7)*(df_both_meta_good_meso['type_mesocosm']==good_meso),:].set_index('mesocosm')
        p6_df = df_both_meta_good_meso.loc[(df_both_meta_good_meso['passage']==6)*(df_both_meta_good_meso['type_mesocosm']==good_meso),:].set_index('mesocosm')
        p7_mesos = np.intersect1d(sel_stuff_meso.index.values,p7_df.index.values)
        sel_stuff_meso67 = sel_stuff_meso67.set_index('mesocosm')
        p67_mesos = np.intersect1d(sel_stuff_meso.index.values,sel_stuff_meso67.index.values)
        
        #print(sel_stuff_meso.index.values, p7_df.index.values)
        sel_stuff_meso.loc[p7_mesos,'actual_p7']= p7_df.loc[p7_mesos,'boot_med1']
        sel_stuff_meso.loc[p67_mesos,'actual_p6']= p6_df.loc[p67_mesos,'boot_med1']
        sel_stuff_meso.loc[p67_mesos,'sel_med67']= sel_stuff_meso67.loc[p67_mesos,'sel_med']
        sel_stuff_meso['p7_preds'] = get_pred_sel(7-t1,sel_stuff_meso['sel_med'].values, sel_stuff_meso['start_value'].values)
        sel_stuff_meso.loc[sel_stuff_meso['actual_p6']<=thresh,'sel_med67']=sel_stuff_meso.loc[sel_stuff_meso['actual_p6']<=thresh,'sel_med']
        sel_stuff_meso.loc[sel_stuff_meso['actual_p6']>=1-thresh,'sel_med67']=sel_stuff_meso.loc[sel_stuff_meso['actual_p6']>=1-thresh,'sel_med']
        dfs.append(sel_stuff_meso.reset_index())
    if len(dfs)>0:
        dfs = pd.concat(dfs,axis=0)
    return dfs

# %%
all_dfs=[]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
t0 = 1
t1 = 2
big_df = []
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']
#species_list = [102478]
for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
        if f'{sp}-{ino}' in bad_inos:
            continue 
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parent1_info.csv'
        if os.path.exists(fname):
            df = get_big_df_time_varying_sel(sp,ino,t0,t1)
            
            if len(df)>0:
                df['species_id']=sp
                big_df.append(df.reset_index())
            
big_df=pd.concat(big_df).reset_index()
len(big_df['species_id'].unique())
# Out:
# bef 2.1230881120299673e-05
# aft 0.0005148071271501575
# bef 4.0520465009900863e-05
# aft 3.921278033218803e-05
# bef 3.949788255350195e-05
# aft 3.916260597480736e-05
# bef 0.0010000000000000009
# aft 0.00043862110135040044
# bef 0.000500000000000056
# aft 0.0009676147336278307
# bef 2.6385900458225642e-05
# aft 0.0010000000000000009
# bef 2.3168310577803553e-06
# aft 0.0009150683625287481
# bef 0.004079085214987788
# aft 0.0031705958966372627
# bef 1.0078317107999751e-05
# aft 0.0005335592136541667
# bef 1.3182700219699535e-05
# aft 1.3176484522235861e-05
# bef 0.0
# aft 0.0
# bef 3.99948983332999e-05
# aft 3.966525558079647e-05
# bef 5.7049588119501005e-05
# aft 5.5845353300838785e-05
# bef 0.0004999999999999449
# aft 0.00017416409081638662
# bef 9.39850140299972e-06
# aft 1.0235870412296857e-05
# bef 2.960856708699843e-06
# aft 3.2200760903843863e-06
# bef 4.857059140489983e-05
# aft 4.857558066910343e-05
# bef 0.0010000000000000009
# aft 0.0006062628169656303
# bef 0.0040000000000000036
# aft 0.0018342332368019854
# bef 0.0010000000000000009
# aft 0.0004770204568388392
# bef 0.0009999999999998899
# aft 0.0002871689969877189
# bef 0.0001417645705389381
# aft 0.05519592513818983
# bef 0.0
# aft 0.0
# bef 0.00016516112037401331
# aft 0.0010000000000000009
# bef 6.524384766299924e-06
# aft 6.497288751239772e-06
# bef 0.0
# aft 0.0
# bef 0.0004999999999998894
# aft 0.00041578819385981736
# bef 0.000999999999999994
# aft 0.0009756807921945526
# bef 1.2598003517000009e-05
# aft 0.00018802773641080073
# bef 0.0
# aft 0.0
# bef 0.0005000000000000004
# aft 0.0003404808071650889
# bef 7.29043999758705e-06
# aft 0.00042215107159060405
# bef 1.4185147629630634e-05
# aft 0.0010000000000000009
# bef 0.00020827828465730391
# aft 0.001471995289615169
# bef 0.0001461214130698968
# aft 0.00014612629388511406
# bef 0.00011119639709100682
# aft 0.007565085771947588
# bef 6.901105772039173e-05
# aft 0.00042895672082698955
# 14

# %%
big_df['counts']=1
big_df['counts_sel']=~big_df['sel_med67'].isna()
big_df['counts_pred']=~big_df['p7_preds'].isna()
big_df['is_gr']=big_df['actual_p7']>big_df['p7_preds']
big_df['sign_early']=big_df['sel_med']>0
big_df['sign_late']=big_df['sel_med67']>0
big_df['species-meso']=big_df['species_id'].astype(str)+'-'+big_df['mesocosm']
big_df['species-type_meso']=big_df['species_id']+'-'+big_df['type_mesocosm']
big_df['big_enough']=(big_df['actual_p7']>1e-1)*(big_df['actual_p7']<1-1e-1)
big_dfgr=big_df.groupby(['species-type_meso','species_id']).sum(numeric_only=True).reset_index()

# %%
big_dfgr['species_id'].unique()
# Out:
# array(['100099', '100146', '100196', '100910', '101059', '101294',
#        '101346', '101400', '102438', '102478', '102506', '102544',
#        '103117', '103656'], dtype=object)

# %%
big_dfgr_good = big_dfgr.loc[big_dfgr['counts']>2,:]
print(len(big_dfgr_good))
# Out:
# 39

# %%
print(len(big_dfgr_goodp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(len(big_dfgr_goodp))
#
# NameError: name 'big_dfgr_goodp' is not defined

# %%
big_dfgr_goodp =big_dfgr_good.loc[big_dfgr_good['big_enough']==big_dfgr_good['counts'],:]
big_dfgr_goodp = big_dfgr_goodp.loc[(big_dfgr_goodp['counts']==big_dfgr_goodp['is_gr'])+(big_dfgr_goodp['is_gr']==0),:]
big_dfgr_goodp['actual_p7_avg']=big_dfgr_goodp['actual_p7']/big_dfgr_goodp['counts']
big_dfgr_goodp['pred_p7_avg']=big_dfgr_goodp['p7_preds']/big_dfgr_goodp['counts']
big_dfgr_goodp.sort_values(by='actual_p7_avg')
# Out:
#          species-type_meso species_id  level_0  index  Unnamed: 0  passage1  \
# 40  102438-AE-AF-mBHI-mGAM     102438       14      6         342         4
# 2   100099-AA-AE-mGAM-mBHI     100099        6      6         280         4
# 12  100146-AA-AE-mGAM-mBHI     100146        6      6         251         4
# 15  100146-AE-AF-mGAM-mBHI     100146        3      3         138         3
# 11  100099-AE-AF-mGAM-mGAM     100099       12      3         314         3
#
#     passage2    sel_med  sel_lower  sel_upper  ...  p7_preds  counts  \
# 40         8   3.069157   3.014684   3.130780  ...  3.748015       4
# 2          8   3.465439   3.440718   3.544157  ...  3.642469       4
# 12         8 -12.842303 -13.114718 -12.543651  ...  0.000039       4
# 15         6   6.501420   6.401293   6.665355  ...  2.990885       3
# 11         6   3.058208   3.012219   3.102863  ...  2.998319       3
#
#     counts_sel  counts_pred  is_gr  sign_early  sign_late  big_enough  \
# 40           4            4      0           4          1           4
# 2            4            4      0           4          3           4
# 12           4            4      4           0          2           4
# 15           3            3      0           3          2           3
# 11           3            3      0           3          3           3
#
#     actual_p7_avg  pred_p7_avg
# 40       0.389243     0.937004
# 2        0.417802     0.910617
# 12       0.544469     0.000010
# 15       0.695889     0.996962
# 11       0.716373     0.999440
#
# [5 rows x 31 columns]

# %%
big_dfgr_goodp =big_dfgr_good.loc[big_dfgr_good['big_enough']>0,:]
sp_mesos = big_dfgr_goodp['species-type_meso'].unique()

# %%
for sp in big_dfgr_goodp['species_id'].unique():
    plots_all=[]
    for ino in inos:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{sp}/{ino}_parent1_info.csv'
        if f'{sp}-{ino}' in bad_inos:
            continue
        if not os.path.isfile(fname):
            print('oo')
            continue
        psstrain,type_mesos = make_logit_plot(sp, ino,
                                       colorby='const',logit=True,
                                        )
      #  print(psstrain)
        for i in range(len(psstrain)):
            p1 = psstrain[i]
            meso = type_mesos[i]
            if f'{sp}-{meso}' not in sp_mesos:
                continue
                
            med1=meso.split('-')[-2]
            med2 = meso.split('-')[-1]
            ino1 = f'{sp}-{med1}-{med2}'
            p1.legend.visible=False
            ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax = get_preds_for_plotting(sp,ino,meso, t0,t1)
            if len(pred_values_logit)>0:
                p1.line(ts,pred_values_logit,color='grey')
                p1.line(ts,pred_values_logitmin,color='grey',line_dash='dashed')
                p1.line(ts,pred_values_logitmax,color='grey',line_dash='dashed')
                p1.yaxis.axis_label_text_font_style = 'normal'
                p1.xaxis.axis_label_text_font_style = 'normal'
                bokeh.io.show(p1)
                p1.output_backend='svg'
                export_plot_pdf(p1,f'time_varying_plot_{sp}_{ino}-{med2}-{t0}_{t1}')
# Out:
# bef 7.29043999758705e-06
# aft 0.00042215107159060405
# bef 7.29043999758705e-06
# aft 0.00042215107159060405
# 0.00042215107159060405
# [0.93856999 0.91339376 0.92253521]
# potatoes [0.83910387 0.80933063 0.80465587]
#   <div id="c686f381-7abb-4fa5-a01c-c35cb37909a0" data-root-id="6976a8ef-cfe5-4fdd-9d85-b7c30703f478" style="display: contents;"></div>
# bef 0.0005000000000000004
# aft 0.0003404808071650889
# bef 0.0
# aft 0.0
# bef 0.0
# aft 0.0
# 0.0
# [0.15602837 0.1663286  0.22020202 0.18864097]
# potatoes [0.09219858 0.08669355 0.08577195 0.07762097]
#   <div id="f3e25fb4-5d9a-4423-bcb0-020311761ba1" data-root-id="f1c37fef-a30b-4491-baeb-655efa1d3a73" style="display: contents;"></div>
# bef 1.2598003517000009e-05
# aft 0.00018802773641080073
# bef 1.2598003517000009e-05
# aft 0.00018802773641080073
# 0.00018802773641080073
# [0.12729124 0.13265306 0.12729124 0.18801653]
# potatoes [0.44045175 0.44364012 0.3914405  0.34759916]
#   <div id="a2844372-9b0b-4a96-99d9-40425781314e" data-root-id="e86092f0-93c0-4347-901b-68e869fc93cd" style="display: contents;"></div>
# bef 0.000999999999999994
# aft 0.0009756807921945526
# bef 0.0004999999999998894
# aft 0.00041578819385981736
# bef 3.949788255350195e-05
# aft 3.916260597480736e-05
# bef 3.949788255350195e-05
# aft 3.916260597480736e-05
# 3.916260597480736e-05
# [0.86842105 0.46178687 0.39245668]
# potatoes [0.10111223 0.17813765 0.18421053]
#   <div id="d68b83b4-75be-4cb4-a953-13dc6fe6aec5" data-root-id="7ae24bc4-cd56-4b90-abac-d49adbe2a9b7" style="display: contents;"></div>
# bef 4.0520465009900863e-05
# aft 3.921278033218803e-05
# bef 2.1230881120299673e-05
# aft 0.0005148071271501575
# bef 2.1230881120299673e-05
# aft 0.0005148071271501575
# 0.0005148071271501575
# [0.03960079 0.12360689 0.17002012 0.17269907]
# potatoes [0.65634675 0.81369587 0.61821904 0.55061983]
#   <div id="bf238271-bce0-48bf-8a1f-843657e76c3b" data-root-id="fb85409b-dfe9-4605-8f0d-7cd51a79daae" style="display: contents;"></div>
# oo
# bef 2.960856708699843e-06
# aft 3.2200760903843863e-06
# bef 2.960856708699843e-06
# aft 3.2200760903843863e-06
# 3.2200760903843863e-06
# [0.06623932 0.14926931 0.02262931]
# potatoes [0.76835574 0.68219462 0.7476828 ]
#   <div id="e5a92c68-ea23-41ca-96a8-3291d6730704" data-root-id="de1af8d7-8e15-42b7-90d2-51f6a21b5cd7" style="display: contents;"></div>
# bef 9.39850140299972e-06
# aft 1.0235870412296857e-05
# bef 6.901105772039173e-05
# aft 0.00042895672082698955
# bef 6.901105772039173e-05
# aft 0.00042895672082698955
# 0.00042895672082698955
# [0.60041841 0.58158996 0.59355509]
# potatoes [0.52966102 0.48665298 0.48905109]
#   <div id="e0d20dd0-d4d0-4b5a-bedf-2e2946d49eda" data-root-id="1d27e911-00c5-4732-be19-c5fb58800981" style="display: contents;"></div>
# bef 0.00011119639709100682
# aft 0.007565085771947588
# bef 0.00011119639709100682
# aft 0.007565085771947588
# 0.007565085771947588
# [0.05476673 0.05386179 0.0945122  0.1453252 ]
# potatoes [0.16902834 0.17163412 0.16598361 0.18032787]
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
#   <div id="f112af03-1a9e-4ccb-8795-1536c3284a2a" data-root-id="417916aa-3b9f-45ad-8b74-3e0a2ca594ad" style="display: contents;"></div>
# bef 0.0001461214130698968
# aft 0.00014612629388511406
# bef 0.00020827828465730391
# aft 0.001471995289615169
# oo
# oo
# bef 0.0004999999999999449
# aft 0.00017416409081638662
# bef 0.0004999999999999449
# aft 0.00017416409081638662
# 0.00017416409081638662
# [0.93346774 0.95674044 0.89756592]
# potatoes [0.93211753 0.92330979 0.92431887]
#   <div id="eec21983-6669-4a13-ab0b-4634458ae9a2" data-root-id="26230a3b-3908-4748-ad95-b17cf9d42053" style="display: contents;"></div>
# bef 5.7049588119501005e-05
# aft 5.5845353300838785e-05
# bef 5.7049588119501005e-05
# aft 5.5845353300838785e-05
# 5.5845353300838785e-05
# [0.04444444 0.05364372 0.02110553 0.06983806]
# potatoes [0.32670157 0.40414508 0.30421377 0.41194645]
#   <div id="d2d50954-4c1f-43df-acc1-ccdfb44bf649" data-root-id="cfce0323-02ec-4764-bf17-765508822356" style="display: contents;"></div>
# bef 3.99948983332999e-05
# aft 3.966525558079647e-05
# bef 0.0
# aft 0.0
# bef 0.0
# aft 0.0
# 0.0
# [0.76078029 0.74564103 0.7807377  0.64906832]
# potatoes [0.5186722  0.57510288 0.54132231 0.62474227]
#   <div id="a3a5a14c-ca77-4d5b-969d-1b19615bd6f8" data-root-id="7ffac860-f109-45ca-ac83-b9fc99df8e52" style="display: contents;"></div>
# bef 1.3182700219699535e-05
# aft 1.3176484522235861e-05
# bef 1.0078317107999751e-05
# aft 0.0005335592136541667
