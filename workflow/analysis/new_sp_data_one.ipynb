# %%
import pandas as pd
import numpy as np
import os
from snp_analysis_tools_sherlock import *
from coalescence_analysis_tools import *
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
import warnings

import pandas as pd
#from pandas.core.common import SettingWithCopyWarning

#warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)


hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='af6feb82-9dad-4eee-b8f1-947d0aa2733d'>
#   <div id="dfeefcd5-5f1d-4151-ae3e-62814849af7d" data-root-id="af6feb82-9dad-4eee-b8f1-947d0aa2733d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df = pd.read_csv('e003_round4_assembly_abundances.csv')
metadata = pd.read_csv('assembly_metadata_round4.csv')

df_marker = pd.read_csv('~/git/coalescence-pilot-mgx/workflow/out/midas2v3_output/merge/species/species_marker_read_counts.tsv',
                       delimiter = '\t').set_index('species_id')

sums = df_marker.sum(axis=0)
sums = sums[sums>0]
len(sums[sums<1e4])
# Out:
# 54

# %%
1e4
# Out:
# 10000.0

# %%
p=iqplot.ecdf(np.log10(sums.values))
bokeh.io.show(p)
# Out:
#   <div id="c2c8d56f-3e28-4479-b472-c57718a51833" data-root-id="440328df-0aae-4ff6-8106-b749de5278bc" style="display: contents;"></div>

# %%
metadata['pseudo-passage']=metadata['passage']
metadata.loc[metadata['exp_type']=='e003GlycerolRevival','pseudo-passage']=metadata.loc[metadata['exp_type']=='e003GlycerolRevival','passage']+5

# %%
metadata['meso-passage']=metadata['mesocosm']+'-'+ metadata['pseudo-passage'].astype(str)
metadata['counts']=1
b=metadata.groupby(['meso-passage']).sum(numeric_only=True)
b2 = b.loc[b['counts']>1,:]
b2
# Out:
#                   passage  pseudo-passage  counts
# meso-passage
# B3-AC/PP-mBHI-3         6               6       2
# C4-AE-mBHI-3            6               6       2
# fecal-AA-fecal-0        0               0       2

# %%
metadata.loc[metadata['meso-passage']=='B3-AC/PP-mBHI-3',:]
# Out:
#                              sample      exp_type media  passage comm subject  \
# 8           B3-e003Assembly-mBHI-p3  e003Assembly  mBHI        3   B3   AC/PP
# 56  Assembly-G2-B3-ACPP-mBHI-3_S693  e003Assembly  mBHI        3   B3   AC/PP
#
#          mesocosm type_mesocosm  pseudo-passage     meso-passage  counts
# 8   B3-AC/PP-mBHI    AC/PP-mBHI               3  B3-AC/PP-mBHI-3       1
# 56  B3-AC/PP-mBHI    AC/PP-mBHI               3  B3-AC/PP-mBHI-3       1

# %%
bad_samples = ['C4-e003Assembly-mBHI-p3','Assembly-G12-fecal-AA-fecal-0_S703','B3-e003Assembly-mBHI-p3']
bad_samples
# Out:
# ['C4-e003Assembly-mBHI-p3',
#  'Assembly-G12-fecal-AA-fecal-0_S703',
#  'B3-e003Assembly-mBHI-p3']

# %%
df_good = df.loc[~df['sample'].isin(bad_samples),:]

# %%
df_good.to_csv('e004_abundances_no_dups.csv')

# %%
df = pd.read_csv('e003_coalescence_metadata_round4_abundances.csv')
metadata = pd.read_csv('e003_coalescence_metadata_round4.csv')

# %%
metadata['meso-passage']=metadata['mesocosm']+'-'+metadata['passage'].astype(str)
metadata['counts']=1
gr = metadata.groupby(['meso-passage']).sum(numeric_only=True)
gr2 = gr.loc[gr['counts']>1,:]
gr2
# Out:
#                       is_inoculumn  passage  redo  counts
# meso-passage
# A2-AA-AA-mBHI-mBHI-0             2        0     0       2
# A5-AA-AF-mBHI-mBHI-0             2        0     0       2

# %%
metadata.loc[metadata['meso-passage']=='A5-AA-AF-mBHI-mBHI-0',:]
# Out:
#     comm comm-media   inoculumn                   inoculumn_sample  \
# 629   A5    A5-mBHI  AA-AF-mBHI  A5-e003Coalescence-Inoculumn-mBHI
# 648   A5    A5-mBHI  AA-AF-mBHI  A5-e003Coalescence-Inoculumn-mBHI
#
#      is_inoculumn media            mesocosm parent_media parent_subjects  \
# 629          True  mBHI  A5-AA-AF-mBHI-mBHI         mBHI           AA-AF
# 648          True  mBHI  A5-AA-AF-mBHI-mBHI         mBHI           AA-AF
#
#      passage                                  sample    type_mesocosm   redo  \
# 629        0  A5-e003Coalescence-mBHI-inoculumn-redo  AA-AF-mBHI-mBHI  False
# 648        0       A5-e003Coalescence-Inoculumn-mBHI  AA-AF-mBHI-mBHI  False
#
#      counts     mesocosm-passage          meso-passage
# 629       1  A5-AA-AF-mBHI-mBHI0  A5-AA-AF-mBHI-mBHI-0
# 648       1  A5-AA-AF-mBHI-mBHI0  A5-AA-AF-mBHI-mBHI-0

# %%
metadata.loc[metadata['meso-passage']=='A5-AA-AF-mBHI-mBHI-0',:]
df.loc[df['sample']=='A2-e003Coalescence-Inoculumn-mBHI',:]
# Out:
#         Unnamed: 0.1                             sample  species_id  \
# 545              545  A2-e003Coalescence-Inoculumn-mBHI      102506
# 1283             545  A2-e003Coalescence-Inoculumn-mBHI      101059
# 2021             545  A2-e003Coalescence-Inoculumn-mBHI      100296
# 2759             545  A2-e003Coalescence-Inoculumn-mBHI      100120
# 3497             545  A2-e003Coalescence-Inoculumn-mBHI      100910
# ...              ...                                ...         ...
# 853673           545  A2-e003Coalescence-Inoculumn-mBHI      103028
# 854411           545  A2-e003Coalescence-Inoculumn-mBHI      102740
# 855149           545  A2-e003Coalescence-Inoculumn-mBHI      100131
# 855887           545  A2-e003Coalescence-Inoculumn-mBHI      100172
# 856625           545  A2-e003Coalescence-Inoculumn-mBHI      100870
#
#         relative_abundance                                            Lineage  \
# ...

# %%
bad_samples = ['A2-e003Coalescence-Inoculumn-mBHI',]

# %%
e2 = pd.read_csv('e003_with_passage_one_redo.csv')
e2.loc[e2['sample']=='A5-e003Coalescence-mBHI-inoculumn-redo',:]
# Out:
#      Unnamed: 0 comm comm-media   inoculumn  \
# 364         364   A5    A5-mBHI  AA-AF-mBHI
#
#                       inoculumn_sample  is_inoculumn media  \
# 364  A5-e003Coalescence-Inoculumn-mBHI          True  mBHI
#
#                mesocosm parent_media parent_subjects  passage  \
# 364  A5-AA-AF-mBHI-mBHI         mBHI           AA-AF        0
#
#                                      sample    type_mesocosm   redo  counts
# 364  A5-e003Coalescence-mBHI-inoculumn-redo  AA-AF-mBHI-mBHI  False       1
