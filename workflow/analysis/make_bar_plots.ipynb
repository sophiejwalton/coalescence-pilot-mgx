# %%
import pandas as pd
import numpy as np
import os
import itertools as it
from snp_analysis_tools_sherlock import *
from coalescence_analysis_tools import *
from plot_tools import *
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='886ffb5d-3bf6-4c80-aa83-b64006c0de1c'>
#   <div id="b6fffe10-d17a-47fd-b909-27e154207e41" data-root-id="886ffb5d-3bf6-4c80-aa83-b64006c0de1c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"36e90b41-9312-4af9-9fd6-f75a8fb52815":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"886ffb5d-3bf6-4c80-aa83-b64006c0de1c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"20f79cd2-00f9-415b-b089-d4a73465b741","attributes":{"plot_id":"886ffb5d-3bf6-4c80-aa83-b64006c0de1c","comm_id":"80651d00046b4f80958f7741194abdd5","client_comm_id":"4e64f133177640b296313214ac97aeef"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"36e90b41-9312-4af9-9fd6-f75a8fb52815","roots":{"886ffb5d-3bf6-4c80-aa83-b64006c0de1c":"b6fffe10-d17a-47fd-b909-27e154207e41"},"root_ids":["886ffb5d-3bf6-4c80-aa83-b64006c0de1c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df_abundance = pd.read_csv('e003_round4_assembly_abundances.csv')
df_abundance_coalescence = pd.read_csv('e004_abundances_no_dups.csv')
df_abundance_coalescence['exp_type'].unique()
df_abundance.loc[df_abundance['exp_type']=='e003GlycerolRevival','passage']=df_abundance.loc[df_abundance['exp_type']=='e003GlycerolRevival','passage']+5

# %%
df_abundance['counts']=1.
df_abundance['no_zero']=(df_abundance['relative_abundance']>0.)
df_abundancegr=df_abundance.groupby(['sample']).sum(numeric_only=True)
df_abundancegr = df_abundancegr.loc[df_abundancegr['relative_abundance']>0,:]
df_abundancegr =df_abundancegr.loc[df_abundancegr['no_zero']>10,:]
df_abundancegr['no_zero'].min()
good_samples = df_abundancegr.index.values
df_abundance=df_abundance.loc[df_abundance['sample'].isin(good_samples),:]

# %%
df_abundance['mesocosm'].unique()
# Out:
# array(['B10-AE-mGAM', 'B11-AF-mGAM', 'B2-AA-mBHI', 'B3-AC/PP-mBHI',
#        'B4-AE-mBHI', 'B5-AF-mBHI', 'B8-AA-mGAM', 'B9-AC/PP-mGAM',
#        'C10-AE-mGAM', 'C11-AF-mGAM', 'C2-AA-mBHI', 'C3-AC/PP-mBHI',
#        'C4-AE-mBHI', 'C5-AF-mBHI', 'C8-AA-mGAM', 'C9-AC/PP-mGAM',
#        'D10-AE-mGAM', 'D11-AF-mGAM', 'D2-AA-mBHI', 'D3-AC/PP-mBHI',
#        'D5-AF-mBHI', 'D8-AA-mGAM', 'D9-AC/PP-mGAM', 'fecal-AC/PP-fecal',
#        'fecal-AE-fecal', 'fecal-AF-fecal', 'fecal-AA-fecal', 'D4-AE-mBHI'],
#       dtype=object)

# %%
meso_to_look_at = 'B8-AA-mGAM'
for meso_to_look_at in ['B8-AA-mGAM']:
    if 'AC' in meso_to_look_at:
        continue
    bar_width = 1.6
    p = make_bar_plot_assembly(meso_to_look_at, df_abundance,bar_width = bar_width, 
                              include_glycerol=False,species_emph=102506)
    p.output_backend = "svg"
    fname_prefix = f'{meso_to_look_at}_bar_plot_{str(bar_width*10)}'
    p.height=250
    p.width=400
    tick_font_size ='20px'
    label_font_size = '24px'
    p.legend.visible=False
    p.yaxis.axis_label_text_font_style = 'normal'
    p.xaxis.axis_label_text_font_style = 'normal'
    p.xaxis.axis_label_text_font_size=label_font_size
    p.xaxis.major_label_text_font_size=tick_font_size
    p.yaxis.axis_label_text_font_size=label_font_size
    p.yaxis.major_label_text_font_size=tick_font_size
    p.xaxis.axis_label = 'Timepoint'
    p.xaxis.minor_tick_line_color= None
    p.yaxis.minor_tick_line_color= None
    p.title.text = meso_to_look_at
    p.title.text_font_style='normal'
    p.title.text_font_size=label_font_size
    p.title.text='Ex: Host A in mGAM'

    export_plot_pdf(p, fname_prefix)
    bokeh.io.show(p)
# Out:
#   <div id="e79217a7-6917-45bb-923c-d0f72db3dd3d" data-root-id="e7d7d92c-ab53-421c-8aa0-56c18f4bc55e" style="display: contents;"></div>

# %%
def ecdf_transform_no_norm(data):
    return data.rank(method="first",ascending=False) #/ len(data)

def make_rank_abundance(type_mesocosm):
    if type_mesocosm.split('-')[-1]=='mGAM':
        color = bokeh.palettes.Set2[8][0]
    if type_mesocosm.split('-')[-1]=='mBHI':
        color = bokeh.palettes.Set2[8][1]
    
    AAmGAM = df_abundance.loc[(df_abundance['type_mesocosm']==type_mesocosm)*(df_abundance['passage']==5),:]
    AAmGAM = AAmGAM.loc[AAmGAM['relative_abundance']>0,:]
    AAmGAM["rel abun ECDF"] = AAmGAM.groupby("sample")[
        "relative_abundance"
    ].transform(ecdf_transform_no_norm)
    
    mesos = AAmGAM['mesocosm'].unique()
    ps = []
    for i,meso in enumerate(mesos):
        if 'fecal' in mesos:
            continue
        if i == 0:
            p1 = hv.Curve(
                data=AAmGAM.loc[AAmGAM['mesocosm']==meso,:].sort_values(by='rel abun ECDF'),
                vdims=['relative_abundance','sample'],
                kdims=[('rel abun ECDF', 'ECDF'), ],label=type_mesocosm.split('-')[-1],
            ).opts(width=200,height=200, color=  color,#xlabel='Relative Abundance',
                   logy=True,logx=True,)
        else:
            p1 = hv.Curve(
                data=AAmGAM.loc[AAmGAM['mesocosm']==meso,:].sort_values(by='rel abun ECDF'),
                vdims=['relative_abundance','sample'],
                kdims=[('rel abun ECDF', 'ECDF'), ],
            ).opts(width=200,height=200, color=  color,#xlabel='Relative Abundance',
                   logy=True,logx=True,)
        ps.append(p1)
        #  ylabel='1-P(f>x)')


    sub = type_mesocosm.split('-')[0]
    AAmGAM = df_abundance.loc[df_abundance['type_mesocosm']==f'{sub}-fecal',:]
    AAmGAM = AAmGAM.loc[AAmGAM['relative_abundance']>0,:]
    AAmGAM["rel abun ECDF"] = AAmGAM.groupby("sample")[
        "relative_abundance"
    ].transform(ecdf_transform_no_norm)

    p4 = hv.Curve(
        data=AAmGAM.sort_values(by='rel abun ECDF'),
        vdims=['relative_abundance','sample'],
        kdims=[('rel abun ECDF', 'ECDF'), ],label='Fecal',
    ).opts(width=250,height=400, color= bokeh.palettes.Set2[8][-2],#xlabel='Relative Abundance',
           logy=True,logx=True,ylim=(1e-3,1))
        #  ylabel='1-P(f>x)')
    if len(ps)==3:
        p=hv.render(p4*ps[0]*ps[1]*ps[2])
    elif len(ps)==2:
        p=hv.render(p4*ps[0]*ps[1])
    elif len(ps)==1:
        p=hv.render(p4*ps[0])
    else:
        p = hv.render(p4)
    tick_font_size ='15px'
    label_font_size = '22px'
    p.yaxis.axis_label_text_font_style = 'normal'
    p.xaxis.axis_label_text_font_style = 'normal'
    p.xaxis.axis_label_text_font_size=label_font_size
    p.xaxis.major_label_text_font_size=tick_font_size
    p.yaxis.axis_label_text_font_size=label_font_size
    p.yaxis.major_label_text_font_size=tick_font_size
    p.xaxis.axis_label = 'Species Rank'
    p.yaxis.axis_label = 'Relative Abundance'
    p.xaxis.minor_tick_line_color= None
    p.yaxis.minor_tick_line_color= None
    p.title.text = type_mesocosm
    p.title.text_font_style='normal'
    p.title.text_font_size=label_font_size
 #   bokeh.io.show(p)
    p.output_backend='svg'
    export_plot_pdf(p,f'rank_abundance_{type_mesocosm}')
    return p

# %%
ps_all = []
for meso in ['AA-mBHI','AE-mBHI','AF-mBHI','AA-mGAM','AE-mGAM','AF-mGAM',]:
    ps = make_rank_abundance(meso)
    ps_all.append(ps)

# %%
grid = bokeh.layouts.gridplot(ps_all,ncols=3)
bokeh.io.show(grid)
fname_prefix = 'all_rank_rels'
plot_fname_svg=f'plots/{fname_prefix}.svg'
plot_fname_pdf=f'plots/{fname_prefix}.pdf'
bokeh.io.export_svg(grid,filename=plot_fname_svg)
convert_scripts = f'rsvg-convert -f pdf -o {plot_fname_pdf} {plot_fname_svg}' 
os.system(convert_scripts)
# Out:
#   <div id="e5af5c74-45e7-41ac-a86d-082d03205878" data-root-id="b311e991-4572-4618-bf0b-c9d4b07881a2" style="display: contents;"></div>
# 0

# %%
convert_scripts = f'rsvg-convert -f pdf -o {plot_fname_pdf} {plot_fname_svg}'

# %%
df_abundance_coalescence = pd.read_csv('e003_coalescence_metadata_round4_abundances.csv')
df_abundance_coalescence.loc[df_abundance_coalescence['type_mesocosm']=='AA-AF-mGAM-mGAM','mesocosm'].unique()
# Out:
# array(['A11-AA-AF-mGAM-mGAM', 'D8-AA-AF-mGAM-mGAM', 'E11-AA-AF-mGAM-mGAM',
#        'H8-AA-AF-mGAM-mGAM', 'A5-AA-AF-mGAM-mGAM', 'D2-AA-AF-mGAM-mGAM'],
#       dtype=object)

# %%
df_abundance_coalescence.loc[df_abundance_coalescence['sample']=='D_A4_A5_AF_AA_mBHI_mBHI_6_S292',:]
# Out:
#         Unnamed: 0.1                          sample  species_id  \
# 174              174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      102506
# 912              174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      101059
# 1650             174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      100296
# 2388             174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      100120
# 3126             174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      100910
# ...              ...                             ...         ...
# 853302           174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      103028
# 854040           174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      102740
# 854778           174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      100131
# 855516           174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      100172
# 856254           174  D_A4_A5_AF_AA_mBHI_mBHI_6_S292      100870
#
#         relative_abundance                                            Lineage  \
# 174                  0.116  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 912                  0.158  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 1650                 0.115  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__P...
# 2388                 0.111  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__T...
# 3126                 0.022  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# ...                    ...                                                ...
# 853302               0.000  d__Bacteria;p__Actinobacteriota;c__Coriobacter...
# 854040               0.000  d__Bacteria;p__Actinobacteriota;c__Coriobacter...
# 854778               0.000  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# 855516               0.000  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__L...
# 856254               0.000  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                  species                  genus  \
# 174                s__Escherichia coli_D         g__Escherichia
# 912             s__Porphyromonas somerae       g__Porphyromonas
# 1650    s__Peptostreptococcus anaerobius  g__Peptostreptococcus
# 2388          s__Peptoniphilus_A harei_A     g__Peptoniphilus_A
# 3126       s__Flavonifractor sp900199495      g__Flavonifractor
# ...                                  ...                    ...
# 853302                               s__         g__Collinsella
# 854040                               s__         g__Collinsella
# 854778     s__Anaerotruncus rubiinfantis       g__Anaerotruncus
# 855516        s__Clostridium_M lavalense       g__Clostridium_M
# 856254                               s__         g__Akkermansia
#
#                           family                 phyla comm  ... media  \
# 174        f__Enterobacteriaceae     p__Proteobacteria   E5  ...  mBHI
# 912        f__Porphyromonadaceae       p__Bacteroidota   E5  ...  mBHI
# 1650    f__Peptostreptococcaceae       p__Firmicutes_A   E5  ...  mBHI
# 2388         f__Peptoniphilaceae       p__Firmicutes_A   E5  ...  mBHI
# 3126         f__Oscillospiraceae       p__Firmicutes_A   E5  ...  mBHI
# ...                          ...                   ...  ...  ...   ...
# 853302      f__Coriobacteriaceae   p__Actinobacteriota   E5  ...  mBHI
# 854040      f__Coriobacteriaceae   p__Actinobacteriota   E5  ...  mBHI
# 854778        f__Ruminococcaceae       p__Firmicutes_A   E5  ...  mBHI
# 855516        f__Lachnospiraceae       p__Firmicutes_A   E5  ...  mBHI
# 856254        f__Akkermansiaceae  p__Verrucomicrobiota   E5  ...  mBHI
#
#                   mesocosm parent_media  parent_subjects passage  \
# 174     E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# 912     E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# 1650    E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# 2388    E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# 3126    E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# ...                    ...          ...              ...     ...
# 853302  E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# 854040  E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# 854778  E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# 855516  E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
# 856254  E5-AA-AF-mBHI-mBHI         mBHI            AA-AF       6
#
#           type_mesocosm   redo counts     mesocosm-passage replicate
# 174     AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# 912     AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# 1650    AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# 2388    AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# 3126    AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# ...                 ...    ...    ...                  ...       ...
# 853302  AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# 854040  AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# 854778  AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# 855516  AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
# 856254  AA-AF-mBHI-mBHI  False      1  E5-AA-AF-mBHI-mBHI6       2.0
#
# [1161 rows x 24 columns]

# %%
meso = 'E11-AA-AF-mGAM-mGAM'
in_sample = df_abundance_coalescence.loc[df_abundance_coalescence['mesocosm']==meso,'inoculumn_sample'].unique()[0]
df_meso_good = df_abundance_coalescence.loc[(df_abundance_coalescence['mesocosm']==meso)+(df_abundance_coalescence['sample']==in_sample),:]
df_meso_good['passage'] = df_meso_good['passage'].astype(int)
p = make_bar_plot_coalescence(df_meso_good,add=.2,bar_width = 2, passages = [0,1,2,3,4,5,6,7],
                              species_emph = 102478,
                             )

p.legend.visible = False
tick_font_size ='15px'
label_font_size = '22px'
p.yaxis.axis_label_text_font_style = 'normal'
p.xaxis.axis_label_text_font_style = 'normal'
p.xaxis.axis_label_text_font_size=label_font_size
p.xaxis.major_label_text_font_size=tick_font_size
p.yaxis.axis_label_text_font_size=label_font_size
p.yaxis.major_label_text_font_size=tick_font_size
p.xaxis.axis_label = 'Timepoint'
p.xaxis.minor_tick_line_color= None
p.yaxis.minor_tick_line_color= None
p.output_backend = "svg"
fname_prefix = f'{meso}_bar_plot'
export_plot_pdf(p, fname_prefix)

bokeh.io.show(p)
# Out:
#   <div id="e262ea92-b15c-4684-81fc-151c03318581" data-root-id="473b5d8f-8ea2-48f2-885e-1265049fd8b5" style="display: contents;"></div>

# %%
df_abundance['mesocosm'].unique()
# Out:
# array(['B10-AE-mGAM', 'B11-AF-mGAM', 'B2-AA-mBHI', 'B3-AC/PP-mBHI',
#        'B4-AE-mBHI', 'B5-AF-mBHI', 'B8-AA-mGAM', 'B9-AC/PP-mGAM',
#        'C10-AE-mGAM', 'C11-AF-mGAM', 'C2-AA-mBHI', 'C3-AC/PP-mBHI',
#        'C4-AE-mBHI', 'C5-AF-mBHI', 'C8-AA-mGAM', 'C9-AC/PP-mGAM',
#        'D10-AE-mGAM', 'D11-AF-mGAM', 'D2-AA-mBHI', 'D3-AC/PP-mBHI',
#        'D5-AF-mBHI', 'D8-AA-mGAM', 'D9-AC/PP-mGAM', 'fecal-AC/PP-fecal',
#        'fecal-AE-fecal', 'fecal-AF-fecal', 'fecal-AA-fecal', 'D4-AE-mBHI'],
#       dtype=object)

# %%
df_abundance_SS = df_abundance.loc[df_abundance['mesocosm']=='B5-AF-mBHI',:]
meso_to_look_at = 'B10-AE-mGAM'
p = make_bar_plot_assembly(meso_to_look_at, df_abundance,add=.2,plot_width = int(768*6/9),
                           bar_width = 1.6, )


p.legend.visible = False
p.xaxis.axis_label_text_font_size='15px'
p.xaxis.major_label_text_font_size='15px'
p.yaxis.axis_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p.xaxis.minor_tick_line_color= None
p.output_backend = "svg"
fname_prefix = f'{meso_to_look_at}_bar_plot'
export_plot_pdf(p, fname_prefix)
bokeh.io.show(p)
# Out:
#   <div id="ff1a8274-d3ce-40b6-ab3c-89204340b444" data-root-id="77398c59-141d-4fbf-8726-d9de6a427430" style="display: contents;"></div>

# %%
meso = 'C10-AE-AE-mGAM-mGAM'
in_sample = df_abundance_coalescence.loc[df_abundance_coalescence['mesocosm']==meso,'inoculumn_sample'].unique()[0]
df_meso_good = df_abundance_coalescence.loc[(df_abundance_coalescence['mesocosm']==meso)+(df_abundance_coalescence['sample']==in_sample),:]
df_meso_good['passage'] = df_meso_good['passage'].astype(int)

df_post_gly =  df_abundance.loc[(df_abundance['mesocosm']=='B10-AE-mGAM')*(df_abundance['exp_type']=='e003GlycerolRevival'),:]
df_post_gly['passage']=6

df_meso_good['passage']=df_meso_good['passage']+7
good_cols = np.intersect1d(df_post_gly.columns.values,df_meso_good.columns.values)
df_meso = pd.concat([df_post_gly[good_cols],df_meso_good[good_cols]])

p = make_bar_plot_coalescence(df_meso,add=.2,bar_width = 2.8, passages = [6,7,8,9,10,11,12,13,14,],
                             species_emph = 102506)

p.legend.visible = False
p.xaxis.axis_label_text_font_size='15px'
p.xaxis.major_label_text_font_size='15px'
p.yaxis.axis_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
p.xaxis.minor_tick_line_color= None
p.x_range = bokeh.models.Range1d(5.5,14.5)
p.output_backend = "svg"
fname_prefix = f'{meso}_post_gly_bar_plot'
export_plot_pdf(p, fname_prefix)

bokeh.io.show(p)
# Out:
#   <div id="a3d120b2-b337-40ba-bd8d-76caaa9d088b" data-root-id="37ea90f2-6896-465f-a5c5-35a42d8f3e06" style="display: contents;"></div>

# %%
6/9
# Out:
# 0.6666666666666666
