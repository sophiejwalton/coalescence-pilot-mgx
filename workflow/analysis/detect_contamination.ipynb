# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control

from scipy.stats import chi2
from snp_analysis_tools_sherlock import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d163cb87-3bd0-4738-9865-e8b5f23d9567'>
#   <div id="b4c5d1b8-2ad9-4bcb-b977-468cf128d97f" data-root-id="d163cb87-3bd0-4738-9865-e8b5f23d9567" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4.csv')
assembly_metadata = pd.read_csv('assembly_metadata_round4.csv')
e003_metadata
# Out:
#     comm comm-media      inoculumn                        inoculumn_sample  \
# 0     A2    A2-mBHI     AA-AA-mBHI  A2-e003Coalescence-mBHI-inoculumn-redo
# 1     A3    A3-mBHI  AA-AC/PP-mBHI  A3-e003Coalescence-mBHI-inoculumn-redo
# 2     A4    A4-mBHI     AA-AE-mBHI  A4-e003Coalescence-mBHI-inoculumn-redo
# 3     A5    A5-mBHI     AA-AF-mBHI       A5-e003Coalescence-Inoculumn-mBHI
# 4     A8    A8-mBHI     AA-AA-mGAM       A2-e003Coalescence-Inoculumn-mGAM
# ..   ...        ...            ...                                     ...
# 818  E11   E11-mGAM     AA-AF-mGAM       A5-e003Coalescence-Inoculumn-mGAM
# 819   E3    E3-mBHI  AA-AC/PP-mBHI       B2-e003Coalescence-Inoculumn-mBHI
# 820   A3    A3-mGAM  AA-AC/PP-mBHI       B2-e003Coalescence-Inoculumn-mBHI
# 821   C8    C8-mGAM     AA-AE-mGAM       C2-e003Coalescence-Inoculumn-mGAM
# 822   D3    D3-mBHI  AC/PP-AF-mBHI       D3-e003Coalescence-Inoculumn-mBHI
#
# ...

# %%
fnames = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/calculateFixedDiffsFastv3/*/*_fixed_diffs.csv')
all_dfs = []
for fname in fnames:
    df = pd.read_csv(fname).drop(columns='Unnamed: 0').rename(columns = {'index': 'sample2'})
    good_samples = df.loc[df['sample2'].isin(e003_metadata['sample']),:]
    good_samples = good_samples.loc[good_samples['sample1'].isin(e003_metadata['sample']),:]
  #  good_samples['parents1'] = good_samples['sample1'].transform(lambda x: e003_metadata.loc[e003_metadata['sample']==x,'parent_subjects'].values[0])
   # good_samples['parents2'] = good_samples['sample2'].transform(lambda x: e003_metadata.loc[e003_metadata['sample']==x,
    #                                                         'parent_subjects'].values[0])
    
    all_dfs.append(good_samples)
all_dfs = pd.concat(all_dfs)
good_samples = all_dfs
all_dfs.head()
# Out:
#                           sample2  fixed_diffs  comparisons  \
# 0    A_A1_A2_AA_AA_mBHI_mBHI_2_S1          0.0    1668934.0
# 1  A_A2_A3_ACPP_AA_mBHI_mBHI_2_S2          0.0    1669349.0
# 2    A_A3_A4_AE_AA_mBHI_mBHI_2_S3          0.0    1673440.0
# 3    A_A4_A5_AF_AA_mBHI_mBHI_2_S4          0.0    1672016.0
# 4  A_A11_A4_AE_AA_mBHI_mBHI_4_S11          0.0    1669241.0
#
#                         sample1  species_id  num_int_sites
# 0  A_A1_A2_AA_AA_mBHI_mBHI_2_S1      100296            NaN
# 1  A_A1_A2_AA_AA_mBHI_mBHI_2_S1      100296            NaN
# 2  A_A1_A2_AA_AA_mBHI_mBHI_2_S1      100296            NaN
# 3  A_A1_A2_AA_AA_mBHI_mBHI_2_S1      100296            NaN
# 4  A_A1_A2_AA_AA_mBHI_mBHI_2_S1      100296            NaN

# %%
good_samples['parents1'] = np.nan
good_samples['parents2'] = np.nan
for parent_subjects in e003_metadata['parent_subjects'].unique():
    samples_parent =  e003_metadata.loc[e003_metadata['parent_subjects']==parent_subjects,'sample'].unique()
    good_samples.loc[good_samples['sample1'].isin(samples_parent),'parents1']=parent_subjects
    good_samples.loc[good_samples['sample2'].isin(samples_parent),'parents2']=parent_subjects
good_samples['passage1'] = np.nan
good_samples['passage2'] = np.nan
for parent_subjects in e003_metadata['passage'].unique():
    samples_parent =  e003_metadata.loc[e003_metadata['passage']==parent_subjects,'sample'].unique()
    good_samples.loc[good_samples['sample1'].isin(samples_parent),'passage1']=parent_subjects
    good_samples.loc[good_samples['sample2'].isin(samples_parent),'passage2']=parent_subjects

good_samples['type_mesocosm1'] = np.nan
good_samples['type_mesocosm2'] = np.nan
for parent_subjects in e003_metadata['type_mesocosm'].unique():
    samples_parent =  e003_metadata.loc[e003_metadata['type_mesocosm']==parent_subjects,'sample'].unique()
    good_samples.loc[good_samples['sample1'].isin(samples_parent),'type_mesocosm1']=parent_subjects
    good_samples.loc[good_samples['sample2'].isin(samples_parent),'type_mesocosm2']=parent_subjects

good_samples['mesocosm1'] = np.nan
good_samples['mesocosm2'] = np.nan
for parent_subjects in e003_metadata['mesocosm'].unique():
    samples_parent =  e003_metadata.loc[e003_metadata['mesocosm']==parent_subjects,'sample'].unique()
    good_samples.loc[good_samples['sample1'].isin(samples_parent),'mesocosm1']=parent_subjects
    good_samples.loc[good_samples['sample2'].isin(samples_parent),'mesocosm2']=parent_subjects

good_samples['inocula1'] = np.nan
good_samples['inocula2'] = np.nan
for parent_subjects in e003_metadata['inoculumn'].unique():
    samples_parent =  e003_metadata.loc[e003_metadata['inoculumn']==parent_subjects,'sample'].unique()
    good_samples.loc[good_samples['sample1'].isin(samples_parent),'inocula1']=parent_subjects
    good_samples.loc[good_samples['sample2'].isin(samples_parent),'inocula2']=parent_subjects
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/3545092661.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'AA-AA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   good_samples.loc[good_samples['sample1'].isin(samples_parent),'parents1']=parent_subjects
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/3545092661.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'AA-AA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   good_samples.loc[good_samples['sample2'].isin(samples_parent),'parents2']=parent_subjects
# ...

# %%
good_samples['passage1'].unique()
# Out:
# array([2., 4., 6., 3., 7., 5., 0., 1.])

# %%
ss_samples = e003_metadata.loc[e003_metadata['is_inoculumn'],:]
ss_samples = e003_metadata.loc[e003_metadata['parent_subjects'].isin(['AA-AA','AE-AE','AF-AF']),'sample'].values

# %%
good_samples_ssp1 = good_samples.loc[good_samples['sample1'].isin(ss_samples),:]
good_samples_ssp1['subject_sharing'] = good_samples_ssp1['parents1'].transform(lambda x: x.split('-')[0]) + '_' + good_samples_ssp1['parents2']
good_samples_ssp1['subject_sharing'] = good_samples_ssp1['subject_sharing'].transform(lambda x: x.split('_')[0] in x.split('_')[1])
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/122547295.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_samples_ssp1['subject_sharing'] = good_samples_ssp1['parents1'].transform(lambda x: x.split('-')[0]) + '_' + good_samples_ssp1['parents2']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/122547295.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
good_samples_ssp1_not_shared = good_samples_ssp1.loc[~good_samples_ssp1['subject_sharing'],:]
good_samples_ssp1_not_shared['abnormal'] = good_samples_ssp1_not_shared['fixed_diffs']<10
good_samples_ssp1_not_shared['counts']=1
good_samples_ssp1_not_shared_gr = good_samples_ssp1_not_shared.groupby(['sample2','parents2','sample1','parents1',
                                                                       'type_mesocosm1','type_mesocosm2']).sum(numeric_only=True).reset_index()
good_samples_ssp1_not_shared_gr_ab = good_samples_ssp1_not_shared_gr.loc[good_samples_ssp1_not_shared_gr['abnormal']>=0,:]
b=good_samples_ssp1_not_shared_gr_ab.loc[good_samples_ssp1_not_shared_gr_ab['parents2'].isin(['AA-AE','AA-AF','AE-AF',
                                                                                             # 'AC/PP-AE','AC/PP-AF','AA-AC/PP',
                                                                                           'AA-AA','AE-AE','AF-AF']),:]
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/3428462137.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_samples_ssp1_not_shared['abnormal'] = good_samples_ssp1_not_shared['fixed_diffs']<10
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/3428462137.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_samples_ssp1_not_shared['counts']=1

# %%
bgood = b.loc[b['abnormal']<3,:]
bgood
print(len(bgood['sample2'].unique()))
# Out:
# 488

# %%
len(b['sample2'].unique())
# Out:
# 488

# %%
len(bbad['sample1'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 len(bbad['sample1'].unique())
#
# NameError: name 'bbad' is not defined

# %%
bbad = b.loc[b['abnormal']>3,:]
print(len(bbad['sample2'].unique()))
bbad['counts']=1
c=bbad.groupby(['sample2','parents2']).sum()
c.loc[c['counts']>1,:]  
bad_ones = ['C4-e003Coalescence-mBHI-p1_S734',
            'Coalescence-B11-H11-AF-AF-mGAM-mBHI-7_S642',
            'Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673',
            'E8-e003Coalescence-mGAM-p3_S153',
            'G100-e003Coalescence-mBHI-p3_S131'
            'G100-e003Coalescence-mGAM-p5_S79',
           'C4-e003Coalescence-mBHI-p1_S734',
           'E8-e003Coalescence-mGAM-p3_S153',
            'G100-e003Coalescence-mBHI-p3_S131'
           ]

bbad = bbad.loc[~bbad['sample2'].isin(bad_ones),:]
c=bbad.groupby(['sample1','parents1']).sum()        
c.loc[c['counts']>1,:]
# Out:
# 0
# Empty DataFrame
# Columns: [sample2, parents2, type_mesocosm1, type_mesocosm2, fixed_diffs, comparisons, species_id, num_int_sites, passage1, passage2, subject_sharing, abnormal, counts]
# Index: []

# %%
pot_bad_samples = ['A4-e003Coalescence-mGAM-p5', 'C4-e003Coalescence-mBHI-p1_S734',
       'Coalescence-B11-H11-AF-AF-mGAM-mBHI-7_S642',
       'Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673',
       'Coalescence-G1-H5-AF-AF-mBHI-mBHI-3_S692',
       'D5-e003Coalescence-mBHI-p5', 'D5-e003Coalescence-mBHI-p7',
       'E8-e003Coalescence-mBHI-p7_S101',
       'E8-e003Coalescence-mGAM-p3_S153',
       'G100-e003Coalescence-mBHI-p3_S131',
       'H5-e003Coalescence-mBHI-p7_S136']

real_bad = ['A4-e003Coalescence-mGAM-p5', 'D5-e003Coalescence-mBHI-p5', 'C4-e003Coalescence-mBHI-p1_S734',
            'B3-e003Coalescence-mBHI-p3',
           'G100-e003Coalescence-mBHI-p3_S131']    

realrealbad = ['C4-e003Coalescence-mBHI-p1_S734',
            'Coalescence-B11-H11-AF-AF-mGAM-mBHI-7_S642',
            'Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673',
            'E8-e003Coalescence-mGAM-p3_S153',
            'G100-e003Coalescence-mBHI-p3_S131',
            'G100-e003Coalescence-mGAM-p5_S79',
           'C4-e003Coalescence-mBHI-p1_S734',
           'E8-e003Coalescence-mGAM-p3_S153',
            'G100-e003Coalescence-mBHI-p3_S131'
               'C_D12_H5_AF_AF_mBHI_mBHI_4_S240',
               'C_D4_D5_AF_AF_mBHI_mBHI_6_S232',
               'D_D4_D5_AF_AF_mBHI_mBHI_6_S328',
               'C_D12_H5_AF_AF_mBHI_mBHI_4_S240',
               'B_A3_E4_AE_AA_mBHI_mBHI_2_S99',
           ]

# %%
realbad2 = real_bad   + pot_bad_samples + realrealbad
good_samples_ssp1_not_shared['abnormal'] = good_samples_ssp1_not_shared['fixed_diffs']<10
good_samples_ssp1_not_shared['counts']=1
good_samples_ssp1_not_shared = good_samples_ssp1_not_shared.loc[~good_samples_ssp1_not_shared['sample1'].isin(realbad2),:]
good_samples_ssp1_not_shared = good_samples_ssp1_not_shared.loc[~good_samples_ssp1_not_shared['sample2'].isin(realbad2),:]

good_samples_ssp1_not_shared_gr = good_samples_ssp1_not_shared.groupby(['sample2','parents2','sample1','parents1',
                                                                       'type_mesocosm1','type_mesocosm2']).sum(numeric_only=True).reset_index()
good_samples_ssp1_not_shared_gr_ab = good_samples_ssp1_not_shared_gr.loc[good_samples_ssp1_not_shared_gr['abnormal']>=0,:]

b=good_samples_ssp1_not_shared_gr_ab.loc[good_samples_ssp1_not_shared_gr_ab['parents2'].isin(['AA-AE','AA-AF','AE-AF',
                                                                                             # 'AC/PP-AE','AC/PP-AF','AA-AC/PP',
                                                                                           'AA-AA','AE-AE','AF-AF']),:]
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/1476305703.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_samples_ssp1_not_shared['abnormal'] = good_samples_ssp1_not_shared['fixed_diffs']<10
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/1476305703.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_samples_ssp1_not_shared['counts']=1

# %%
c=b.loc[b['abnormal']>2,:]
c['counts']=1
c.groupby(['sample2','parents2']).sum()
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/4108181592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['counts']=1
#                                                                                              sample1  \
# sample2                                  parents2
# A_A11_A4_AE_AA_mBHI_mBHI_4_S11           AA-AE     A_D12_D5_AF_AF_mBHI_mBHI_4_S48A_D4_D5_AF_AF_mB...
# A_D12_D5_AF_AF_mBHI_mBHI_4_S48           AF-AF              Coalescence-E5-C4-AE-AE-mBHI-mBHI-3_S672
# A_D4_D5_AF_AF_mBHI_mBHI_2_S40            AF-AF              Coalescence-E5-C4-AE-AE-mBHI-mBHI-3_S672
# B_A11_A10_AE_AA_mGAM_mBHI_4_S107         AA-AE     A_D12_D5_AF_AF_mBHI_mBHI_4_S48A_D4_D5_AF_AF_mB...
# ...

# %%
num_comparisons = all_dfs.groupby(['sample2','species_id']).median(numeric_only=True).reset_index()
num_comparisons['counts']=1
num_comparisons = num_comparisons.groupby(['sample2']).sum().reset_index()
#all_dfs['parents1'].unique()

# %%
e003_metadata_good = e003_metadata.loc[~e003_metadata['sample'].isin(realbad2),:]

e003_metadata_good['counts']=1
#e003_metadata_good['comparisons'] = e003_metadata_good['sample'].transform(lambda x:num_comparisons.loc[x,'counts'])
e003_metadata_good['mesocosm-passage']=e003_metadata_good['mesocosm']+e003_metadata_good['passage'].astype(str)
e003_metadata_good = e003_metadata_good.loc[e003_metadata_good['sample'].isin(num_comparisons['sample2'].values),:]

grd =e003_metadata_good.groupby(['mesocosm','passage','type_mesocosm','mesocosm-passage']).sum(numeric_only=True) #.drop(columns='Unnamed: 0')
grd_mult  = grd.loc[grd['counts']>1,:].reset_index()
for grd_m in grd_mult['mesocosm-passage'].values:
    samples = e003_metadata_good.loc[e003_metadata_good['mesocosm-passage']==grd_m,'sample']
    good_samples = np.intersect1d(num_comparisons['sample2'].unique(),samples)
    
    print(num_comparisons.loc[num_comparisons['sample2'].isin(good_samples),['sample2','counts']])
    print(np.intersect1d(good_samples, pot_bad_samples))
#more_dont_use = ['Coalescence-A1-A4-AA-AE-mBHI-mBHI-7_S620','Coalescence-E7-C8-AA-AE-mGAM-mGAM-3_S674','E111-e003Coalescence-mGAM-p7_S152',
 #                'Coalescence-F6-G3-ACPP-AE-mBHI-mBHI-3_S685']
# Out:
#                                    sample2  counts
# 14       A2-e003Coalescence-Inoculumn-mBHI      21
# 16  A2-e003Coalescence-mBHI-inoculumn-redo      22
# []
#                                    sample2  counts
# 37       A5-e003Coalescence-Inoculumn-mBHI      18
# 39  A5-e003Coalescence-mBHI-inoculumn-redo      22
# []
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/897446688.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   e003_metadata_good['counts']=1
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_56889/897446688.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
e003_metadata_good.to_csv('e003_coalescence_metadata_round4_good.csv')

# %%
e003_metadata_good['replicate']=0.
for meso in e003_metadata_good['type_mesocosm'].unique():
    num_reps = len(e003_metadata_good.loc[(e003_metadata_good['type_mesocosm']==meso)*(e003_metadata_good['passage']>0),'replicate'])
    e003_metadata_good.loc[(e003_metadata_good['type_mesocosm']==meso)*(e003_metadata_good['passage']>0),'replicate']= np.arange(num_reps)
e003_metadata_good.to_csv('e003_coalescence_metadata_round4_good.csv')
e003_metadata_good.head()
# Out:
#   comm comm-media      inoculumn                        inoculumn_sample  \
# 0   A2    A2-mBHI     AA-AA-mBHI  A2-e003Coalescence-mBHI-inoculumn-redo
# 1   A3    A3-mBHI  AA-AC/PP-mBHI  A3-e003Coalescence-mBHI-inoculumn-redo
# 2   A4    A4-mBHI     AA-AE-mBHI  A4-e003Coalescence-mBHI-inoculumn-redo
# 3   A5    A5-mBHI     AA-AF-mBHI       A5-e003Coalescence-Inoculumn-mBHI
# 4   A8    A8-mBHI     AA-AA-mGAM       A2-e003Coalescence-Inoculumn-mGAM
#
#    is_inoculumn media               mesocosm parent_media parent_subjects  \
# 0         False  mBHI     A2-AA-AA-mBHI-mBHI         mBHI           AA-AA
# 1         False  mBHI  A3-AA-AC/PP-mBHI-mBHI         mBHI        AA-AC/PP
# 2         False  mBHI     A4-AA-AE-mBHI-mBHI         mBHI           AA-AE
# 3         False  mBHI     A5-AA-AF-mBHI-mBHI         mBHI           AA-AF
# 4         False  mBHI     A8-AA-AA-mGAM-mBHI         mGAM           AA-AA
#
#    passage                          sample       type_mesocosm   redo  counts  \
# ...

# %%
good_samples_ssp1_not_shared_gr_ab = good_samples_ssp1_not_shared_gr.loc[good_samples_ssp1_not_shared_gr['abnormal']>0,:]
b=good_samples_ssp1_not_shared_gr_ab.loc[good_samples_ssp1_not_shared_gr_ab['parents2'].isin([ 'AC/PP-AE','AC/PP-AF','AA-AC/PP',
                                                                                           'AC/PP-AC/PP']),:]
bad_sp = ['100196','102320','100099',]
#b=b.loc[~b['species_id'].isin(bad_sp),:]
bc=b.loc[b['abnormal']>1,:]
bc.loc[bc['parents1']=='AA-AA',:]

# %%
bad = 'E8-e003Coalescence-mGAM-p3_S153'
bad2='G100-e003Coalescence-mBHI-p3_S131'
list(GOOD_SAMPLES).remove(bad)
list(GOOD_SAMPLES).remove(bad2)

# %%
#GOOD_SAMPLES=list(GOOD_SAMPLES).remove(bad)
bad in GOOD_SAMPLES

# %%
good_samples_ss = good_samples.loc[good_samples['parents1'].isin(['AA-AA','AE-AE','AF-AF']),:]
good_samples_ss=good_samples_ss.loc[good_samples_ss['sample1']!='A2-e003Coalescence-Inoculumn-mBHI',:]
good_samples_ss=good_samples_ss.loc[good_samples_ss['sample2']!='A2-e003Coalescence-Inoculumn-mBHI',:]
GOOD_SAMPLES = list(pd.read_csv('e003_with_passage_one_redo_good.csv')['sample'].values)
bad = 'E8-e003Coalescence-mGAM-p3_S153'
bad2='G100-e003Coalescence-mBHI-p3_S131'
GOOD_SAMPLES.remove(bad)
GOOD_SAMPLES.remove(bad2)
good_samples_ss=good_samples_ss.loc[good_samples_ss['sample1'].isin(GOOD_SAMPLES),:]
good_samples_ss=good_samples_ss.loc[good_samples_ss['sample2'].isin(GOOD_SAMPLES),:]

good_samples_ss = good_samples_ss.loc[good_samples_ss['parents1']==good_samples_ss['parents2'],:]
good_samples_ss_b = good_samples_ss.loc[good_samples_ss['sample1']=='A2-e003Coalescence-mBHI-inoculumn-redo',:]


good_samples_ss=good_samples_ss.loc[good_samples_ss['sample1']!=good_samples_ss['sample2'],:]
#good_samples_ss_b.loc[good_samples_ss_b['species_id']==102506,:].sort_values(by='fixed_diffs')

# %%
good_samples_ss=good_samples.loc[good_samples['type_mesocosm1'].isin(['AF-AF-mBHI-mBHI','AF-AF-mGAM-mGAM',
                                                                            'AE-AE-mBHI-mBHI','AE-AE-mGAM-mGAM',
                                                                            'AA-AA-mBHI-mBHI','AA-AA-mGAM-mGAM']),:]

good_samples_ss=good_samples_ss.loc[good_samples_ss['type_mesocosm2'].isin(['AF-AF-mBHI-mBHI','AF-AF-mGAM-mGAM',
                                                                            'AE-AE-mBHI-mBHI','AE-AE-mGAM-mGAM',
                                                                            'AA-AA-mBHI-mBHI','AA-AA-mGAM-mGAM']),:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 good_samples_ss=good_samples.loc[good_samples['type_mesocosm1'].isin(['AF-AF-mBHI-mBHI','AF-AF-mGAM-mGAM',
#       2                                                                             'AE-AE-mBHI-mBHI','AE-AE-mGAM-mGAM',
#       3                                                                             'AA-AA-mBHI-mBHI','AA-AA-mGAM-mGAM']),:]
#       5 good_samples_ss=good_samples_ss.loc[good_samples_ss['type_mesocosm2'].isin(['AF-AF-mBHI-mBHI','AF-AF-mGAM-mGAM',
#       6                                                                             'AE-AE-mBHI-mBHI','AE-AE-mGAM-mGAM',
#       7                                                                             'AA-AA-mBHI-mBHI','AA-AA-mGAM-mGAM']),:]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'loc'

# %%
good_samples_ss['log_fixed_diffs']=np.log10(1+good_samples_ss['fixed_diffs'])
good_samples_ss['passage12']=good_samples_ss['passage1'].astype(str)+'-'+good_samples_ss['passage2'].astype(str)
good_samples_ss['passage12']=good_samples_ss['passage12'].transform(lambda x: '-'.join(np.sort(x.split('-'))))
to_plot=good_samples_ss.loc[good_samples_ss['type_mesocosm1']==good_samples_ss['type_mesocosm2'],:]
to_plot=to_plot.loc[to_plot['sample1']!=to_plot['sample2'],:]
to_plot['same_mesocosm']=to_plot['mesocosm1']==to_plot['mesocosm2']
for parents in ['AA-AA','AE-AE','AF-AF',]:
    to_plot2=to_plot.loc[to_plot['parents1']==parents,:]
   # b=to_plot2.loc[to_plot2['passage1']==7,:]
    for passage2 in to_plot2['passage2'].unique():
        p=iqplot.strip(to_plot2.loc[to_plot2['passage1']==passage2,:].sort_values(by='passage12'),
                        q='log_fixed_diffs',cats = ['passage12','same_mesocosm'],height=300, color_column='same_mesocosm',#conf_int=True,
                      title = f'{parents} and {passage2}',jitter=True,
                      #color_column='parents1',#jitter=True,
                      )
        bokeh.io.show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 good_samples_ss['log_fixed_diffs']=np.log10(1+good_samples_ss['fixed_diffs'])
#       2 good_samples_ss['passage12']=good_samples_ss['passage1'].astype(str)+'-'+good_samples_ss['passage2'].astype(str)
#       3 good_samples_ss['passage12']=good_samples_ss['passage12'].transform(lambda x: '-'.join(np.sort(x.split('-'))))
#
# NameError: name 'good_samples_ss' is not defined

# %%
good_samples_ss['log_fixed_diffs']=np.log10(1+good_samples_ss['fixed_diffs'])
good_samples_ss['passage12']=good_samples_ss['passage1'].astype(str)+'-'+good_samples_ss['passage2'].astype(str)
good_samples_ss['passage12']=good_samples_ss['passage12'].transform(lambda x: '-'.join(np.sort(x.split('-'))))
to_plot=good_samples_ss.loc[good_samples_ss['inocula1']==good_samples_ss['inocula2'],:]
#to_plot=to_plot.loc[to_plot['sample1']!=to_plot['sample2'],:]
to_plot['same_mesocosm']=to_plot['mesocosm1']==to_plot['mesocosm2']
to_plot['same_media']=to_plot['type_mesocosm1']==to_plot['type_mesocosm2']
#for passage2 in to_plot2['passage2'].unique():
p=iqplot.strip(to_plot.loc[to_plot['passage12'].isin(['0.0-1.0','1.0-3.0','3.0-5.0','5.0-7.0']),:].sort_values(by='passage12'),
                        q='log_fixed_diffs',cats = ['passage12', 'same_media'],height=400, color_column='same_mesocosm',#conf_int=True,
                      title = f'{passage2}',jitter=True,
                       marker_kwargs=dict(alpha=.5),
                      #color_column='parents1',#jitter=True,
                      )
bokeh.io.show(p)
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_5377/2951273664.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_plot['same_mesocosm']=to_plot['mesocosm1']==to_plot['mesocosm2']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_5377/2951273664.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_plot['same_media']=to_plot['type_mesocosm1']==to_plot['type_mesocosm2']
# ...

# %%
to_plot=to_plot.loc[(to_plot['log_fixed_diffs']>3)+(to_plot['log_fixed_diffs']<2),:]
to_plot['strain_shift']=to_plot['log_fixed_diffs']>3
to_plot['counts']=1
to_plot_num_shifts = to_plot.groupby(['sample1','sample2','mesocosm1','mesocosm2','same_media','same_mesocosm',
                                      'passage1','passage2','passage12']).sum(numeric_only=True).reset_index()
to_plot_num_shifts['frac_shifts']=to_plot_num_shifts['strain_shift']/to_plot_num_shifts['counts']
to_plot_num_shifts['same_point']=to_plot_num_shifts['passage1']==to_plot_num_shifts['passage2']
plot=to_plot_num_shifts.loc[to_plot_num_shifts['passage12'].isin(['0.0-1.0','1.0-3.0','3.0-5.0','5.0-7.0','0.0-0.0','1.0-1.0','3.0-3.0','5.0-5.0','7.0-7.0']),:].sort_values(by='passage12')

p=iqplot.ecdf(plot, #.loc[plot['same_mesocosm'],:],
                        q='strain_shift',cats = ['passage12','same_mesocosm'],height=400, #color_column='same_mesocosm',#conf_int=True,
                      title = f'{passage2}',#jitter=True,
                       marker_kwargs=dict(alpha=.5),
                      #color_column='parents1',#jitter=True,
                      )
bokeh.io.show(p)
# Out:
#   <div id="ffd4bb9b-f44d-453c-83db-a8110b5facfa" data-root-id="3cfc4c60-87c7-4cfd-bf79-1abd87db44f9" style="display: contents;"></div>

# %%
to_plot_num_shifts['same_point']=to_plot_num_shifts['passage1']==to_plot_num_shifts['passage2']
to_plot_num_shifts.groupby(['same_mesocosm','same_media','same_point']).mean(numeric_only=True)
# Out:
#                                      passage1  passage2  fixed_diffs  \
# same_mesocosm same_media same_point
# False         False      False       3.701365  3.701365  9873.634812
#                          True        4.073171  4.073171  8472.243902
#               True       False       3.605769  3.605769  7765.445513
#                          True        4.047619  4.047619  6279.392857
# True          True       False       3.882576  3.882576  8033.439394
#
#                                      num_int_sites    species_id  \
# same_mesocosm same_media same_point
# False         False      False        2.683493e+07  1.033729e+06
#                          True         2.589602e+07  9.830065e+05
#               True       False        2.923271e+07  1.172858e+06
#                          True         2.980051e+07  1.182718e+06
# True          True       False        2.920803e+07  1.175489e+06
#
#                                      log_fixed_diffs  strain_shift     counts  \
# ...

# %%
b=plot.sort_values(by='frac_shifts',ascending=False)
b=b.loc[b['same_mesocosm'],:]
b #.loc[b['frac_shifts']==1,:]
# Out:
#                                        sample1  \
# 203           C10-e003Coalescence-mBHI-p1_S766
# 506   Coalescence-D6-A2-AA-AA-mBHI-mGAM-3_S661
# 1261          H111-e003Coalescence-mBHI-p5_S44
# 1167           G4-e003Coalescence-mGAM-p1_S802
# 670            D5-e003Coalescence-mBHI-p1_S743
# ...                                        ...
# 1242          H11-e003Coalescence-mGAM-p1_S843
# 30                  A2-e003Coalescence-mBHI-p3
# 46                  A2-e003Coalescence-mBHI-p5
# 1346            H5-e003Coalescence-mBHI-p5_S40
# 1304          H111-e003Coalescence-mGAM-p5_S92
#
#                                          sample2            mesocosm1  \
# 203                  C10-e003Coalescence-mBHI-p3  C10-AE-AE-mGAM-mBHI
# 506              A2-e003Coalescence-mGAM-p1_S720   A2-AA-AA-mBHI-mGAM
# 1261  Coalescence-B11-H11-AF-AF-mGAM-mBHI-7_S642  H11-AF-AF-mGAM-mBHI
# 1167              G4-e003Coalescence-mGAM-p3_S83   G4-AE-AE-mBHI-mGAM
# ...

# %%
to_plot2=to_plot.loc[to_plot['parents1']==parents,:]
to_plot2
# Out:
#                                            sample2  fixed_diffs  \
# 254      Coalescence-B12-H5-AF-AF-mBHI-mGAM-7_S643          7.0
# 346                H5-e003Coalescence-mGAM-p1_S811          8.0
# 16       Coalescence-E8-D11-AF-AF-mGAM-mBHI-3_S675         76.0
# 31                D11-e003Coalescence-mBHI-p1_S775         73.0
# 99      Coalescence-A12-D11-AF-AF-mGAM-mBHI-7_S631         24.0
# ...                                            ...          ...
# 138569    Coalescence-G1-H5-AF-AF-mBHI-mBHI-3_S692          0.0
# 138595             H5-e003Coalescence-mBHI-p7_S136          0.0
# 146434             H5-e003Coalescence-mBHI-p1_S807          0.0
# 146654    Coalescence-G1-H5-AF-AF-mBHI-mBHI-3_S692          0.0
# 146659              H5-e003Coalescence-mBHI-p5_S40          0.0
#
#         num_int_sites                                    sample1  species_id  \
# 254           2360447            H5-e003Coalescence-mGAM-p1_S811      100032
# ...

# %%
b.loc[b['passage2']==7,:]
# Out:
#                                            sample2  fixed_diffs  \
# 2628    Coalescence-B11-H11-AF-AF-mGAM-mBHI-7_S642          0.0
# 350      Coalescence-B12-H5-AF-AF-mBHI-mGAM-7_S643          0.0
# 10206    Coalescence-B12-H5-AF-AF-mBHI-mGAM-7_S643          0.0
# 10332                  D11-e003Coalescence-mGAM-p7          0.0
# 10346            H111-e003Coalescence-mGAM-p7_S188         20.0
# ...                                            ...          ...
# 123815  Coalescence-B11-H11-AF-AF-mGAM-mBHI-7_S642          0.0
# 123906  Coalescence-A12-D11-AF-AF-mGAM-mBHI-7_S631          0.0
# 146373                  D5-e003Coalescence-mBHI-p7         10.0
# 146680             H5-e003Coalescence-mBHI-p7_S136          0.0
# 276      Coalescence-B12-H5-AF-AF-mBHI-mGAM-7_S643          0.0
#
#         num_int_sites                                     sample1  species_id  \
# 2628          2147280  Coalescence-B11-H11-AF-AF-mGAM-mBHI-7_S642      100035
# ...

# %% [markdown]
# ## now for assembly

# %%
fnames = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/calculateFixedDiffsFastv3/*/*_fixed_diffs.csv')
all_dfs = []
for fname in fnames:
    df = pd.read_csv(fname).drop(columns='Unnamed: 0').rename(columns = {'index': 'sample2'})
    good_samples = df.loc[df['sample2'].isin(assembly_metadata['sample']),:]
    good_samples = good_samples.loc[good_samples['sample1'].isin(assembly_metadata['sample']),:]
  #  good_samples['parents1'] = good_samples['sample1'].transform(lambda x: e003_metadata.loc[e003_metadata['sample']==x,'parent_subjects'].values[0])
   # good_samples['parents2'] = good_samples['sample2'].transform(lambda x: e003_metadata.loc[e003_metadata['sample']==x,
    #                                                         'parent_subjects'].values[0])
    
    all_dfs.append(good_samples)
all_dfs = pd.concat(all_dfs)
good_samples = all_dfs
all_dfs.head()
# Out:
#                             sample2  fixed_diffs  num_int_sites  \
# 1904        B2-e003Assembly-mBHI-p5          0.0      1669003.0
# 1952        D2-e003Assembly-mBHI-p3         25.0      1659761.0
# 1958        C2-e003Assembly-mBHI-p5          4.0      1677673.0
# 1962        D2-e003Assembly-mBHI-p5         28.0      1677031.0
# 1963  Assembly-G6-C2-AA-mBHI-3_S697         33.0      1674447.0
#
#                       sample1  species_id  comparisons
# 1904  B2-e003Assembly-mBHI-p5      100296          NaN
# 1952  B2-e003Assembly-mBHI-p5      100296          NaN
# 1958  B2-e003Assembly-mBHI-p5      100296          NaN
# 1962  B2-e003Assembly-mBHI-p5      100296          NaN
# 1963  B2-e003Assembly-mBHI-p5      100296          NaN

# %%
good_samples = all_dfs.loc[all_dfs['sample2'].isin(assembly_metadata['sample']),:]
good_samples = good_samples.loc[good_samples['sample1'].isin(assembly_metadata['sample']),:]
good_samples['parents1'] = good_samples['sample1'].transform(lambda x: assembly_metadata.loc[assembly_metadata['sample']==x,
                                                             'subject'].values[0])
good_samples['parents2'] = good_samples['sample2'].transform(lambda x: assembly_metadata.loc[assembly_metadata['sample']==x,
                                                             'subject'].values[0])

# %%
good_samples['subject_sharing'] = good_samples['parents1'] ==  good_samples['parents2']
good_samples_not_shared = good_samples.loc[~good_samples['subject_sharing'],:]
good_samples_not_shared['abnormal'] = good_samples_not_shared['fixed_diffs']<10
good_samples_not_shared['counts']=1
good_samples_ssp1_not_shared_gr = good_samples_not_shared.groupby(['sample2','parents2','sample1','parents1',]).sum().reset_index()
good_samples_ssp1_not_shared_gr_ab = good_samples_ssp1_not_shared_gr.loc[good_samples_ssp1_not_shared_gr['abnormal']>2,:]
good_samples_ssp1_not_shared_gr_ab
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_85717/2882019841.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_samples_not_shared['abnormal'] = good_samples_not_shared['fixed_diffs']<10
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_85717/2882019841.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_samples_not_shared['counts']=1
#                               sample2 parents2  \
# 209   Assembly-G2-B3-ACPP-mBHI-3_S693    AC/PP
# ...

# %%
real_bad = []
pot_bad = ['C9-e003GlycerolRevival-mGAM-p2','C4-e003GlycerolRevival-mBHI-p2','	C3-e003GlycerolRevival-mBHI-p2']
pot_bad_ACPP=['C9-e003GlycerolRevival-mGAM-p2']
# Out:
#                                         sample2  fixed_diffs  num_int_sites  \
# 0               C2-e003Coalescence-mGAM-p1_S722          0.0        1674565
# 1                E4-e003Coalescence-mBHI-p7_S99          1.0        1674551
# 3                    B2-e003Coalescence-mBHI-p3          9.0        1680658
# 4               C2-e003Coalescence-mBHI-p1_S718          1.0        1674702
# 5                    A4-e003Coalescence-mBHI-p7          8.0        1683815
# ...                                         ...          ...            ...
# 17951           G2-e003Coalescence-mGAM-p1_S786         72.0        1449605
# 17952  Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673        291.0        4008621
# 17953               A11-e003Coalescence-mGAM-p3          2.0        1828156
# 17954           E8-e003Coalescence-mGAM-p7_S149         16.0        3951585
# 17955                D2-e003Coalescence-mBHI-p3          0.0        3856192
#
# ...
