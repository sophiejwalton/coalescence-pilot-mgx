# %%
import pandas as pd
import numpy as np
import iqplot
from scipy.spatial.distance import jensenshannon

import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
import itertools as it
from bokeh.layouts import gridplot

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f42a80a4-15d7-4366-ac98-9bb315fbbbe6'>
#   <div id="a75ddfd3-dc47-49ed-983c-2a49380a2ede" data-root-id="f42a80a4-15d7-4366-ac98-9bb315fbbbe6" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/species/species_relative_abundance.tsv'
df_abundance = pd.read_csv(fname, delimiter = '\t')
df_abundance
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_abundance_melted = pd.melt(df_abundance, 
                                  var_name = 'sample', 
                                  id_vars='species_id',
                                  value_name = 'relative_abundance')


df_abundance_melted = transform_df(df_abundance_melted)
df_abundance_melted.head()
# Out:
#    species_id                       sample  relative_abundance  \
# 0      102506  C12-e003Coalescence-mBHI-p3               0.187
# 1      102320  C12-e003Coalescence-mBHI-p3               0.121
# 2      100099  C12-e003Coalescence-mBHI-p3               0.119
# 3      100196  C12-e003Coalescence-mBHI-p3               0.123
# 4      101346  C12-e003Coalescence-mBHI-p3               0.038
#
#                                              Lineage  \
# 0  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 1  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# 3  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 4  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                            species              genus                 family  \
# 0            s__Escherichia coli_D     g__Escherichia  f__Enterobacteriaceae
# 1      s__Enterococcus_B faecium_B  g__Enterococcus_B     f__Enterococcaceae
# ...

# %%
e003_metadata = pd.read_csv('e003_with_passage_one_redo_good.csv').drop(columns = 'Unnamed: 0').set_index('sample')
df_abundance_melted_coal = df_abundance_melted.loc[df_abundance_melted['sample'].isin(e003_metadata.index.values),:]

df_abundance_melted_coal_abundant_families = df_abundance_melted_coal.groupby(['family']).sum().sort_values(by='relative_abundance',
                                                                                                            ascending=False)

df_abundance_melted_coal['family_sp'] = df_abundance_melted_coal['family'] + '-' + df_abundance_melted_coal['species']
df_abundance_melted_coal_abundant_families

family_palettes = {'f__Bacteroidaceae': bokeh.palettes.PuRd[9],
                   'f__Enterobacteriaceae': bokeh.palettes.Category20c[20][:4],
                   'f__Porphyromonadaceae': bokeh.palettes.Category20c[20][4:8],
                   'f__Oscillospiraceae': bokeh.palettes.Category20c[20][8:12],
                   'f__Peptoniphilaceae': bokeh.palettes.Category20c[20][12:16],
                   'f__Tannerellaceae': bokeh.palettes.Category20b[20][8:12],
                   'f__Enterococcaceae':bokeh.palettes.Category20b[20][12:16],
                   'f__Lachnospiraceae': bokeh.palettes.varying_alpha_palette(bokeh.palettes.Reds[9][1],20),
                   'f__Veillonellaceae':bokeh.palettes.Category20b[20][4:8],
                   'f_other':bokeh.palettes.Accent[4],
}
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33238/2641892595.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abundance_melted_coal['family_sp'] = df_abundance_melted_coal['family'] + '-' + df_abundance_melted_coal['species']

# %%
df_abundance_melted_coal['mesocosm']=df_abundance_melted_coal['sample'].transform(lambda x: e003_metadata.loc[x,'mesocosm'])
df_abundance_melted_coal['passage']=df_abundance_melted_coal['sample'].transform(lambda x: e003_metadata.loc[x,'passage'])
df_abundance_melted_coal['media']=df_abundance_melted_coal['sample'].transform(lambda x: e003_metadata.loc[x,'media'])
df_abundance_melted_coal['parent_media']=df_abundance_melted_coal['sample'].transform(lambda x: e003_metadata.loc[x,'parent_media'])
df_abundance_melted_coal['inoculumn_sample']=df_abundance_melted_coal['sample'].transform(lambda x: e003_metadata.loc[x,'inoculumn_sample'])
df_abundance_melted_coal['type_mesocosm']=df_abundance_melted_coal['sample'].transform(lambda x: e003_metadata.loc[x,'type_mesocosm'])
df_abundance_melted_coal['parent_subjects']=df_abundance_melted_coal['sample'].transform(lambda x: e003_metadata.loc[x,'parent_subjects'])
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33238/4228964252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abundance_melted_coal['mesocosm']=df_abundance_melted_coal['sample'].transform(lambda x: e003_metadata.loc[x,'mesocosm'])
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33238/4228964252.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_abundance_melted_coal['counts']=1
df_abundance_melted_coal_alpha = df_abundance_melted_coal.loc[df_abundance_melted_coal['relative_abundance']>.001,:]
df_abundance_melted_coal_alpha= df_abundance_melted_coal_alpha.groupby(['sample','mesocosm','passage','media','parent_media',
                                                                  'type_mesocosm','parent_subjects']).sum(numeric_only=True).reset_index()
#df_abundance_melted_coal_alpha
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33238/3538869069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abundance_melted_coal['counts']=1

# %%
df_abundance_melted_coal_alpha_coal=df_abundance_melted_coal_alpha.loc[df_abundance_melted_coal_alpha['parent_subjects'].isin(['AA-AE',
                                                                                                                               'AA-AF',
                                                                                                                               'AE-AF']),:]
p=iqplot.strip(df_abundance_melted_coal_alpha.sort_values(by='passage'),q='counts',cats=['passage',],
              # color='blue',
               jitter=True,
                                palette = [bokeh.palettes.Colorblind[7][0],bokeh.palettes.Colorblind[7][4],
                            bokeh.palettes.Colorblind[7][-2],bokeh.palettes.Colorblind[7][1],bokeh.palettes.Colorblind[7][6],],
  width = 250,
                 show_legend=False,q_axis='y')

p.ygrid.grid_line_color = None
#p.y_range = bokeh.models.Range1d(0,1)
p.xaxis.axis_label = 'Passage'
bokeh.io.show(p)
# Out:
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/iqplot/cat.py:173: UserWarning: `jitter` is deprecated. Use spread='jitter'.
#   warnings.warn("`jitter` is deprecated. Use spread='jitter'.")
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/iqplot/cat.py:175: UserWarning: `jitter` is deprecated. Use spread='jitter'.
#   warnings.warn("`jitter` is deprecated. Use spread='jitter'.")
#   <div id="d83948f9-0f85-4346-8b6d-e9b3da50ac4d" data-root-id="551678ad-5b8e-417f-a780-37dd2789d71a" style="display: contents;"></div>

# %%
df_abundance_melted_coal_alpha_coal=df_abundance_melted_coal_alpha.loc[df_abundance_melted_coal_alpha['parent_subjects'].isin(['AA-AA',
                                                                                                                               'AF-AF',
                                                                                                                               'AE-AE']),:]
p=iqplot.strip(df_abundance_melted_coal_alpha_coal.sort_values(by='passage'),q='counts',cats=['passage',],
              # color='blue',
               jitter=True,
                                palette = [bokeh.palettes.Colorblind[7][0],bokeh.palettes.Colorblind[7][4],
                            bokeh.palettes.Colorblind[7][-2],bokeh.palettes.Colorblind[7][1],bokeh.palettes.Colorblind[7][6],],
  width = 250,
                 show_legend=False,q_axis='y')

p.ygrid.grid_line_color = None
#p.y_range = bokeh.models.Range1d(0,1)
p.xaxis.axis_label = 'Passage'
bokeh.io.show(p)
# Out:
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/iqplot/cat.py:173: UserWarning: `jitter` is deprecated. Use spread='jitter'.
#   warnings.warn("`jitter` is deprecated. Use spread='jitter'.")
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/iqplot/cat.py:175: UserWarning: `jitter` is deprecated. Use spread='jitter'.
#   warnings.warn("`jitter` is deprecated. Use spread='jitter'.")
#   <div id="d4eb04c1-46e6-43eb-86c0-32c90f6d0e89" data-root-id="97c6f110-1f8d-40ff-9067-e5b3912f1220" style="display: contents;"></div>

# %%
df_abun=df_abundance_melted_coal.copy()
sample1s = []
sample2s = []
JSDs = []
for type_meso in df_abun['mesocosm'].unique():
    df_abun_type_meso = df_abun.loc[df_abun['mesocosm'] == type_meso,:]
    in_sample = df_abun_type_meso['inoculumn_sample'].values[0]
    good_samples = list(df_abun_type_meso['sample'].unique()) + [in_sample]
    for sample1,sample2 in it.combinations(good_samples,2):
        sample1s.append(sample1)
        sample2s.append(sample2)
        s1_abuns = df_abun.loc[df_abun['sample'] == sample1,:].sort_values(by='species_id')
        s2_abuns  = df_abun.loc[df_abun['sample'] == sample2,:].sort_values(by='species_id')
        JSDs.append(jensenshannon(s1_abuns['relative_abundance'].values, s2_abuns['relative_abundance'].values))

# %%
df_pairwise_JSD = pd.DataFrame(data = {'sample1': sample1s, 'sample2': sample2s, 
                                       'JSD': JSDs, })

df_pairwise_JSD['type_mesocosm1'] = df_pairwise_JSD['sample1'].transform(lambda x: df_abun.loc[df_abun['sample'] == x,'type_mesocosm'].values[0])
df_pairwise_JSD['type_mesocosm2'] = df_pairwise_JSD['sample2'].transform(lambda x: df_abun.loc[df_abun['sample'] == x,'type_mesocosm'].values[0])

#df_pairwise_JSD['subject1'] = df_pairwise_JSD['sample1'].transform(lambda x: df_abun.loc[df_abun['sample'] == x,'subject'].values[0])
#df_pairwise_JSD['subject2'] = df_pairwise_JSD['sample2'].transform(lambda x: df_abun.loc[df_abun['sample'] == x,'subject'].values[0])

df_pairwise_JSD['passage1'] = df_pairwise_JSD['sample1'].transform(lambda x: df_abun.loc[df_abun['sample'] == x,'passage'].values[0])
df_pairwise_JSD['passage2'] = df_pairwise_JSD['sample2'].transform(lambda x: df_abun.loc[df_abun['sample'] == x,'passage'].values[0])

df_pairwise_JSD['passage1-passage2'] =  df_pairwise_JSD['passage1'].astype(str) + '-' + df_pairwise_JSD['passage2'].astype(str)

# %%
df_pairwise_JSD['subjects1'] = df_pairwise_JSD['type_mesocosm1'].transform(lambda x: '-'.join(x.split('-')[:2]))
df_pairwise_JSD['subjects2'] =df_pairwise_JSD['type_mesocosm2'].transform(lambda x: '-'.join(x.split('-')[:2]))

df_pairwise_JSD['env1'] = df_pairwise_JSD['type_mesocosm1'].transform(lambda x: '-'.join(x.split('-')[2:]))
df_pairwise_JSD['env2'] = df_pairwise_JSD['type_mesocosm2'].transform(lambda x: '-'.join(x.split('-')[2:]))

# %%
df_pairwise_JSD['same_subjects'] = df_pairwise_JSD['subjects1'] == df_pairwise_JSD['subjects2'] 
df_pairwise_JSD['same_envs'] = df_pairwise_JSD['env1'] == df_pairwise_JSD['env2'] 
df_pairwise_JSD_only_double = df_pairwise_JSD.loc[~df_pairwise_JSD['subjects1'].isin(['AA-AA','AC/PP-AC/PP',
                                                                                      'AE-AE','AF-AF']),:]

df_pairwise_JSD['passage1-passage2'] =  df_pairwise_JSD['passage1'].astype(str) + '-' + df_pairwise_JSD['passage2'].astype(str)
df_pairwise_JSD['passage1-passage2'] = df_pairwise_JSD['passage1-passage2'].transform(lambda x: '-'.join(np.sort(x.split('-'))))

df_pairwise_JSD_only_double = df_pairwise_JSD_only_double.loc[~df_pairwise_JSD_only_double['subjects2'].isin(['AA-AA','AC/PP-AC/PP',
                                                                                      'AE-AE','AF-AF']),:]

# %%
df_pairwise_JSD_good = df_pairwise_JSD_only_double.loc[df_pairwise_JSD_only_double['passage1-passage2'].isin(['0-1','1-3',
                                                                                                              '3-5','5-7']),:]
p = iqplot.strip(df_pairwise_JSD_good.sort_values(by='passage1-passage2', ascending=True), 
                 q = 'JSD', cats = ['passage1-passage2', ], spread='jitter',
                 color_column = 'passage1-passage2',
                 palette = [bokeh.palettes.Colorblind[7][0],bokeh.palettes.Colorblind[7][4],
                            bokeh.palettes.Colorblind[7][-2],bokeh.palettes.Colorblind[7][1],],
                width = 250,
                 show_legend=False,q_axis='y')

p.ygrid.grid_line_color = None
p.y_range = bokeh.models.Range1d(0,1)
#p.xaxis.axis_label = 'Same Media - Same Subject'
bokeh.io.show(p)
# Out:
#   <div id="fce3ff19-4bb7-499c-8051-7d05acb74c78" data-root-id="3b2be590-becd-4528-9f2e-8c564b2203b9" style="display: contents;"></div>

# %%
df_pairwise_JSD_only_double = df_pairwise_JSD.loc[df_pairwise_JSD['subjects1'].isin(['AA-AA','AC/PP-AC/PP',
                                                                                      'AE-AE','AF-AF']),:]

df_pairwise_JSD_only_double = df_pairwise_JSD_only_double.loc[df_pairwise_JSD_only_double['subjects2'].isin(['AA-AA',#'AC/PP-AC/PP',
                                                                                      'AE-AE','AF-AF']),:]

df_pairwise_JSD['passage1-passage2'] =  df_pairwise_JSD['passage1'].astype(str) + '-' + df_pairwise_JSD['passage2'].astype(str)
df_pairwise_JSD['passage1-passage2'] = df_pairwise_JSD['passage1-passage2'].transform(lambda x: '-'.join(np.sort(x.split('-'))))
df_pairwise_JSD_only_double['media_switch']=False
df_pairwise_JSD_only_double.loc[df_pairwise_JSD_only_double['type_mesocosm1'].isin(['AF-AF-mGAM-mBHI','AE-AE-mGAM-mBHI', 'AA-AA-mGAM-mBHI',
                                                            'AF-AF-mBHI-mGAM','AE-AE-mBHI-mGAM', 'AA-AA-mBHI-mGAM',]),'media_switch']=True
df_pairwise_JSD_only_double =df_pairwise_JSD_only_double#.loc[df_pairwise_JSD_only_double['type_mesocosm1'].isin(['AF-AF-mGAM-mGAM',
                                                             #                                                    'AF-AF-mGAM-mBHI'])
                                                                                                               #  ,:]
df_pairwise_JSD_good = df_pairwise_JSD_only_double.loc[df_pairwise_JSD['passage1-passage2'].isin(['0-1','1-3','3-5','5-7']),:]
p = iqplot.strip(df_pairwise_JSD_good.sort_values(by='passage1-passage2', ascending=True), 
                 q = 'JSD', cats = ['passage1-passage2',], spread='jitter',
                 color_column = 'media_switch',
                 palette = [bokeh.palettes.Colorblind[7][0],bokeh.palettes.Colorblind[7][4],
                            bokeh.palettes.Colorblind[7][-2],bokeh.palettes.Colorblind[7][1],],
                width = 400,
                 q_axis='y')

p.ygrid.grid_line_color = None
p.y_range = bokeh.models.Range1d(0,1)
#p.xaxis.axis_label = 'Same Media - Same Subject'
bokeh.io.show(p)
# Out:
#   <div id="ef136beb-2f92-4233-ae29-722552c2ea18" data-root-id="c8be929e-0d78-4f2a-9259-f4d3be48b6e3" style="display: contents;"></div>
