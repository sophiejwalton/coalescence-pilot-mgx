# %%
import numpy as np

# %%
snps_sample = np.random.exponential(.01,1000)
snps_sample[np.random.choice(np.arange(1000),750)]=0
n_snps=len(snps_sample )
depth_med=10
-np.log(np.sum(snps_sample ==0)/n_snps)/depth_med
# Out:
# np.float64(0.062362111791133504)

# %%
lamb = .001*depth_med

snps_sample = np.random.poisson(lamb,10000)
np.median(snps_sample)
# Out:
# np.float64(0.0)

# %%
-np.log(np.sum(snps_sample == 0)/n_snps)/depth_med
# Out:
# np.float64(-23.022850479850437)

# %%
np.log(np.sum(snps_sample 0)/n_snps)
# Out:
# np.float64(2.302285047985044)

# %%
(np.sum(snps_sample == 0)/n_snps)
# Out:
# np.float64(9.997)

# %%
depth_med*.01
# Out:
# 0.001

# %%
depth_med=100

# %%
lamb=depth_med*.001
lamb
# Out:
# 0.1

# %%
np.exp(-lamb)
# Out:
# np.float64(0.9048374180359595)

# %%
lamb = .004*depth_med

snps_sample = np.random.poisson(lamb,10000)
n_snps=len(snps_sample)
print(np.median(snps_sample))
-np.log(np.sum(snps_sample == 0)/(1.1*n_snps))/depth_med
# Out:
# 0.0
# np.float64(0.01320779039965394)

# %%
np.median(snps_sample)
# Out:
# np.float64(1.0)
