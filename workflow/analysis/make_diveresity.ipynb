# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control
#from bokeh.models import FixedTicker, FuncTickFormatter 
from scipy.stats import chi2

#from bokeh.io import output_notebook
from plot_tools import *
from snp_analysis_tools_sherlock import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e2ef1052-fd6f-4164-bd71-2c26e5ce1543'>
#   <div id="b4436606-e151-4c5d-a23d-b4fdbe9bb735" data-root-id="e2ef1052-fd6f-4164-bd71-2c26e5ce1543" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
def get_both_dfs(fname):
    df1 = pd.read_csv(fname).drop(columns='Unnamed: 0').set_index('sample')
    df2 = pd.read_csv(fname.split('parent1_info.csv')[0] + 'parent2_info.csv').drop(columns='Unnamed: 0').set_index('sample')
    df2['conf_int'] = df2['boot_high']-df2['boot_low']
    
    df1['conf_int'] = df1['boot_high']-df1['boot_low']
    df_both = pd.concat([df1.rename(columns = {'boot_med':'boot_med1', 'boot_low':'boot_low1', 'boot_high':'boot_high1',
       'actual_med':'actual_med1', 'conf_int':'conf_int1'}),
                         df2.rename(columns = {'boot_med':'boot_med2', 'boot_low':'boot_low2', 'boot_high':'boot_high2',
       'actual_med':'actual_med2', 'conf_int':'conf_int2'})],axis=1)
    
    df_both['species'] = fname.split('/')[-2]
    df_both['fname'] = fname
    print('-'.join(fname1.split('/')[-1].split('-')[:-1]))
   # parent_media = 
    
    df_both['subjects_measured'] = '-'.join(fname1.split('/')[-1].split('-')[:-1])
    df_both['in_measured'] = '-'.join(fname1.split('/')[-1].split('_')[:-2])
    df_both['total_shift'] = np.abs(1-(df_both['actual_med1'] + df_both['actual_med2']))
    df_both['total_shift12'] = np.abs(1-(df_both['boot_low1'] + df_both['boot_high2']))
    df_both['total_shift21'] = np.abs(1-(df_both['boot_low2'] + df_both['boot_high1']))
    df_both['total_shift_max'] = df_both['total_shift21']
    df_both.loc[df_both['total_shift_max']<df_both['total_shift12'],'total_shift_max'] = df_both.loc[df_both['total_shift_max']<df_both['total_shift12'],'total_shift12']

    return df_both

# %%
sp = '101346'
df_div_depth = pd.read_csv(f'~/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/{sp}/{sp}_diversity_df1.csv').rename(columns = {'Unnamed: 0': 'sample','0': 'div'}).set_index('sample')
e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')
df_div_depth = df_div_depth.loc[np.intersect1d(df_div_depth.index.values,e003_metadata.index.values),:]                                                                                                                                                   

df_div_depth= pd.concat([df_div_depth,e003_metadata.loc[np.intersect1d(df_div_depth.index.values,
                                                                                   e003_metadata.index.values),:]],
                                         axis=1).reset_index()

df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']= df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']+5

# %%
def make_div_plot(df,color='black',alpha=1.,p=None,log=True):
    df = df.sort_values(by='passage')
    if p is None:
        p = bokeh.plotting.figure(width = 500, height = 250,  y_axis_type="log")
        p.quad(top=[1], bottom=[1e-6], left=[6],
       right=[15], color=bokeh.palettes.Light[3][0],alpha=.2)
    p.line(df['passage'].values,
                   df['div'].values,color=color,alpha=alpha)
    p.scatter(df['passage'].values,
                   df['div'].values,color = color,size = 5,
                      alpha=alpha)
    p.yaxis.axis_label = f'SNP Diversity'
    p.xaxis.axis_label = 'Passage'
   # p2.y_range = bokeh.models.Range1d(-.005,1.005)
   # p2.x_range = bokeh.models.Range1d(-.5,7.5)
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    p.y_range = bokeh.models.Range1d(1e-5,1)
    p.x_range = bokeh.models.Range1d(-.5,14.5)
    p.title.text_font_style='italic'
    p.yaxis.axis_label_text_font_style = 'normal'
    p.xaxis.axis_label_text_font_style = 'normal'
    label_font_size = '22px'
    tick_font_size = '15px'
    p.xaxis.axis_label_text_font_size=label_font_size
    p.xaxis.major_label_text_font_size=tick_font_size
    p.yaxis.axis_label_text_font_size=label_font_size
    p.yaxis.major_label_text_font_size=tick_font_size
    p.xaxis.axis_label = 'Timepoint'
    p.xaxis.minor_tick_line_color= None
  #  p.yaxis.minor_tick_line_color= None
    p.title.text_font_style='italic'
    p.yaxis.axis_label='% Polymorphic SNPs'
    p.title.text_font_size=label_font_size
    p.ray(x=-2,y=1e-3, color='grey',alpha=.2,width=5)
    p.y_range = bokeh.models.Range1d(5e-6,5e-2)
    
    return p

# %%
e003_metadata_ss = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
e003_metadata_ss=e003_metadata_ss.loc[e003_metadata_ss['parent_subjects'].isin(['AA-AA','AE-AE','AF-AF',]),:]
e003_metadata_ss['subject']=e003_metadata_ss['parent_subjects'].transform(lambda x: x.split('-')[0])
e003_metadata_ss['passage'] = e003_metadata_ss['passage'] + 7
e003_metadata_ss['exp_type']='e003Coalescence'
e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')
e003_metadata_all = pd.concat([e003_metadata, e003_metadata_ss[e003_metadata.columns.values]])
e003_metadata_all
# Out:
#                                                        exp_type media  \
# sample
# B10-e003Assembly-mGAM-p3                           e003Assembly  mGAM
# B10-e003Assembly-mGAM-p5                           e003Assembly  mGAM
# B10-e003GlycerolRevival-mGAM-p2             e003GlycerolRevival  mGAM
# B11-e003Assembly-mGAM-p3                           e003Assembly  mGAM
# B11-e003Assembly-mGAM-p5                           e003Assembly  mGAM
# ...                                                         ...   ...
# Coalescence-E5-C4-AE-AE-mBHI-mBHI-3_S672        e003Coalescence  mBHI
# Coalescence-D6-A2-AA-AA-mBHI-mGAM-3_S661        e003Coalescence  mGAM
# Coalescence-A12-D11-AF-AF-mGAM-mBHI-7_S631      e003Coalescence  mBHI
# Coalescence-B12-H5-AF-AF-mBHI-mGAM-7_S643       e003Coalescence  mGAM
# Coalescence-E8-D11-AF-AF-mGAM-mBHI-3_S675       e003Coalescence  mBHI
#
#                                             passage comm subject  \
# sample
# ...

# %%
sp = '101346'
df_div_depth = pd.read_csv(f'~/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/{sp}/{sp}_diversity_df1.csv').rename(columns = {'Unnamed: 0': 'sample','0': 'div'}).set_index('sample')
#e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')

df_div_depth = df_div_depth.loc[np.intersect1d(df_div_depth.index.values,e003_metadata_all.index.values),:]                                                                                                                                                   

df_div_depth= pd.concat([df_div_depth,e003_metadata_all.loc[np.intersect1d(df_div_depth.index.values,
                                                                                   e003_metadata_all.index.values),:]],
                                         axis=1).reset_index()

df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']= df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']+5
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B11-AF-mGAM','fecal-AF-fecal',
                                                         'H11-AF-AF-mGAM-mGAM',]),:]
p=make_div_plot(df_meso,log=True)
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B11-AF-mGAM','fecal-AF-fecal',
                                                         'D11-AF-AF-mGAM-mGAM',]),:]
p= make_div_plot(df_meso,log=True,p=p)

p.title.text = 'Bacteroides uniformis'

bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,'buniformis_div_oligo')
# Out:
#   <div id="e42d3485-7d85-4e3d-a5f6-ec8ee871b8ea" data-root-id="27c4963e-e883-4574-830b-0b034f8b4bed" style="display: contents;"></div>

# %%
sp = '102478'
df_div_depth = pd.read_csv(f'~/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/{sp}/{sp}_diversity_df1.csv').rename(columns = {'Unnamed: 0': 'sample','0': 'div'}).set_index('sample')
#e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')

df_div_depth = df_div_depth.loc[np.intersect1d(df_div_depth.index.values,e003_metadata_all.index.values),:]                                                                                                                                                   

df_div_depth= pd.concat([df_div_depth,e003_metadata_all.loc[np.intersect1d(df_div_depth.index.values,
                                                                                   e003_metadata_all.index.values),:]],
                                         axis=1).reset_index()

df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']= df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']+5
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B11-AF-mGAM','fecal-AF-fecal',
                                                         'H11-AF-AF-mGAM-mGAM',]),:]
p=make_div_plot(df_meso,log=True)
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B11-AF-mGAM','fecal-AF-fecal',
                                                         'D11-AF-AF-mGAM-mGAM',]),:]
p= make_div_plot(df_meso,log=True,p=p)
p.title.text = 'Bacteroides dorei'
bokeh.io.show(p)
# Out:
#   <div id="e28ff578-c4ab-43f8-95b1-ff066a2c4b7b" data-root-id="dee9cb9f-91f0-451b-9a2e-6d56cf7f1826" style="display: contents;"></div>

# %%
sp = '101346'
df_div_depth = pd.read_csv(f'~/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/{sp}/{sp}_diversity_df1.csv').rename(columns = {'Unnamed: 0': 'sample','0': 'div'}).set_index('sample')
#e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')

df_div_depth = df_div_depth.loc[np.intersect1d(df_div_depth.index.values,e003_metadata_all.index.values),:]                                                                                                                                                   

df_div_depth= pd.concat([df_div_depth,e003_metadata_all.loc[np.intersect1d(df_div_depth.index.values,
                                                                                   e003_metadata_all.index.values),:]],
                                         axis=1).reset_index()

df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']= df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']+5
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B10-AE-mGAM','fecal-AE-fecal',
                                                         'G10-AE-AE-mGAM-mGAM',]),:]
p=make_div_plot(df_meso,log=True)
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B10-AE-mGAM','fecal-AE-fecal',
                                                         'C10-AE-AE-mGAM-mGAM',]),:]
p= make_div_plot(df_meso,log=True,p=p)
p.title.text='Bacteroides uniformis'
p.output_backend='svg'
export_plot_pdf(p,'buniformis_div_oligo')
bokeh.io.show(p)
# Out:
#   <div id="eeefe4a8-4c72-417b-bdc0-6433cca836de" data-root-id="eba9156b-5f9a-49ca-87dd-6e774cadbf58" style="display: contents;"></div>

# %%
sp = '101346'
df_div_depth = pd.read_csv(f'~/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/{sp}/{sp}_diversity_df1.csv').rename(columns = {'Unnamed: 0': 'sample','0': 'div'}).set_index('sample')
#e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')

df_div_depth = df_div_depth.loc[np.intersect1d(df_div_depth.index.values,e003_metadata_all.index.values),:]                                                                                                                                                   

df_div_depth= pd.concat([df_div_depth,e003_metadata_all.loc[np.intersect1d(df_div_depth.index.values,
                                                                                   e003_metadata_all.index.values),:]],
                                         axis=1).reset_index()

df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']= df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']+5
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B8-AA-mGAM','fecal-AA-fecal',
                                                         'E8-AA-AA-mGAM-mGAM',]),:]
p=make_div_plot(df_meso,log=True)
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B8-AA-mGAM','fecal-AA-fecal',
                                                         'A8-AA-AA-mGAM-mGAM',]),:]
p= make_div_plot(df_meso,log=True,p=p)
p.title.text='Bacteroides uniformis'

bokeh.io.show(p)
# Out:
#   <div id="a4b0eaff-81a4-42c6-ae4a-0e9e600a7861" data-root-id="c62d6a0d-8d9c-467e-8694-062476ebbd42" style="display: contents;"></div>

# %%
sp = '102478'
df_div_depth = pd.read_csv(f'~/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/{sp}/{sp}_diversity_df1.csv').rename(columns = {'Unnamed: 0': 'sample','0': 'div'}).set_index('sample')
#e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')

df_div_depth = df_div_depth.loc[np.intersect1d(df_div_depth.index.values,e003_metadata_all.index.values),:]                                                                                                                                                   

df_div_depth= pd.concat([df_div_depth,e003_metadata_all.loc[np.intersect1d(df_div_depth.index.values,
                                                                                   e003_metadata_all.index.values),:]],
                                         axis=1).reset_index()

df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']= df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']+5
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B11-AF-mGAM','fecal-AF-fecal',
                                                         'H11-AF-AF-mGAM-mGAM',]),:]
p=make_div_plot(df_meso,log=True)
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B11-AF-mGAM','fecal-AF-fecal',
                                                         'D11-AF-AF-mGAM-mGAM',]),:]
p= make_div_plot(df_meso,log=True,p=p)
p.title.text='Bacteroides dorei'
bokeh.io.show(p)
# Out:
#   <div id="bff9287d-78a4-4225-9be7-509e678460b7" data-root-id="08e8c434-7335-4d06-9879-3c8820e5a12c" style="display: contents;"></div>

# %%
sp = '101346'
df_div_depth = pd.read_csv(f'~/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/{sp}/{sp}_diversity_df1.csv').rename(columns = {'Unnamed: 0': 'sample','0': 'div'}).set_index('sample')
#e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')

df_div_depth = df_div_depth.loc[np.intersect1d(df_div_depth.index.values,e003_metadata_all.index.values),:]                                                                                                                                                   

df_div_depth= pd.concat([df_div_depth,e003_metadata_all.loc[np.intersect1d(df_div_depth.index.values,
                                                                                   e003_metadata_all.index.values),:]],
                                         axis=1).reset_index()

df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']= df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']+5
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B10-AE-mGAM','fecal-AE-fecal',
                                                         'G10-AE-AE-mGAM-mGAM',]),:]
p=make_div_plot(df_meso,log=True)
df_meso = df_div_depth.loc[df_div_depth['mesocosm'].isin(['B10-AE-mGAM','fecal-AE-fecal',
                                                         'G10-AE-AE-mGAM-mGAM',]),:]
p= make_div_plot(df_meso,log=True,p=p)
p.title.text='Bacteroides uniformis'
bokeh.io.show(p)
# Out:
#   <div id="c5942d7f-fdea-44cd-8beb-e13b75c46beb" data-root-id="7dfb2081-5908-4d04-bdd2-df6271ac5418" style="display: contents;"></div>

# %%
globs = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/*/')
sps = [i.split('/')[-2] for i in globs]
all_dfs = []
for sp in sps:

    df_div_depth = pd.read_csv(f'~/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/{sp}/{sp}_diversity_df1.csv').rename(columns = {'Unnamed: 0': 'sample','0': 'div'}).set_index('sample')
#e003_metadata = pd.read_csv('assembly_metadata_round4.csv').set_index('sample')

    df_div_depth = df_div_depth.loc[np.intersect1d(df_div_depth.index.values,e003_metadata_all.index.values),:]                                                                                                                                                   
    
    df_div_depth= pd.concat([df_div_depth,e003_metadata_all.loc[np.intersect1d(df_div_depth.index.values,
                                                                                       e003_metadata_all.index.values),:]],
                                             axis=1).reset_index()

    df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']= df_div_depth.loc[df_div_depth['exp_type']=='e003GlycerolRevival','passage']+5
    df_div_depth['species']=sp
    all_dfs.append(df_div_depth)
all_dfs_div = pd.concat(all_dfs)
all_dfs_div['species-type_mesocosm']=all_dfs_div['species']+'-'+all_dfs_div['type_mesocosm']
all_dfs_div['parent_media']=all_dfs_div['type_mesocosm'].transform(lambda x: x.split('-')[-2])
all_dfs_div['parent_subjects']=all_dfs_div['type_mesocosm'].transform(lambda x: x.split('-')[0])

all_dfs_div['media_switch']= all_dfs_div['media']!=all_dfs_div['parent_media']
all_dfs_div.loc[all_dfs_div['passage']<7,'parent_media']=all_dfs_div.loc[all_dfs_div['passage']<7,
            'type_mesocosm'].transform(lambda x: x.split('-')[-1])
all_dfs_div=all_dfs_div.loc[all_dfs_div['sample']!='A2-e003Coalescence-Inoculumn-mBHI',:]
all_dfs_div['inoculumn']=all_dfs_div['parent_subjects']+'-'+all_dfs_div['parent_media']
all_dfs_div= all_dfs_div.loc[all_dfs_div['parent_subjects'].isin(['AA','AE','AF']),:]
np.sort(all_dfs_div['inoculumn'].unique())
all_dfs_div['media_switch']=all_dfs_div['media']==all_dfs_div['parent_media']

# %%
in_mesos = [ 'B2-AA-mBHI','B4-AE-mBHI','B5-AF-mBHI'
             'B8-AA-mGAM','B10-AE-mGAM','B11-AF-mGAM']
all_dfs_div['is_in']=False
all_dfs_div.loc[(all_dfs_div['mesocosm'].isin(in_mesos))*(all_dfs_div['passage']==5),'is_in']=True
all_dfs_div_analysis = all_dfs_div.loc[all_dfs_div['is_in']+(all_dfs_div['passage']>=6),:]
all_dfs_div_analysis=all_dfs_div_analysis.loc[~all_dfs_div_analysis['mesocosm'].isin(['C2-AA-mBHI','C4-AE-mBHI','C5-AF-mBHI',
                                                                                      'C8-AA-mGAM','C10-AE-mGAM','C11-AF-mGAM',]),:]
                                                                                      
all_dfs_div_analysis['species-in']=all_dfs_div_analysis['species']+'-'+all_dfs_div_analysis['inoculumn']
all_dfs_div_analysis_ins = all_dfs_div_analysis.loc[all_dfs_div_analysis['is_in'],:]

all_dfs_div_analysis['in_diversity']=np.nan
for sp_in in all_dfs_div_analysis_ins['species-in'].unique():
    val = all_dfs_div_analysis_ins.loc[all_dfs_div_analysis_ins['species-in']==sp_in,'div'].values[0]
    all_dfs_div_analysis.loc[all_dfs_div_analysis['species-in']==sp_in,'in_diversity']=val
all_dfs_div_analysis = all_dfs_div_analysis.loc[~all_dfs_div_analysis['in_diversity'].isna(),:]

p = hv.Points(all_dfs_div_analysis.loc[all_dfs_div_analysis['passage']>12,:].sort_values(by='in_diversity',ascending=False),
              kdims = ['species-in','div'],vdims = ['species-in','media_switch']).opts(xrotation=60,width=600,
                                                                                           height= 400,
                                                           logy=True,
                                                           #logy=True,#ylim=(1,10**5),
                                                                        jitter = .2,alpha=1.,
                                                                                      # xaxis=None,
                                                                        cmap = bokeh.palettes.Light[8],
                                                               xlabel='Species',xticks=None,
                                                                        show_legend=True,
                                                                        legend_position='right',  
                                                                                     #  multi_level=False,
                                                               ylabel='Diversity',
                                                              color='media_switch')
p2 = hv.Points(all_dfs_div_analysis.loc[all_dfs_div_analysis['is_in'],:].sort_values(by='in_diversity',ascending=False),
              kdims = ['species-in','div'],vdims = ['species-in','is_in']).opts(xrotation=60,width=700,
                                                                                           height= 400,
                                                           logy=True,
                                                           #logy=True,#ylim=(1,10**5),
                                                                        jitter = .2,alpha=1.,
                                                                                size=6,
                                                                                line_color='black',
                                                                                      # xaxis=None,
                                                                        cmap = bokeh.palettes.Light[8],
                                                                                color=  bokeh.palettes.Light[8][2],
                                                               xlabel='Species',xticks=None,
                                                                        show_legend=True,
                                                                        legend_position='right',  
                                                                                     #  multi_level=False,
                                                               ylabel='Diversity',
                                                       )
p2*p
# Out:
# :Overlay
#    .Points.I  :Points   [species-in,div]   (species-in,is_in)
#    .Points.II :Points   [species-in,div]   (species-in,media_switch)

# %%
# maintained oligo both media - 102506-AE-mGAM, 102506-AE-mBHI, 	
# maybe - 100099-AE-mBHI

# %%
all_dfs_div_analysis['counts']=1
all_dfs_div_analysis['is_oligo']=all_dfs_div_analysis['div']>1e-3
all_dfs_div_analysis['is_mono']=all_dfs_div_analysis['div']<1e-4
all_dfs_div_analysis['is_initial_oligo']=all_dfs_div_analysis['in_diversity']>1e-3
all_dfs_div_analysis_high = all_dfs_div_analysis.loc[all_dfs_div_analysis['passage']>12,:]
all_dfs_div_analysisg= all_dfs_div_analysis_high.groupby(['species-in','media_switch']).sum(numeric_only=True)
all_dfs_div_analysisg=all_dfs_div_analysisg.loc[all_dfs_div_analysisg['is_initial_oligo']>0,:]
all_dfs_div_analysisg['in_diversity']=all_dfs_div_analysisg['in_diversity']/all_dfs_div_analysisg['counts']
all_dfs_div_analysisg['div']=all_dfs_div_analysisg['div']/all_dfs_div_analysisg['counts']
all_dfs_div_analysisg.sort_values(by='in_diversity',ascending=False)
#AEmGAM,AEmBHI,AFmGAM,
# Out:
#                                   div  passage  is_in  in_diversity  counts  \
# species-in     media_switch
# 102506-AE-mGAM False         0.013210       54      0      0.013204       4
#                True          0.012390       54      0      0.013204       4
# 102506-AE-mBHI True          0.012311       40      0      0.012012       3
#                False         0.012927       54      0      0.012012       4
# 102544-AE-mBHI True          0.007055       40      0      0.010764       3
# ...                               ...      ...    ...           ...     ...
# 100910-AE-mBHI True          0.000039       40      0      0.001591       3
# 100099-AA-mBHI True          0.003915       41      0      0.001113       3
#                False         0.000262       41      0      0.001113       3
# 100296-AA-mBHI False         0.000253       41      0      0.001006       3
#                True          0.000286       41      0      0.001006       3
#
# ...
