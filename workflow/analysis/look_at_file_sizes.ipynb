# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control
import os
from scipy.stats import chi2
from snp_analysis_tools_sherlock import *
from plot_tools import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot

hv.extension('bokeh')

# %%
df =pd.read_csv('~/git/coalescence-pilot-mgx/file_sizes.csv').drop(columns='Unnamed: 0')
dffnames = pd.read_csv('~/git/coalescence-pilot-mgx/sample_fnames.csv')
filtones = list(dffnames['filter1'].values)+list(dffnames['filter2'].values)
filtones =['/oak/stanford/groups/dpetrov/swalton/coalescence-pilot-mgx/'+f for f in filtones]
#filtones
#dffnames

# %%
df['sample'] = df['fname'].transform(lambda x: x.split('.')[0])
df['e004'] = df['sample'].transform(lambda x: 'e004' in x)
print(len(df))
df = df.loc[~df['e004'],:]
df['concat']=df['sample'].transform(lambda x: 'concat' in x)
df = df.loc[~df['fname'].isin(filtones),:]
df.to_csv('TableS1_samples_depths.csv')
print(len(df))
dfgr = df.groupby(['sample']).sum(numeric_only=True)
dfgr
np.median(dfgr['file_sizes'])

# %%
df['sample'] = df['fname'].transform(lambda x: x.split('.')[0])
df['sample'] = df['sample'].transform(lambda x: x.split('/')[-1])
df['sample']=df['sample'].transform(lambda x: x.split('-filtered')[0])
df = df.drop(columns = ['e004','concat',])
df.to_csv('TableS1_samples_depths.csv',index=False)
df

# %%
df
