# %%
import pandas as pd
from scipy import stats
import numpy as np
from scipy.stats import false_discovery_control
import os
from plot_tools import *
from scipy.stats import chi2
from snp_analysis_tools_sherlock import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='67812f7c-5c5b-4799-8b86-a6b95366489b'>
#   <div id="ccf23b25-822a-4b76-93b8-fa04ad895c97" data-root-id="67812f7c-5c5b-4799-8b86-a6b95366489b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"82da3e6e-1700-4b44-9277-33cfa8531c1e":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"67812f7c-5c5b-4799-8b86-a6b95366489b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"14cdfdd2-3263-44c9-94c6-df81da0bfd3d","attributes":{"plot_id":"67812f7c-5c5b-4799-8b86-a6b95366489b","comm_id":"674b35d508c2469b900d298397ca0452","client_comm_id":"c62ff0ad3f39474e8ac26de4f358dc62"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"82da3e6e-1700-4b44-9277-33cfa8531c1e","roots":{"67812f7c-5c5b-4799-8b86-a6b95366489b":"ccf23b25-822a-4b76-93b8-fa04ad895c97"},"root_ids":["67812f7c-5c5b-4799-8b86-a6b95366489b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
df = pd.read_csv('~/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/101346/AA-AF-mBHI_parentboth_info.csv')
df_both = get_selection_stuff_both(101346,'AA-AF-mBHI')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
all_dfs = []
for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
     #   try:
        if os.path.exists(f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{sp}/{ino}_parentboth_info.csv'):
            df,_=get_selection_stuff_both(sp,ino)#.reset_index()
       # except:
        #    continue
            df['species_id']=sp
            df['inoculumn']=ino
            df['species-ino']= sp+'-' + ino
            all_dfs.append(df.reset_index())
            
all_dfs=pd.concat(all_dfs)
print(len(all_dfs['species_id'].unique()))
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']

print(len(all_dfs))
all_dfs = all_dfs.groupby(['sample1','sample2','mesocosm','inoculumn','type_mesocosm','species-ino','species_id','media']).median(numeric_only=True).reset_index()
all_dfs = all_dfs.loc[~all_dfs['species-ino'].isin(bad_inos),:]
print(len(all_dfs))
len(all_dfs['species_id'].unique())
#all_dfs = all_dfs.loc[(all_dfs['passage1']==0)*((all_dfs['passage2']==7)),:]
all_dfs['sel_coeff']=all_dfs['sel_med']
# Out:
# bef 0.00013344570866689887
# aft 0.0001270807697070081
# bef 6.931391489409938e-05
# aft 0.0013402360852668993
# bef 2.1230881120299673e-05
# aft 0.0005148071271501575
# bef 4.0520465009900863e-05
# aft 3.921278033218803e-05
# bef 3.949788255350195e-05
# aft 3.916260597480736e-05
# bef 0.0010000000000000009
# aft 0.00043862110135040044
# bef 0.000500000000000056
# aft 0.0009676147336278307
# bef 0.013000000000000012
# aft 0.006150658002124332
# bef 2.6385900458225642e-05
# aft 0.0010000000000000009
# bef 2.3168310577803553e-06
# aft 0.0009150683625287481
# bef 0.004079085214987788
# aft 0.0031705958966372627
# bef 1.0078317107999751e-05
# aft 0.0005335592136541667
# bef 1.3182700219699535e-05
# aft 1.3176484522235861e-05
# bef 0.0
# aft 0.0
# bef 3.99948983332999e-05
# aft 3.966525558079647e-05
# bef 5.7049588119501005e-05
# aft 5.5845353300838785e-05
# bef 0.0004999999999999449
# aft 0.00017416409081638662
# bef 9.39850140299972e-06
# aft 1.0235870412296857e-05
# bef 2.5905675031398512e-05
# aft 2.5049156166401937e-05
# bef 0.0010000000000000009
# aft 0.0007686632721815023
# bef 0.0
# aft 0.0004364237032818963
# bef 2.960856708699843e-06
# aft 3.2200760903843863e-06
# bef 0.0020000000000000018
# aft 0.0014949903332814318
# bef 4.857059140489983e-05
# aft 4.857558066910343e-05
# bef 0.0010000000000000009
# aft 0.0006062628169656303
# bef 0.0040000000000000036
# aft 0.0018342332368019854
# bef 0.0010000000000000009
# aft 0.0004770204568388392
# bef 0.0009999999999998899
# aft 0.0002871689969877189
# bef 0.0
# aft 0.0
# bef 0.0
# aft 0.0003685413707217311
# bef 0.0001417645705389381
# aft 0.05519592513818983
# bef 0.0
# aft 0.0
# bef 0.00016516112037401331
# aft 0.0010000000000000009
# bef 1.225189904440014e-05
# aft 1.2236847764985053e-05
# bef 0.0009999999999999176
# aft 0.0008451155719828851
# bef 0.0019999999999998908
# aft 0.0015875996890312716
# bef 1.3806503850100418e-05
# aft 1.432413895271177e-05
# bef 0.000499999999999997
# aft 0.0005243838489774472
# bef 6.524384766299924e-06
# aft 6.497288751239772e-06
# bef 1.1102230246251565e-16
# aft 1.1102230246251565e-16
# bef 0.0010000000000000009
# aft 0.000992627110529512
# bef 0.00013344570866689887
# aft 0.0001270807697070081
# bef 0.0010000000000000009
# aft 0.0009516958170345119
# bef 0.0009999999999998899
# aft 0.0008874669191016871
# bef 0.0
# aft 0.0
# bef 6.0819357969300186e-05
# aft 6.143569075280943e-05
# bef 0.0004999999999998894
# aft 0.00041578819385981736
# bef 0.000999999999999994
# aft 0.0009756807921945526
# bef 1.2598003517000009e-05
# aft 0.00018802773641080073
# bef 0.0
# aft 0.0
# bef 0.0005000000000000004
# aft 0.0003404808071650889
# bef 7.29043999758705e-06
# aft 0.00042215107159060405
# bef 0.0
# aft 0.0
# bef 1.4185147629630634e-05
# aft 0.0010000000000000009
# bef 0.00020827828465730391
# aft 0.001471995289615169
# bef 0.0001461214130698968
# aft 0.00014612629388511406
# bef 0.00011119639709100682
# aft 0.007565085771947588
# bef 6.901105772039173e-05
# aft 0.00042895672082698955
# bef 0.00019257703081230343
# aft 0.00018140330620532857
# 17
# 6779
# 4563

# %%
def make_plot_interval(full_df, interval):
    mGAMs_max=[]
    mGAMs_min=[]
    mBHIs_max=[]
    mBHIs_min=[]
    mBHI_est=[]
    mGAM_est=[]
    sp_inos=[]
    pvals=[]
    int1,int2 = interval
    all_dfs = full_df.loc[(full_df['passage1']==int1)*((full_df['passage2']==int2)),:]
    for sp_ino in all_dfs['species-ino'].unique():
        df_sp_ino = all_dfs.loc[all_dfs['species-ino']==sp_ino,:]
        df_sp_ino=df_sp_ino.loc[~df_sp_ino['sel_med'].isna(),:]
        media = df_sp_ino['media'].unique()
        if len(media)<2:
            print(sp_ino, media)
            continue
        mGAMs = df_sp_ino.loc[df_sp_ino['media']=='mGAM','sel_med'].values
        mBHIs = df_sp_ino.loc[df_sp_ino['media']=='mBHI','sel_med'].values
        if len(mBHIs) <1 or len(mGAMs) < 1:
            print(sp_ino)
            continue
        
        mGAMs_min.append(np.min(mGAMs))
        mGAMs_max.append(np.max(mGAMs))
        mGAM_est.append(np.median(mGAMs))
     
        print(sp_ino,np.min(mGAMs)>0, np.max(mGAMs)>0, np.median(mGAMs)>0)
        
    
        mBHIs_min.append(np.min(mBHIs))
        mBHIs_max.append(np.max(mBHIs))
        mBHI_est.append(np.median(mBHIs))
    
        sp_inos.append(sp_ino)
        t_statistic, p_value = stats.ttest_ind(mGAMs, mBHIs)
        pvals.append(p_value)
    
    df = pd.DataFrame(data={'mGAM_min':mGAMs_min,'mBHI_min':mBHIs_min,
                            'mGAM_max':mGAMs_max,'mBHI_max':mBHIs_max,
                            'mBHI':mBHI_est,
                            'mGAM':mGAM_est,
                            'pvals':pvals,
                            'species-inoculumn': sp_inos})
    df=df.sort_values(by='pvals')
    df=df.loc[~df['pvals'].isna(),:]
    qvals = np.sort(df['pvals'].values)
    qvals = stats.false_discovery_control(np.sort(qvals[~np.isnan(qvals)]))
    df['qvals']=qvals
    df.loc[df['qvals']<.05,:]
    len(df)
    print(len(df))
    print(len(df.loc[df['qvals']<.05,:]))
    df['species_id']=df['species-inoculumn'].transform(lambda x: x.split('-')[0])
    df=df.sort_values(by='pvals')
    df=df.loc[~df['pvals'].isna(),:]
    qvals = np.sort(df['pvals'].values)
    qvals = stats.false_discovery_control(np.sort(qvals[~np.isnan(qvals)]))
    df['qvals']=qvals
    df.loc[df['qvals']<.05,:]
    df['repol']=False
    df.loc[df['mBHI']<0,'repol']=True
    to_repol = df.loc[df['repol'],'species-inoculumn'].unique()
    df.loc[df['mBHI']<0,'mGAM']=-df.loc[df['mBHI']<0,'mGAM']
    df.loc[df['mBHI']<0,'mBHI']=-df.loc[df['mBHI']<0,'mBHI']
    df = df.sort_values(by='qvals')
    df = df.loc[df['species-inoculumn']!='100910-AA-AE-mBHI',:]
    
    df['species']=df['species-inoculumn'].transform(lambda x: x.split('-')[0])
    
    df = df.sort_values(by='mBHI',ascending=False)
    p = hv.Points(df, vdims=['mGAM'],kdims=['species-inoculumn','mGAM'], label='mGAM',).opts(width=int((2/3)*700),
                                                                                                         size=5,
                                                                                                    color=bokeh.palettes.Set2[8][0],
                                                                                                   line_color='black',
                                                                                                     xrotation=60)
    p2=hv.Points(df, vdims=['mBHI'],kdims=['species-inoculumn','mBHI'],label='mBHI',).opts(width=int((2/3)*500),
                                                                                                        size=5,
                                                                                                       line_color='black',
                                                                                        color=bokeh.palettes.Set2[8][1],
                                                                                                                  legend_position='right',
                                                                                                    xrotation=60)
    all_dfs['species-inoculumn']=all_dfs['species-ino']
    all_dfs_p= all_dfs.loc[all_dfs['species-inoculumn'].isin(df['species-inoculumn'].values),:]
    all_dfs_p.loc[all_dfs_p['species-inoculumn'].isin(to_repol),'sel_coeff']= -all_dfs_p.loc[all_dfs_p['species-inoculumn'].isin(to_repol),'sel_coeff']
    
    all_dfs_p['species']=all_dfs_p['species-inoculumn'].transform(lambda x: x.split('-')[0])
    
    p3 = hv.Points(all_dfs_p.loc[all_dfs_p['media']=='mGAM',:], vdims=['sel_coeff'],kdims=['species-inoculumn','sel_coeff'],).opts(width=int((2/3)*500),
                                                                                                        size=5,
                                                                                        color=bokeh.palettes.Set2[8][0],
                                                                                              alpha=.5,
                                                                                                    xrotation=60)
    
    p4 = hv.Points(all_dfs_p.loc[all_dfs_p['media']=='mBHI',:], vdims=['sel_coeff'],kdims=['species-inoculumn','sel_coeff']).opts(width=int((2/3)*500),
                                                                                                        size=5,
                                                                                        color=bokeh.palettes.Set2[8][1],
                                                                                              alpha=.5,
                                                                                                    xrotation=60)
    
    dfsig = df.loc[df['qvals']<.05,:].copy()
    dfsig  = dfsig.loc[dfsig['qvals']>.001,:]
    dfsig['sel_coeff']= -1.5
    dfsig['media'] = 'p<.05'
    p5 = hv.Points(dfsig, vdims=['sel_coeff'],kdims=['species-inoculumn','sel_coeff'], label = 'p<.05').opts(width=500,marker='*',color = 'black',
                                                                                                        size=5,
                                                                                    )
    
    dfsigsig = df.loc[df['qvals']<.001,:].copy()
    dfsigsig['sel_coeff']= -1.5
    dfsigsig['media'] = 'p<.05'
    p6 = hv.Points(dfsigsig, vdims=['sel_coeff'],kdims=['species-inoculumn','sel_coeff'],  label = 'p<.001').opts(width=500,marker='+',color = 'black',
                                                                                                        size=5,)
                                                                                    
    p=hv.render(p*p2*p3*p4*p2*p5*p6)
    p.yaxis.axis_label='Sel Coeff'
    p.xaxis.axis_label='Competition'
    p.ray(x=0,y=0,angle=0,color='black')
    p.output_backend = "svg"
    p.y_range = bokeh.models.Range1d(-2.4,6.4)
    
    test_name='bloh'
    bokeh.io.export_svgs(p, filename = test_name + '.svg')
    export_plot_pdf(p,f'media_stuff_{int1}_{int2}')
    bokeh.io.show(p)
    return df

# %%
dfp0p1= make_plot_interval(all_dfs, (0,1))
dfp0p7= make_plot_interval(all_dfs, (0,7))
dfp0p7= make_plot_interval(all_dfs, (0,2))
dfp0p7= make_plot_interval(all_dfs, (0,3))
dfp0p7= make_plot_interval(all_dfs, (0,4))
dfp0p7= make_plot_interval(all_dfs, (0,5))
dfp0p7= make_plot_interval(all_dfs, (0,6))


dfp0p7= make_plot_interval(all_dfs, (1,7))
dfp0p7= make_plot_interval(all_dfs, (2,7))
dfp0p7= make_plot_interval(all_dfs, (3,7))
dfp0p7= make_plot_interval(all_dfs, (4,7))
dfp0p7= make_plot_interval(all_dfs, (5,7))
dfp0p7= make_plot_interval(all_dfs, (6,7))
# Out:
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM ['mBHI']
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False True False
# 100196-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI True True True
# 102528-AA-AE-mBHI False False False
# 102438-AA-AE-mBHI ['mGAM']
# 100099-AA-AF-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM True True True
# 100196-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 103117-AA-AF-mGAM False True False
# 101346-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM False False False
# 102544-AA-AE-mBHI False False False
# 100099-AE-AF-mGAM True True True
# 100146-AE-AF-mGAM False False False
# 102438-AE-AF-mGAM True True True
# 101294-AE-AF-mGAM True True True
# 103656-AE-AF-mGAM True True True
# 102478-AE-AF-mGAM ['mGAM']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI True True True
# 101294-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI ['mGAM']
# 26
# 13
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6194: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#   <div id="f87f44da-d100-48b4-8f8b-9141b483deda" data-root-id="488fdd77-2dc1-4280-ae64-e0d8770a9d14" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM False True False
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI True True True
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI False False False
# 100099-AA-AF-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM ['mGAM']
# 100196-AA-AF-mGAM False False False
# 103117-AA-AF-mGAM ['mGAM']
# 102544-AA-AE-mBHI False False False
# 102528-AA-AE-mBHI False False False
# 100099-AE-AF-mGAM True True True
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM True True True
# 103656-AE-AF-mGAM ['mGAM']
# 100099-AE-AF-mBHI False False False
# 101294-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI True True True
# 102528-AE-AF-mBHI False False False
# 101400-AA-AF-mBHI True True True
# 102528-AA-AF-mBHI ['mGAM']
# 25
# 10
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6194: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#   <div id="a7915c03-cf2f-40ea-8781-bf11ed477dd3" data-root-id="e28a4ab1-4079-48de-840b-76bdba7b8d29" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM False True True
# 101294-AA-AE-mGAM False False False
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI ['mBHI']
# 102438-AA-AE-mBHI False False False
# 100196-AA-AE-mBHI ['mGAM']
# 100099-AA-AF-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 103117-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 102544-AA-AE-mBHI ['mBHI']
# 100099-AE-AF-mGAM True True True
# 100146-AE-AF-mGAM False False False
# 102438-AE-AF-mGAM True True True
# 101294-AE-AF-mGAM True True True
# 100099-AE-AF-mBHI False False False
# 101294-AE-AF-mBHI ['mGAM']
# 102438-AE-AF-mBHI True True True
# 102528-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI ['mGAM']
# 103656-AE-AF-mGAM ['mGAM']
# 22
# 11
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
#   <div id="c1159e5c-4787-4657-af3c-ef283676d8fc" data-root-id="019c8eaa-70c5-44a4-b092-399431cb3e85" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM True True True
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI False False False
# 102438-AA-AE-mBHI False False False
# 102528-AA-AE-mBHI False True False
# 100196-AA-AE-mBHI ['mGAM']
# 100099-AA-AF-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 100196-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM False False False
# 103656-AA-AF-mGAM ['mGAM']
# 103117-AA-AF-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 102544-AA-AE-mBHI ['mBHI']
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM True True True
# 102478-AE-AF-mGAM ['mBHI']
# 103656-AE-AF-mGAM ['mGAM']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI True True True
# 101294-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI True True True
# 102528-AA-AF-mBHI ['mGAM']
# 25
# 11
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
#   <div id="a82a6b3d-b549-4316-808b-9ba093d619a5" data-root-id="b32e05d2-5b2f-4e4e-a167-9797371f3f9d" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM False True True
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM False False False
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI ['mBHI']
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI ['mGAM']
# 100099-AA-AF-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 100196-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 103656-AA-AF-mGAM ['mGAM']
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM False True True
# 102478-AE-AF-mGAM ['mBHI']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI False True True
# 101294-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI True True True
# 102528-AA-AF-mBHI ['mGAM']
# 103656-AE-AF-mGAM ['mGAM']
# 23
# 9
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
#   <div id="b876ff0f-f5a2-42d4-8d02-c2fe34173c75" data-root-id="b99bbdde-4bc4-4785-ba86-e86faabf4423" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM False True True
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM False False False
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI ['mBHI']
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI ['mGAM']
# 102528-AA-AE-mBHI ['mGAM']
# 101059-AA-AF-mBHI True True True
# 100099-AA-AF-mBHI False False False
# 102438-AA-AF-mBHI False False False
# 102528-AA-AF-mBHI ['mGAM']
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 100196-AA-AF-mGAM ['mGAM']
# 101294-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 103656-AA-AF-mGAM ['mGAM']
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM False True True
# 102478-AE-AF-mGAM True True True
# 103656-AE-AF-mGAM ['mGAM']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI False True True
# 102528-AE-AF-mBHI ['mBHI']
# 101294-AE-AF-mBHI ['mGAM']
# 23
# 11
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
#   <div id="cb188514-2516-4c8e-a3e5-611a27789738" data-root-id="f21575a7-9f80-4c0a-ae89-268842fae3f1" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM False True False
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI False False False
# 102438-AA-AE-mBHI False False False
# 100196-AA-AE-mBHI ['mGAM']
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mBHI False False False
# 102528-AA-AF-mBHI ['mGAM']
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 103656-AA-AF-mGAM ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 102528-AA-AE-mBHI ['mGAM']
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM False True True
# 103656-AE-AF-mGAM ['mGAM']
# 102478-AE-AF-mGAM ['mBHI']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI False True False
# 102528-AE-AF-mBHI True True True
# 101294-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI True True True
# 24
# 10
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6194: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#   <div id="f4afaee1-2bbc-4d31-8efb-918795e91616" data-root-id="4f38cfd8-1c86-43dc-a31f-18b6c867c3ab" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM ['mBHI']
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM False True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 102438-AE-AF-mGAM False True True
# 101294-AE-AF-mGAM True True True
# 103656-AE-AF-mGAM ['mGAM']
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI ['mGAM']
# 102528-AA-AE-mBHI ['mGAM']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI False False False
# 101294-AE-AF-mBHI ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM ['mGAM']
# 100099-AA-AF-mBHI False False False
# 102478-AE-AF-mGAM ['mBHI']
# 20
# 5
#   <div id="d6241cbf-0c5e-4c1e-9666-09be825739cc" data-root-id="98b79964-b131-440e-9d1a-ae0bcac9a5df" style="display: contents;"></div>
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mGAM False True True
# 100146-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM True True True
# 102478-AA-AF-mGAM False True False
# 102506-AA-AF-mGAM False False False
# 100099-AE-AF-mBHI False True False
# 102438-AE-AF-mBHI False False False
# 102528-AE-AF-mBHI ['mBHI']
# 100099-AA-AE-mGAM False True True
# 100146-AA-AE-mGAM False False False
# 102438-AA-AE-mGAM False True False
# 100099-AE-AF-mGAM False False False
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM False True True
# 101294-AA-AF-mGAM ['mGAM']
# 101346-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM ['mGAM']
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI ['mGAM']
# 101294-AE-AF-mBHI ['mGAM']
# 101294-AA-AE-mGAM ['mGAM']
# 102478-AA-AE-mGAM False False False
# 103656-AA-AE-mGAM ['mGAM']
# 103656-AE-AF-mGAM ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 100099-AA-AF-mBHI False False False
# 102478-AE-AF-mGAM ['mBHI']
# 19
# 0
#   <div id="db74ef44-8a5b-4b54-9343-8a1b5b128417" data-root-id="9f96ee89-acbb-4180-a293-89823649df0e" style="display: contents;"></div>
# 100099-AA-AE-mGAM False True False
# 100146-AA-AE-mGAM False False False
# 101294-AA-AE-mGAM ['mGAM']
# 102438-AA-AE-mGAM False True False
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AF-mGAM False True True
# 100146-AA-AF-mGAM False True False
# 102438-AA-AF-mGAM False True True
# 102478-AA-AF-mGAM False True False
# 102506-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM ['mGAM']
# 101346-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI ['mBHI']
# 101059-AA-AF-mBHI True True True
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 102438-AE-AF-mGAM True True True
# 101294-AE-AF-mGAM ['mGAM']
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI ['mGAM']
# 100099-AE-AF-mBHI False True False
# 101294-AE-AF-mBHI ['mGAM']
# 102438-AE-AF-mBHI False False False
# 102478-AA-AE-mGAM False False False
# 100196-AA-AF-mGAM ['mGAM']
# 100099-AA-AF-mBHI False False False
# 102438-AA-AF-mBHI False False False
# 102528-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI ['mGAM']
# 17
# 0
#   <div id="fe0c7d7d-c4c3-4758-97de-857d539e18b5" data-root-id="effa0a45-fa1f-4902-870d-56d94e1323eb" style="display: contents;"></div>
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI False False False
# 102438-AA-AE-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AE-AF-mBHI False True False
# 102438-AE-AF-mBHI False False False
# 100196-AA-AE-mBHI ['mGAM']
# 102528-AA-AE-mBHI ['mGAM']
# 101294-AE-AF-mBHI ['mGAM']
# 100099-AA-AE-mGAM False True False
# 100146-AA-AE-mGAM False False False
# 102438-AA-AE-mGAM False True False
# 102478-AA-AE-mGAM False False False
# 100099-AA-AF-mGAM False True True
# 100146-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False True True
# 102478-AA-AF-mGAM False True False
# 102506-AA-AF-mGAM False False False
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM False True False
# 102478-AE-AF-mGAM ['mBHI']
# 101294-AA-AE-mGAM ['mGAM']
# 101294-AA-AF-mGAM False True True
# 101346-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 100099-AA-AF-mBHI False False False
# 101400-AA-AF-mBHI False False False
# 20
# 1
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6194: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#   <div id="eddc9d9f-3b01-440e-a962-d42bfcf6477f" data-root-id="70e18dcc-33f2-4aca-9882-15d64d1087e1" style="display: contents;"></div>
# 100099-AA-AE-mGAM False True False
# 100146-AA-AE-mGAM False False False
# 102438-AA-AE-mGAM False True False
# 102478-AA-AE-mGAM False False False
# 100099-AA-AF-mGAM False True False
# 100146-AA-AF-mGAM False True False
# 101346-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM True True True
# 102478-AA-AF-mGAM False True True
# 102506-AA-AF-mGAM False False False
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI ['mBHI']
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM True True True
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM True True True
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI ['mGAM']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI False True False
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 101294-AA-AF-mGAM False True True
# 103656-AA-AF-mGAM ['mGAM']
# 101059-AA-AF-mBHI False True True
# 102438-AA-AF-mBHI False False False
# 101294-AE-AF-mBHI ['mGAM']
# 100099-AA-AF-mBHI False False False
# 101400-AA-AF-mBHI ['mBHI']
# 100196-AA-AF-mGAM ['mGAM']
# 102478-AE-AF-mGAM ['mBHI']
# 19
# 0
#   <div id="dec9da75-25b9-426f-8cbc-7581b75af0bf" data-root-id="4fa11efd-4146-4b83-803a-98c5315e0bd0" style="display: contents;"></div>
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI ['mBHI']
# 101059-AA-AF-mBHI True True True
# 100099-AA-AE-mGAM False True False
# 100146-AA-AE-mGAM False True False
# 102438-AA-AE-mGAM False True False
# 102478-AA-AE-mGAM False False False
# 100099-AE-AF-mBHI False True True
# 102438-AE-AF-mBHI False True False
# 102528-AE-AF-mBHI ['mBHI']
# 100099-AE-AF-mGAM True True True
# 100146-AE-AF-mGAM False True False
# 101294-AE-AF-mGAM False False False
# 102438-AE-AF-mGAM True True True
# 102478-AE-AF-mGAM ['mBHI']
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AF-mGAM False True False
# 100146-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False True False
# 101346-AA-AF-mGAM ['mGAM']
# 102438-AA-AF-mGAM False True True
# 102478-AA-AF-mGAM False True False
# 102506-AA-AF-mGAM False False False
# 103656-AA-AF-mGAM ['mGAM']
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI ['mGAM']
# 101294-AE-AF-mBHI ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 100099-AA-AF-mBHI False False False
# 102438-AA-AF-mBHI False False False
# 102528-AA-AF-mBHI ['mGAM']
# 18
# 1
#   <div id="d19cc175-bdee-44e6-8e2d-6ec5f9d379be" data-root-id="f7cd259c-d9f3-4b68-a251-378792daea75" style="display: contents;"></div>

# %%
dfp0p7= make_plot_interval(all_dfs, (0,7))
dfp0p1= make_plot_interval(all_dfs, (0,1))
# Out:
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM False True False
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI False False False
# 102438-AA-AE-mBHI False False False
# 100196-AA-AE-mBHI ['mGAM']
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mBHI False False False
# 102528-AA-AF-mBHI ['mGAM']
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 103656-AA-AF-mGAM ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 102528-AA-AE-mBHI ['mGAM']
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM False True True
# 103656-AE-AF-mGAM ['mGAM']
# 102478-AE-AF-mGAM ['mBHI']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI False True False
# 102528-AE-AF-mBHI True True True
# 101294-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI True True True
# 24
# 10
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6194: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#   <div id="bbf1e44b-d371-4d1d-8d16-5e71eb3637e2" data-root-id="7dc2bd77-bf3f-404b-b303-9b58619fb11a" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM ['mBHI']
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False True False
# 100196-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI True True True
# 102528-AA-AE-mBHI False False False
# 102438-AA-AE-mBHI ['mGAM']
# 100099-AA-AF-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM True True True
# 100196-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 103117-AA-AF-mGAM False True False
# 101346-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM False False False
# 102544-AA-AE-mBHI False False False
# 100099-AE-AF-mGAM True True True
# 100146-AE-AF-mGAM False False False
# 102438-AE-AF-mGAM True True True
# 101294-AE-AF-mGAM True True True
# 103656-AE-AF-mGAM True True True
# 102478-AE-AF-mGAM ['mGAM']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI True True True
# 101294-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI ['mGAM']
# 26
# 13
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6194: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#   <div id="a1b6908c-a159-420c-b526-61f1ef9ddf36" data-root-id="061fc1e9-2910-42d6-8704-cd6e749d9295" style="display: contents;"></div>

# %%
dfp0p1= make_plot_interval(all_dfs, (0,1))
dfp0p7= make_plot_interval(all_dfs, (0,7))
dfp1p7= make_plot_interval(all_dfs, (1,7))
# Out:
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM ['mBHI']
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False True False
# 100196-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI True True True
# 102528-AA-AE-mBHI False False False
# 102438-AA-AE-mBHI ['mGAM']
# 100099-AA-AF-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM True True True
# 100196-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 103117-AA-AF-mGAM False True False
# 101346-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM False False False
# 102544-AA-AE-mBHI False False False
# 100099-AE-AF-mGAM True True True
# 100146-AE-AF-mGAM False False False
# 102438-AE-AF-mGAM True True True
# 101294-AE-AF-mGAM True True True
# 103656-AE-AF-mGAM True True True
# 102478-AE-AF-mGAM ['mGAM']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI True True True
# 101294-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI ['mGAM']
# 26
# 13
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6194: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#   <div id="a8e4ef28-6c95-40c9-916c-d4af528cdf69" data-root-id="f77e81c5-d241-4536-b250-0bde3843713f" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM False True False
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM True True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI False False False
# 102438-AA-AE-mBHI False False False
# 100196-AA-AE-mBHI ['mGAM']
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AA-AF-mBHI False False False
# 102528-AA-AF-mBHI ['mGAM']
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 103656-AA-AF-mGAM ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 102528-AA-AE-mBHI ['mGAM']
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 101294-AE-AF-mGAM True True True
# 102438-AE-AF-mGAM False True True
# 103656-AE-AF-mGAM ['mGAM']
# 102478-AE-AF-mGAM ['mBHI']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI False True False
# 102528-AE-AF-mBHI True True True
# 101294-AE-AF-mBHI ['mGAM']
# 101400-AA-AF-mBHI True True True
# 24
# 10
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/scipy/stats/_stats_py.py:6194: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
#   <div id="fe150352-340c-48c0-9f01-50498d0e7d24" data-root-id="d2d00bb6-202c-4ba9-9cf1-17ba7336a4f7" style="display: contents;"></div>
# 100099-AA-AE-mGAM False False False
# 100146-AA-AE-mGAM ['mBHI']
# 102438-AA-AE-mGAM False False False
# 102478-AA-AE-mGAM False True True
# 101294-AA-AE-mGAM ['mGAM']
# 103656-AA-AE-mGAM ['mGAM']
# 100099-AA-AF-mGAM False False False
# 100146-AA-AF-mGAM False False False
# 102438-AA-AF-mGAM False False False
# 102478-AA-AF-mGAM True True True
# 102506-AA-AF-mGAM False False False
# 101294-AA-AF-mGAM False False False
# 101346-AA-AF-mGAM ['mGAM']
# 100099-AA-AE-mBHI False False False
# 100910-AA-AE-mBHI False False False
# 101059-AA-AF-mBHI True True True
# 102438-AA-AF-mBHI False False False
# 100099-AE-AF-mGAM False True True
# 100146-AE-AF-mGAM False False False
# 102438-AE-AF-mGAM False True True
# 101294-AE-AF-mGAM True True True
# 103656-AE-AF-mGAM ['mGAM']
# 100196-AA-AE-mBHI ['mGAM']
# 102438-AA-AE-mBHI ['mGAM']
# 102528-AA-AE-mBHI ['mGAM']
# 100099-AE-AF-mBHI False False False
# 102438-AE-AF-mBHI False False False
# 101294-AE-AF-mBHI ['mGAM']
# 100196-AA-AF-mGAM ['mGAM']
# 103656-AA-AF-mGAM ['mGAM']
# 100099-AA-AF-mBHI False False False
# 102478-AE-AF-mGAM ['mBHI']
# 20
# 5
#   <div id="e9cdaecd-b3b2-40c0-8311-83e1c9fc541e" data-root-id="55f3ca33-7817-4d94-a55f-4cf90da35911" style="display: contents;"></div>

# %%
dfp0p7sig = dfp0p7.loc[dfp0p7['qvals']<.05,:]
dfp0p1['same_dir']=(dfp0p1['mBHI']>0)==(dfp0p1['mGAM']>0)
dfp1p7['same_dir']=(dfp1p7['mBHI']>0)==(dfp1p7['mGAM']>0)

shifts = dfp1p7.loc[~dfp1p7['same_dir'],'species-inoculumn'].values
dfp0p1.loc[dfp0p1['species-inoculumn'].isin(shifts),:]
# Out:
#     mGAM_min  mBHI_min  mGAM_max  mBHI_max      mBHI      mGAM         pvals  \
# 0  -1.679742 -2.090167 -1.411771 -1.906073  1.998504  1.580033  6.457849e-04
# 21 -3.269342 -2.592083 -2.470159 -1.942086  1.987853  2.785740  9.972197e-02
# 22  1.528049  1.268673  1.947909  1.511274  1.350247  1.828919  2.058298e-02
# 13 -0.974728  1.113613 -0.809704  1.162287  1.157865 -0.917519  1.453069e-07
# 20  1.475402  0.947669  1.704017  1.035008  0.981870  1.487863  4.936947e-04
#
#     species-inoculumn     qvals species_id  repol species  same_dir
# 0   100099-AA-AE-mGAM  0.002399     100099   True  100099      True
# 21  100146-AE-AF-mGAM  0.162048     100146   True  100146      True
# 22  102438-AE-AF-mGAM  0.041166     102438  False  102438      True
# 13  101294-AA-AF-mGAM  0.000004     101294  False  101294     False
# 20  100099-AE-AF-mGAM  0.002399     100099  False  100099      True

# %%
dfp1p7.loc[~dfp1p7['same_dir'],:].sort_values(by='qvals')
good = ['100099-AA-AE-mGAM','100146-AE-AF-mGAM']
# Out:
#     mGAM_min  mBHI_min  mGAM_max  mBHI_max      mBHI      mGAM     pvals  \
# 8  -0.210959  1.063507 -0.054966  1.076087  1.069797 -0.159626  0.000016
# 0  -0.136765  0.285950 -0.058075  0.485246  0.291398 -0.095738  0.000156
# 14 -0.173589  0.391601 -0.173589  0.459640  0.440940 -0.173589  0.004481
# 13 -0.282440 -1.298932  0.914974 -0.637468  0.849212 -0.050611  0.023632
# 15 -0.514680 -0.560237  0.711547 -0.165263  0.520712 -0.369793  0.119729
#
#     species-inoculumn     qvals species_id  repol species  same_dir
# 8   101294-AA-AF-mGAM  0.000329     101294  False  101294     False
# 0   100099-AA-AE-mGAM  0.001563     100099  False  100099     False
# 14  100146-AE-AF-mGAM  0.022403     100146  False  100146     False
# 13  100099-AE-AF-mGAM  0.052515     100099   True  100099     False
# 15  102438-AE-AF-mGAM  0.159639     102438   True  102438     False
