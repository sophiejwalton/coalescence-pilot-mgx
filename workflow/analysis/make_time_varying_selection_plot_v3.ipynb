# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control
#from bokeh.models import FixedTicker, FuncTickFormatter 
from scipy.stats import chi2

#from bokeh.io import output_notebook

from snp_analysis_tools_sherlock import *
from plot_tools import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e058244d-e942-40c8-b99d-5995dc28ae13'>
#   <div id="bd04e3e9-165a-42ee-a433-4789d166a0aa" data-root-id="e058244d-e942-40c8-b99d-5995dc28ae13" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"56e36f1d-7113-424c-b76f-62db84bdb847":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e058244d-e942-40c8-b99d-5995dc28ae13"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"dec1a15d-64cf-4ada-b913-743b37298d30","attributes":{"plot_id":"e058244d-e942-40c8-b99d-5995dc28ae13","comm_id":"c75396bce69246b9980142022a06ff49","client_comm_id":"d65eb7aca1614a9d91cbe9a54614524d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"56e36f1d-7113-424c-b76f-62db84bdb847","roots":{"e058244d-e942-40c8-b99d-5995dc28ae13":"bd04e3e9-165a-42ee-a433-4789d166a0aa"},"root_ids":["e058244d-e942-40c8-b99d-5995dc28ae13"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_metadata  =transform_df(df_metadata)
df_metadata.loc[df_metadata['species_id']==101349,:]
# Out:
#       species_id    representative MGnify_accession  species_closest  \
# 1348      101349  GUT_GENOME096096  MGYG-HGUT-01349         102640.0
#
#       ani_closest  gtpro_kmer_counts  phyeco_marker_counts  phyeco_pass_ratio  \
# 1348      94.0625            55924.0                  15.0                1.0
#
#       pangene_counts  genome_counts  ...     N50  GC_content  Completeness  \
# 1348          100370            789  ...  257597       38.67         100.0
#
#       Contamination                                            Lineage  \
# 1348            0.0  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o...
#
#       Continent                   species           genus              family  \
# 1348        NaN  s__Veillonella parvula_A  g__Veillonella  f__Veillonellaceae
#
#                 phyla
# 1348  p__Firmicutes_C
#
# [1 rows x 23 columns]

# %%
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',

            
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
            
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
            
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',

            
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
            
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
            
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
            
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
            
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',

            
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI',]

# %%
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parent1_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    freq1 = pd.read_csv(fname1)
    df_both = get_both_dfs(fname1)
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['total_shift']<.1,:]
    

    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()


   # print('bef',np.max(df_both_meta_good['actual_med1']- df_both_meta_good['boot_med1']))
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med1']/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med1']/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])

# %%
def get_pred_sel(ts,sel_coeff, start_value,):
    pred=np.exp(ts*sel_coeff)
    pred = pred*start_value/(1 - start_value + start_value*pred)
    return pred

# %%
def get_preds_for_plottingv2(sp,ino,type_meso, t0,t1):

    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
    print(fname1)
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parent1_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    freq1 = pd.read_csv(fname1)
    df_both = get_both_dfs(fname1)
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['total_shift']<.1,:]
    

    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()


   # print('bef',np.max(df_both_meta_good['actual_med1']- df_both_meta_good['boot_med1']))
    df_both_meta_good.loc[df_both_meta_good['boot_med1']<1e-3,'boot_med1']=1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med1']>1-1e-3,'boot_med1']=1-1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med2']<1e-3,'boot_med2']=1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med1']>1-1e-3,'boot_med1']=1-1e-3
    
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med1']/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med1']/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])
   # print(df_both_meta_good['boot_med1'])
    df_both_meta_good.loc[df_both_meta_good['boot_med1']<1e-3,'boot_med1']=1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med1']>1-1e-3,'boot_med1']=1-1e-3

    sel_stuff['type_mesocosm']=sel_stuff['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:]))
    sel_stuff['species']=sp
    sel_stuff['inoculumn']=ino
    sel_stuff = sel_stuff.loc[sel_stuff['type_mesocosm']==type_meso,:]
    sel_stuff['start_val']=np.nan
    sel_stuff['t1_val']=np.nan
    
    if len(sel_stuff)==0:
        return [],[],[],[]
    good_mesos = []
    for meso in sel_stuff['mesocosm'].unique():
    
        sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'late_sel_med']
        start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1']
        if len(start_val)>0:
            sel_stuff.loc[sel_stuff['mesocosm']==meso,'start_val'] = start_val.values[0]
        passages = list(df_both_meta_good.loc[df_both_meta_good['mesocosm']==meso,'passage'].values)
        if len(np.intersect1d([1,2,6,7],passages))==4:
            good_mesos.append(meso)
    ts=np.arange(9)
    #print(start_values)
    sel_stuff=sel_stuff.loc[~sel_stuff['start_val'].isna(),:]
    sel_stuff = sel_stuff.loc[sel_stuff['mesocosm'].isin(good_mesos),:]
    if len(sel_stuff)==0:
        return [],[],[],[]
    sel_stuff_med = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).median(numeric_only=True)
    
   #print(sel_stuff_med)
    pred_values = get_pred_sel(ts-t1,sel_stuff_med['early_sel_med'].values[0], sel_stuff_med['start_val'].values[0])
    pred_values_logit = np.log(pred_values/(1-pred_values))
    sel_coeffs = sel_stuff['early_sel_med'].values
    print(len(sel_stuff))
    start_values = sel_stuff['start_val'].values
    print('starts',start_values)
    print(sel_coeffs)
    pred_values_t7=get_pred_sel(7-t1,sel_coeffs, start_values,)
    argmax_7 =np.argmax(pred_values_t7) 
    argmin_7 =np.argmin(pred_values_t7) 

    ts=np.arange(9)
    pred_valuesmax = get_pred_sel(ts-t1,sel_coeffs[argmax_7], start_values[argmax_7],)
    pred_values_logitmax = np.log(pred_valuesmax/(1-pred_valuesmax))

    pred_valuesmin = get_pred_sel(ts-t1,sel_coeffs[argmin_7], start_values[argmin_7],)
    pred_values_logitmin = np.log(pred_valuesmin/(1-pred_valuesmin))
  #  print('potatoes',sel_stuff_meso.loc[(sel_stuff_meso['passage1']==t0)*(sel_stuff_meso['passage2']==t1),'start_value1'].values)
    
        
    return ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax

# %%
.93/(.1+.93)
# Out:
# 0.9029126213592233

# %%
import os
inos=['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]

#inos = ['AA-AF-mGAM']
1#inos = ['AE-AF-mBHI']
species = [102438,100196, 100099, 100146, 101346, 102506, 102478]
species = [102438,100196, 100099, 100146, 101346, 102506, 102478,102358,101294]
species = [102438]
species = ['100146', '101059', '100910', '102478', '102438', '100196',
       '103117', '103656', '102544', '102506', '101346', '100099',
       '101400', '101294']

species
t0=1
t1=2
inos = ['AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI','AE-AF-mGAM',]
#inos = ['AE-AF-mBHI',]
species = [100099]
for sp in species:
    plots_all=[]
    for ino in inos:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{sp}/{ino}_parent1_info.csv'
        if f'{sp}-{ino}' in bad_inos:
            continue
        if not os.path.isfile(fname):
            print('oo')
            continue
        psstrain,type_mesos = make_logit_plot(sp, ino,
                                       colorby='const',logit=True,
                                        )
      #  print(psstrain)
        for i in range(len(psstrain)):
            p1 = psstrain[i]
            meso = type_mesos[i]
            med1=meso.split('-')[-2]
            med2 = meso.split('-')[-1]
            ino1 = f'{sp}-{med1}-{med2}'
            p1.legend.visible=False
            ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax = get_preds_for_plottingv2(sp,ino,meso, t0,t1)
            if len(pred_values_logit)>0:
                p1.line(ts,pred_values_logit,color='grey')
                p1.line(ts,pred_values_logitmin,color='grey',line_dash='dashed')
                p1.line(ts,pred_values_logitmax,color='grey',line_dash='dashed')
                p1.yaxis.axis_label_text_font_style = 'normal'
                p1.xaxis.axis_label_text_font_style = 'normal'
                bokeh.io.show(p1)
                p1.output_backend='svg'
                export_plot_pdf(p1,f'time_varying_plotv2_{sp}_{ino}-{med2}-{t0}_{t1}')
# Out:
# bef 0.000250000000000028
# aft 0.0001701968080887184
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AF-mGAM_0_1_6_7_parent1_info_shift.csv
# 2
# starts [0.19331984 0.17712551]
# [-1.04339899 -1.11123075]
#   <div id="a164732f-6094-49f2-9eca-1babcffb3c87" data-root-id="f999a2ec-5bab-4a23-908a-2fb74a734a8f" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AF-mGAM_0_1_6_7_parent1_info_shift.csv
# 4
# starts [0.31589744 0.33521127 0.38821138 0.32284264]
# [-0.39083502 -0.25797628 -0.06886291 -0.31478287]
#   <div id="ca787bab-3a95-4978-b87a-52c35e5a9c30" data-root-id="ed79badb-1ac1-48d1-b9e2-e3ebacd93442" style="display: contents;"></div>
# bef 1.1102230246251565e-16
# aft 9.71445146547012e-17
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AE-mGAM_0_1_6_7_parent1_info_shift.csv
# 4
# starts [0.09219858 0.08669355 0.08577195 0.07762097]
# [-1.91035827 -1.99352716 -2.0052232  -2.09270193]
#   <div id="ffb9d7b2-ad33-4f49-a6cc-993f197be37c" data-root-id="57f54251-c2a1-49d3-b0ef-88877f0b0794" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AE-mGAM_0_1_6_7_parent1_info_shift.csv
# 4
# starts [0.11257606 0.14488349 0.12626263 0.12145749]
# [-1.68122492 -1.41240237 -1.56630645 -1.59274797]
#   <div id="e5366df2-f936-4d9f-92ce-481984ec410b" data-root-id="a7dc0e4e-f80b-4802-99a7-3b3ebd1d5266" style="display: contents;"></div>
# bef 4.1560630551010225e-06
# aft 0.0007515221322722532
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AE-AF-mBHI_0_1_6_7_parent1_info_shift.csv
# 4
# starts [0.36908517 0.30922432 0.33581296 0.36908517]
# [-1.30645868 -1.74468224 -1.45800652 -1.47706725]
#   <div id="e5afaed7-cd18-44be-9f0e-a9afa21a68d4" data-root-id="13e791c8-60e8-496b-a3ed-75b03583e798" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AE-AF-mBHI_0_1_6_7_parent1_info_shift.csv
# 4
# starts [0.44045175 0.44364012 0.3914405  0.34759916]
# [-1.01200921 -1.17064211 -1.20884332 -1.57013905]
#   <div id="ccd1343b-d047-455b-8253-c402018f22b7" data-root-id="37155d68-184b-4ff6-ae37-68f15de02d22" style="display: contents;"></div>
# bef 2.0321123693000515e-05
# aft 2.0324874233677154e-05
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AF-mBHI_0_1_6_7_parent1_info_shift.csv
# 2
# starts [0.09182644 0.0840081 ]
# [-1.23654217 -1.05034406]
#   <div id="c0609cf5-0440-4f44-88b7-d017b6db0589" data-root-id="c84f2975-272e-4686-bd5c-2e8223b63fdc" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AF-mBHI_0_1_6_7_parent1_info_shift.csv
# 1
# starts [0.11466942]
# [-0.99448567]
#   <div id="a965c4ab-13b3-40f3-a82c-bd77c1803567" data-root-id="f5686a27-1174-4f2b-b6a8-f6644faf88b9" style="display: contents;"></div>
# bef 1.593764155470058e-05
# aft 1.5826446067498945e-05
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AE-mBHI_0_1_6_7_parent1_info_shift.csv
# 1
# starts [0.23188406]
# [0.47446678]
#   <div id="efade00e-2577-46c4-b93a-3c8cd1d0773e" data-root-id="d572a640-265b-4643-bb6f-880a1bea0097" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AE-mBHI_0_1_6_7_parent1_info_shift.csv
# 2
# starts [0.12677485 0.17269907]
# [-0.17988473  0.10121222]
#   <div id="e7c403e7-3e58-42fd-9457-b4a3f51a1725" data-root-id="5f3f0ec8-8688-4170-871f-26068c92ce6f" style="display: contents;"></div>
# bef 4.799994025805887e-06
# aft 0.00042215107159060405
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AE-AF-mGAM_0_1_6_7_parent1_info_shift.csv
# 3
# starts [0.71646341 0.70948012 0.72616633]
# [0.98249873 0.94767004 1.03500821]
#   <div id="f90b3eaf-445c-433a-99d5-321ee085f09d" data-root-id="5d466d0b-be9d-4a0b-be3f-82d2a76f29c9" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AE-AF-mGAM_0_1_6_7_parent1_info_shift.csv
# 3
# starts [0.83910387 0.80933063 0.80465587]
# [1.70401731 1.49906741 1.4741954 ]
#   <div id="cdd4057d-48ad-4621-b663-1577b9a2b78b" data-root-id="ad983603-fa66-4600-a5d9-970f4e5bf08d" style="display: contents;"></div>

# %%
species = 101346
inoculumn = 'AE-AF-mBHI'
t0=1
t1=2
fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
df = pd.read_csv(fname1)
df.columns.values

# %%
def get_selection_stuff_time_vary(species,inoculumn,t0,t1,thresh=1e-3):
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
    print(fname1)
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parent1_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    freq1 = pd.read_csv(fname1)
    df_both = get_both_dfs(fname1)
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['total_shift']<.1,:]
    

    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()


   # print('bef',np.max(df_both_meta_good['actual_med1']- df_both_meta_good['boot_med1']))
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med1']/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med1']/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])
    sel_stuff['type_mesocosm']=sel_stuff['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:]))
    sel_stuff['species']=species
    sel_stuff['inoculumn']=inoculumn
   # sel_stuff = sel_stuff.loc[sel_stuff['type_mesocosm']==type_meso,:]
    sel_stuff['start_val']=np.nan
    sel_stuff['t1_val']=np.nan
    
    if len(sel_stuff)==0:
        return [],[]
    good_mesos = []
    for meso in sel_stuff['mesocosm'].unique():
    
        sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'early_sel_med']
        start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1']
        if len(start_val)>0:
            sel_stuff.loc[sel_stuff['mesocosm']==meso,'start_val'] = start_val.values[0]
        passages = list(df_both_meta_good.loc[df_both_meta_good['mesocosm']==meso,'passage'].values)
        if len(np.intersect1d([1,2,6,7],passages))==4:
            good_mesos.append(meso)
    ts=np.arange(9)
    
    #print(start_values)
    sel_stuff=sel_stuff.loc[~sel_stuff['start_val'].isna(),:]
    sel_stuff = sel_stuff.loc[sel_stuff['mesocosm'].isin(good_mesos),:]
    sel_stuff.loc[sel_stuff['start_val']<=1e-3,'late_sel_med']=sel_stuff.loc[sel_stuff['start_val']<=1e-3,'early_sel_med']
    sel_stuff.loc[sel_stuff['start_val']>=1-1e-3,'late_sel_med']=sel_stuff.loc[sel_stuff['start_val']>=1-1e-3,'early_sel_med']
    if len(sel_stuff)==0:
        return [],[]
    sel_stuff_meso_meds = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).median(numeric_only=True)
    sel_stuff_meso_maxs= sel_stuff.groupby(['type_mesocosm','species','inoculumn']).max(numeric_only=True)
    
    sel_stuff_meso_mins = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).min(numeric_only=True)
   # print(species, sel_stuff_meso_meds.columns.values)
    for column in ['early_sel_med','act_7_med','pred7_med','late_sel_med']:
        sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'max_{column}']=sel_stuff_meso_maxs.loc[sel_stuff_meso_meds.index.values,column]
        sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'min_{column}']=sel_stuff_meso_mins.loc[sel_stuff_meso_meds.index.values,column]
    return sel_stuff_meso_meds,sel_stuff

# %%
all_dfs=[]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
t0 = 1
t1 = 2
big_dfs = []
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']
for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
        if f'{sp}-{ino}' in bad_inos:
            continue 
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
        if os.path.exists(fname):
            df,_= get_selection_stuff_time_vary(sp,ino,t0,t1,thresh=1e-3)
            
            if len(df)>0:
                df['species_id']=sp
                big_dfs.append(df.reset_index())
            
big_df=pd.concat(big_dfs).reset_index()
len(big_df['species_id'].unique())
big_df['species-type_meso']=big_df['species_id'].astype(str)+'-'+big_df['type_mesocosm'].astype(str)
big_df = big_df.set_index('species-type_meso')
big_df.head()
# Out:
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100146/AA-AE-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100146/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100146/AE-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/101059/AA-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100910/AA-AE-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102478/AA-AE-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102478/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102478/AE-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AE-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AE-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AE-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AE-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100196/AA-AE-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100196/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/103117/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/103656/AA-AE-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/103656/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/103656/AE-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102544/AA-AE-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102528/AA-AE-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102528/AA-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102528/AE-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102506/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/101346/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AE-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AE-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AE-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/100099/AE-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/101400/AA-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/101294/AE-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/101294/AA-AE-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/101294/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/101294/AE-AF-mGAM_1_2_6_7_parent1_info_shift.csv
#                         index    type_mesocosm species   inoculumn  \
# species-type_meso
# 100146-AA-AE-mGAM-mBHI      0  AA-AE-mGAM-mBHI  100146  AA-AE-mGAM
# 100146-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  100146  AA-AF-mGAM
# 100146-AE-AF-mGAM-mBHI      0  AE-AF-mGAM-mBHI  100146  AE-AF-mGAM
# 101059-AA-AF-mBHI-mBHI      0  AA-AF-mBHI-mBHI  101059  AA-AF-mBHI
# 101059-AA-AF-mBHI-mGAM      1  AA-AF-mBHI-mGAM  101059  AA-AF-mBHI
#
#                         Unnamed: 0  diff7_med  diff7_lower  diff7_upper  \
# species-type_meso
# 100146-AA-AE-mGAM-mBHI         1.5  -0.541100    -0.544710    -0.529888
# 100146-AA-AF-mGAM-mGAM         2.0  -0.004680    -0.005808    -0.003702
# 100146-AE-AF-mGAM-mBHI         1.0   0.289999     0.286087     0.293289
# 101059-AA-AF-mBHI-mBHI         1.5        NaN          NaN          NaN
# 101059-AA-AF-mBHI-mGAM         4.0        NaN          NaN          NaN
#
#                         pred_7_upper  pred_7_lower  ...  t1_val  \
# species-type_meso                                   ...
# 100146-AA-AE-mGAM-mBHI  4.189340e-06  2.849576e-06  ...     NaN
# 100146-AA-AF-mGAM-mGAM  1.522294e-14  1.397497e-15  ...     NaN
# 100146-AE-AF-mGAM-mBHI  9.991126e-01  9.978233e-01  ...     NaN
# 101059-AA-AF-mBHI-mBHI           NaN           NaN  ...     NaN
# 101059-AA-AF-mBHI-mGAM           NaN           NaN  ...     NaN
#
#                         max_early_sel_med  min_early_sel_med  max_act_7_med  \
# species-type_meso
# 100146-AA-AE-mGAM-mBHI          -1.744257          -3.854358       0.795501
# 100146-AA-AF-mGAM-mGAM          -5.241445          -7.176380       0.006544
# 100146-AE-AF-mGAM-mBHI           4.071997           1.055020       0.773469
# 101059-AA-AF-mBHI-mBHI                NaN                NaN            NaN
# 101059-AA-AF-mBHI-mGAM                NaN                NaN            NaN
#
#                         min_act_7_med  max_pred7_med  min_pred7_med  \
# species-type_meso
# 100146-AA-AE-mGAM-mBHI       0.298174   3.458236e-05   1.746664e-10
# 100146-AA-AF-mGAM-mGAM       0.001000   1.456583e-14   3.743383e-19
# 100146-AE-AF-mGAM-mBHI       0.612870   1.000000e+00   9.921438e-01
# 101059-AA-AF-mBHI-mBHI            NaN            NaN            NaN
# 101059-AA-AF-mBHI-mGAM            NaN            NaN            NaN
#
#                         max_late_sel_med  min_late_sel_med  species_id
# species-type_meso
# 100146-AA-AE-mGAM-mBHI          0.756514         -0.352602      100146
# 100146-AA-AF-mGAM-mGAM          1.846620          0.000000      100146
# 100146-AE-AF-mGAM-mBHI          0.239881         -0.349112      100146
# 101059-AA-AF-mBHI-mBHI               NaN               NaN      101059
# 101059-AA-AF-mBHI-mGAM               NaN               NaN      101059
#
# [5 rows x 36 columns]

# %%
big_df['counts']=1
big_dfgr=big_df.reset_index().groupby(['species-type_meso']).sum(numeric_only=True)
big_dfgr=big_dfgr.loc[big_dfgr['counts']>2,:]
big_dfgr
# Out:
# Empty DataFrame
# Columns: [index, Unnamed: 0, diff7_med, diff7_lower, diff7_upper, pred_7_upper, pred_7_lower, pred7_med, as_extreme7, act7_upper, act_7_lower, act_7_med, early_sel_upper, early_sel_lower, early_sel_med, late_sel_upper, late_sel_lower, late_sel_med, sample_early1, sample_early2, sample_late1, sample_late2, start_val, t1_val, max_early_sel_med, min_early_sel_med, max_act_7_med, min_act_7_med, max_pred7_med, min_pred7_med, max_late_sel_med, min_late_sel_med, counts]
# Index: []
#
# [0 rows x 33 columns]

# %%
def make_big_plot(meds,logit_scale=False,sel_range = (-.5,.5),line=True,width=400):
    if logit_scale:
        meds = meds.copy()
        for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med','pred7_med']:
            meds[freq_column]=np.log(meds[freq_column]/(1-meds[freq_column]))

         #   'early_sel_med','act_7_med','pred7_med','late_sel_med'
    scatter = hv.Scatter(meds, kdims =  'pred7_med', vdims=['act_7_med',hv.Dimension('early_sel_med',range=sel_range)]).opts(#size=4, 
                                                                                        alpha = 1.0, color = 'early_sel_med',#height=700,
                                                                                           width = width,line_color='black',
                                                                                                      
                                                                                      cmap = 'Magma',
                                                                                                            colorbar=True, 
                                                                                                  # logx=True, logy=True,
                                                                                                    legend_position='right',
                                                                                                        size=10,
                                                                                         )
    seg = hv.Segments(meds, ['pred7_med', 
                             'min_act_7_med', 
                             'pred7_med', 'max_act_7_med', ]).opts(color='black',alpha=.2)
    
    seg2 = hv.Segments(meds, ['min_pred7_med', 
                             'act_7_med', 
                             'max_pred7_med', 'act_7_med', ]).opts(color='black',alpha=.2)

    exps_adjust = np.array([.001,.01,.1,.5,.9,.99,.999])
    lins_adjust = np.log(exps_adjust/(1-exps_adjust))
    #exps_adjust = exps_adjust[::2]
   # lins_adjust = lins_adjust[::2]
    if logit_scale:
        scatter.opts(xticks=[(lins_adjust[i], exps_adjust[i]) for i in range(len(lins_adjust))],
                 yticks=[(lins_adjust[i], exps_adjust[i]) for i in range(len(lins_adjust))]
                )
    
    ticks = np.linspace(sel_range[0],sel_range[1],6)
    labels = [str(tick) for tick in ticks]
   # if sel_range[0]!=0:
    labels[0] = '<' + labels[0]
   # if sel_range[-1]!= 0:
    labels[-1] = '>' + labels[-1]

    #labels[-1] = '>' + labels[-1]
    print(labels)
  #  labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    
    # Apply colorbar customization
    scatter.opts(
        colorbar=True,
        colorbar_opts={
            'major_label_overrides': dict(zip(ticks, labels))
        }
    )

    scatter = hv.render(scatter*seg*seg2)
    if line:
        if logit_scale:
            scatter.line(np.linspace(-8,8), np.linspace(-8,8),color = 'black', )
        else:
            scatter.line(np.linspace(1e-20,1), np.linspace(1e-20,1),color = 'black', )
        
    scatter.legend.visible = True
    scatter.xaxis.axis_label = 'Predicted final frequency'
    scatter.yaxis.axis_label = 'Actual final frequency'
    #bokeh.io.show(scatter)
    return scatter,meds

# %%
def polarize(df):
    to_polarize = df.loc[df['pred7_med']>.5,:].index.values
    print(to_polarize)
    for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med',]:
        df.loc[to_polarize,freq_column]= 1- df.loc[to_polarize,freq_column]
    for sel_column in ['early_sel_med','max_early_sel_med','min_early_sel_med',
                      'late_sel_med','max_late_sel_med','min_late_sel_med',]:
        df.loc[to_polarize,sel_column]= -df.loc[to_polarize,sel_column]
    print(df.loc[to_polarize,'pred7_med'])
    df.loc[to_polarize,'pred7_med']=1-df.loc[to_polarize,'pred7_med']
    return df


def adjust(df,thresh=1e-3):
   # to_polarize = df.loc[df['pred_p7s']>.5,:].index.values
    for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med','pred7_med']:
        df.loc[df[freq_column]>1-thresh,freq_column]= 1-thresh
        df.loc[df[freq_column]<thresh,freq_column]= thresh
    return df

# %%
            
big_df=pd.concat(big_dfs).reset_index()
len(big_df['species_id'].unique())
big_df['species-type_meso']=big_df['species_id'].astype(str)+'-'+big_df['type_mesocosm'].astype(str)
big_df = big_df.set_index('species-type_meso')
big_df.head()
pol = polarize(big_df)
pol = adjust(pol)
# Out:
# ['100146-AE-AF-mGAM-mBHI' '100910-AA-AE-mBHI-mBHI'
#  '102478-AA-AF-mGAM-mGAM' '102438-AE-AF-mBHI-mGAM'
#  '102438-AE-AF-mGAM-mGAM' '100099-AA-AE-mGAM-mBHI'
#  '100099-AE-AF-mGAM-mGAM' '101294-AE-AF-mGAM-mBHI'
#  '101294-AE-AF-mGAM-mGAM']
# species-type_meso
# 100146-AE-AF-mGAM-mBHI    0.998802
# 100910-AA-AE-mBHI-mBHI    0.999998
# 102478-AA-AF-mGAM-mGAM    1.000000
# 102438-AE-AF-mBHI-mGAM    0.995720
# 102438-AE-AF-mGAM-mGAM    0.940588
# 100099-AA-AE-mGAM-mBHI    0.933492
# 100099-AE-AF-mGAM-mGAM    0.999598
# 101294-AE-AF-mGAM-mBHI    0.999992
# 101294-AE-AF-mGAM-mGAM    0.870661
# Name: pred7_med, dtype: float64

# %%
pol.loc[pol['species_id']=='103656',:]
# Out:
# Empty DataFrame
# Columns: [index, type_mesocosm, species, inoculumn, Unnamed: 0, diff7_med, diff7_lower, diff7_upper, pred_7_upper, pred_7_lower, pred7_med, as_extreme7, act7_upper, act_7_lower, act_7_med, early_sel_upper, early_sel_lower, early_sel_med, late_sel_upper, late_sel_lower, late_sel_med, sample_early1, sample_early2, sample_late1, sample_late2, start_val, t1_val, max_early_sel_med, min_early_sel_med, max_act_7_med, min_act_7_med, max_pred7_med, min_pred7_med, max_late_sel_med, min_late_sel_med, species_id]
# Index: []
#
# [0 rows x 36 columns]

# %%
b=pol.loc[pol['pred7_med']<1e-1,:]
print(len(b))
b=b.loc[b['act_7_med']>1e-1,:]
print(len(b))
# Out:
# 36
# 7

# %%
p,_ = make_big_plot(pol,sel_range = (-2,0),logit_scale=True)

#p.x_range = bokeh.models.Range1d(-.05,.5)
#p.y_range = bokeh.models.Range1d(-.05,1.05)
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,f'time_varying_{str(t0)}_{str(t1)}_freq')
# Out:
# ['<-2.0', '-1.6', '-1.2', '-0.7999999999999998', '-0.3999999999999999', '>0.0']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_4707/292325157.py:61: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   scatter.legend.visible = True
#   <div id="dfdc7a78-ca2f-4e38-b70a-bfbaf177cda4" data-root-id="f9391799-b114-4e6f-ac4b-0871e3fb969d" style="display: contents;"></div>

# %%
p,_ = make_big_plot(pol.loc[pol['pred7_med']<1e-1,:],sel_range = (-4.0,0),width=400,logit_scale=True)
p.x_range = bokeh.models.Range1d(-8.,-2)
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,'time_varying_01_freq_inset')
# Out:
# ['<-4.0', '-3.2', '-2.4', '-1.5999999999999996', '-0.7999999999999998', '>0.0']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_40457/292325157.py:61: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   scatter.legend.visible = True
#   <div id="b6c3a15d-d89e-4930-8a1f-ddb522c0160b" data-root-id="3af49d2b-d9f4-4d9e-8ecd-6d53faf97165" style="display: contents;"></div>

# %%
def make_big_plot_sel(meds,line=True,width=400):
    scatter = hv.Scatter(meds.sort_values(by='act_7_med'), kdims =  'early_sel_med', vdims=['late_sel_med',hv.Dimension('act_7_med',range=(0,1))]).opts(#size=4, 
                                                                                        alpha = 1.0, color = 'act_7_med',#height=700,
                                                                                           width = width,line_color='black',
                                                                                                      
                                                                                      cmap = 'Magma',
                                                                                                            colorbar=True, 
                                                                                                  # logx=True, logy=True,
                                                                                                    legend_position='right',
                                                                                                        size=10,
                                                                                         )
    seg = hv.Segments(meds, ['early_sel_med', 
                             'min_late_sel_med', 
                             'early_sel_med', 'max_late_sel_med', ]).opts(color='black',alpha=.2)
    
    seg2 = hv.Segments(meds, ['min_early_sel_med', 
                             'late_sel_med', 
                             'max_early_sel_med', 'late_sel_med', ]).opts(color='black',alpha=.2)
    
    ticks = np.linspace(0,1,6)
    labels = [str(tick) for tick in ticks]
   # if sel_range[0]!=0:
    labels[0] = '<' + labels[0]
   # if sel_range[-1]!= 0:
    labels[-1] = '>' + labels[-1]

    #labels[-1] = '>' + labels[-1]
    print(labels)
  #  labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    
    # Apply colorbar customization
    scatter.opts(
        colorbar=True,
        #\colorbar_opts={
      #      'major_label_overrides': dict(zip(ticks, labels))
      #  }
    )

    scatter = hv.render(scatter*seg*seg2)
    scatter.line(np.linspace(-10,10), np.linspace(-10,10),color = 'black', )
        
    scatter.legend.visible = True
    scatter.xaxis.axis_label = 'Sel 1-2'
    scatter.yaxis.axis_label = 'Sel 6-7'
    #bokeh.io.show(scatter)
    return scatter

# %%
pol.loc[pol['species']=='101294',:]
# Out:
#                         index    type_mesocosm species   inoculumn  \
# species-type_meso
# 101294-AE-AF-mBHI-mGAM      0  AE-AF-mBHI-mGAM  101294  AE-AF-mBHI
# 101294-AA-AE-mGAM-mGAM      0  AA-AE-mGAM-mGAM  101294  AA-AE-mGAM
# 101294-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  101294  AA-AF-mGAM
# 101294-AE-AF-mGAM-mGAM      0  AE-AF-mGAM-mGAM  101294  AE-AF-mGAM
#
#                         Unnamed: 0     diff7_med   diff7_lower  diff7_upper  \
# species-type_meso
# 101294-AE-AF-mBHI-mGAM         1.5  2.159844e-03  4.639397e-04     0.004925
# 101294-AA-AE-mGAM-mGAM         1.5 -3.028589e-07 -9.013886e-07     0.000000
# 101294-AA-AF-mGAM-mGAM         1.5 -5.845709e-02 -6.607108e-02    -0.049085
# 101294-AE-AF-mGAM-mGAM         0.0  1.576307e-01  1.496718e-01     0.165466
#
#                         pred_7_upper  pred_7_lower  ...  t1_val  \
# species-type_meso                                   ...
# 101294-AE-AF-mBHI-mGAM      0.005461      0.001548  ...     NaN
# 101294-AA-AE-mGAM-mGAM      0.000110      0.000018  ...     NaN
# 101294-AA-AF-mGAM-mGAM      0.007850      0.003746  ...     NaN
# 101294-AE-AF-mGAM-mGAM      0.980084      0.971931  ...     NaN
#
#                         max_early_sel_med  min_early_sel_med  max_act_7_med  \
# species-type_meso
# 101294-AE-AF-mBHI-mGAM          -0.746456          -2.184296       0.010302
# 101294-AA-AE-mGAM-mGAM          -0.663836          -1.127502       0.001001
# 101294-AA-AF-mGAM-mGAM           0.056307          -0.703516       0.136131
# 101294-AE-AF-mGAM-mGAM          -0.664370          -0.664370       0.181174
#
#                         min_act_7_med  max_pred7_med  min_pred7_med  \
# species-type_meso
# 101294-AE-AF-mBHI-mGAM       0.001000       0.028253       0.001000
# 101294-AA-AE-mGAM-mGAM       0.001000       0.001000       0.001000
# 101294-AA-AF-mGAM-mGAM       0.053320       0.070768       0.003987
# 101294-AE-AF-mGAM-mGAM       0.181174       0.023452       0.023452
#
#                         max_late_sel_med  min_late_sel_med  species_id
# species-type_meso
# 101294-AE-AF-mBHI-mGAM         -1.265072         -2.606543      101294
# 101294-AA-AE-mGAM-mGAM         -0.663836         -1.127502      101294
# 101294-AA-AF-mGAM-mGAM          0.040761         -0.424464      101294
# 101294-AE-AF-mGAM-mGAM          0.061920          0.061920      101294
#
# [4 rows x 36 columns]

# %%
p = make_big_plot_sel(pol,)
p.y_range = bokeh.models.Range1d(-7,7)
p.x_range = bokeh.models.Range1d(-7,1.)
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,f'time_varying_{str(t0)}_{str(t1)}_sel')
# Out:
# ['<0.0', '0.2', '0.4', '0.6000000000000001', '0.8', '>1.0']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_40457/248920664.py:42: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   scatter.legend.visible = True
#   <div id="cf95e00f-68a4-4251-af95-22dd482785e8" data-root-id="6dcdb663-22d8-44f7-91a8-065fb9dc37c6" style="display: contents;"></div>
