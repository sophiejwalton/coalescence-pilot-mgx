# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control

from scipy.stats import chi2
from snp_analysis_tools_sherlock import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='99a91a00-e8b5-4987-805c-aa9f1d787f6c'>
#   <div id="e5d47a03-b6e3-4234-b77e-68aa99c7a2a0" data-root-id="99a91a00-e8b5-4987-805c-aa9f1d787f6c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4d9bb23e-7031-43db-9617-fd40e3501a52":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"99a91a00-e8b5-4987-805c-aa9f1d787f6c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"ce2c22bb-e63c-46bd-8436-383f410b9c3a","attributes":{"plot_id":"99a91a00-e8b5-4987-805c-aa9f1d787f6c","comm_id":"9133d4d106634c7c9b555bceb430b15b","client_comm_id":"e14c534ab99c4e0fb083ef0d51386661"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"4d9bb23e-7031-43db-9617-fd40e3501a52","roots":{"99a91a00-e8b5-4987-805c-aa9f1d787f6c":"e5d47a03-b6e3-4234-b77e-68aa99c7a2a0"},"root_ids":["99a91a00-e8b5-4987-805c-aa9f1d787f6c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
#df_metadata.head()
def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata = transform_df(df_metadata)
df_metadata['species_id'] = df_metadata['species_id'].astype(str)
df_metadata = df_metadata.set_index('species_id').astype(str)
df_metadata['species_plot']=df_metadata['species'].transform(lambda x: x.split('s__')[-1])
df_metadata
# Out:
#               representative MGnify_accession species_closest ani_closest  \
# species_id
# 100001      GUT_GENOME000001  MGYG-HGUT-00001        100049.0      83.356
# 100002      GUT_GENOME000004  MGYG-HGUT-00002        100201.0    84.86955
# 100003      GUT_GENOME000008  MGYG-HGUT-00003        103279.0    93.41555
# 100004      GUT_GENOME000010  MGYG-HGUT-00004        103876.0     78.1762
# 100005      GUT_GENOME000017  MGYG-HGUT-00005        101623.0    85.84275
# ...                      ...              ...             ...         ...
# 104640      GUT_GENOME286389  MGYG-HGUT-04640        103346.0    90.06215
# 104641      GUT_GENOME286625  MGYG-HGUT-04641             nan         nan
# 104642      GUT_GENOME286704  MGYG-HGUT-04642        104273.0     79.5001
# 104643      GUT_GENOME286769  MGYG-HGUT-04643        100646.0    79.02775
# 104644      GUT_GENOME286887  MGYG-HGUT-04644        101057.0    79.53465
#
#            gtpro_kmer_counts phyeco_marker_counts phyeco_pass_ratio  \
# species_id
# 100001                   nan                 15.0               1.0
# 100002               29822.0                 15.0               1.0
# 100003                1115.0                 15.0               1.0
# 100004                   nan                 15.0               1.0
# 100005                   nan                 15.0               1.0
# ...                      ...                  ...               ...
# 104640                   nan                 13.0               1.0
# 104641                   nan                 12.0               1.0
# 104642                   nan                 15.0               1.0
# 104643               89795.0                 15.0               1.0
# 104644              114400.0                 15.0               1.0
#
#            pangene_counts genome_counts Genome_type  ... GC_content  \
# species_id                                           ...
# 100001               4893             4     Isolate  ...      28.26
# 100002             147601           358     Isolate  ...       42.6
# 100003             113409          1178     Isolate  ...      58.52
# 100004              12599            24     Isolate  ...      54.19
# 100005               5488             2     Isolate  ...      28.59
# ...                   ...           ...         ...  ...        ...
# 104640               7938            11         MAG  ...      51.72
# 104641               1451             1         MAG  ...      62.69
# 104642               8769            30         MAG  ...      38.81
# 104643              40134           246         MAG  ...      41.96
# 104644              45432            64         MAG  ...      57.36
#
#            Completeness Contamination  \
# species_id
# 100001            98.59           0.7
# 100002            99.37           0.0
# 100003            100.0           0.0
# 100004            98.66          0.22
# 100005             99.3           0.0
# ...                 ...           ...
# 104640            84.97          0.35
# 104641            68.94           0.0
# 104642            93.29           0.0
# 104643            97.99           0.0
# 104644            93.96          0.67
#
#                                                       Lineage Continent  \
# species_id
# 100001      d__Bacteria;p__Firmicutes_A;c__Clostridia;o__P...    Europe
# 100002      d__Bacteria;p__Firmicutes_A;c__Clostridia;o__L...    Europe
# 100003      d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...    Europe
# 100004      d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...    Europe
# 100005      d__Bacteria;p__Firmicutes_A;c__Clostridia;o__P...    Europe
# ...                                                       ...       ...
# 104640      d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...    Europe
# 104641      d__Bacteria;p__Proteobacteria;c__Gammaproteoba...    Europe
# 104642      d__Bacteria;p__Firmicutes_A;c__Clostridia;o__L...    Europe
# 104643      d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...    Europe
# 104644      d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...    Europe
#
#                                      species                genus  \
# species_id
# 100001                                   s__     g__GCA-900066495
# 100002              s__Blautia_A sp900066165         g__Blautia_A
# 100003                   s__Alistipes shahii         g__Alistipes
# 100004          s__Anaerotruncus colihominis     g__Anaerotruncus
# 100005      s__Terrisporobacter glycolicus_A  g__Terrisporobacter
# ...                                      ...                  ...
# 104640                                   s__        g__Prevotella
# 104641                                   s__        g__Sutterella
# 104642                                   s__                  g__
# 104643          s__Eubacterium_R sp003526845     g__Eubacterium_R
# 104644                                   s__  g__Negativibacillus
#
#                               family              phyla  \
# species_id
# 100001      f__Peptostreptococcaceae    p__Firmicutes_A
# 100002            f__Lachnospiraceae    p__Firmicutes_A
# 100003              f__Rikenellaceae    p__Bacteroidota
# 100004            f__Ruminococcaceae    p__Firmicutes_A
# 100005      f__Peptostreptococcaceae    p__Firmicutes_A
# ...                              ...                ...
# 104640             f__Bacteroidaceae    p__Bacteroidota
# 104641           f__Burkholderiaceae  p__Proteobacteria
# 104642                           f__    p__Firmicutes_A
# 104643         f__Acutalibacteraceae    p__Firmicutes_A
# 104644            f__Ruminococcaceae    p__Firmicutes_A
#
#                              species_plot
# species_id
# 100001
# 100002              Blautia_A sp900066165
# 100003                   Alistipes shahii
# 100004          Anaerotruncus colihominis
# 100005      Terrisporobacter glycolicus_A
# ...                                   ...
# 104640
# 104641
# 104642
# 104643          Eubacterium_R sp003526845
# 104644
#
# [4644 rows x 23 columns]

# %%
e003_metadata = pd.read_csv('e003_with_passage_one_redo_good.csv')
species = '101346'
fname1 = '/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/101346/AE-AF-mBHI_parent1_info.csv'
fname2 = '/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/101346/AE-AF-mBHI_parent2_info.csv'

# %%
df1 = pd.read_csv(fname1).drop(columns='Unnamed: 0')
df2 = pd.read_csv(fname2).drop(columns='Unnamed: 0')

# %%
fnames = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/*/*parent1_info.csv')
dfs = []
for fname in fnames:
    
    df1 = pd.read_csv(fname).drop(columns='Unnamed: 0').set_index('sample')
    df2 = pd.read_csv(fname.split('parent1_info.csv')[0] + 'parent2_info.csv').drop(columns='Unnamed: 0').set_index('sample')
    df2['conf_int'] = df2['boot_high']-df2['boot_low']
    
    df1['conf_int'] = df1['boot_high']-df1['boot_low']
    df_both = pd.concat([df1.rename(columns = {'boot_med':'boot_med1', 'boot_low':'boot_low1', 'boot_high':'boot_high1',
       'actual_med':'actual_med1', 'conf_int':'conf_int1'}),
                         df2.rename(columns = {'boot_med':'boot_med2', 'boot_low':'boot_low2', 'boot_high':'boot_high2',
       'actual_med':'actual_med2', 'conf_int':'conf_int2'})],axis=1)
    
    df_both['species'] = fname.split('/')[-2]
    df_both['fname'] = fname
    dfs.append(df_both)
    
    
df_full = pd.concat(dfs)
df_full['total_shift'] = np.abs(1-(df_full['actual_med1'] + df_full['actual_med2']))
df_full['total_shift12'] = np.abs(1-(df_full['boot_low1'] + df_full['boot_high2']))
df_full['total_shift21'] = np.abs(1-(df_full['boot_low2'] + df_full['boot_high1']))
df_full['total_shift_max'] = df_full['total_shift21']
df_full.loc[df_full['total_shift_max']<df_full['total_shift12'],'total_shift_max'] = df_full.loc[df_full['total_shift_max']<df_full['total_shift12'],'total_shift12']
#df_full.loc[df_full['conf_int1_plo']<1e-5,'conf_int1'] = 1e-5
p = iqplot.ecdf(df_full.loc[df_full['total_shift']<.1,:], 
              #  cats = 'species',
                q = 'conf_int1', x_axis_type='log')
             #  marker_kwargs = dict(color='red'),
              # x_axis_type='log')
p.x_range = bokeh.models.Range1d(1e-5,1)
bokeh.io.show(p)
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33039/4213173011.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_full = pd.concat(dfs)
#   <div id="d3403d53-900f-4940-b941-41856668fed4" data-root-id="c43a8029-0a6c-4ff0-84ab-6e42e022023c" style="display: contents;"></div>

# %%
fname1 = '/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/101346/AE-AF-mBHI_parent1_info.csv'
fname2 = '/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/101346/AE-AF-mBHI_parent2_info.csv'

# %%
def get_both_dfs(fname):
    df1 = pd.read_csv(fname).drop(columns='Unnamed: 0').set_index('sample')
    df2 = pd.read_csv(fname.split('parent1_info.csv')[0] + 'parent2_info.csv').drop(columns='Unnamed: 0').set_index('sample')
    df2['conf_int'] = df2['boot_high']-df2['boot_low']
    
    df1['conf_int'] = df1['boot_high']-df1['boot_low']
    df_both = pd.concat([df1.rename(columns = {'boot_med':'boot_med1', 'boot_low':'boot_low1', 'boot_high':'boot_high1',
       'actual_med':'actual_med1', 'conf_int':'conf_int1'}),
                         df2.rename(columns = {'boot_med':'boot_med2', 'boot_low':'boot_low2', 'boot_high':'boot_high2',
       'actual_med':'actual_med2', 'conf_int':'conf_int2'})],axis=1)
    
    df_both['species'] = fname.split('/')[-2]
    df_both['fname'] = fname
    print('-'.join(fname1.split('/')[-1].split('-')[:-1]))
   # parent_media = 
    
    df_both['subjects_measured'] = '-'.join(fname1.split('/')[-1].split('-')[:-1])
    df_both['in_measured'] = '-'.join(fname1.split('/')[-1].split('_')[:-2])
    df_both['total_shift'] = np.abs(1-(df_both['actual_med1'] + df_both['actual_med2']))
    df_both['total_shift12'] = np.abs(1-(df_both['boot_low1'] + df_both['boot_high2']))
    df_both['total_shift21'] = np.abs(1-(df_both['boot_low2'] + df_both['boot_high1']))
    df_both['total_shift_max'] = df_both['total_shift21']
    df_both.loc[df_both['total_shift_max']<df_both['total_shift12'],'total_shift_max'] = df_both.loc[df_both['total_shift_max']<df_both['total_shift12'],'total_shift12']

    return df_both

# %%
e003_metadata = pd.read_csv('e003_metadata_cultures_round2_change_AA.csv').set_index('sample')
e003_metadata = pd.read_csv('e003_with_passage_one_redo_good.csv').set_index('sample')
e003_metadata['comm'].unique()
# Out:
# array(['C9', 'C11', 'D11', 'C8', 'D10', 'B2', 'A8', 'A4', 'B4', 'A3',
#        'B9', 'B3', 'D4', 'C2', 'C4', 'C3', 'A11', 'B8', 'D3', 'B11', 'D2',
#        'D5', 'B5', 'A10', 'A5', 'D8', 'D9', 'B10', 'A9', 'C5', 'A2',
#        'C10', 'H5', 'E2', 'G5', 'H11', 'H4', 'F5', 'F8', 'H3', 'H2', 'E5',
#        'F10', 'F9', 'E3', 'G4', 'E8', 'G2', 'E9', 'G11', 'G10', 'F11',
#        'H9', 'F2', 'G8', 'F3', 'E10', 'H10', 'E11', 'H8', 'G9', 'G3',
#        'E4', 'F4'], dtype=object)

# %%
df_both = get_both_dfs(fname1)
df_both_meta = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values, e003_metadata.index.values),:]],axis=1).reset_index()
df_both_meta_good = df_both_meta.loc[df_both_meta['total_shift']<.1,:]
df_both_meta_good.head()
# Out:
# AE-AF
#                                    sample  boot_med1  boot_low1  boot_high1  \
# 0  C5-e003Coalescence-mBHI-inoculumn-redo      0.576      0.571       0.582
# 2              C5-e003Coalescence-mBHI-p3      0.231      0.211       0.238
# 3              C5-e003Coalescence-mBHI-p5      0.212      0.207       0.215
# 4              C5-e003Coalescence-mBHI-p7      0.121      0.118       0.125
# 5         C5-e003Coalescence-mGAM-p1_S746      0.674      0.670       0.679
#
#    actual_med1  conf_int1  boot_med2  boot_low2  boot_high2  actual_med2  ...  \
# 0        0.576      0.011      0.339      0.338       0.340        0.339  ...
# 2        0.229      0.027      0.688      0.667       0.692        0.688  ...
# 3        0.212      0.008      0.721      0.719       0.723        0.721  ...
# 4        0.121      0.007      0.845      0.843       0.846        0.845  ...
# 5        0.674      0.009      0.243      0.242       0.245        0.243  ...
#
#    is_inoculumn media            mesocosm parent_media parent_subjects  \
# 0          True  mBHI  C5-AE-AF-mBHI-mBHI         mBHI           AE-AF
# 2         False  mBHI  C5-AE-AF-mBHI-mBHI         mBHI           AE-AF
# 3         False  mBHI  C5-AE-AF-mBHI-mBHI         mBHI           AE-AF
# 4         False  mBHI  C5-AE-AF-mBHI-mBHI         mBHI           AE-AF
# 5         False  mGAM  C5-AE-AF-mBHI-mGAM         mBHI           AE-AF
#
#    passage    type_mesocosm   redo  counts     mesocosm-passage
# 0        0  AE-AF-mBHI-mBHI  False       1  C5-AE-AF-mBHI-mBHI0
# 2        3  AE-AF-mBHI-mBHI  False       1  C5-AE-AF-mBHI-mBHI3
# 3        5  AE-AF-mBHI-mBHI  False       1  C5-AE-AF-mBHI-mBHI5
# 4        7  AE-AF-mBHI-mBHI  False       1  C5-AE-AF-mBHI-mBHI7
# 5        1  AE-AF-mBHI-mGAM  False       1  C5-AE-AF-mBHI-mGAM1
#
# [5 rows x 35 columns]

# %%
def plot_trajectories_with_in(freq_df, strain1=True,cmap = {'fecal': bokeh.palettes.Set2[8][-2],
        'mBHI':bokeh.palettes.Set2[8][1],
        'mGAM': bokeh.palettes.Set2[8][0],},shift=False):
    p2 = bokeh.plotting.figure(width = 500, height = 300)

    for i, type_meso in enumerate(freq_df['type_mesocosm'].unique()):
        mesos = freq_df.loc[freq_df['type_mesocosm'] ==type_meso, 'mesocosm'].unique()
        media = type_meso.split('-')[-1]
        color = cmap[media]
        for mesocosm in mesos:
           
            df_meso = freq_df.loc[freq_df['mesocosm'] == mesocosm,:]
          #  print('shee',df_meso)
            in_sample = df_meso['inoculumn_sample'].unique()[0]
            if in_sample not in df_meso['sample'].values:
                 #   print('yay')
                df_meso= pd.concat([df_meso,freq_df.loc[freq_df['sample'] == in_sample,:]],axis=0)
                
           # print('woo', df_meso.columns.values)
            if strain1:
                minor_strain = 'boot_med1'
                if shift:
                    minor_strain = 'boot_med1_shift'
                upper = 'boot_high1'
                lower = 'boot_low1'
            else:
                minor_strain = 'boot_med2'
                upper = 'boot_high2'
                lower = 'boot_low2'
                
            df_meso = df_meso.sort_values(by = 'passage') 
            #print(df_meso[upper].values)
            #print(df_meso[lower].values)
            df_source = bokeh.models.ColumnDataSource(data=dict(base=df_meso['passage'].values, 
                                                                upper=df_meso[upper].values, lower=df_meso[lower].values))
            error = bokeh.models.Whisker(base=minor_strain, upper='upper', lower='lower', source=df_source,
              #  level="annotation",
                                         line_width=2)
            error.upper_head.size=20
            error.lower_head.size=20
            p2.add_layout(error)
            p2.line(df_meso['passage'].values,
                   df_meso[minor_strain].values,color=color)
            p2.scatter(df_meso['passage'].values,
                   df_meso[minor_strain].values,color = color, legend_label = type_meso, size = 5)
            p2.segment(
                        source=df_meso,
                        x0='passage',
                        y0=lower,
                        x1='passage',
                        y1=upper,
                        line_width=2,
                color = 'black',
                    )
            


                           
    p2.yaxis.axis_label = f'Frequency'
    p2.xaxis.axis_label = 'Passage'
    p2.y_range = bokeh.models.Range1d(-.005,1.005)
   # p2.x_range = bokeh.models.Range1d(-.5,7.5)
    p2.xgrid.grid_line_color = None
    p2.ygrid.grid_line_color = None
    

    return p2

# %%
#e003_metadata.loc[e003_metadata['type_mesocosm'] == 'AE-AF-mBHI-mBHI',:]

# %%
df_both.reset_index().sort_values(by='sample')
# Out:
#                                       sample  boot_med1  boot_low1  \
# 0     C5-e003Coalescence-mBHI-inoculumn-redo   0.576000   0.571000
# 1            C5-e003Coalescence-mBHI-p1_S742   0.458000   0.450000
# 2                 C5-e003Coalescence-mBHI-p3   0.231000   0.211000
# 3                 C5-e003Coalescence-mBHI-p5   0.212000   0.207000
# 4                 C5-e003Coalescence-mBHI-p7   0.121000   0.118000
# 5            C5-e003Coalescence-mGAM-p1_S746   0.674000   0.670000
# 6                 C5-e003Coalescence-mGAM-p3   0.005000   0.005000
# 7                 C5-e003Coalescence-mGAM-p7   0.000434   0.000392
# 8   Coalescence-D2-C5-AE-AF-mBHI-mGAM-5_S657   0.000861   0.000769
# 9          D4-e003Coalescence-Inoculumn-mBHI   0.582000   0.576000
# 10           D4-e003Coalescence-mBHI-p1_S735   0.476000   0.470000
# 11                D4-e003Coalescence-mBHI-p3   0.093000   0.088000
# 12                D4-e003Coalescence-mBHI-p5   0.167000   0.158000
# 13                D4-e003Coalescence-mBHI-p7   0.147000   0.143000
# 14           D4-e003Coalescence-mGAM-p1_S739   0.643000   0.639000
# 15                D4-e003Coalescence-mGAM-p3   0.005000   0.005000
# 16                D4-e003Coalescence-mGAM-p5   0.000216   0.000194
# 17                D4-e003Coalescence-mGAM-p7   0.000228   0.000204
# 18           G5-e003Coalescence-mBHI-p1_S806   0.429000   0.417000
# 19            G5-e003Coalescence-mBHI-p3_S36   0.111000   0.108000
# 20            G5-e003Coalescence-mBHI-p5_S28   0.088000   0.086000
# 21           G5-e003Coalescence-mBHI-p7_S124   0.116000   0.113000
# 22           G5-e003Coalescence-mGAM-p1_S810   0.609000   0.604000
# 23            G5-e003Coalescence-mGAM-p3_S84   0.011000   0.011000
# 24            G5-e003Coalescence-mGAM-p5_S76   0.001035   0.000977
# 25           G5-e003Coalescence-mGAM-p7_S172   0.000231   0.000210
# 26           H4-e003Coalescence-mBHI-p1_S799   0.433500   0.429000
# 27            H4-e003Coalescence-mBHI-p3_S47   0.414000   0.407000
# 28            H4-e003Coalescence-mBHI-p5_S39   0.107000   0.103487
# 29           H4-e003Coalescence-mBHI-p7_S135   0.174000   0.167000
# 30           H4-e003Coalescence-mGAM-p1_S803   0.593000   0.588000
# 31            H4-e003Coalescence-mGAM-p3_S95   0.002541   0.002385
# 32            H4-e003Coalescence-mGAM-p5_S87   0.000353   0.000315
# 33           H4-e003Coalescence-mGAM-p7_S183   0.000130   0.000119
#
#     boot_high1  actual_med1  conf_int1  boot_med2  boot_low2  boot_high2  \
# 0     0.582000     0.576000   0.011000   0.339000   0.338000    0.340000
# 1     0.467000     0.458000   0.017000   0.417000   0.412000    0.421000
# 2     0.238000     0.229000   0.027000   0.688000   0.667000    0.692000
# 3     0.215000     0.212000   0.008000   0.721000   0.719000    0.723000
# 4     0.125000     0.121000   0.007000   0.845000   0.843000    0.846000
# 5     0.679000     0.674000   0.009000   0.243000   0.242000    0.245000
# 6     0.005000     0.005000   0.000000   0.992000   0.992000    0.993000
# 7     0.000472     0.000443   0.000080   0.999517   0.999501    0.999534
# 8     0.000954     0.000942   0.000185   0.999083   0.999049    0.999122
# 9     0.587000     0.582000   0.011000   0.330000   0.328000    0.331000
# 10    0.481000     0.475500   0.011000   0.421000   0.419000    0.424000
# 11    0.096000     0.093000   0.008000   0.865000   0.864000    0.867000
# 12    0.169000     0.167000   0.011000   0.786000   0.786000    0.789000
# 13    0.150500     0.147000   0.007500   0.814000   0.812000    0.816000
# 14    0.646000     0.643000   0.007000   0.277000   0.276000    0.279000
# 15    0.005000     0.005000   0.000000   0.993000   0.992000    0.993000
# 16    0.000239     0.000218   0.000045   0.999757   0.999750    0.999765
# 17    0.000256     0.000240   0.000052   0.999763   0.999753    0.999772
# 18    0.434025     0.429000   0.017025   0.444000   0.438000    0.444000
# 19    0.115000     0.111000   0.007000   0.839000   0.838000    0.841000
# 20    0.090000     0.088000   0.004000   0.871000   0.870000    0.873000
# 21    0.119000     0.116000   0.006000   0.833000   0.831000    0.833000
# 22    0.613500     0.609000   0.009500   0.300000   0.298000    0.302000
# 23    0.012000     0.011000   0.001000   0.982000   0.981000    0.982000
# 24    0.001093     0.001046   0.000116   0.994000   0.994000    0.994000
# 25    0.000252     0.000240   0.000042   0.999674   0.999665    0.999683
# 26    0.439000     0.433000   0.010000   0.462000   0.458000    0.463000
# 27    0.420000     0.414000   0.013000   0.493000   0.491000    0.500000
# 28    0.111000     0.107000   0.007513   0.841000   0.840000    0.843000
# 29    0.176025     0.174000   0.009025   0.759000   0.757000    0.762000
# 30    0.597000     0.593000   0.009000   0.314000   0.312000    0.316000
# 31    0.002709     0.002584   0.000325   0.996904   0.996832    0.996974
# 32    0.000391     0.000387   0.000076   0.999600   0.999585    0.999615
# 33    0.000141     0.000136   0.000022   0.999815   0.999810    0.999821
#
#     actual_med2  conf_int2 species  \
# 0      0.339000   0.002000  101346
# 1      0.417000   0.009000  101346
# 2      0.688000   0.025000  101346
# 3      0.721000   0.004000  101346
# 4      0.845000   0.003000  101346
# 5      0.243000   0.003000  101346
# 6      0.992000   0.001000  101346
# 7      0.999490   0.000033  101346
# 8      0.998726   0.000073  101346
# 9      0.330000   0.003000  101346
# 10     0.421000   0.005000  101346
# 11     0.865000   0.003000  101346
# 12     0.786000   0.003000  101346
# 13     0.814000   0.004000  101346
# 14     0.277000   0.003000  101346
# 15     0.993000   0.001000  101346
# 16     0.999746   0.000015  101346
# 17     0.999724   0.000020  101346
# 18     0.444000   0.006000  101346
# 19     0.839000   0.003000  101346
# 20     0.871000   0.003000  101346
# 21     0.833000   0.002000  101346
# 22     0.300000   0.004000  101346
# 23     0.982000   0.001000  101346
# 24     0.994000   0.000000  101346
# 25     0.999620   0.000018  101346
# 26     0.462000   0.005000  101346
# 27     0.493000   0.009000  101346
# 28     0.841000   0.003000  101346
# 29     0.759000   0.005000  101346
# 30     0.314000   0.004000  101346
# 31     0.996666   0.000142  101346
# 32     0.999474   0.000031  101346
# 33     0.999786   0.000011  101346
#
#                                                 fname subjects_measured  \
# 0   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 1   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 2   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 3   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 4   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 5   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 6   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 7   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 8   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 9   /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 10  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 11  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 12  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 13  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 14  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 15  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 16  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 17  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 18  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 19  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 20  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 21  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 22  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 23  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 24  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 25  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 26  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 27  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 28  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 29  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 30  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 31  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 32  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
# 33  /Users/sophiewalton/git/coalescence-pilot-mgx/...             AE-AF
#
#    in_measured  total_shift  total_shift12  total_shift21  total_shift_max
# 0   AE-AF-mBHI     0.085000       0.089000       0.080000         0.089000
# 1   AE-AF-mBHI     0.125000       0.129000       0.121000         0.129000
# 2   AE-AF-mBHI     0.083000       0.097000       0.095000         0.097000
# 3   AE-AF-mBHI     0.067000       0.070000       0.066000         0.070000
# 4   AE-AF-mBHI     0.034000       0.036000       0.032000         0.036000
# 5   AE-AF-mBHI     0.083000       0.085000       0.079000         0.085000
# 6   AE-AF-mBHI     0.003000       0.002000       0.003000         0.003000
# 7   AE-AF-mBHI     0.000067       0.000074       0.000027         0.000074
# 8   AE-AF-mBHI     0.000332       0.000109       0.000003         0.000109
# 9   AE-AF-mBHI     0.088000       0.093000       0.085000         0.093000
# 10  AE-AF-mBHI     0.103500       0.106000       0.100000         0.106000
# 11  AE-AF-mBHI     0.042000       0.045000       0.040000         0.045000
# 12  AE-AF-mBHI     0.047000       0.053000       0.045000         0.053000
# 13  AE-AF-mBHI     0.039000       0.041000       0.037500         0.041000
# 14  AE-AF-mBHI     0.080000       0.082000       0.078000         0.082000
# 15  AE-AF-mBHI     0.002000       0.002000       0.003000         0.003000
# 16  AE-AF-mBHI     0.000036       0.000041       0.000011         0.000041
# 17  AE-AF-mBHI     0.000036       0.000024       0.000008         0.000024
# 18  AE-AF-mBHI     0.127000       0.139000       0.127975         0.139000
# 19  AE-AF-mBHI     0.050000       0.051000       0.047000         0.051000
# 20  AE-AF-mBHI     0.041000       0.041000       0.040000         0.041000
# 21  AE-AF-mBHI     0.051000       0.054000       0.050000         0.054000
# 22  AE-AF-mBHI     0.091000       0.094000       0.088500         0.094000
# 23  AE-AF-mBHI     0.007000       0.007000       0.007000         0.007000
# 24  AE-AF-mBHI     0.004954       0.005023       0.004907         0.005023
# 25  AE-AF-mBHI     0.000140       0.000107       0.000084         0.000107
# 26  AE-AF-mBHI     0.105000       0.108000       0.103000         0.108000
# 27  AE-AF-mBHI     0.093000       0.093000       0.089000         0.093000
# 28  AE-AF-mBHI     0.052000       0.053513       0.049000         0.053513
# 29  AE-AF-mBHI     0.067000       0.071000       0.066975         0.071000
# 30  AE-AF-mBHI     0.093000       0.096000       0.091000         0.096000
# 31  AE-AF-mBHI     0.000751       0.000641       0.000459         0.000641
# 32  AE-AF-mBHI     0.000139       0.000070       0.000025         0.000070
# 33  AE-AF-mBHI     0.000078       0.000060       0.000049         0.000060

# %%
good_sp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 good_sp
#
# NameError: name 'good_sp' is not defined

# %%
df_both_meta['type_mesocosm'].unique()
# Out:
# array(['AE-AF-mBHI-mBHI', 'AE-AF-mBHI-mGAM'], dtype=object)

# %%
folders = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/*/')
good_sp=[]

for folder in folders:
    species_id = folder.split('/')[-2]
    fnames = glob(f'{folder}/*_parent1_info.csv')
    plots = []
    for fname1 in fnames:
      #  if 'ACPP' in fname1: 
       #     print(fname1)
        #    continue
        df_both = get_both_dfs(fname1)
        df_both['boot_med1_shift'] = df_both['boot_med1']/(df_both['boot_med1']+df_both['boot_med2'])
       # df_both  = df_both.loc[df_both['total_shift'].abs()<.1,:]
        print(len(df_both))
        df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
        df_both_meta = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                           e003_metadata.index.values),:]],
                                 axis=1).reset_index()
        print(len(df_both_meta))
        df_both_meta_good = df_both_meta.loc[df_both_meta['total_shift']<.1,:]
        print(df_both_meta.loc[df_both_meta['total_shift']>.1,'sample'])
        df_both_meta_good.head()
        p = plot_trajectories_with_in(df_both_meta_good, strain1=True,shift=False)
        species = fname1.split('/')[-2]
        subject1 = fname1.split('/')[-1].split('-')[0]
        in_name = fname1.split('/')[-1].split('_')[0]
        p.title.text = f'{species}, {subject1} in {in_name} collisions'
        p.legend.visible=False
       # bokeh.io.show(p)
        plots.append(p)
    if len(plots)>0:
        good_sp.append(species_id)
        bokeh.io.export_png(bokeh.layouts.gridplot(plots,ncols=2),filename = f'{species_id}_plots_with1.png')
# Out:
# AA-ACPP
# 20
# 20
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 25
# 25
# 2          B5-e003Coalescence-mBHI-p3
# 5     B5-e003Coalescence-mGAM-p1_S745
# 12    D3-e003Coalescence-mGAM-p1_S731
# 16     F5-e003Coalescence-mBHI-p3_S24
# 18    F5-e003Coalescence-mGAM-p1_S809
# 22     H3-e003Coalescence-mBHI-p3_S46
# Name: sample, dtype: object
# AE-AF
# 27
# 27
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 32
# 32
# 0     B10-e003Coalescence-mBHI-p1_S765
# 3     B10-e003Coalescence-mGAM-p1_S769
# 12     C9-e003Coalescence-mGAM-p1_S762
# 20    F10-e003Coalescence-mBHI-p1_S829
# 21    F10-e003Coalescence-mGAM-p1_S833
# 25     G9-e003Coalescence-mBHI-p1_S822
# 28     G9-e003Coalescence-mGAM-p1_S826
# 31     G9-e003Coalescence-mGAM-p7_S174
# Name: sample, dtype: object
# AA-AF
# 32
# 32
# 11    Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673
# 16             D8-e003Coalescence-mBHI-p1_S751
# Name: sample, dtype: object
# AA-ACPP
# 30
# 30
# 2                     A9-e003Coalescence-mBHI-p3
# 4                     A9-e003Coalescence-mBHI-p7
# 6                     A9-e003Coalescence-mGAM-p5
# 10                    B8-e003Coalescence-mBHI-p5
# 12               B8-e003Coalescence-mGAM-p1_S753
# 16    Coalescence-E1-B8-AA-ACPP-mGAM-mBHI-3_S668
# 18                 E9-e003Coalescence-mBHI-p5_S6
# Name: sample, dtype: object
# AA-AE
# 30
# 29
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 29
# 29
# 5     Coalescence-C11-B11-ACPP-AF-mGAM-mBHI-5_S654
# 13                      D9-e003Coalescence-mGAM-p5
# 14                      D9-e003Coalescence-mGAM-p7
# 20               F111-e003Coalescence-mGAM-p3_S168
# 23                 H9-e003Coalescence-mBHI-p1_S823
# 24                  H9-e003Coalescence-mBHI-p5_S42
# Name: sample, dtype: object
# AA-AF
# 17
# 17
# Series([], Name: sample, dtype: object)
# The geckodriver version (0.35.0) detected in PATH at /Users/sophiewalton/miniconda3/envs/bokeh_update/bin/geckodriver might not be compatible with the detected firefox version (134.0); currently, geckodriver 0.36.0 is recommended for firefox 134.*, so it is advised to delete the driver in PATH and retry
# AA-AE
# 23
# 22
# Series([], Name: sample, dtype: object)
# AA-ACPP
# 29
# 29
# 0         A3-e003Coalescence-mBHI-inoculumn-redo
# 2                     A3-e003Coalescence-mBHI-p3
# 5              B2-e003Coalescence-Inoculumn-mBHI
# 7                     B2-e003Coalescence-mBHI-p3
# 8                     B2-e003Coalescence-mBHI-p5
# 9                     B2-e003Coalescence-mGAM-p3
# 10    Coalescence-A6-B2-AA-ACPP-mBHI-mGAM-7_S625
# 11    Coalescence-B7-E3-AA-ACPP-mBHI-mBHI-7_S638
# 13    Coalescence-D1-B2-AA-ACPP-mBHI-mGAM-5_S656
# 16                E3-e003Coalescence-mBHI-p3_S10
# 17                 E3-e003Coalescence-mBHI-p5_S2
# 24                F2-e003Coalescence-mBHI-p5_S13
# Name: sample, dtype: object
# ACPP-AF
# 25
# 25
# 0               B5-e003Coalescence-Inoculumn-mBHI
# 1                 B5-e003Coalescence-mBHI-p1_S741
# 2                      B5-e003Coalescence-mBHI-p3
# 4                      B5-e003Coalescence-mGAM-p3
# 5                      B5-e003Coalescence-mGAM-p5
# 6                      B5-e003Coalescence-mGAM-p7
# 7      Coalescence-B4-D3-ACPP-AF-mBHI-mGAM-7_S635
# 8     Coalescence-E11-D3-ACPP-AF-mBHI-mBHI-3_S678
# 9               D3-e003Coalescence-Inoculumn-mBHI
# 10                D3-e003Coalescence-mBHI-p1_S727
# 13                     D3-e003Coalescence-mGAM-p5
# 17                 F5-e003Coalescence-mGAM-p5_S64
# 20                 H3-e003Coalescence-mBHI-p3_S46
# 23                 H3-e003Coalescence-mGAM-p5_S86
# Name: sample, dtype: object
# AE-AF
# 19
# 19
# 15    G111-e003Coalescence-mGAM-p5_S80
# Name: sample, dtype: object
# ACPP-AE
# 15
# 15
# Series([], Name: sample, dtype: object)
# AA-AF
# 32
# 32
# Series([], Name: sample, dtype: object)
# AA-ACPP
# 22
# 22
# Series([], Name: sample, dtype: object)
# AA-AE
# 32
# 31
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 21
# 21
# 11    F11-e003Coalescence-mBHI-p1_S837
# Name: sample, dtype: object
# AA-AF
# 29
# 29
# 2     A5-e003Coalescence-mBHI-p1_S740
# 9     D2-e003Coalescence-mBHI-p1_S719
# 27     H2-e003Coalescence-mGAM-p5_S85
# Name: sample, dtype: object
# AA-ACPP
# 29
# 29
# Series([], Name: sample, dtype: object)
# AA-AE
# 22
# 21
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 33
# 33
# Series([], Name: sample, dtype: object)
# AE-AF
# 31
# 31
# 9    Coalescence-F8-H10-AE-AF-mGAM-mGAM-3_S687
# Name: sample, dtype: object
# ACPP-AE
# 33
# 33
# 8    C9-e003Coalescence-mBHI-p1_S758
# Name: sample, dtype: object
# AA-AF
# 32
# 32
# Series([], Name: sample, dtype: object)
# AA-ACPP
# 33
# 33
# 9     B8-e003Coalescence-mBHI-p1_S749
# 25    F8-e003Coalescence-mBHI-p1_S813
# Name: sample, dtype: object
# AA-AE
# 34
# 33
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 30
# 30
# 0      B11-e003Coalescence-mBHI-p1_S773
# 3           B11-e003Coalescence-mGAM-p7
# 8       D9-e003Coalescence-mBHI-p1_S759
# 9            D9-e003Coalescence-mBHI-p5
# 11      D9-e003Coalescence-mGAM-p1_S763
# 15     F11-e003Coalescence-mBHI-p1_S837
# 16     F11-e003Coalescence-mGAM-p1_S841
# 19    F111-e003Coalescence-mBHI-p7_S116
# 23      H9-e003Coalescence-mBHI-p1_S823
# 26      H9-e003Coalescence-mGAM-p1_S827
# Name: sample, dtype: object
# AE-AF
# 33
# 33
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 32
# 31
# Series([], Name: sample, dtype: object)
# AA-AF
# 29
# 29
# Series([], Name: sample, dtype: object)
# AA-ACPP
# 25
# 25
# 1      A3-e003Coalescence-mGAM-p1_S728
# 3    B2-e003Coalescence-Inoculumn-mBHI
# Name: sample, dtype: object
# AA-AE
# 31
# 30
# 2                   A4-e003Coalescence-mBHI-p3
# 3                   A4-e003Coalescence-mBHI-p5
# 4                   A4-e003Coalescence-mBHI-p7
# 8                   C2-e003Coalescence-mBHI-p3
# 9                   C2-e003Coalescence-mBHI-p5
# 15    Coalescence-D8-A4-AA-AE-mBHI-mGAM-3_S663
# 17               E4-e003Coalescence-mBHI-p5_S3
# 18              E4-e003Coalescence-mBHI-p7_S99
# 22             E4-e003Coalescence-mGAM-p7_S147
# 24              G2-e003Coalescence-mBHI-p3_S33
# 25              G2-e003Coalescence-mBHI-p5_S25
# 26             G2-e003Coalescence-mBHI-p7_S121
# 28              G2-e003Coalescence-mGAM-p3_S81
# Name: sample, dtype: object
# ACPP-AF
# 34
# 34
# 6          B5-e003Coalescence-mGAM-p3
# 16         D3-e003Coalescence-mGAM-p3
# 23     F5-e003Coalescence-mGAM-p3_S72
# 25    F5-e003Coalescence-mGAM-p7_S160
# 31     H3-e003Coalescence-mGAM-p3_S94
# Name: sample, dtype: object
# AE-AF
# 32
# 32
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 33
# 33
# 22    F100-e003Coalescence-mBHI-p7_S115
# Name: sample, dtype: object
# AA-AF
# 32
# 32
# 1                   A11-e003Coalescence-mBHI-p3
# 2                   A11-e003Coalescence-mBHI-p5
# 3                   A11-e003Coalescence-mBHI-p7
# 5                   A11-e003Coalescence-mGAM-p3
# 6                   A11-e003Coalescence-mGAM-p7
# 11     Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673
# 13    Coalescence-F10-H8-AA-AF-mGAM-mGAM-3_S689
# 17                   D8-e003Coalescence-mBHI-p5
# 22            E111-e003Coalescence-mBHI-p3_S108
# 23              E111-e003Coalescence-mBHI-p5_S8
# 24            E111-e003Coalescence-mBHI-p7_S104
# 28              H8-e003Coalescence-mBHI-p7_S137
# Name: sample, dtype: object
# AA-ACPP
# 33
# 33
# 12    B8-e003Coalescence-mGAM-p1_S753
# 29    F8-e003Coalescence-mGAM-p1_S817
# 30    F8-e003Coalescence-mGAM-p3_S165
# Name: sample, dtype: object
# AA-AE
# 35
# 34
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 0
# 0
# Series([], Name: sample, dtype: object)
# AE-AF
# 34
# 34
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 32
# 31
# Series([], Name: sample, dtype: object)
# AA-AF
# 31
# 31
# Series([], Name: sample, dtype: object)
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33039/3247160898.py:29: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   p.legend.visible=False
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='5b6d582d-fba5-4955-9c73-d70f30b43a6c', ...)
# AA-AF
# 13
# 13
# Series([], Name: sample, dtype: object)
# AA-ACPP
# 8
# 8
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 12
# 12
# 5    F11-e003Coalescence-mGAM-p1_S841
# Name: sample, dtype: object
# ACPP-AE
# 12
# 11
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 32
# 31
# 6     C3-e003Coalescence-mBHI-p1_S726
# 9     C3-e003Coalescence-mGAM-p1_S730
# 19    F4-e003Coalescence-mBHI-p7_S111
# 27    G3-e003Coalescence-mBHI-p7_S122
# Name: sample, dtype: object
# AA-ACPP
# 20
# 20
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 27
# 27
# 9     C9-e003Coalescence-mGAM-p1_S762
# 26    G9-e003Coalescence-mGAM-p7_S174
# Name: sample, dtype: object
# ACPP-AE
# 19
# 18
# 17    G3-e003Coalescence-mGAM-p5_S74
# Name: sample, dtype: object
# AA-ACPP
# 2
# 2
# Series([], Name: sample, dtype: object)
# AA-AE
# 6
# 6
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 1
# 1
# Series([], Name: sample, dtype: object)
# AE-AF
# 11
# 11
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 13
# 13
# Series([], Name: sample, dtype: object)
# AA-AF
# 10
# 10
# 2                  A5-e003Coalescence-mBHI-p7
# 3    Coalescence-C7-A5-AA-AF-mBHI-mBHI-5_S650
# 4    Coalescence-D5-H2-AA-AF-mBHI-mBHI-5_S660
# 9             H2-e003Coalescence-mGAM-p7_S181
# Name: sample, dtype: object
# AA-AF
# 31
# 31
# 0            A5-e003Coalescence-Inoculumn-mBHI
# 1       A5-e003Coalescence-mBHI-inoculumn-redo
# 2              A5-e003Coalescence-mBHI-p1_S740
# 3                   A5-e003Coalescence-mBHI-p3
# 5              A5-e003Coalescence-mGAM-p1_S744
# 6                   A5-e003Coalescence-mGAM-p3
# 7     Coalescence-C7-A5-AA-AF-mBHI-mBHI-5_S650
# 8     Coalescence-D5-H2-AA-AF-mBHI-mBHI-5_S660
# 9            D2-e003Coalescence-Inoculumn-mBHI
# 10             D2-e003Coalescence-mBHI-p1_S719
# 11                  D2-e003Coalescence-mBHI-p3
# 12                  D2-e003Coalescence-mBHI-p5
# 14             D2-e003Coalescence-mGAM-p1_S723
# 16             E5-e003Coalescence-mBHI-p1_S804
# 17              E5-e003Coalescence-mBHI-p3_S12
# 18               E5-e003Coalescence-mBHI-p5_S4
# 20             E5-e003Coalescence-mGAM-p1_S808
# 21              E5-e003Coalescence-mGAM-p3_S60
# 23             E5-e003Coalescence-mGAM-p7_S148
# 24             H2-e003Coalescence-mBHI-p1_S783
# 27             H2-e003Coalescence-mGAM-p1_S787
# 29              H2-e003Coalescence-mGAM-p5_S85
# 30             H2-e003Coalescence-mGAM-p7_S181
# Name: sample, dtype: object
# AA-ACPP
# 31
# 31
# 1                A3-e003Coalescence-mBHI-p1_S724
# 2                     A3-e003Coalescence-mBHI-p3
# 3                A3-e003Coalescence-mGAM-p1_S728
# 4                     A3-e003Coalescence-mGAM-p7
# 6                B2-e003Coalescence-mBHI-p1_S717
# 7                     B2-e003Coalescence-mBHI-p3
# 12    Coalescence-B7-E3-AA-ACPP-mBHI-mBHI-7_S638
# 16               E3-e003Coalescence-mBHI-p1_S788
# 17                E3-e003Coalescence-mBHI-p3_S10
# 18                 E3-e003Coalescence-mBHI-p5_S2
# 19               E3-e003Coalescence-mGAM-p1_S792
# 23               F2-e003Coalescence-mBHI-p1_S781
# 24                F2-e003Coalescence-mBHI-p3_S21
# 25                F2-e003Coalescence-mBHI-p5_S13
# 27               F2-e003Coalescence-mGAM-p1_S785
# Name: sample, dtype: object
# AA-AE
# 34
# 32
# 21    E4-e003Coalescence-mGAM-p1_S800
# Name: sample, dtype: object
# ACPP-AF
# 33
# 33
# 0               B5-e003Coalescence-Inoculumn-mBHI
# 1                 B5-e003Coalescence-mBHI-p1_S741
# 2                      B5-e003Coalescence-mBHI-p3
# 3                      B5-e003Coalescence-mBHI-p5
# 4                      B5-e003Coalescence-mBHI-p7
# 5                 B5-e003Coalescence-mGAM-p1_S745
# 6                      B5-e003Coalescence-mGAM-p3
# 7                      B5-e003Coalescence-mGAM-p5
# 8                      B5-e003Coalescence-mGAM-p7
# 9      Coalescence-B4-D3-ACPP-AF-mBHI-mGAM-7_S635
# 10    Coalescence-E11-D3-ACPP-AF-mBHI-mBHI-3_S678
# 11              D3-e003Coalescence-Inoculumn-mBHI
# 12                D3-e003Coalescence-mBHI-p1_S727
# 13                     D3-e003Coalescence-mBHI-p5
# 14                     D3-e003Coalescence-mBHI-p7
# 15                D3-e003Coalescence-mGAM-p1_S731
# 16                     D3-e003Coalescence-mGAM-p3
# 17                     D3-e003Coalescence-mGAM-p5
# 18                F5-e003Coalescence-mBHI-p1_S805
# 19                 F5-e003Coalescence-mBHI-p3_S24
# 20                 F5-e003Coalescence-mBHI-p5_S16
# 21                F5-e003Coalescence-mBHI-p7_S112
# 22                F5-e003Coalescence-mGAM-p1_S809
# 23                 F5-e003Coalescence-mGAM-p3_S72
# 24                 F5-e003Coalescence-mGAM-p5_S64
# 25                F5-e003Coalescence-mGAM-p7_S160
# 26                H3-e003Coalescence-mBHI-p1_S791
# 27                 H3-e003Coalescence-mBHI-p3_S46
# 28                 H3-e003Coalescence-mBHI-p5_S38
# 29                H3-e003Coalescence-mBHI-p7_S134
# 30                 H3-e003Coalescence-mGAM-p3_S94
# 31                 H3-e003Coalescence-mGAM-p5_S86
# 32                H3-e003Coalescence-mGAM-p7_S182
# Name: sample, dtype: object
# AE-AF
# 32
# 32
# 0               C11-e003Coalescence-mBHI-p1_S774
# 2                    C11-e003Coalescence-mBHI-p5
# 3               C11-e003Coalescence-mGAM-p1_S778
# 8     Coalescence-A10-C11-AE-AF-mGAM-mBHI-7_S629
# 10                   D10-e003Coalescence-mBHI-p3
# 11                   D10-e003Coalescence-mBHI-p5
# 13              D10-e003Coalescence-mGAM-p1_S771
# 18              G11-e003Coalescence-mBHI-p1_S838
# 19              G11-e003Coalescence-mGAM-p1_S842
# 20             G111-e003Coalescence-mBHI-p3_S132
# 21              G111-e003Coalescence-mBHI-p5_S32
# 22             G111-e003Coalescence-mBHI-p7_S128
# 26              H10-e003Coalescence-mBHI-p1_S831
# 27              H10-e003Coalescence-mGAM-p1_S835
# 28              H100-e003Coalescence-mBHI-p5_S43
# 29             H100-e003Coalescence-mBHI-p7_S139
# Name: sample, dtype: object
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33039/3247160898.py:29: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   p.legend.visible=False
# ACPP-AE
# 33
# 33
# 0                B10-e003Coalescence-mBHI-p1_S765
# 1                     B10-e003Coalescence-mBHI-p3
# 2                     B10-e003Coalescence-mBHI-p5
# 3                B10-e003Coalescence-mGAM-p1_S769
# 8                 C9-e003Coalescence-mBHI-p1_S758
# 10                     C9-e003Coalescence-mBHI-p5
# 11                     C9-e003Coalescence-mBHI-p7
# 12                C9-e003Coalescence-mGAM-p1_S762
# 16    Coalescence-A4-B10-ACPP-AE-mGAM-mBHI-7_S623
# 17    Coalescence-B10-G9-ACPP-AE-mGAM-mBHI-7_S641
# 19    Coalescence-F5-F10-ACPP-AE-mGAM-mBHI-3_S684
# 20               F10-e003Coalescence-mBHI-p1_S829
# 21               F10-e003Coalescence-mGAM-p1_S833
# 22              F100-e003Coalescence-mBHI-p7_S115
# 26                G9-e003Coalescence-mBHI-p1_S822
# 27                G9-e003Coalescence-mBHI-p3_S130
# 28                 G9-e003Coalescence-mBHI-p5_S30
# 29                G9-e003Coalescence-mGAM-p1_S826
# Name: sample, dtype: object
# AA-AF
# 32
# 32
# 11    Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673
# Name: sample, dtype: object
# AA-ACPP
# 30
# 30
# 22    E9-e003Coalescence-mGAM-p5_S54
# Name: sample, dtype: object
# AA-AE
# 35
# 34
# 0     A10-e003Coalescence-mBHI-p1_S764
# 4     A10-e003Coalescence-mGAM-p1_S768
# 9      C8-e003Coalescence-mBHI-p1_S750
# 12     C8-e003Coalescence-mGAM-p1_S754
# 19    E10-e003Coalescence-mBHI-p1_S828
# 20    E10-e003Coalescence-mGAM-p1_S832
# 26     G8-e003Coalescence-mBHI-p1_S814
# 30     G8-e003Coalescence-mGAM-p1_S818
# Name: sample, dtype: object
# ACPP-AF
# 31
# 31
# Series([], Name: sample, dtype: object)
# AE-AF
# 34
# 34
# 1     C5-e003Coalescence-mBHI-p1_S742
# 2          C5-e003Coalescence-mBHI-p3
# 10    D4-e003Coalescence-mBHI-p1_S735
# 11         D4-e003Coalescence-mBHI-p3
# 12         D4-e003Coalescence-mBHI-p5
# 14    D4-e003Coalescence-mGAM-p1_S739
# 18    G5-e003Coalescence-mBHI-p1_S806
# 19     G5-e003Coalescence-mBHI-p3_S36
# 20     G5-e003Coalescence-mBHI-p5_S28
# 22    G5-e003Coalescence-mGAM-p1_S810
# 26    H4-e003Coalescence-mBHI-p1_S799
# 27     H4-e003Coalescence-mBHI-p3_S47
# 28     H4-e003Coalescence-mBHI-p5_S39
# 29    H4-e003Coalescence-mBHI-p7_S135
# 30    H4-e003Coalescence-mGAM-p1_S803
# Name: sample, dtype: object
# ACPP-AE
# 33
# 32
# 4     B4-e003Coalescence-mGAM-p1_S737
# 29    G3-e003Coalescence-mGAM-p1_S794
# Name: sample, dtype: object
# AA-AF
# 31
# 31
# Series([], Name: sample, dtype: object)
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='ac882a73-6de2-4494-ae2e-7a0136aaad68', ...)
# AA-ACPP
# 26
# 26
# 6     B2-e003Coalescence-mBHI-p1_S717
# 13    E3-e003Coalescence-mBHI-p1_S788
# Name: sample, dtype: object
# AA-AE
# 29
# 28
# 23    G2-e003Coalescence-mBHI-p3_S33
# Name: sample, dtype: object
# ACPP-AF
# 34
# 34
# 12    D3-e003Coalescence-mBHI-p1_S727
# 21    F5-e003Coalescence-mBHI-p7_S112
# 27     H3-e003Coalescence-mBHI-p3_S46
# 28     H3-e003Coalescence-mBHI-p5_S38
# 29    H3-e003Coalescence-mBHI-p7_S134
# Name: sample, dtype: object
# AE-AF
# 31
# 31
# 0              C11-e003Coalescence-mBHI-p1_S774
# 1                   C11-e003Coalescence-mBHI-p3
# 3              C11-e003Coalescence-mGAM-p1_S778
# 9     Coalescence-F8-H10-AE-AF-mGAM-mGAM-3_S687
# 11                  D10-e003Coalescence-mBHI-p5
# 13             D10-e003Coalescence-mGAM-p1_S771
# 18             G11-e003Coalescence-mBHI-p1_S838
# 19             G11-e003Coalescence-mGAM-p1_S842
# 25             H10-e003Coalescence-mBHI-p1_S831
# 26             H10-e003Coalescence-mGAM-p1_S835
# 27             H100-e003Coalescence-mBHI-p5_S43
# 29             H100-e003Coalescence-mGAM-p5_S91
# Name: sample, dtype: object
# ACPP-AE
# 33
# 33
# 3      B10-e003Coalescence-mGAM-p1_S769
# 8       C9-e003Coalescence-mBHI-p1_S758
# 12      C9-e003Coalescence-mGAM-p1_S762
# 21     F10-e003Coalescence-mGAM-p1_S833
# 22    F100-e003Coalescence-mBHI-p7_S115
# 29      G9-e003Coalescence-mGAM-p1_S826
# Name: sample, dtype: object
# AA-AF
# 32
# 32
# 0             A11-e003Coalescence-mBHI-p1_S772
# 1                  A11-e003Coalescence-mBHI-p3
# 11    Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673
# 16             D8-e003Coalescence-mBHI-p1_S751
# 17                  D8-e003Coalescence-mBHI-p5
# 20            E11-e003Coalescence-mBHI-p1_S836
# 22           E111-e003Coalescence-mBHI-p3_S108
# 23             E111-e003Coalescence-mBHI-p5_S8
# 24           E111-e003Coalescence-mBHI-p7_S104
# 26             H8-e003Coalescence-mBHI-p1_S815
# Name: sample, dtype: object
# AA-ACPP
# 32
# 32
# 1                A9-e003Coalescence-mBHI-p1_S756
# 9                B8-e003Coalescence-mBHI-p1_S749
# 11                    B8-e003Coalescence-mBHI-p7
# 17    Coalescence-E2-B8-AA-ACPP-mGAM-mGAM-3_S669
# 18               E9-e003Coalescence-mBHI-p1_S820
# 24               F8-e003Coalescence-mBHI-p1_S813
# 29               F8-e003Coalescence-mGAM-p3_S165
# Name: sample, dtype: object
# AA-AE
# 34
# 33
# 0             A10-e003Coalescence-mBHI-p1_S764
# 1                  A10-e003Coalescence-mBHI-p5
# 2                  A10-e003Coalescence-mBHI-p7
# 3             A10-e003Coalescence-mGAM-p1_S768
# 8              C8-e003Coalescence-mBHI-p1_S750
# 10                  C8-e003Coalescence-mBHI-p7
# 11             C8-e003Coalescence-mGAM-p1_S754
# 17    Coalescence-F9-C8-AA-AE-mGAM-mGAM-3_S688
# 18            E10-e003Coalescence-mBHI-p1_S828
# 19            E10-e003Coalescence-mGAM-p1_S832
# 20             E100-e003Coalescence-mBHI-p5_S7
# 21           E100-e003Coalescence-mBHI-p7_S103
# 22           E100-e003Coalescence-mGAM-p3_S155
# 25             G8-e003Coalescence-mBHI-p1_S814
# 26             G8-e003Coalescence-mBHI-p3_S129
# 27              G8-e003Coalescence-mBHI-p5_S29
# 28             G8-e003Coalescence-mBHI-p7_S125
# Name: sample, dtype: object
# ACPP-AF
# 31
# 31
# 16     F11-e003Coalescence-mBHI-p1_S837
# 20    F111-e003Coalescence-mBHI-p7_S116
# 24      H9-e003Coalescence-mBHI-p1_S823
# Name: sample, dtype: object
# AE-AF
# 34
# 34
# 1     C5-e003Coalescence-mBHI-p1_S742
# 10    D4-e003Coalescence-mBHI-p1_S735
# 18    G5-e003Coalescence-mBHI-p1_S806
# 26    H4-e003Coalescence-mBHI-p1_S799
# Name: sample, dtype: object
# ACPP-AE
# 32
# 31
# 2         B4-e003Coalescence-mBHI-p3
# 17    F4-e003Coalescence-mBHI-p3_S23
# 22    F4-e003Coalescence-mGAM-p5_S63
# 25    G3-e003Coalescence-mBHI-p3_S34
# Name: sample, dtype: object
# AA-AF
# 30
# 30
# 0     A5-e003Coalescence-Inoculumn-mBHI
# 16       E5-e003Coalescence-mBHI-p3_S12
# Name: sample, dtype: object
# AA-ACPP
# 31
# 31
# Series([], Name: sample, dtype: object)
# AA-AE
# 33
# 31
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 33
# 33
# Series([], Name: sample, dtype: object)
# AE-AF
# 31
# 31
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 33
# 33
# Series([], Name: sample, dtype: object)
# AA-AF
# 32
# 32
# 11    Coalescence-E6-D8-AA-AF-mGAM-mBHI-3_S673
# Name: sample, dtype: object
# AA-ACPP
# 30
# 30
# Series([], Name: sample, dtype: object)
# AA-AE
# 35
# 34
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 0
# 0
# Series([], Name: sample, dtype: object)
# AE-AF
# 34
# 34
# Series([], Name: sample, dtype: object)
# ACPP-AE
# 0
# 0
# Series([], Name: sample, dtype: object)
# AA-AF
# 30
# 30
# Series([], Name: sample, dtype: object)
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33039/3247160898.py:29: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   p.legend.visible=False
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33039/3247160898.py:29: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   p.legend.visible=False
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='65803dd5-1263-483c-b4b5-33a413ebba25', ...)
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='eca48a0b-1f69-4724-8309-98805203b8be', ...)
# AA-ACPP
# 29
# 29
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 32
# 32
# 1     B5-e003Coalescence-mBHI-p1_S741
# 12    D3-e003Coalescence-mBHI-p1_S727
# 18    F5-e003Coalescence-mBHI-p1_S805
# 25    H3-e003Coalescence-mBHI-p1_S791
# Name: sample, dtype: object
# AA-AF
# 26
# 26
# 2              A5-e003Coalescence-mBHI-p1_S740
# 3                   A5-e003Coalescence-mBHI-p3
# 4                   A5-e003Coalescence-mBHI-p7
# 5                   A5-e003Coalescence-mGAM-p3
# 6     Coalescence-C7-A5-AA-AF-mBHI-mBHI-5_S650
# 7     Coalescence-D5-H2-AA-AF-mBHI-mBHI-5_S660
# 9                   D2-e003Coalescence-mBHI-p3
# 10                  D2-e003Coalescence-mBHI-p5
# 11             D2-e003Coalescence-mGAM-p1_S723
# 12                  D2-e003Coalescence-mGAM-p5
# 13             E5-e003Coalescence-mBHI-p1_S804
# 14              E5-e003Coalescence-mBHI-p3_S12
# 15               E5-e003Coalescence-mBHI-p5_S4
# 16             E5-e003Coalescence-mBHI-p7_S100
# 17             E5-e003Coalescence-mGAM-p1_S808
# 18             E5-e003Coalescence-mGAM-p7_S148
# 19             H2-e003Coalescence-mBHI-p1_S783
# 20              H2-e003Coalescence-mBHI-p3_S45
# 21             H2-e003Coalescence-mBHI-p7_S133
# 22             H2-e003Coalescence-mGAM-p1_S787
# 23              H2-e003Coalescence-mGAM-p3_S93
# 24              H2-e003Coalescence-mGAM-p5_S85
# 25             H2-e003Coalescence-mGAM-p7_S181
# Name: sample, dtype: object
# AA-AF
# 18
# 18
# Series([], Name: sample, dtype: object)
# AE-AF
# 27
# 27
# Series([], Name: sample, dtype: object)
# AA-AF
# 27
# 27
# Series([], Name: sample, dtype: object)
# AA-AE
# 21
# 20
# Series([], Name: sample, dtype: object)
# AE-AF
# 18
# 18
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 7
# 7
# Series([], Name: sample, dtype: object)
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33039/3247160898.py:29: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   p.legend.visible=False
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='887b34f1-a91a-452b-8093-791e7fcfab61', ...)
# ACPP-AE
# 0
# 0
# Series([], Name: sample, dtype: object)
# AA-ACPP
# 6
# 6
# Series([], Name: sample, dtype: object)
# ACPP-AF
# 20
# 20
# 4    B5-e003Coalescence-mBHI-p7
# Name: sample, dtype: object
# AA-AF
# 9
# 9
# Series([], Name: sample, dtype: object)
# AA-ACPP
# 28
# 28
# Series([], Name: sample, dtype: object)
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_33039/3247160898.py:29: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   p.legend.visible=False
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='a7d326f2-e651-4285-a9ef-ae373ab64bb9', ...)
# ACPP-AF
# 0
# 0
# Series([], Name: sample, dtype: object)

# %%
fname1
# Out:
# '/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/102320/ACPP-AF-mGAM_parent1_info.csv'

# %%
#100196-AE-AF-mBHI	
#102506-AE-AF-mBHI
# 100099-AA-AE-mGAM	
#100146-AE-AF-mGAM
#102478-AE-AF-mGAM
#	102438-AA-AF-mGAM
fname1='/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/102438/AA-AF-mGAM_parent1_info.csv'

df_both = get_both_dfs(fname1)
df_both['boot_med1_shift'] = df_both['boot_med1']/(df_both['boot_med1']+df_both['boot_med2'])
       # df_both  = df_both.loc[df_both['total_shift'].abs()<.1,:]

df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
df_both_meta = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                           e003_metadata.index.values),:]],
                                 axis=1).reset_index()
      #  print(len(df_both_meta))
df_both_meta_good = df_both_meta.loc[df_both_meta['total_shift']<.1,:]
p = plot_trajectories_with_in(df_both_meta_good, strain1=True,shift=False)
species = fname1.split('/')[-2]
species_name = df_metadata.loc[species,'species_plot']
subject1 = fname1.split('/')[-1].split('-')[0]
in_name = fname1.split('/')[-1].split('_')[0]
p.title.text = f'{species_name}, {subject1} in {in_name} collisions'
p.legend.visible=False
bokeh.io.show(p)
# Out:
# AA-AF
#   <div id="e234adc0-a85c-4747-a965-8984c00ffd3f" data-root-id="4bf45e7a-0647-4d4d-a834-187e827d6ec5" style="display: contents;"></div>

# %%
fname1='/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/102438/AA-AF-mGAM_parent1_info.csv'

df_both = get_both_dfs(fname1)
df_both['boot_med1_shift'] = df_both['boot_med1']/(df_both['boot_med1']+df_both['boot_med2'])
       # df_both  = df_both.loc[df_both['total_shift'].abs()<.1,:]

df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
df_both_meta = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                           e003_metadata.index.values),:]],
                                 axis=1).reset_index()
      #  print(len(df_both_meta))
df_both_meta_good = df_both_meta.loc[df_both_meta['total_shift']<.1,:]
p = plot_trajectories_with_in(df_both_meta_good, strain1=True,shift=False)
species = fname1.split('/')[-2]
species_name = df_metadata.loc[species,'species_plot']
subject1 = fname1.split('/')[-1].split('-')[0]
in_name = fname1.split('/')[-1].split('_')[0]
p.title.text = f'{species_name}, {subject1} in {in_name} collisions'
p.legend.visible=False
bokeh.io.show(p)

# %%
from scipy.stats import linregress

# %%
xs = np.array([0, 1, 3])
passage0_est = .5
sel_coeff_13=-.1
pred_p5 = np.exp(1*sel_coeff_13)
passage1_est= pred_p5*passage0_est/(1 - passage0_est + passage0_est*pred_p5)

pred_p5 = np.exp(3*sel_coeff_13)
passage3_est = pred_p5*passage0_est/(1 - passage0_est + passage0_est*pred_p5)

xs = np.array([0, 1, 3])
ys = np.array([np.log(passage0_est/(1-passage0_est)),
                             np.log(passage1_est/(1-passage1_est)),
                             np.log(passage3_est/(1-passage3_est))
                             ])

sel = linregress(xs,ys).slope
sel

# %%
np.log(passage0_est/(1-passage0_est))

# %%
def get_selection_coef(df_both_meta_old, p1, p2, strain1=True, ep=1e-3):
    df_both_meta = df_both_meta_old.copy()
    if strain1:
        med= 'boot_med1'
        upper = 'boot_high1'
        lower = 'boot_low1'
    else:
        med = 'boot_med2'
        upper = 'boot_high2'
        lower = 'boot_low2'
        
    dt = p2-p1
    df_p1 = df_both_meta.loc[df_both_meta['passage'] == p1,:].set_index('mesocosm')

    df_both_meta.loc[df_both_meta[med]<ep,med] = ep
    df_both_meta.loc[df_both_meta[med]>1-ep,med] = 1-ep

    df_both_meta.loc[df_both_meta[lower]<ep,lower] = ep
    df_both_meta.loc[df_both_meta[lower]>1-ep,lower] = 1-ep

    df_both_meta.loc[df_both_meta[upper]<ep,upper] = ep
    df_both_meta.loc[df_both_meta[upper]>1-ep,upper] = 1-ep
    
    if p1 != 0:
     #   print('potatoes')
        df_p1 = df_both_meta.loc[df_both_meta['passage'] == p1,:].set_index('mesocosm')
        df_p2 = df_both_meta.loc[df_both_meta['passage'] == p2,:].set_index('mesocosm')
        good_mesos = np.intersect1d(df_p1.index.values, df_p2.index.values)

        df_p1 = df_p1.loc[good_mesos,:]
        df_p2 = df_p2.loc[good_mesos,:]
      
        
        df_p1p2 = pd.DataFrame()  
        df_p1p2['mesocosm'] = df_p1.index.values
        df_p1p2 = df_p1p2.set_index('mesocosm')
       # print(df_p1p2)
        df_p1p2['inoculumn'] = df_p1['inoculumn_sample'].values
    #    print(df_p1p2)
        df_p1p2['p1_freq'] = df_p1[med].copy()
        df_p1p2['p2_freq'] = df_p2[med].copy()
       # print(df_p1[med].copy())
        df_p1p2['shift'] = df_p1p2['p2_freq']- df_p1p2['p1_freq']
        df_p1p2['p1_freq_low'] = df_p1[lower].copy()
        df_p1p2['p1_freq_high'] = df_p1[upper].copy()

        df_p1p2['p2_freq_low'] = df_p2[lower].copy()
        df_p1p2['p2_freq_high'] = df_p2[upper].copy()
        
    if p1 == 0:
        df_p1 = df_both_meta.loc[df_both_meta['passage'] == p1,:].set_index('inoculumn_sample')
        df_p2 = df_both_meta.loc[df_both_meta['passage'] == p2,:].set_index('mesocosm')
        good_ins = np.intersect1d(df_p1.index.values, df_p2['inoculumn_sample'].unique())
        if len(good_ins) == 0:
            return pd.DataFrame()
        
        df_p1 = df_p1.loc[good_ins,:]
        df_p2 = df_p2.loc[df_p2['inoculumn_sample'].isin(good_ins),:]
        df_p1p2 = pd.DataFrame() 
        df_p1p2['mesocosm'] = df_p2.index.values
        df_p1p2 = df_p1p2.set_index('mesocosm')
        
        df_p1p2['inoculumn_sample'] = df_p2['inoculumn_sample'].values
   #     print(df_p1p2)
        df_p1p2['p2_freq'] = df_p2[med].copy()
        df_p1p2['p2_freq_low'] = df_p2[lower].copy()
        df_p1p2['p2_freq_high'] = df_p2[upper].copy()
        df_p1p2['p1_freq'] = np.nan
        df_p1p2['p1_freq_low'] = np.nan
        df_p1p2['p1_freq_high'] = np.nan

       # print(df_p1p2.columns.values)
       # print(df_p1)
        for ind in good_ins:
            df_p1p2.loc[df_p1p2['inoculumn_sample'] == ind, 'p1_freq'] = df_p1.loc[ind, med]
            df_p1p2.loc[df_p1p2['inoculumn_sample'] == ind, 'p1_freq_low'] = df_p1.loc[ind, lower]
            df_p1p2.loc[df_p1p2['inoculumn_sample'] == ind, 'p1_freq_high'] = df_p1.loc[ind, upper]
        
    df_p1p2['shift'] = df_p1p2['p2_freq'] - df_p1p2['p1_freq']
    df_p1p2['low_shift'] = df_p1p2['p2_freq_low'] - df_p1p2['p1_freq_high']
    df_p1p2['high_shift'] = df_p1p2['p2_freq_high'] - df_p1p2['p1_freq_low']
    df_p1p2['p1'] = p1
    df_p1p2['p2'] = p2
    df_p1p2['dt'] = p2-p1
    df_p1p2['sel'] = (1/dt)*(np.log(df_p1p2['p2_freq']/(1-df_p1p2['p2_freq'])) + \
                             np.log((1-df_p1p2['p1_freq'])/(df_p1p2['p1_freq'])))

    df_p1p2['sel_low'] = (1/dt)*(np.log(df_p1p2['p2_freq_low']/(1-df_p1p2['p2_freq_low'])) + \
                             np.log((1-df_p1p2['p1_freq_high'])/(df_p1p2['p1_freq_high'])))

    df_p1p2['sel_high'] = (1/dt)*(np.log(df_p1p2['p2_freq_high']/(1-df_p1p2['p2_freq_high'])) + \
                             np.log((1-df_p1p2['p1_freq_low'])/(df_p1p2['p1_freq_low'])))
    return df_p1p2
        
        
        
        
        
        
                
def adjust_sel_coef(to_adjust, adjust_by, ep = 1e-3):
    to_adjust_mesos = to_adjust.loc[to_adjust['p1_freq']== ep,:].index.values
    to_adjust_mesos = np.intersect1d(to_adjust_mesos, adjust_by.index.values)
    pass


    full_dfp7['p7_pred_frp3'] = full_dfp7['p0_freq']*np.exp(full_dfp7['p3_s'] *7)
    full_dfp7['p7_pred_frp3'] = full_dfp7['p7_pred_frp3']/(1- full_dfp7['p0_freq'] + full_dfp7['p7_pred_frp3'])

def get_pred_freq(vals, sel, dt):
    pred = vals*np.exp(sel*dt)
    pred= pred/(1- vals + pred)
    return pred

# %%
def get_full_timecourse(df_both_meta_good,strain1=True, ep=1e-3):
    all_sels = []

    # build off of 0 to 3
    df_p0p3 = get_selection_coef(df_both_meta_good, 0, 3, strain1=strain1, ep=ep)
    df_p0p3['pred_7'] = get_pred_freq(df_p0p3['p2_freq'].values, df_p0p3['sel'].values, 4)
    df_p0p3['pred_5'] = get_pred_freq(df_p0p3['p2_freq'].values, df_p0p3['sel'].values, 2)

    df_p3p5 = get_selection_coef(df_both_meta_good, 3, 5, strain1=strain1, ep=ep)
    df_p0p5 = get_selection_coef(df_both_meta_good, 0, 5, strain1=strain1, ep=ep)
    df_p3p5['pred_7'] = get_pred_freq(df_p3p5['p2_freq'].values, df_p3p5['sel'].values, 2)
    df_p0p5['pred_7'] = get_pred_freq(df_p0p5['p2_freq'].values, df_p0p5['sel'].values, 2)
    

    df_p0p7 = get_selection_coef(df_both_meta_good, 0, 7, strain1=strain1, ep=ep)
    df_p3p7 = get_selection_coef(df_both_meta_good, 3, 7, strain1=strain1, ep=ep)
    df_p5p7 = get_selection_coef(df_both_meta_good, 5, 7, strain1=strain1, ep=ep)

    return df_p0p3,df_p3p5, df_p0p5, df_p3p7, df_p5p7, df_p0p7

# %%
df_p1p2 = get_selection_coef(df_both_meta_good, 0, 3, strain1=True)
df_p0p3,df_p3p5, df_p0p5, df_p3p7, df_p5p7, df_p0p7 = get_full_timecourse(df_both_meta_good,strain1=True, ep=1e-3)
