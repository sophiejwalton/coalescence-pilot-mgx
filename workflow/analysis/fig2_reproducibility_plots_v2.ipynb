# %%
import pandas as pd
import numpy as np
import os
import itertools as it
from snp_analysis_tools_sherlock import *
from coalescence_analysis_tools import *
from plot_tools import *
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='49c6899d-5cf6-4af9-9172-50b188dd72b7'>
#   <div id="d8b17a73-2d3d-4243-8c7a-f6a34748042e" data-root-id="49c6899d-5cf6-4af9-9172-50b188dd72b7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e0b36cf7-1ee5-4cf4-9b46-619c6721c3a8":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"49c6899d-5cf6-4af9-9172-50b188dd72b7"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d134d006-d6ef-4f24-8a03-8e4e0e800b25","attributes":{"plot_id":"49c6899d-5cf6-4af9-9172-50b188dd72b7","comm_id":"6bde220ac5b74eb2a324b659f574f45d","client_comm_id":"2a3a6352cdc448748bf4e14b4d1fd91b"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"e0b36cf7-1ee5-4cf4-9b46-619c6721c3a8","roots":{"49c6899d-5cf6-4af9-9172-50b188dd72b7":"d8b17a73-2d3d-4243-8c7a-f6a34748042e"},"root_ids":["49c6899d-5cf6-4af9-9172-50b188dd72b7"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_metadata  =transform_df(df_metadata)
df_metadata
# Out:
#       species_id    representative MGnify_accession  species_closest  \
# 0         100001  GUT_GENOME000001  MGYG-HGUT-00001         100049.0
# 1         100002  GUT_GENOME000004  MGYG-HGUT-00002         100201.0
# 2         100003  GUT_GENOME000008  MGYG-HGUT-00003         103279.0
# 3         100004  GUT_GENOME000010  MGYG-HGUT-00004         103876.0
# 4         100005  GUT_GENOME000017  MGYG-HGUT-00005         101623.0
# ...          ...               ...              ...              ...
# 4639      104640  GUT_GENOME286389  MGYG-HGUT-04640         103346.0
# 4640      104641  GUT_GENOME286625  MGYG-HGUT-04641              NaN
# 4641      104642  GUT_GENOME286704  MGYG-HGUT-04642         104273.0
# 4642      104643  GUT_GENOME286769  MGYG-HGUT-04643         100646.0
# 4643      104644  GUT_GENOME286887  MGYG-HGUT-04644         101057.0
#
#       ani_closest  gtpro_kmer_counts  phyeco_marker_counts  phyeco_pass_ratio  \
# 0        83.35600                NaN                  15.0                1.0
# 1        84.86955            29822.0                  15.0                1.0
# 2        93.41555             1115.0                  15.0                1.0
# 3        78.17620                NaN                  15.0                1.0
# 4        85.84275                NaN                  15.0                1.0
# ...           ...                ...                   ...                ...
# 4639     90.06215                NaN                  13.0                1.0
# 4640          NaN                NaN                  12.0                1.0
# 4641     79.50010                NaN                  15.0                1.0
# 4642     79.02775            89795.0                  15.0                1.0
# 4643     79.53465           114400.0                  15.0                1.0
#
#       pangene_counts  genome_counts  ...     N50  GC_content  Completeness  \
# 0               4893              4  ...   47258       28.26         98.59
# 1             147601            358  ...  109266       42.60         99.37
# 2             113409           1178  ...  158570       58.52        100.00
# 3              12599             24  ...   90296       54.19         98.66
# 4               5488              2  ...  350032       28.59         99.30
# ...              ...            ...  ...     ...         ...           ...
# 4639            7938             11  ...   11755       51.72         84.97
# 4640            1451              1  ...   17325       62.69         68.94
# 4641            8769             30  ...  153485       38.81         93.29
# 4642           40134            246  ...  433108       41.96         97.99
# 4643           45432             64  ...   14090       57.36         93.96
#
#       Contamination                                            Lineage  \
# 0              0.70  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__P...
# 1              0.00  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__L...
# 2              0.00  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 3              0.22  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# 4              0.00  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__P...
# ...             ...                                                ...
# 4639           0.35  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 4640           0.00  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 4641           0.00  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__L...
# 4642           0.00  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# 4643           0.67  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
#
#       Continent                           species                genus  \
# 0        Europe                               s__     g__GCA-900066495
# 1        Europe          s__Blautia_A sp900066165         g__Blautia_A
# 2        Europe               s__Alistipes shahii         g__Alistipes
# 3        Europe      s__Anaerotruncus colihominis     g__Anaerotruncus
# 4        Europe  s__Terrisporobacter glycolicus_A  g__Terrisporobacter
# ...         ...                               ...                  ...
# 4639     Europe                               s__        g__Prevotella
# 4640     Europe                               s__        g__Sutterella
# 4641     Europe                               s__                  g__
# 4642     Europe      s__Eubacterium_R sp003526845     g__Eubacterium_R
# 4643     Europe                               s__  g__Negativibacillus
#
#                         family              phyla
# 0     f__Peptostreptococcaceae    p__Firmicutes_A
# 1           f__Lachnospiraceae    p__Firmicutes_A
# 2             f__Rikenellaceae    p__Bacteroidota
# 3           f__Ruminococcaceae    p__Firmicutes_A
# 4     f__Peptostreptococcaceae    p__Firmicutes_A
# ...                        ...                ...
# 4639         f__Bacteroidaceae    p__Bacteroidota
# 4640       f__Burkholderiaceae  p__Proteobacteria
# 4641                       f__    p__Firmicutes_A
# 4642     f__Acutalibacteraceae    p__Firmicutes_A
# 4643        f__Ruminococcaceae    p__Firmicutes_A
#
# [4644 rows x 23 columns]

# %%
all_dfs=[]
abundances_coal = pd.read_csv('e003_coalescence_metadata_round4_abundances.csv')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
for sp in species_list:
    abundances_coal_sp = abundances_coal.loc[abundances_coal['species_id']==int(sp),:].set_index('sample')
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
     #   try:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
        if os.path.exists(fname):
            df_both=pd.read_csv(fname).set_index('sample')
       # except:
        #    continue
            df_both['species_id']=sp
            df_both['sp_plot']=df_metadata.loc[df_metadata['species_id']==int(sp),'species'].values[0]
         #   print(df_metadata.loc[df_metadata['species_id']==int(sp),'species'])
            
            df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
            df_both=df_both.loc[df_both['shifts_med']<.1,:]
            good_samples = np.intersect1d(df_both.index.values,e003_metadata.index.values)
            df_both_meta = pd.concat([df_both,e003_metadata.loc[good_samples,:],  abundances_coal_sp.loc[good_samples,'relative_abundance']],
                                                 axis=1).reset_index()
            all_dfs.append(df_both_meta)
            
all_dfs=pd.concat(all_dfs)
all_dfs.head()

all_dfs['species-ino']=all_dfs['species_id'].astype(str) +'-'+ all_dfs['inoculumn'].astype(str)
all_dfs = all_dfs.loc[~all_dfs['species-ino'].isin(bad_inos),:]
all_dfs
# Out:
#                                sample  Unnamed: 0  boot_med  boot_low  \
# 0    A10-e003Coalescence-mBHI-p1_S764           0  0.617920  0.615385
# 1         A10-e003Coalescence-mBHI-p5           1  0.411946  0.411946
# 2         A10-e003Coalescence-mBHI-p7           2  0.500000  0.500000
# 3         A10-e003Coalescence-mGAM-p3           3  0.127291  0.126008
# 4         A10-e003Coalescence-mGAM-p7           4  0.004968  0.004296
# ..                                ...         ...       ...       ...
# 36   G111-e003Coalescence-mGAM-p5_S80          36  0.780231  0.775595
# 37   H10-e003Coalescence-mBHI-p1_S831          37  0.588054  0.580875
# 38   H10-e003Coalescence-mGAM-p1_S835          38  0.489074  0.482937
# 39   H100-e003Coalescence-mBHI-p5_S43          39  0.994112  0.993041
# 40  H100-e003Coalescence-mBHI-p7_S139          40  0.997228  0.996734
#
#     boot_high  actual_med  shifts_low  shifts_high  shifts_med species_id  \
# 0    0.620513    0.618219    0.019000     0.029000    0.024000     100146
# 1    0.422998    0.411946    0.012000     0.044000    0.029000     100146
# 2    0.500000    0.500000    0.000000     0.000000    0.000000     100146
# 3    0.134343    0.127291    0.000000     0.018000    0.018000     100146
# 4    0.005644    0.004960   -0.000421     0.001404    0.000512     100146
# ..        ...         ...         ...          ...         ...        ...
# 36   0.784902    0.778008    0.024000     0.042000    0.036000     101294
# 37   0.588054    0.588054    0.017000     0.044000    0.029000     101294
# 38   0.493750    0.489051    0.025000     0.047000    0.039000     101294
# 39   0.995038    0.994117   -0.000377     0.003014    0.001314     101294
# 40   0.997685    0.997204    0.000514     0.002130    0.001288     101294
#
#     ... parent_media  parent_subjects  passage    type_mesocosm   redo  \
# 0   ...         mGAM            AA-AE        1  AA-AE-mGAM-mBHI  False
# 1   ...         mGAM            AA-AE        5  AA-AE-mGAM-mBHI  False
# 2   ...         mGAM            AA-AE        7  AA-AE-mGAM-mBHI  False
# 3   ...         mGAM            AA-AE        3  AA-AE-mGAM-mGAM  False
# 4   ...         mGAM            AA-AE        7  AA-AE-mGAM-mGAM  False
# ..  ...          ...              ...      ...              ...    ...
# 36  ...         mGAM            AE-AF        5  AE-AF-mGAM-mGAM  False
# 37  ...         mGAM            AE-AF        1  AE-AF-mGAM-mBHI  False
# 38  ...         mGAM            AE-AF        1  AE-AF-mGAM-mGAM  False
# 39  ...         mGAM            AE-AF        5  AE-AF-mGAM-mBHI  False
# 40  ...         mGAM            AE-AF        7  AE-AF-mGAM-mBHI  False
#
#     counts      mesocosm-passage  replicate  relative_abundance  \
# 0        1  A10-AA-AE-mGAM-mBHI1        2.0               0.027
# 1        1  A10-AA-AE-mGAM-mBHI5        2.0               0.019
# 2        1  A10-AA-AE-mGAM-mBHI7        2.0               0.014
# 3        1  A10-AA-AE-mGAM-mGAM3        2.0               0.008
# 4        1  A10-AA-AE-mGAM-mGAM7        2.0               0.020
# ..     ...                   ...        ...                 ...
# 36       1  G11-AE-AF-mGAM-mGAM5        1.0               0.017
# 37       1  H10-AE-AF-mGAM-mBHI1        2.0               0.004
# 38       1  H10-AE-AF-mGAM-mGAM1        2.0               0.018
# 39       1  H10-AE-AF-mGAM-mBHI5        2.0               0.004
# 40       1  H10-AE-AF-mGAM-mBHI7        2.0               0.005
#
#           species-ino
# 0   100146-AA-AE-mGAM
# 1   100146-AA-AE-mGAM
# 2   100146-AA-AE-mGAM
# 3   100146-AA-AE-mGAM
# 4   100146-AA-AE-mGAM
# ..                ...
# 36  101294-AE-AF-mGAM
# 37  101294-AE-AF-mGAM
# 38  101294-AE-AF-mGAM
# 39  101294-AE-AF-mGAM
# 40  101294-AE-AF-mGAM
#
# [1314 rows x 41 columns]

# %%
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
counts = []
for sp in species_list:
    abundances_coal_sp = abundances_coal.loc[abundances_coal['species_id']==int(sp),:].set_index('sample')
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
     #   try:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_count_parents.csv'
        if os.path.exists(fname):
            df_both=pd.read_csv(fname).max()
            counts.append(df_both.values[-1])
            counts.append(df_both.values[-2])

np.percentile(counts,75)
# Out:
# np.float64(12300.0)

# %%
full_dfp7= all_dfs.loc[all_dfs['passage']==7,:]
full_dfp0= all_dfs.loc[all_dfs['passage']==0,:]

full_dfp0.head()
# Out:
#                                sample  Unnamed: 0  boot_med  boot_low  \
# 5   A4-e003Coalescence-Inoculumn-mGAM           5  0.134957  0.131712
# 15  C2-e003Coalescence-Inoculumn-mGAM          15  0.077465  0.071862
# 6   A5-e003Coalescence-Inoculumn-mGAM           6  0.224016  0.215306
# 25  D2-e003Coalescence-Inoculumn-mGAM          25  0.211635  0.202840
# 15  C5-e003Coalescence-Inoculumn-mGAM          15  0.600203  0.598159
#
#     boot_high  actual_med  shifts_low  shifts_high  shifts_med species_id  \
# 5    0.139113    0.134752    0.006987        0.016       0.011     100146
# 15   0.080241    0.077465    0.003000        0.013       0.006     100146
# 6    0.228395    0.224016    0.000000        0.036       0.013     100146
# 25   0.220238    0.212274    0.000000        0.022       0.011     100146
# 15   0.603061    0.600000    0.011000        0.020       0.015     100146
#
#     ... parent_media  parent_subjects  passage    type_mesocosm   redo  \
# 5   ...         mGAM            AA-AE        0  AA-AE-mGAM-mGAM  False
# 15  ...         mGAM            AA-AE        0  AA-AE-mGAM-mGAM  False
# 6   ...         mGAM            AA-AF        0  AA-AF-mGAM-mGAM  False
# 25  ...         mGAM            AA-AF        0  AA-AF-mGAM-mGAM  False
# 15  ...         mGAM            AE-AF        0  AE-AF-mGAM-mGAM  False
#
#     counts     mesocosm-passage  replicate  relative_abundance  \
# 5        1  A4-AA-AE-mGAM-mGAM0        0.0               0.015
# 15       1  C2-AA-AE-mGAM-mGAM0        0.0               0.020
# 6        1  A5-AA-AF-mGAM-mGAM0        0.0               0.009
# 25       1  D2-AA-AF-mGAM-mGAM0        0.0               0.011
# 15       1  C5-AE-AF-mGAM-mGAM0        0.0               0.018
#
#           species-ino
# 5   100146-AA-AE-mGAM
# 15  100146-AA-AE-mGAM
# 6   100146-AA-AF-mGAM
# 25  100146-AA-AF-mGAM
# 15  100146-AE-AF-mGAM
#
# [5 rows x 41 columns]

# %%
all_diffs = []
for passage in [1,2,3,4,5,6,7]:
    e003_metadatap7 = e003_metadata.loc[e003_metadata['passage'] == passage,:]
    e003_metadatap7['replicate'] = np.nan 
    e003_metadatap7 = e003_metadatap7.sort_values(by='comm')
    reps = [1,2,3,4]
    full_dfp7= all_dfs.loc[all_dfs['passage']==passage,:]
    full_dfp7['type_meso']=full_dfp7['type_mesocosm'].copy()
    full_dfp7['species-type_meso'] = full_dfp7['species_id'].astype(str) + '-' + full_dfp7['type_meso']
    full_dfp7['replicate'] = 0.
    full_dfp0['type_meso']=full_dfp0['type_mesocosm']
    full_dfp0['species-type_meso'] = full_dfp0['species_id'].astype(str) + '-' + full_dfp0['type_meso']
    full_dfp0med=full_dfp0.groupby(['species-type_meso']).median(numeric_only=True).reset_index()
    full_dfp7med=full_dfp7.groupby(['species-type_meso']).median(numeric_only=True).reset_index()
    full_dfp7=full_dfp7.loc[full_dfp7['species-type_meso'].isin(full_dfp0med['species-type_meso'].values),:]
    
    species_type_mesos=[]
    meso_1s=[]
    meso_2s=[]
    strain_freq_diffs=[]
    sp_abundance_diffs = []
    med_p0_freqs=[]
    med_p7_freqs = []
    for species_type_meso in full_dfp7['species-type_meso'].unique():
        num_reps = len(full_dfp7.loc[full_dfp7['species-type_meso'] == species_type_meso, 'replicate'])
        full_dfp7.loc[full_dfp7['species-type_meso'] == species_type_meso, 'replicate'] = reps[:num_reps]
      #  print(full_dfp0med.loc[full_dfp0med['species-type_meso'] == species_type_meso, 'actual_med1'].values)
        full_dfp7.loc[full_dfp7['species-type_meso'] == species_type_meso, 'p0_med']= \
            full_dfp0med.loc[full_dfp0med['species-type_meso'] == species_type_meso, 'actual_med'].values[0]
        full_dfp7_sp_type_meso = full_dfp7.loc[full_dfp7['species-type_meso'] == species_type_meso,:]
        if num_reps>1:
            for meso1,meso2 in it.combinations(full_dfp7_sp_type_meso['mesocosm'].unique(),2):
                species_type_mesos.append(species_type_meso)
                meso_1s.append(meso1)
                meso_2s.append(meso2)
                med_p0_freqs.append(full_dfp0med.loc[full_dfp0med['species-type_meso'] == species_type_meso, 'actual_med'].values[0])
                med_p7_freqs.append(full_dfp7med.loc[full_dfp7med['species-type_meso'] == species_type_meso, 'actual_med'].values[0])
                meso1_freq=full_dfp7_sp_type_meso.loc[full_dfp7_sp_type_meso['mesocosm']==meso1,'actual_med'].values[0]
                meso2_freq=full_dfp7_sp_type_meso.loc[full_dfp7_sp_type_meso['mesocosm']==meso2,'actual_med'].values[0]
                if meso1 == meso2:
                    print('ck')
                meso1_sp=full_dfp7_sp_type_meso.loc[full_dfp7_sp_type_meso['mesocosm']==meso1,'relative_abundance'].values[0]
                meso2_sp=full_dfp7_sp_type_meso.loc[full_dfp7_sp_type_meso['mesocosm']==meso2,'relative_abundance'].values[0]
                strain_freq_diffs.append(meso1_freq-meso2_freq)
                sp_abundance_diffs.append(2*(meso1_sp-meso2_sp)/(meso1_sp+meso2_sp))
            
    df_diffs = pd.DataFrame(data={'species_type_meso': species_type_mesos,
                                  'Meso1': meso_1s,'Meso2': meso_2s,'strain_freq_diffs':strain_freq_diffs,
                                  'sp_abundance_diffs':sp_abundance_diffs,
                              'p0_freqs':med_p0_freqs, 'p7_freqs': med_p7_freqs})
    df_diffs['strain_freq_diffs_abs']=df_diffs['strain_freq_diffs'].abs()
    df_diffs['passage']=passage
    all_diffs.append(df_diffs)

# %%
all_diffs_df = pd.concat(all_diffs)
all_diffs_df['species-ino']=all_diffs_df['species_type_meso'].transform(lambda x: '-'.join(x.split('-')[:-1]))
all_diffs_df = all_diffs_df.loc[~all_diffs_df['species-ino'].isin(bad_inos),:]

all_diffs_df_nonzero = all_diffs_df.loc[(all_diffs_df['p7_freqs']>1e-2)*(all_diffs_df['p7_freqs']<1-1e-2),:]
frequencies, edges = np.histogram(all_diffs_df['strain_freq_diffs_abs'], 20)
    #print('Values: %s, Edges: %s' % (frequencies.shape[0], edges.shape[0]))
hv.Histogram((edges, frequencies)).opts(width=400, height=200, xlabel='|Diff Between Replicates|', 
                                            ylabel='Counts',fill_color= bokeh.palettes.Bright[6][1]
                                           )
# Out:
# :Histogram   [x]   (Frequency)

# %%
all_dfs=[]
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4.csv').set_index('sample')

for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
     #   try:
        fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
        if os.path.exists(fname1):
            
            df_both=pd.read_csv(fname1).set_index('sample')
            df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
            df_both_meta = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]],
                                         axis=1).reset_index()
       # except:
        #    continue
            df_both_meta['species_id']=sp
            df_both_meta['diff_from_in']=df_both_meta['actual_med']
           # df_both_meta['diff_from_in2']=df_both_meta['actual_med2']
            in_samples = df_both_meta['inoculumn_sample'].unique()
            if len(in_samples) != len(df_both_meta.loc[df_both_meta['sample'].isin(in_samples),'actual_med']):
                continue
            
            for in_sample in df_both_meta['inoculumn_sample'].unique():
                
                with_in_sample = df_both_meta.loc[df_both_meta['inoculumn_sample']==in_sample,'sample'].values
                in1_val=df_both_meta.loc[df_both_meta['sample']==in_sample,'actual_med'].values[0]
                df_both_meta.loc[df_both_meta['sample'].isin(with_in_sample),'diff_from_in']= \
                    df_both_meta.loc[df_both_meta['sample'].isin(with_in_sample),'diff_from_in'] - in1_val
                

            all_dfs.append(df_both_meta)
all_dfs=pd.concat(all_dfs)
all_dfs['species-type_meso']=all_dfs['species_id'].astype(str)+'-'+all_dfs['type_mesocosm']

bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']
all_dfs['species-ino']=all_dfs['species_id'].astype(str) +'-'+ all_dfs['inoculumn'].astype(str)
all_dfs = all_dfs.loc[~all_dfs['species-ino'].isin(bad_inos),:]
all_dfs
#all_dfs_gr=all_dfs.groupby(['species-type_meso']).median(numeric_only=True).reset_index()
# Out:
#                                sample  Unnamed: 0  boot_med  boot_low  \
# 0    A10-e003Coalescence-mBHI-p1_S764           0  0.617920  0.615385
# 1         A10-e003Coalescence-mBHI-p5           1  0.411946  0.411946
# 2         A10-e003Coalescence-mBHI-p7           2  0.500000  0.500000
# 3         A10-e003Coalescence-mGAM-p3           3  0.127291  0.126008
# 4         A10-e003Coalescence-mGAM-p7           4  0.004968  0.004296
# ..                                ...         ...       ...       ...
# 36   G111-e003Coalescence-mGAM-p5_S80          36  0.780231  0.775595
# 37   H10-e003Coalescence-mBHI-p1_S831          37  0.588054  0.580875
# 38   H10-e003Coalescence-mGAM-p1_S835          38  0.489074  0.482937
# 39   H100-e003Coalescence-mBHI-p5_S43          39  0.994112  0.993041
# 40  H100-e003Coalescence-mBHI-p7_S139          40  0.997228  0.996734
#
#     boot_high  actual_med  shifts_low  shifts_high  shifts_med comm  ...  \
# 0    0.620513    0.618219    0.019000     0.029000    0.024000  A10  ...
# 1    0.422998    0.411946    0.012000     0.044000    0.029000  A10  ...
# 2    0.500000    0.500000    0.000000     0.000000    0.000000  A10  ...
# 3    0.134343    0.127291    0.000000     0.018000    0.018000  A10  ...
# 4    0.005644    0.004960   -0.000421     0.001404    0.000512  A10  ...
# ..        ...         ...         ...          ...         ...  ...  ...
# 36   0.784902    0.778008    0.024000     0.042000    0.036000  G11  ...
# 37   0.588054    0.588054    0.017000     0.044000    0.029000  H10  ...
# 38   0.493750    0.489051    0.025000     0.047000    0.039000  H10  ...
# 39   0.995038    0.994117   -0.000377     0.003014    0.001314  H10  ...
# 40   0.997685    0.997204    0.000514     0.002130    0.001288  H10  ...
#
#    parent_subjects passage    type_mesocosm   redo counts  \
# 0            AA-AE       1  AA-AE-mGAM-mBHI  False      1
# 1            AA-AE       5  AA-AE-mGAM-mBHI  False      1
# 2            AA-AE       7  AA-AE-mGAM-mBHI  False      1
# 3            AA-AE       3  AA-AE-mGAM-mGAM  False      1
# 4            AA-AE       7  AA-AE-mGAM-mGAM  False      1
# ..             ...     ...              ...    ...    ...
# 36           AE-AF       5  AE-AF-mGAM-mGAM  False      1
# 37           AE-AF       1  AE-AF-mGAM-mBHI  False      1
# 38           AE-AF       1  AE-AF-mGAM-mGAM  False      1
# 39           AE-AF       5  AE-AF-mGAM-mBHI  False      1
# 40           AE-AF       7  AE-AF-mGAM-mBHI  False      1
#
#         mesocosm-passage species_id diff_from_in       species-type_meso  \
# 0   A10-AA-AE-mGAM-mBHI1     100146     0.483467  100146-AA-AE-mGAM-mBHI
# 1   A10-AA-AE-mGAM-mBHI5     100146     0.277195  100146-AA-AE-mGAM-mBHI
# 2   A10-AA-AE-mGAM-mBHI7     100146     0.365248  100146-AA-AE-mGAM-mBHI
# 3   A10-AA-AE-mGAM-mGAM3     100146    -0.007461  100146-AA-AE-mGAM-mGAM
# 4   A10-AA-AE-mGAM-mGAM7     100146    -0.129792  100146-AA-AE-mGAM-mGAM
# ..                   ...        ...          ...                     ...
# 36  G11-AE-AF-mGAM-mGAM5     101294     0.351628  101294-AE-AF-mGAM-mGAM
# 37  H10-AE-AF-mGAM-mBHI1     101294     0.143609  101294-AE-AF-mGAM-mBHI
# 38  H10-AE-AF-mGAM-mGAM1     101294     0.044607  101294-AE-AF-mGAM-mGAM
# 39  H10-AE-AF-mGAM-mBHI5     101294     0.549673  101294-AE-AF-mGAM-mBHI
# 40  H10-AE-AF-mGAM-mBHI7     101294     0.552760  101294-AE-AF-mGAM-mBHI
#
#           species-ino
# 0   100146-AA-AE-mGAM
# 1   100146-AA-AE-mGAM
# 2   100146-AA-AE-mGAM
# 3   100146-AA-AE-mGAM
# 4   100146-AA-AE-mGAM
# ..                ...
# 36  101294-AE-AF-mGAM
# 37  101294-AE-AF-mGAM
# 38  101294-AE-AF-mGAM
# 39  101294-AE-AF-mGAM
# 40  101294-AE-AF-mGAM
#
# [1368 rows x 27 columns]

# %%
len(all_dfs['species_id'].unique())
# Out:
# 14

# %%
all_dfs['species-mesocosm']=all_dfs['species_id'].astype(str) + '-' + all_dfs['mesocosm'].astype(str)
all_dfs7 = all_dfs.loc[all_dfs['passage']==7,:]
all_dfs0 = all_dfs.loc[all_dfs['passage']==0,:]
all_dfs7['passage_0'] = np.nan
all_dfs7['sp_ino']=all_dfs7['species_id'].astype(str)+'-'+all_dfs7['inoculumn_sample']
all_dfs0['sp_ino']=all_dfs0['species_id'].astype(str)+'-'+all_dfs0['inoculumn_sample']
for spin in all_dfs7['sp_ino'].unique():
    in_sample = '-'.join(spin.split('-')[1:])
    all_dfs0_good=all_dfs0.loc[all_dfs0['sp_ino']==spin,:]
    all_dfs0_good=all_dfs0_good.loc[all_dfs0_good['sample']==in_sample,'actual_med'].values
    if len(all_dfs0_good)==0:
        continue
    all_dfs7.loc[all_dfs7['sp_ino']==spin,'passage_0']=all_dfs0_good[0]

# %%
all_dfs7 = all_dfs7.loc[~all_dfs7['passage_0'].isna(),:]
all_dfs7p = all_dfs7.copy()
all_dfs7p.loc[all_dfs7p['passage_0']>.5,'actual_med']=1.-all_dfs7p.loc[all_dfs7p['passage_0']>.5,'actual_med']
all_dfs7p.loc[all_dfs7p['passage_0']>.5,'passage_0']=1.-all_dfs7p.loc[all_dfs7p['passage_0']>.5,'passage_0']
all_dfs7p['species-ino'].unique()
print(np.intersect1d(all_dfs7p['species-ino'].unique(), bad_inos))
all_dfs7.columns.values
# Out:
# []
# array(['sample', 'Unnamed: 0', 'boot_med', 'boot_low', 'boot_high',
#        'actual_med', 'shifts_low', 'shifts_high', 'shifts_med', 'comm',
#        'comm-media', 'inoculumn', 'inoculumn_sample', 'is_inoculumn',
#        'media', 'mesocosm', 'parent_media', 'parent_subjects', 'passage',
#        'type_mesocosm', 'redo', 'counts', 'mesocosm-passage',
#        'species_id', 'diff_from_in', 'species-type_meso', 'species-ino',
#        'species-mesocosm', 'passage_0', 'sp_ino'], dtype=object)

# %%
p = hv.Scatter(all_dfs7, kdims = ['passage_0'],
               vdims = ['diff_from_in','passage_0']).opts(size=10, 
                                                        fill_color= bokeh.palettes.Bright[6][-1],
                                                        alpha = .5, line_color = 'black',)
                                                        
p
# Out:
# :Scatter   [passage_0]   (diff_from_in,passage_0)

# %%
all_dfs=all_dfs.loc[all_dfs['shifts_med']<.1,:]
print(np.intersect1d(all_dfs['species-ino'].unique(), bad_inos))
all_dfs_p7 = all_dfs.loc[all_dfs['passage']==7,:]
all_dfs_p7['diff_from_in_abs']=all_dfs_p7['diff_from_in'].abs()
all_dfs_gr=all_dfs_p7.groupby(['species-type_meso']).median(numeric_only=True).reset_index()
all_dfs_gr['diff_from_in_abs']=all_dfs_gr['diff_from_in'].abs()
frequencies, edges = np.histogram(all_dfs_p7['diff_from_in_abs'],bins=20)
#print('Values: %s, Edges: %s' % (frequencies.shape[0], edges.shape[0]))
hv.Histogram((edges, frequencies)).opts(width=400, height=200, xlabel='|Absolute Frequency Shift|', 
                                        ylabel='Counts',fill_color= bokeh.palettes.Bright[6][1]
                                       )
# Out:
# []
# :Histogram   [x]   (Frequency)

# %%
all_dfs_p7['freq_shift']=all_dfs_p7["diff_from_in_abs"]
#big_df.loc[big_df['compare_type']=='Btw',:] = 'Over time (P0-7)'
#big_df.loc[big_df['compare_type']=='Wtn',:] = 'Btw Reps'
all_dfs_p7['compare_type']='Over time (P0-7)'
all_diffs_df['freq_shift']=all_diffs_df["strain_freq_diffs_abs"]
all_diffs_df['compare_type']='Btw Reps'
len(all_dfs_p7['species-mesocosm'].unique())
def ecdf_transform(data):
    return 1- data.rank(method="first") / len(data)

all_dfs_p7.loc[:, "freq shift ECDF"] = all_dfs_p7[
    "freq_shift"
].transform(ecdf_transform)

all_dfs['conf_interval']= all_dfs['boot_high']- all_dfs['boot_low']

all_dfs.loc[:, "conf_interval ECDF"] = all_dfs[
    "conf_interval"
].transform(ecdf_transform)

all_diffs_df.loc[:, "freq shift ECDF"] = all_diffs_df[
    "freq_shift"
].transform(ecdf_transform)
all_dfs['compare_type']='Sample Error'
all_dfs['freq_shift'] = all_dfs['conf_interval']
all_dfsg = all_dfs.loc[(all_dfs['boot_med']>1e-3)*(all_dfs['boot_med']<1-1e-3),:]

big_df = pd.concat([all_dfs_p7[['freq_shift','compare_type']],
                    all_diffs_df[['freq_shift','compare_type']],
                   all_dfsg[['freq_shift', 'compare_type']]])
big_df.loc[:, "freq shift ECDF"] = big_df.groupby('compare_type')[
    "freq_shift"
].transform(ecdf_transform)

# %%
p1=hv.Scatter(
    data=all_dfs_p7,
    kdims='freq_shift',
    vdims=[('freq shift ECDF', 'ECDF'), 'compare_type'],
).opts(color='compare_type')
p2=hv.Scatter(
    data=all_diffs_df,
    kdims='freq_shift',
    vdims=[('freq shift ECDF', 'ECDF'), 'compare_type'],
).opts(color='compare_type')
p1*p2.opts(show_legend=True)

p3=hv.Scatter(
    data=big_df,
    kdims='freq_shift',
    vdims=[('freq shift ECDF', 'ECDF'), 'compare_type'],
).opts(color='compare_type',cmap = [bokeh.palettes.Bright[6][1],bokeh.palettes.Bright[6][4],bokeh.palettes.Vibrant[7][-1]],
       width=250,height=200,xlabel='Freq Shift',#legend_position='right',
      ylabel='1-CDF')

p3=hv.render(p3)
p3.legend.visible=False
p3.output_backend = "svg"
bokeh.io.show(p3)
export_plot_pdf(p3, 'overtime_btwn_small')
# Out:
#   <div id="cceff29e-5ad2-4e08-b682-6dbe1d7a099d" data-root-id="51a06f6e-5d8b-4bc4-9ae1-910891af5403" style="display: contents;"></div>

# %%
all_dfsb =all_dfs.loc[all_dfs['passage']>0,:]
#all_dfsb.groupby(['species-mesocosm']).sum(numeric_only=True)
len(all_dfsb['species-type_meso'].unique())
#len(all_dfsb['species_id'].unique())
# Out:
# 62

# %%
p3=hv.Scatter(
    data=big_df,#.loc[big_df['compare_type']!='Over time (P0-7)',:],
    kdims='freq_shift',
    vdims=[('freq shift ECDF', 'ECDF'), 'compare_type'],
).opts(color='compare_type',cmap = [bokeh.palettes.Bright[6][1],bokeh.palettes.Bright[6][4],bokeh.palettes.Vibrant[7][-1]],size=5,
       width=300,height=400,xlabel='Freq Shift',#legend_position='right',
      ylabel='1-CDF')

p3=hv.render(p3)
p3.yaxis.major_label_text_font_size='18px'
p3.xaxis.major_label_text_font_size='18px'
p3.legend.visible=False
p3.output_backend = "svg"
bokeh.io.show(p3)
export_plot_pdf(p3, 'overtime_btwn')
# Out:
#   <div id="a17d7ac8-729e-4d23-ba81-6ca14eb48b33" data-root-id="636e172a-ce98-4ae8-b5ac-47fed454d81d" style="display: contents;"></div>

# %%
len(big_df.loc[big_df['compare_type']=='Over time (P0-7)',:])
big_df
# Out:
#     freq_shift      compare_type  freq shift ECDF
# 2     0.365248  Over time (P0-7)         0.518293
# 4     0.129792  Over time (P0-7)         0.859756
# 18    0.220710  Over time (P0-7)         0.725610
# 19    0.023647  Over time (P0-7)         0.969512
# 41    0.660749  Over time (P0-7)         0.109756
# ..         ...               ...              ...
# 36    0.009307      Sample Error         0.109737
# 37    0.007179      Sample Error         0.162287
# 38    0.010813      Sample Error         0.083462
# 39    0.001997      Sample Error         0.495363
# 40    0.000951      Sample Error         0.732612
#
# [2365 rows x 3 columns]

# %%
print(np.quantile(big_df.loc[big_df['compare_type']=='Sample Error','freq_shift'],.75))
print(np.quantile(big_df.loc[big_df['compare_type']=='Sample Error','freq_shift'],.25))
# Out:
# 0.004973273987358501
# 0.0010020040080159984

# %%
from scipy.stats import permutation_test

def get_median(array1,array2):
    return np.median(array1)-np.median(array2)
    

permutation_test((big_df.loc[big_df['compare_type']=='Over time (P0-7)','freq_shift'].values,
                 big_df.loc[big_df['compare_type']=='Sample Error','freq_shift'].values), get_median)
# Out:
# PermutationTestResult(statistic=np.float64(0.38398991648114683), pvalue=np.float64(0.0002), null_distribution=array([ 1.48430710e-04, -5.20836914e-04, -3.97117046e-04, ...,
#        -5.53738322e-05,  6.55772358e-04, -2.77410061e-04], shape=(9999,)))

# %%
permutation_test((big_df.loc[big_df['compare_type']=='Over time (P0-7)','freq_shift'].values,
                 big_df.loc[big_df['compare_type']=='Btw Reps','freq_shift'].values), get_median)
# Out:
# PermutationTestResult(statistic=np.float64(0.367907494139263), pvalue=np.float64(0.0002), null_distribution=array([ 0.00698376, -0.00016502,  0.00679008, ..., -0.00141932,
#        -0.00542006, -0.00075689], shape=(9999,)))

# %%
btw= big_df.loc[big_df['compare_type']=='Btw Reps',:]
len(btw.loc[btw['freq_shift']<.1,:])/len(btw)
# Out:
# 0.8743109151047409

# %%
p3=hv.Scatter(
    data=big_df.loc[big_df['compare_type']=='Sample Error',:],
    kdims='freq_shift',
    vdims=[('freq shift ECDF', 'ECDF'), 'compare_type'],
).opts(color='compare_type',cmap = [bokeh.palettes.Vibrant[7][-1]],size=5,
       width=300,height=400,xlabel='Freq Shift',#legend_position='right',
      ylabel='1-CDF')

p3=hv.render(p3)
p3.legend.visible=False
p3.output_backend = "svg"
p3.x_range = bokeh.models.Range1d(-.1,1.05)
bokeh.io.show(p3)
export_plot_pdf(p3, 'overtime_btwn')
# Out:
#   <div id="b44de6ea-8d8e-4bc5-8767-9597658fedde" data-root-id="fa5706e1-67aa-4231-b147-14377f83edc6" style="display: contents;"></div>

# %%
bokeh.palettes.Vibrant[7][-1]
# Out:
# '#BBBBBB'

# %%
from scipy.stats import pearsonr
all_diffs_df=all_diffs_df.loc[all_diffs_df['Meso1']!=all_diffs_df['Meso2'],:]

all_diffs_df['sp_abundance_diffs_abs']=all_diffs_df['sp_abundance_diffs'].abs()
all_diffs_df['strain_freq_diffs_abs']=all_diffs_df['strain_freq_diffs'].abs()

all_diffs_df['strain_freq_diffs_abs_adj'] = all_diffs_df['strain_freq_diffs_abs']
all_diffs_df.loc[all_diffs_df['strain_freq_diffs_abs_adj']<1e-3,'strain_freq_diffs_abs_adj']=1e-3
all_diffs_df['sp_abundance_diffs_abs_adj'] = all_diffs_df['sp_abundance_diffs_abs']
all_diffs_df.loc[all_diffs_df['sp_abundance_diffs_abs_adj']<1e-3,'sp_abundance_diffs_abs']=1e-3
all_diffs_df_nozero = all_diffs_df#.loc[all_diffs_df['strain_freq_diffs_abs']>1e-3,:]

print(pearsonr(all_diffs_df_nozero['strain_freq_diffs_abs'],all_diffs_df_nozero['sp_abundance_diffs_abs']))
p = hv.Scatter(
    data=all_diffs_df_nozero,
    kdims='sp_abundance_diffs_abs_adj',
    vdims=['strain_freq_diffs_abs_adj', 'passage'],
).opts(color='passage',logy=True,logx=True,cmap=bokeh.palettes.Bokeh[6][::-1],alpha=.5,size=4,
       colorbar=True,
       width=400,height=300,ylabel='Diff Strain Freq',xlabel='Diff in Sp Abun (Normalized)'
      )
p=hv.render(p)
p.xaxis.axis_label_text_font_style = 'normal'
p.yaxis.axis_label_text_font_style = 'normal'
p.xaxis.major_label_text_font_size='20px'
p.yaxis.major_label_text_font_size='20px'
p.xaxis.axis_label_text_font_size='22px'
p.yaxis.axis_label_text_font_size='22px'
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,'sp_strain_shifts')
# Out:
# WARNING:param.PointPlot00458: Logarithmic axis range encountered value less than or equal to zero, please supply explicit lower bound to override default of 0.010.
# PearsonRResult(statistic=np.float64(0.28723721769655436), pvalue=np.float64(1.0919787491453233e-18))
#   <div id="f8063981-4886-4272-9dd7-f53e8482d813" data-root-id="633584b6-ef33-4e3d-ad3a-944d47649e5e" style="display: contents;"></div>

# %%
bad_inos
# Out:
# ['100146-AA-AF-mBHI',
#  '100146-AE-AF-mBHI',
#  '102478-AA-AF-mBHI',
#  '102478-AE-AF-mBHI',
#  '100196-AA-AF-mBHI',
#  '100196-AE-AF-mBHI',
#  '100196-AA-AE-mGAM',
#  '100196-AE-AF-mGAM',
#  '102544-AA-AF-mBHI',
#  '102544-AE-AF-mBHI',
#  '101349-AA-AF-mBHI',
#  '101349-AE-AF-mBHI',
#  '102506-AA-AE-mBHI',
#  '102506-AE-AF-mBHI',
#  '102506-AA-AF-mBHI',
#  '102506-AE-AF-mBHI',
#  '102506-AA-AE-mGAM',
#  '102506-AE-AF-mGAM',
#  '101346-AA-AE-mBHI',
#  '101346-AE-AF-mBHI',
#  '101346-AA-AF-mBHI',
#  '101346-AE-AF-mBHI',
#  '101346-AA-AE-mGAM',
#  '101346-AE-AF-mGAM',
#  '101346-AA-AE-mBHI',
#  '101346-AA-AF-mBHI',
#  '100120-AA-AF-mBHI',
#  '100120-AE-AF-mBHI',
#  '102327-AA-AF-mBHI',
#  '102327-AE-AF-mBHI']

# %%
pvals = []
for passage in [1,2,3,4,5,6,7]:
    all_diffs_df_passage = all_diffs_df_nozero.loc[all_diffs_df_nozero['passage']==passage,:]
    pvals.append(pearsonr(all_diffs_df_passage['strain_freq_diffs_abs'],all_diffs_df_passage['sp_abundance_diffs_abs']).pvalue)
    p3=hv.Scatter(
        data=all_diffs_df_passage,
        kdims='sp_abundance_diffs_abs',
        vdims=['strain_freq_diffs_abs', 'compare_type'],
    ).opts(color=bokeh.palettes.Vibrant[3][-1],logy=True,logx=True,
           width=300,height=300,
          )
    bokeh.io.show(hv.render(p3))
# Out:
# WARNING:param.PointPlot00479: Logarithmic axis range encountered value less than or equal to zero, please supply explicit lower bound to override default of 0.010.
#   <div id="bc362cbe-d471-462d-b864-98c3009dae7e" data-root-id="443efd60-e017-4477-a989-08bb15ca6ff0" style="display: contents;"></div>
#   <div id="a2493993-f104-4f72-93f1-d4ae6c9996b4" data-root-id="e99bf7d2-19ca-4310-8530-224fddcd7aec" style="display: contents;"></div>
#   <div id="f9483f4c-6b14-4ac3-bd00-8d8e7c913be7" data-root-id="48648913-18d8-4e96-abec-e4a5630a4477" style="display: contents;"></div>
#   <div id="c5ab1bbd-a2a0-40e1-a50b-fab08fa89c8c" data-root-id="8eb2c92e-4be6-4758-83c9-6dfd9fb58412" style="display: contents;"></div>
#   <div id="c7403f9e-0cb0-4acf-8f38-e739f9d16792" data-root-id="ec63e0ad-9631-42c5-831a-33e77b5bd1b4" style="display: contents;"></div>
#   <div id="ec61403b-3261-4427-952f-8cb01e355dd4" data-root-id="8bee5333-1429-458b-8f38-93006538e3fe" style="display: contents;"></div>
#   <div id="ee927ca0-1f19-4164-a524-1eb99dae342d" data-root-id="2f95cc21-a21f-49c3-8829-06d6a52ac243" style="display: contents;"></div>

# %%
from scipy.stats import false_discovery_control
qvals = false_discovery_control(pvals)
qvals<.05
# Out:
# array([False, False,  True,  True,  True,  True,  True])

# %%
pvals
# Out:
# [np.float64(0.3481416368138457),
#  np.float64(0.832182101662693),
#  np.float64(0.007212212858951872),
#  np.float64(0.014791766713487153),
#  np.float64(3.588677155209361e-10),
#  np.float64(0.0001900504008563844),
#  np.float64(0.00046287140410315443)]
