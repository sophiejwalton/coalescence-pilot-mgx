# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control
#from bokeh.models import FixedTicker, FuncTickFormatter 
from scipy.stats import chi2

#from bokeh.io import output_notebook
import warnings
from scipy.optimize import OptimizeWarning # Example for SciPy

# Ignore all warnings
warnings.filterwarnings("ignore")

# Or, ignore a specific warning type
warnings.filterwarnings("ignore", category=OptimizeWarning)
from snp_analysis_tools_sherlock import *
from plot_tools import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0c709402-a11c-4060-bc7f-09e43985bb8e'>
#   <div id="d56233b9-0421-464f-ae16-b92f0120a45d" data-root-id="0c709402-a11c-4060-bc7f-09e43985bb8e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f85e44db-d0a2-49b0-b8f6-c40ad437279a":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"0c709402-a11c-4060-bc7f-09e43985bb8e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5557c82c-ea89-449b-8a6b-4c6c3d1e739b","attributes":{"plot_id":"0c709402-a11c-4060-bc7f-09e43985bb8e","comm_id":"29ea7454755343ba9e7679de07058615","client_comm_id":"d938cf114ff7429a82c4982d73a94ad9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"f85e44db-d0a2-49b0-b8f6-c40ad437279a","roots":{"0c709402-a11c-4060-bc7f-09e43985bb8e":"d56233b9-0421-464f-ae16-b92f0120a45d"},"root_ids":["0c709402-a11c-4060-bc7f-09e43985bb8e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
def transitive_relation(x,c):
    return x+c
    
def get_estimate_c(full_dfp7_goodgr_small, passages_fit = [0,1]):
    xs=[]
    ys=[]
    xs_min = []
    xs_max = []
    passages=[]
    xsfit = []
    ysfit = []
    for passage in [0,1,2,3,4,5,6,7]:
        passage_df = full_dfp7_goodgr_small.loc[full_dfp7_goodgr_small['passage']==passage,:]
        if len(passage_df['parent_subjects'].unique())<3:
            continue
        x1 = passage_df.loc[passage_df['parent_subjects']=='AA-AE','boot_med'].values[0]
        x2 =passage_df.loc[passage_df['parent_subjects']=='AE-AF','boot_med'].values[0]
        xs.append(x1+x2)
        ys.append(passage_df.loc[passage_df['parent_subjects']=='AA-AF','boot_med'].values[0])
        passages.append(passage)
        if passage in passages_fit:
            
            xsfit.append(x1+x2)
            ysfit.append(passage_df.loc[passage_df['parent_subjects']=='AA-AF','boot_med'].values[0])
    if len(ys)==0:
        return np.nan,np.nan,np.nan,np.nan
    if len(ysfit)==0:
        return np.nan,np.nan,np.nan,np.nan
    c,_ = curve_fit(transitive_relation,xsfit,ysfit)
  #  print(curve_fit(transitive_relation,xs,ys))
   # print(c)
    return c[0],xs, ys,passages


def get_estimate_c_errors(full_dfp7, passages_fit = [0,1]):
    all_dfs = []
    for i in range(100):
        x1r = np.random.choice(full_dfp7.loc[full_dfp7['parent_subjects']=='AA-AE','replicate'].unique(), len(full_dfp7.loc[full_dfp7['parent_subjects']=='AA-AE','replicate'].unique()))
      #  print(x1r)
        x1 = full_dfp7.loc[(full_dfp7['parent_subjects']=='AA-AE')*((full_dfp7['replicate'].isin(x1r)) + (full_dfp7['passage']==0)),:]
       # print(full_dfp7.loc[full_dfp7['replicate'].isin(list(x1r)),'passage'])
        x2r=np.random.choice(full_dfp7.loc[full_dfp7['parent_subjects']=='AE-AF','replicate'].unique(), len(full_dfp7.loc[full_dfp7['parent_subjects']=='AE-AF','replicate'].unique()))
        x2 = full_dfp7.loc[(full_dfp7['parent_subjects']=='AE-AF')*((full_dfp7['replicate'].isin(x2r))+ (full_dfp7['passage']==0)),:]
        yr=np.random.choice(full_dfp7.loc[full_dfp7['parent_subjects']=='AA-AF','replicate'].unique(), len(full_dfp7.loc[full_dfp7['parent_subjects']=='AA-AF','replicate'].unique()))
        y = full_dfp7.loc[(full_dfp7['parent_subjects']=='AA-AF')*((full_dfp7['replicate'].isin(yr))+(full_dfp7['passage']==0)),:]
        df = pd.concat([x1,x2,y])
       # print(x1,x2,y)
        c,xs,ys,passages = get_estimate_c(df.groupby(['parent_subjects','passage']).median(numeric_only=True).reset_index(),passages_fit=passages_fit)
        df2 = pd.DataFrame(data={'x':xs,'y':ys,'passages':passages})
        df2['c']=c
        df2['ys_est']=df2['c']+df2['x']
        all_dfs.append(df2)
    return pd.concat(all_dfs)

# %%
def adjust_freq(df_both,shift=True, thresh=1e-3,):
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['shifts_med']<.1,:]

    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]],
                                         axis=1).reset_index()

    #df_both_meta_good=df_both_meta.loc[df_both_meta['total_shift']<.1,:]

    for col in ['boot_med','boot_low','boot_high']:
        df_both_meta_good.loc[df_both_meta_good[col]<thresh,col]=thresh
        df_both_meta_good.loc[df_both_meta_good[col]>1-thresh,col]=1-thresh
    df_both_meta_good_logit = df_both_meta_good.copy()
    df_both_meta_good_logit[['boot_med','boot_low','boot_high']] = np.log(df_both_meta_good_logit[['boot_med','boot_low','boot_high',]]/(1-df_both_meta_good_logit[['boot_med','boot_low','boot_high',
   ]]) )

    return df_both_meta_good_logit

# %%
all_dfs=[]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
        if f'{sp}-{ino}' in bad_inos:
            continue
        if os.path.exists(fname):
            df_both = pd.read_csv(fname).set_index('sample')
            df=adjust_freq(df_both).reset_index()
            df['species_id']=sp
            all_dfs.append(df)
            
all_dfs=pd.concat(all_dfs)
all_dfs_adjust= all_dfs.copy()
all_dfs_gr = all_dfs.groupby(['species_id','parent_subjects','type_mesocosm','passage']).median(numeric_only=True).reset_index()
full_dfp7=all_dfs.copy()
full_dfp7['species-type_meso']= full_dfp7['species_id'] + '-' + full_dfp7['type_mesocosm']
full_dfp7['species-env']= full_dfp7['species_id']+'-' + full_dfp7['parent_media'] + '-' + full_dfp7['media'] 
id_columns = ['species-type_meso','species-env','parent_subjects', 'media', 'parent_media', 'species_id','type_mesocosm',
              'inoculumn_sample','inoculumn',
             'passage']
full_dfp7 = full_dfp7.loc[~full_dfp7['boot_med'].isna(),:]    

full_dfp7_goodgr = full_dfp7[id_columns + ['boot_med',]].groupby(id_columns).median().reset_index()
full_dfp7_goodgrmax = full_dfp7[id_columns + ['boot_med',]].groupby(id_columns).max().reset_index()
full_dfp7_goodgrmin = full_dfp7[id_columns + ['boot_med',]].groupby(id_columns).min().reset_index()
full_dfp7['sp-inenv']=full_dfp7['species_id']+'-'+full_dfp7['parent_media']
full_dfp7_goodgr['sp-inenv']=full_dfp7_goodgr['species_id']+'-'+full_dfp7_goodgr['parent_media']
full_dfp7_goodgrmin['sp-inenv']=full_dfp7_goodgrmin['species_id']+'-'+full_dfp7_goodgrmin['parent_media']
full_dfp7_goodgrmax['sp-inenv']=full_dfp7_goodgrmax['species_id']+'-'+full_dfp7_goodgrmax['parent_media']

# %%
sp_envs=[]
c_ests=[]
big_df = []

for sp_env in full_dfp7_goodgr['species-env'].unique():
    
    full_dfp7_goodgr_small = full_dfp7_goodgr.loc[full_dfp7_goodgr['species-env']==sp_env,:]
    inenv = sp_env.split('-')[0]+'-' + sp_env.split('-')[1]
    ins = full_dfp7_goodgr.loc[(full_dfp7_goodgr['passage']==0)*(full_dfp7_goodgr['sp-inenv']==inenv),:]
    if full_dfp7_goodgr_small['passage'].min()>0:
        full_dfp7_goodgr_small=pd.concat([full_dfp7_goodgr_small,ins])
        
    insmin = full_dfp7_goodgrmin.loc[(full_dfp7_goodgrmin['passage']==0)*(full_dfp7_goodgrmin['sp-inenv']==inenv),:]   
    full_dfp7_goodgr_smallmin = full_dfp7_goodgrmin.loc[full_dfp7_goodgrmin['species-env']==sp_env,:]
    if full_dfp7_goodgr_smallmin['passage'].min()>0:
        full_dfp7_goodgr_smallmin=pd.concat([full_dfp7_goodgr_smallmin,insmin])

    insmax = full_dfp7_goodgrmax.loc[(full_dfp7_goodgrmax['passage']==0)*(full_dfp7_goodgrmax['sp-inenv']==inenv),:] 
    full_dfp7_goodgr_smallmax = full_dfp7_goodgrmax.loc[full_dfp7_goodgrmax['species-env']==sp_env,:]
    if full_dfp7_goodgr_smallmax['passage'].min()>0:
        full_dfp7_goodgr_smallmax=pd.concat([full_dfp7_goodgr_smallmax,insmax])
    full_dfp7_small = full_dfp7.loc[full_dfp7['species-env']==sp_env,:]
    ins = full_dfp7.loc[(full_dfp7['passage']==0)*(full_dfp7['sp-inenv']==inenv),:]
    if full_dfp7_small['passage'].max()<=1:
        continue
    if full_dfp7_small['passage'].min()>0:
        full_dfp7_small=pd.concat([full_dfp7_small,ins])
    if len(full_dfp7_goodgr_small['parent_subjects'].unique())==3:
        c_est,xs,ys,passages = get_estimate_c(full_dfp7_goodgr_small,passages_fit = [0,1])
       # df = get_estimate_c_errors(full_dfp7_small,passages_fit = [0,1])
        _,xs_min,ys_max,_ = get_estimate_c(full_dfp7_goodgr_smallmin,passages_fit = [0,1])
        _,xs_max,ys_min,_ = get_estimate_c(full_dfp7_goodgr_smallmax,passages_fit = [0,1])
        if np.isnan(c_est):
            continue
        sp_envs.append(sp_env)
        c_ests.append(c_est)
        yests = xs + c_est
        rmse = np.sqrt(np.sum((yests-ys)**2)/len(ys))
        dfs_boot = get_estimate_c_errors(full_dfp7_small,passages_fit = [0,1])
        
        df=pd.DataFrame(data={'species-env':sp_env, 'c_ests':c_est, 'xs':xs,'ys':ys,
                              'ys_min':ys_min, 'ys_max':ys_max,
                             # 'ys_min': xs_min,  'ys_max': xs_max, 
                              'rmse':rmse,
                              'passages':passages}).set_index('passages')
    
       # df['ys_max']=np.nan
        #df['ys_min']=np.nan
        passg = df.index.values
       # print(passg)
#        df['ys_est']=df['c_ests']+df['xs']
        df['ys_est']=df['c_ests']+df['xs']
        df.loc[passg,'ys_est_max']=dfs_boot.groupby('passages').max().loc[passg,'ys_est']
        df.loc[passg,'ys_est_min']=dfs_boot.groupby('passages').min().loc[passg,'ys_est']
        big_df.append(df.reset_index())
   # print(c_est)

   # print(sp_env)


c_ests_df = pd.DataFrame(data={'species-env':sp_envs, 'c_ests':c_ests})
big_df = pd.concat(big_df)
big_df.head()
print(len(big_df))
# Out:
# 96

# %%
big_df
# Out:
#     passages       species-env    c_ests         xs        ys    ys_min  \
# 0          0  100099-mBHI-mBHI -0.340903  -0.896382 -1.014172 -0.970554
# 1          1  100099-mBHI-mBHI -0.340903  -1.670262 -2.234279 -2.177022
# 2          2  100099-mBHI-mBHI -0.340903  -6.422085 -3.104346 -2.706974
# 3          3  100099-mBHI-mBHI -0.340903  -8.693197 -3.948604 -3.704250
# 4          4  100099-mBHI-mBHI -0.340903 -11.483713 -2.697239 -2.697239
# ..       ...               ...       ...        ...       ...       ...
# 3          3  103656-mGAM-mGAM -0.236941  -3.402931 -6.253431 -6.180376
# 4          4  103656-mGAM-mGAM -0.236941  -1.068019 -4.384015 -4.182424
# 5          5  103656-mGAM-mGAM -0.236941  -5.735951 -4.495690 -4.219987
# 6          6  103656-mGAM-mGAM -0.236941  -2.839131 -6.081154 -5.255903
# 7          7  103656-mGAM-mGAM -0.236941  -3.355575 -6.906596 -6.906587
#
#       ys_max      rmse     ys_est  ys_est_max  ys_est_min
# 0  -1.057790  6.127893  -1.237286   -0.981288   -1.325647
# 1  -2.291535  6.127893  -2.011165   -2.019440   -2.322687
# 2  -3.501719  6.127893  -6.762988   -5.459324   -7.865521
# 3  -4.192958  6.127893  -9.034101   -7.389706   -9.216355
# 4  -2.697239  6.127893 -11.824617   -9.893097  -11.881871
# ..       ...       ...        ...         ...         ...
# 3  -6.326487  2.548556  -3.639872   -2.291560   -3.475440
# 4  -4.585606  2.548556  -1.304960    0.785299   -1.449295
# 5  -4.771392  2.548556  -5.972892   -4.117863   -6.012794
# 6  -6.906405  2.548556  -3.076072   -1.124170   -6.875725
# 7  -6.906606  2.548556  -3.592516   -1.205010   -4.296677
#
# [96 rows x 11 columns]

# %%
big_df
# Out:
#     passages       species-env    c_ests         xs        ys    ys_min  \
# 0          0  100099-mBHI-mBHI -0.340903  -0.896382 -1.014172 -0.970554
# 1          1  100099-mBHI-mBHI -0.340903  -1.670262 -2.234279 -2.177022
# 2          2  100099-mBHI-mBHI -0.340903  -6.422085 -3.104346 -2.706974
# 3          3  100099-mBHI-mBHI -0.340903  -8.693197 -3.948604 -3.704250
# 4          4  100099-mBHI-mBHI -0.340903 -11.483713 -2.697239 -2.697239
# ..       ...               ...       ...        ...       ...       ...
# 3          3  103656-mGAM-mGAM -0.236941  -3.402931 -6.253431 -6.180376
# 4          4  103656-mGAM-mGAM -0.236941  -1.068019 -4.384015 -4.182424
# 5          5  103656-mGAM-mGAM -0.236941  -5.735951 -4.495690 -4.219987
# 6          6  103656-mGAM-mGAM -0.236941  -2.839131 -6.081154 -5.255903
# 7          7  103656-mGAM-mGAM -0.236941  -3.355575 -6.906596 -6.906587
#
#       ys_max      rmse     ys_est  ys_est_max  ys_est_min
# 0  -1.057790  6.127893  -1.237286   -0.981288   -1.325647
# 1  -2.291535  6.127893  -2.011165   -2.019440   -2.322687
# 2  -3.501719  6.127893  -6.762988   -5.459324   -7.865521
# 3  -4.192958  6.127893  -9.034101   -7.389706   -9.216355
# 4  -2.697239  6.127893 -11.824617   -9.893097  -11.881871
# ..       ...       ...        ...         ...         ...
# 3  -6.326487  2.548556  -3.639872   -2.291560   -3.475440
# 4  -4.585606  2.548556  -1.304960    0.785299   -1.449295
# 5  -4.771392  2.548556  -5.972892   -4.117863   -6.012794
# 6  -6.906405  2.548556  -3.076072   -1.124170   -6.875725
# 7  -6.906606  2.548556  -3.592516   -1.205010   -4.296677
#
# [96 rows x 11 columns]

# %%
big_df['ys_linear']= 1/(1+np.exp(-big_df['ys_est']))
big_df['ys_est_linear'] = 1/(1+np.exp(-big_df['ys']))
big_df['error']=big_df['ys_linear']-big_df['ys_est_linear']
print(len(big_df['species-env'].unique()))
# Out:
# 13

# %%
big_df.sort_values(by='error',ascending=False)
len(big_df['species-env'].unique())
# Out:
# 13

# %%
frequencies, edges = np.histogram(big_df['error'].values,bins=20)
#print('Values: %s, Edges: %s' % (frequencies.shape[0], edges.shape[0]))
p=hv.Histogram((edges, frequencies)).opts(width=400, xlabel='Obs Freq - Pred Freq', 
                                        ylabel='Counts',fill_color= bokeh.palettes.Bright[6][1]
                                       )
p=hv.render(p)
p.yaxis.visible = False

p.output_backend='svg'
p.xaxis.axis_label_text_font_size='20px'
p.xaxis.major_label_text_font_size='15px'
bokeh.io.show(p)
export_plot_pdf(p, 'trans_error')
# Out:
#   <div id="ff1bea5d-81d1-4a78-ac09-2be8c5b250e5" data-root-id="869974ee-5ef3-451d-bd82-8519ecb1b3e8" style="display: contents;"></div>
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)

# %%
def ecdf_transform(data):
    return 1- data.rank(method="first") / len(data)

big_df['error_abs']=big_df['error'].abs()
big_df.loc[:, "error ECDF"] = big_df[
    "error_abs"
].transform(ecdf_transform)



p3=hv.Scatter(
    data=big_df,
    kdims='error_abs',
    vdims=[('error ECDF', 'ECDF')],
).opts(color = bokeh.palettes.Bright[6][1], #,bokeh.palettes.Bright[6][4],bokeh.palettes.Vibrant[7][-1]],
       width=400,height=400,xlabel='Obs Freq- Pred Freq',#legend_position='right',
      ylabel='1-CDF',size=5,xlim=(-0.05,1))
p3=hv.render(p3)
p3.yaxis.major_label_text_font_size='20px'
p3.xaxis.major_label_text_font_size='20px'
p3.output_backend='svg'
export_plot_pdf(p3,'trans_error_cdf')
bokeh.io.show(p3)
# Out:
#   <div id="afd4d3f0-069a-462c-8e53-24b8ac5bcb3d" data-root-id="e4b44ce2-2dc3-44b9-b50c-c469036d0212" style="display: contents;"></div>

# %%
big_df['species_id']=big_df['species-env'].transform(lambda x: x.split('-')[0])
big_df['species_id'].unique()
# Out:
# array(['100099', '100146', '101294', '102438', '103656'], dtype=object)

# %%
import os
inos=['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
inos = ['AE-AF-mGAM','AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
name_dic = {'100099':'Flavonifractor plautii',
            '100146':'Dorea formicigenerans',
            '100196': 'Bacteroides thetaiotaomicron',
            '101294': 'Parasutterella excrementihominis',
            '101346': 'Bacteroides uniformis',
            '102438': 'Parabacteroides distasonis',
            '102478': 'Bacteroides dorei',
            '102506': 'Escherichia coli',
            '103656': 'Acutalibacteraceae sp'}
            
#inos = ['AA-AF-mGAM']
1#inos = ['AE-AF-mBHI']
species = [102438,100196, 100099, 100146, 101346, 102506, 102478]
species = [102478]

#species = [101294]
inos=['AA-AF-mGAM','AA-AF-mBHI']
for sp in big_df['species_id'].unique():
    plots_all=[]
    for ino in inos:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
        if f'{sp}-{ino}' in bad_inos:
            continue
        if not os.path.isfile(fname):
            print('pop')
            print('oo')
            continue
        psstrain,type_mesos = make_logit_plot(sp, ino,
                                       colorby='const',useboth=True,logit=False,
                                        )
      #  print(psstrain)
        for i in range(len(psstrain)):
            p1 = psstrain[i]
            meso = type_mesos[i]
            med1=meso.split('-')[-2]
            med2 = meso.split('-')[-1]
            ino1 = f'{sp}-{med1}-{med2}'
            p1.legend.visible=False
            preds = big_df.loc[big_df['species-env']==ino1,:]
          #  print(preds)
            if len(preds)>1:
               # preds = big_df.loc[big_df['species-env']==ino1,:]
                preds['ys_est_linear'] = 1/(1+np.exp(-preds['ys_est']))
                preds['ys_estmin_linear'] = 1/(1+np.exp(-preds['ys_est_min']))
                preds['ys_estmax_linear'] = 1/(1+np.exp(-preds['ys_est_max']))
                p1.line(preds['passages'],preds['ys_est_linear'],color='grey')
                p1.circle(preds['passages'],preds['ys_est_linear'],color='grey',size=5)
                p1.line(preds['passages'],preds['ys_estmin_linear'],color='grey',line_dash='dashed')
                p1.line(preds['passages'],preds['ys_estmax_linear'],color='grey',line_dash='dashed')
                p1.output_backend = "svg"

                p2s,_= make_logit_plot(sp, f'AA-AE-{med1}',
                                       colorby='const',
                                         medias = [med2],useboth=True,logit=False,
                                        )
              #  print(p2s)
                p2=p2s[0]
                p3s,_= make_logit_plot(sp, f'AE-AF-{med1}',
                                       colorby='const',
                                         medias = [med2],useboth=True,logit=False,
                                        )
                p3=p3s[0]
                p2.legend.visible=False
                p1.legend.visible=False
                p3.legend.visible=False
                p2.output_backend = "svg"
                p3.output_backend='svg'
                grid = bokeh.layouts.gridplot([p2,p3,p1],ncols=3)
                bokeh.io.show(grid)
                fname_prefix = f'{sp}_{ino}_{med2}_transitive'

                plot_fname_svg=f'plots/{fname_prefix}.svg'
                plot_fname_pdf=f'plots/{fname_prefix}.pdf'
                bokeh.io.export_svg(grid,filename=plot_fname_svg)
                convert_scripts = f'rsvg-convert -f pdf -o {plot_fname_pdf} {plot_fname_svg}' 
                os.system(convert_scripts)
# Out:
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="b1229a96-6b35-4976-9092-e054a0b6c354" data-root-id="0828ca79-3269-4150-a3b2-69b8eb0d1bdd" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="a9babc57-0ac3-4996-88b4-e58633ec420a" data-root-id="8864d487-c6aa-43fb-842b-a242fa9ac658" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="a579d5d4-dc05-456e-8503-c8a35303f4ae" data-root-id="faf6e841-cdaf-443b-82aa-ecb04129dd71" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="bd5467f1-e5f1-4f8a-8282-e21d15f17933" data-root-id="aac20d67-106e-4536-8d47-553b93d0496f" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="e5f5edd9-523f-411e-b655-c00a12d591bd" data-root-id="006d9892-cefd-4d43-b46d-c078f7ab5297" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="f8ad9374-cbcb-457d-bcda-f682af03fc6d" data-root-id="0d0d9242-2c88-4b76-9830-2439fb537a85" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="e2136088-6244-427e-a8e3-57b7a3873c37" data-root-id="b49387d7-014d-45dd-b85a-76b47cdfa091" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="a2be0ffc-a5e4-41fa-bb7c-d6436b4c82dd" data-root-id="a17fc052-dd47-4f3d-9e7b-4162ca26611e" style="display: contents;"></div>
# pop
# oo
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="a64fe92a-5bc1-43b9-8a5b-6ed12f5fe0b8" data-root-id="bfeaa1fe-5193-43b0-82c4-b9fa7519a407" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="d9b143c7-9ff2-48f5-a7f7-2b3e91de74f0" data-root-id="87816bce-4c3c-4445-83a1-ec6766d3bc7a" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="b39c7dad-4f9c-4533-bab7-6f040640b477" data-root-id="5f5a4708-24f0-410a-bcd7-e8ec732ab8a2" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="db4c566d-451f-4955-8cc9-d44dfc28ad08" data-root-id="8893a9b1-47f7-44c9-9e9d-c208bb89725e" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="ae410c1a-883a-40b9-bba7-e2f319c3d0a8" data-root-id="458c97a0-6525-4336-befd-ca731906adde" style="display: contents;"></div>
# pop
# oo

# %%
df_metadata = pd.read_csv('~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv',delimiter='\t')
df_metadata['sp_name']=df_metadata['Lineage'].transform(lambda x: x.split(';')[-1])
df_metadata['genus_name']=df_metadata['Lineage'].transform(lambda x: x.split(';')[-2])
df_metadata['family_name']=df_metadata['Lineage'].transform(lambda x: x.split(';')[-3])
df_metadata.loc[df_metadata['species_id'].astype(int).isin([102438,100196,103656, 100099, 100146, 101346, 102506, 102478,102358,101294]),
:]
# Out:
#       species_id    representative MGnify_accession  species_closest  \
# 98        100099  GUT_GENOME000518  MGYG-HGUT-00099         100090.0
# 145       100146  GUT_GENOME000706  MGYG-HGUT-00146         100206.0
# 195       100196  GUT_GENOME001120  MGYG-HGUT-00196         102281.0
# 1293      101294  GUT_GENOME095941  MGYG-HGUT-01294         103352.0
# 1345      101346  GUT_GENOME096083  MGYG-HGUT-01346         100057.0
# 2357      102358  GUT_GENOME141754  MGYG-HGUT-02358              NaN
# 2437      102438  GUT_GENOME143131  MGYG-HGUT-02438         100221.0
# 2477      102478  GUT_GENOME143505  MGYG-HGUT-02478         100243.0
# 2505      102506  GUT_GENOME144544  MGYG-HGUT-02506         102323.0
# 3655      103656  GUT_GENOME238522  MGYG-HGUT-03656         101760.0
#
#       ani_closest  gtpro_kmer_counts  phyeco_marker_counts  phyeco_pass_ratio  \
# 98       82.28345            21694.0                  15.0                1.0
# 145      84.52855            38018.0                  15.0                1.0
# 195      88.95435            15304.0                  15.0                1.0
# 1293     91.01130             5131.0                  15.0                1.0
# 1345     91.28060             2814.0                  15.0                1.0
# 2357          NaN                NaN                  15.0                1.0
# 2437     77.90225            23623.0                  15.0                1.0
# 2477     81.27660              227.0                  15.0                1.0
# 2505     92.16920            99776.0                  15.0                1.0
# 3655     78.96165            92100.0                  15.0                1.0
#
#       pangene_counts  genome_counts  ... N_contigs      N50  GC_content  \
# 98             99015            635  ...        26   451145       60.00
# 145            74205            146  ...        33   363061       41.17
# 195           173878            572  ...        84   188408       43.19
# 1293           65133            727  ...        96    72548       48.55
# 1345          617984           5983  ...        62   149898       46.38
# 2357            2594              1  ...       147    32277       38.92
# 2437          351726           4702  ...         3  3389137       45.27
# 2477          704501           5750  ...         1  5444912       42.04
# 2505          731187           8288  ...         2  5168620       50.58
# 3655          215489            956  ...        21   222044       53.15
#
#       Completeness  Contamination  \
# 98           99.33           0.13
# 145          99.42           0.00
# 195          99.41           0.00
# 1293        100.00           0.11
# 1345         99.26           0.00
# 2357         99.84           1.48
# 2437         99.42           0.00
# 2477         99.25           0.00
# 2505         99.97           0.04
# 3655         98.66           0.00
#
#                                                 Lineage      Continent  \
# 98    d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...  North America
# 145   d__Bacteria;p__Firmicutes_A;c__Clostridia;o__L...         Europe
# 195   d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...           Asia
# 1293  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...            NaN
# 1345  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...            NaN
# 2357  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...           Asia
# 2437  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...           Asia
# 2477  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...         Europe
# 2505  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...            NaN
# 3655  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...  North America
#
#                                   sp_name          genus_name  \
# 98              s__Flavonifractor plautii   g__Flavonifractor
# 145              s__Dorea formicigenerans            g__Dorea
# 195       s__Bacteroides thetaiotaomicron      g__Bacteroides
# 1293  s__Parasutterella excrementihominis   g__Parasutterella
# 1345             s__Bacteroides uniformis      g__Bacteroides
# 2357                  s__Pelistega indica        g__Pelistega
# 2437        s__Parabacteroides distasonis  g__Parabacteroides
# 2477               s__Bacteroides_B dorei    g__Bacteroides_B
# 2505                s__Escherichia coli_D      g__Escherichia
# 3655               s__UBA1417 sp003531055          g__UBA1417
#
#                 family_name
# 98      f__Oscillospiraceae
# 145      f__Lachnospiraceae
# 195       f__Bacteroidaceae
# 1293    f__Burkholderiaceae
# 1345      f__Bacteroidaceae
# 2357    f__Burkholderiaceae
# 2437      f__Tannerellaceae
# 2477      f__Bacteroidaceae
# 2505  f__Enterobacteriaceae
# 3655  f__Acutalibacteraceae
#
# [10 rows x 22 columns]

# %%
big_df['species_id'].unique()
# Out:
# array(['100099', '100146', '101294', '102438', '103656'], dtype=object)

# %%
import os
inos=['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
inos = ['AE-AF-mGAM','AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]

#inos = ['AA-AF-mGAM']
1#inos = ['AE-AF-mBHI']
species = [102438,100196, 100099, 100146, 101346, 102506, 102478]
species = [102438,100196, 100099, 100146, 101346, 102506, 102478,102358,101294,103656,]
species = [103656]
inos=['AA-AF-mGAM','AA-AF-mBHI']
for sp in big_df['species_id'].unique():
    plots_all=[]
    for ino in inos:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
        if f'{sp}-{ino}' in bad_inos:
            continue
        if not os.path.isfile(fname):
            #print('oo')
            continue
        psstrain,type_mesos = make_logit_plot(sp, ino,useboth=True,
                                       colorby='const',logit=False,
                                        )
      #  print(psstrain)
        for i in range(len(psstrain)):
            p1 = psstrain[i]
            meso = type_mesos[i]
            med1=meso.split('-')[-2]
            med2 = meso.split('-')[-1]
            ino1 = f'{sp}-{med1}-{med2}'
            p1.legend.visible=False
            preds = big_df.loc[big_df['species-env']==ino1,:]
            preds['ys_est_linear'] = 1/(1+np.exp(-preds['ys_est']))
            preds['ys_estmin_linear'] = 1/(1+np.exp(-preds['ys_est_min']))
            preds['ys_estmax_linear'] = 1/(1+np.exp(-preds['ys_est_max']))
                      #  print(preds)
            if len(preds)>0:
                p1.line(preds['passages'],preds['ys_est_linear'],color='grey')
                p1.circle(preds['passages'],preds['ys_est_linear'],color='grey',size=5)
                p1.line(preds['passages'],preds['ys_estmin_linear'],color='grey',line_dash='dashed')
                p1.line(preds['passages'],preds['ys_estmax_linear'],color='grey',line_dash='dashed')
                p1.output_backend = "svg"

                p2s,_= make_logit_plot(sp, f'AA-AE-{med1}',
                                       colorby='const',
                                         medias = [med2],logit=False,
                                        )
                p2=p2s[0]
                p3s,_= make_logit_plot(sp, f'AE-AF-{med1}',
                                       colorby='const',
                                         medias = [med2],logit=False,
                                        )
                if len(p3s)==0:
                    continue
                p3=p3s[0]
                p2.legend.visible=False
                p1.legend.visible=False
                p3.legend.visible=False
                for p in [p1,p2,p3]:
                    p.yaxis.axis_label_text_font_style = 'normal'
                    p.xaxis.axis_label_text_font_style = 'normal'
                    p.legend.visible=False
                p2.output_backend = "svg"
                p3.output_backend='svg'
                p2.title.text = name_dic[sp]
                p2.title.text_font_style='italic'
                p2.title.text_font_size='22px'
                grid = bokeh.layouts.gridplot([p2,p3,p1],ncols=3)
                
                bokeh.io.show(p1)
                fname_prefix = f'{sp}_{ino}_{med2}_transitive_linear'

                plot_fname_svg=f'plots/trans_plots/{fname_prefix}.svg'
                plot_fname_pdf=f'plots/trans_plots/{fname_prefix}.pdf'
                bokeh.io.export_svg(grid,filename=plot_fname_svg)
                
                convert_scripts = f'rsvg-convert -f pdf -o {plot_fname_pdf} {plot_fname_svg}' 
                os.system(convert_scripts)
# Out:
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="ace24cde-4b9d-4a8e-bc5b-e4469954ae94" data-root-id="3b2b7fd9-d49a-4221-8530-d1f0115887c0" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="c6a309e3-5271-46a2-b90d-27cb5a9fd755" data-root-id="9b8300cb-b6e1-4113-af38-8f912f5009cb" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="b2820d22-8d83-4895-9974-f76a19a460ee" data-root-id="b4da0137-a2f7-4c2a-b567-3e8dee923ae1" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="ea3f6bab-1f33-47da-9655-7a1fde552e3b" data-root-id="682bc784-6994-4cbd-9790-d0f50631ab91" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="e18473fb-9350-42a0-ae20-8c38d230934d" data-root-id="4a6b0179-6290-47f0-8d43-2035f6f9a25d" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="dc1cbd4b-cb2e-4743-9267-697ca406b095" data-root-id="553ede39-06f4-4df6-881a-77ead1cf74d8" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="e41e1607-e23a-4613-93f8-4717df9c65f8" data-root-id="4ad13dbd-a651-47b0-aab3-92d1a2b63d1d" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="b3f76487-5823-4d0c-a686-12b27152e3dc" data-root-id="e58c9834-409a-4850-853b-47dd87ced64e" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="f9d9b935-2cdf-47f4-b846-14ca2e42951a" data-root-id="a6c30eea-4dcd-4397-8ebf-90daae49cbc8" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="c7b42589-06b3-4fc1-a487-8d3306b03617" data-root-id="fd558c85-07fd-4124-9efa-7518f3c0a502" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="a0994612-7f77-43e8-bb6d-ea367acb3bde" data-root-id="54283bac-6c9a-4ec7-bb1c-51cde6bcb4cc" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="f018e103-e53f-42c7-84d1-6d3cf6c94212" data-root-id="2f6a7ff0-cb3c-4923-bb83-0e3591571fa8" style="display: contents;"></div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="e1fcb674-f77d-4dca-8863-c5ddaba4c926" data-root-id="e31a19a9-45ec-4260-aa9c-021089eeaa20" style="display: contents;"></div>

# %%
bokeh.palettes.Set2[8][2]
# Out:
# '#8da0cb'

# %%
big_df
# Out:
#     passages       species-env    c_ests         xs        ys    ys_min  \
# 0          0  100099-mBHI-mBHI -0.340903  -0.896382 -1.014172 -0.970554
# 1          1  100099-mBHI-mBHI -0.340903  -1.670262 -2.234279 -2.177022
# 2          2  100099-mBHI-mBHI -0.340903  -6.422085 -3.104346 -2.706974
# 3          3  100099-mBHI-mBHI -0.340903  -8.693197 -3.948604 -3.704250
# 4          4  100099-mBHI-mBHI -0.340903 -11.483713 -2.697239 -2.697239
# ..       ...               ...       ...        ...       ...       ...
# 3          3  103656-mGAM-mGAM -0.236941  -3.402931 -6.253431 -6.180376
# 4          4  103656-mGAM-mGAM -0.236941  -1.068019 -4.384015 -4.182424
# 5          5  103656-mGAM-mGAM -0.236941  -5.735951 -4.495690 -4.219987
# 6          6  103656-mGAM-mGAM -0.236941  -2.839131 -6.081154 -5.255903
# 7          7  103656-mGAM-mGAM -0.236941  -3.355575 -6.906596 -6.906587
#
#       ys_max      rmse     ys_est  ys_est_max  ys_est_min  ys_linear  \
# 0  -1.057790  6.127893  -1.237286   -0.981288   -1.325647   0.224909
# 1  -2.291535  6.127893  -2.011165   -2.019440   -2.322687   0.118036
# 2  -3.501719  6.127893  -6.762988   -5.459324   -7.865521   0.001154
# 3  -4.192958  6.127893  -9.034101   -7.389706   -9.216355   0.000119
# 4  -2.697239  6.127893 -11.824617   -9.893097  -11.881871   0.000007
# ..       ...       ...        ...         ...         ...        ...
# 3  -6.326487  2.548556  -3.639872   -2.291560   -3.475440   0.025584
# 4  -4.585606  2.548556  -1.304960    0.785299   -1.449295   0.213331
# 5  -4.771392  2.548556  -5.972892   -4.117863   -6.012794   0.002540
# 6  -6.906405  2.548556  -3.076072   -1.124170   -6.875725   0.044105
# 7  -6.906606  2.548556  -3.592516   -1.205010   -4.296677   0.026791
#
#     ys_est_linear     error  error_abs  error ECDF species_id
# 0        0.266164 -0.041255   0.041255    0.395833     100099
# 1        0.096714  0.021321   0.021321    0.583333     100099
# 2        0.042928 -0.041774   0.041774    0.385417     100099
# 3        0.018917 -0.018798   0.018798    0.614583     100099
# 4        0.063136 -0.063129   0.063129    0.302083     100099
# ..            ...       ...        ...         ...        ...
# 3        0.001920  0.023664   0.023664    0.552083     103656
# 4        0.012321  0.201010   0.201010    0.104167     103656
# 5        0.011034 -0.008493   0.008493    0.729167     103656
# 6        0.002280  0.041825   0.041825    0.375000     103656
# 7        0.001000  0.025791   0.025791    0.541667     103656
#
# [96 rows x 17 columns]

# %%
big_df['ys_linear']=1/(1+np.exp(-big_df['ys']))
big_df['ys_est_linear_max']=1/(1+np.exp(-big_df['ys_est_max']))
big_df['ys_est_linear_min']=1/(1+np.exp(-big_df['ys_est_min']))

big_df['ys_linear_max']=1/(1+np.exp(-big_df['ys_max']))
big_df['ys_linear_min']=1/(1+np.exp(-big_df['ys_min']))

# %%
good=big_df.loc[(big_df['ys_linear_max']>(big_df['ys_est_linear_max'] + .05))+\
        (big_df['ys_linear_min']<(big_df['ys_est_linear_min']-.05)),:]

good = good.loc[good['passages']>0,:]
len(good['species-env'].unique())
# Out:
# 7

# %%
len(big_df.loc[big_df['passages']>0,'species-env'].unique())
# Out:
# 13
