# %%
import pandas as pd
import numpy as np
import iqplot


import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='305a8ffe-0ccc-4907-a146-80719555c784'>
#   <div id="b30a1695-1f03-4a7b-bd60-2c2ece4dc87b" data-root-id="305a8ffe-0ccc-4907-a146-80719555c784" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/species/species_relative_abundance.tsv'
df_abundance = pd.read_csv(fname, delimiter = '\t')
df_abundance
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_abundance_melted = pd.melt(df_abundance, 
                                  var_name = 'sample', 
                                  id_vars='species_id',
                                  value_name = 'relative_abundance')


df_abundance_melted = transform_df(df_abundance_melted)
df_abundance_melted.head()

# %%
df_abundance_melted

# %%
def make_stacked_bar_plot(df, cmap_dict, taxa_level = 'species'):
    top_species = list(cmap_dict.keys())
    #df['passage'] = df['sample'].transform(lambda x: int(x.split('-')[-1][-1]))
    df_small = df.loc[df['species'].isin(top_species),:]
   # val = df_small.loc[df_small['species'] != 's__','relative_abundance'].sum()
    #print(val)

    
   # df_small.loc[df_small['species'] == 's__', 'relative_abundance'] = 1- val 

   # print('yay', df_small.loc[df_small['species'] == 's__', 'relative_abundance'])
  #  print(df_small.loc[df_small['species'] == 's__', 'relative_abundance'])
    df_small = df_small.groupby(['species']).median().reset_index()
    val = df_small.loc[df_small['species'] != 's__','relative_abundance'].sum()
 #   print(val)
    df_small.loc[df_small['species'] == 's__', 'relative_abundance'] = 1- val 
    
    #print(df_small.loc[df_small['species'] == 's__', 'relative_abundance'])
   # print(df_small['relative_abundance'].sum())
  #  print(df_small.sort_values(by='passage'))
    bars = hv.Bars(df_small , kdims=['passage','species'],
               vdims = ['relative_abundance'])

    bars.opts(width=400,height = 800, ).opts(stacked=True, xrotation = 90,cmap = cmap_dict)

    bars.opts(legend_position='left')
    return bars

# %%
def make_stacked_bar_plot(df, cmap_dict, taxa_level = 'species'):
    top_species = list(cmap_dict.keys())
    #df['passage'] = df['sample'].transform(lambda x: int(x.split('-')[-1][-1]))
    df_small = df.loc[df['species'].isin(top_species),:]
   # val = df_small.loc[df_small['species'] != 's__','relative_abundance'].sum()
    #print(val)

    
   # df_small.loc[df_small['species'] == 's__', 'relative_abundance'] = 1- val 

   # print('yay', df_small.loc[df_small['species'] == 's__', 'relative_abundance'])
  #  print(df_small.loc[df_small['species'] == 's__', 'relative_abundance'])
    df_small = df_small.groupby(['species']).median().reset_index()
    val = df_small.loc[df_small['species'] != 's__','relative_abundance'].sum()
 #   print(val)
    df_small.loc[df_small['species'] == 's__', 'relative_abundance'] = 1- val 
    
    #print(df_small.loc[df_small['species'] == 's__', 'relative_abundance'])
   # print(df_small['relative_abundance'].sum())
  #  print(df_small.sort_values(by='passage'))
  #  print(df_small['species'].unique())
    bars = hv.Bars(df_small , kdims=['passage','species'],
               vdims = ['relative_abundance'])

    bars.opts(width=500,height = 900, ).opts(stacked=True, xrotation = 90,cmap = cmap_dict)

    bars.opts(legend_position='left')
    bars = hv.render(bars)
    bars.y_range = bokeh.models.Range1d(0, 1)
    return bars

# %% [markdown]
# ## make major families colormap

# %%
 bokeh.palettes.varying_alpha_palette(bokeh.palettes.Reds[9][1],20)

# %%
e003_metadata = pd.read_csv('e003_metadata_cultures_round2.csv').drop(columns = 'Unnamed: 0')
df_abundance_melted_coal = df_abundance_melted.loc[df_abundance_melted['sample'].isin(e003_metadata['sample'].values),:]
df_abundance_melted_coal = df_abundance_melted_coal.loc[df_abundance_melted_coal['relative_abundance']>.01,:]
df_abundance_melted_coal_abundant_families = df_abundance_melted_coal.groupby(['family']).sum().sort_values(by='relative_abundance',
                                                                                                            ascending=False)

df_abundance_melted_coal['family_sp'] = df_abundance_melted_coal['family'] + '-' + df_abundance_melted_coal['species']
df_abundance_melted_coal_abundant_families

family_palettes = {'f__Bacteroidaceae': bokeh.palettes.PuRd[9],
                   'f__Enterobacteriaceae': bokeh.palettes.Category20c[20][:4],
                   'f__Porphyromonadaceae': bokeh.palettes.Category20c[20][4:8],
                   'f__Oscillospiraceae': bokeh.palettes.Category20c[20][8:12],
                   'f__Peptoniphilaceae': bokeh.palettes.Category20c[20][12:16],
                   'f__Tannerellaceae': bokeh.palettes.Category20b[20][8:12],
                   'f__Enterococcaceae':bokeh.palettes.Category20b[20][12:16],
                   'f__Lachnospiraceae': bokeh.palettes.varying_alpha_palette(bokeh.palettes.Reds[9][1],20),
                   'f__Veillonellaceae':bokeh.palettes.Category20b[20][4:8],
                   'f_other':bokeh.palettes.Accent[4],
}







def make_stacked_bar_plot_family(rel_abundance, cmap_dict,  good_fam,show_legend=False):
    rel_abundance_adjust = rel_abundance.copy()
    rel_abundance_adjust.loc[~rel_abundance_adjust['family'].isin(good_fam),'family'] = 'f_other'
    rel_abundance_adjust_gr = rel_abundance_adjust.groupby(['sample','passage','family']).sum().reset_index()
    val = rel_abundance_adjust_gr.loc[rel_abundance_adjust_gr['family'] != 'f_other','relative_abundance'].sum()
    rel_abundance_adjust_gr.loc[rel_abundance_adjust_gr['family'] == 'f_other', 'relative_abundance'] = 1- val 
    
    rel_abundance_adjust_gr = rel_abundance_adjust_gr.sort_values(by='family')
    rel_abundance_adjust = rel_abundance_adjust.sort_values(by='family')
    rel_abundance_adjust_gr['passage'] = rel_abundance_adjust_gr['passage'].astype(str)
    
    bars = hv.Bars(rel_abundance_adjust_gr, kdims=['passage','family'],
               vdims = ['relative_abundance'])

    bars.opts(width=500,height = 900, ).opts(stacked=True, xrotation = 90,cmap = cmap_dict,
                                            show_legend=show_legend)

    bars.opts(legend_position='left')
    #bars = hv.render(bars) 
    #bars.y_range = bokeh.models.Range1d(0, 1)
    return bars

# %%
family_colors = {'f__Bacteroidaceae': bokeh.palettes.PuRd[9][0],
                   'f__Enterobacteriaceae': bokeh.palettes.Category20c[20][:4][0],
                   'f__Porphyromonadaceae': bokeh.palettes.Category20c[20][4:8][0],
                   'f__Oscillospiraceae': bokeh.palettes.Category20c[20][8:12][0],
                   'f__Peptoniphilaceae': bokeh.palettes.Category20c[20][12:16][0],
                   'f__Tannerellaceae': bokeh.palettes.Category20b[20][8:12][0],
                   'f__Enterococcaceae':bokeh.palettes.Category20b[20][12:16][0],
                   'f__Lachnospiraceae': bokeh.palettes.Reds[9][1],
                   'f__Veillonellaceae':bokeh.palettes.Category20b[20][4:8][0],
                   'f_other':bokeh.palettes.Accent[4][-1],
}


family_colors = {'f__Bacteroidaceae': bokeh.palettes.Muted[9][-1],
                   'f__Enterobacteriaceae': bokeh.palettes.Muted[8][1],
                   'f__Porphyromonadaceae': bokeh.palettes.Muted[8][2],
                   'f__Oscillospiraceae': bokeh.palettes.Muted[8][3],
                   'f__Peptoniphilaceae': bokeh.palettes.Muted[8][4],
                   'f__Tannerellaceae': bokeh.palettes.Muted[8][5],
                   'f__Enterococcaceae':bokeh.palettes.Muted[8][6],
                   'f__Lachnospiraceae': bokeh.palettes.Muted[8][0],
                   'f__Veillonellaceae':bokeh.palettes.Muted[8][7],
                   'f_other':bokeh.palettes.Light[9][-1],
}

# %%
family_colors
# Out:
# {'f__Bacteroidaceae': '#AA4499',
#  'f__Enterobacteriaceae': '#332288',
#  'f__Porphyromonadaceae': '#DDCC77',
#  'f__Oscillospiraceae': '#117733',
#  'f__Peptoniphilaceae': '#88CCEE',
#  'f__Tannerellaceae': '#882255',
#  'f__Enterococcaceae': '#44AA99',
#  'f__Lachnospiraceae': '#CC6677',
#  'f__Veillonellaceae': '#999933',
#  'f_other': '#DDDDDD'}

# %%
family_colors_colorblind = {'f__Bacteroidaceae': '#AA4499',
 'f__Enterobacteriaceae': '#332288',
 'f__Porphyromonadaceae': '#DDCC77',
 'f__Oscillospiraceae': '#117733',
 'f__Peptoniphilaceae': '#88CCEE',
 'f__Tannerellaceae': '#882255',
 'f__Enterococcaceae': '#44AA99',
 'f__Lachnospiraceae': '#CC6677',
 'f__Veillonellaceae': '#999933',
 'f_other': '#DDDDDD'}

# %%
def get_cmap_dict(rel_abundance, family, palette, cmap_dict = {}):
    rel_abundance_f = rel_abundance.loc[rel_abundance['family'] == family,:]
    good_sp = list(rel_abundance_f.groupby(['species']).max().sort_values(by='relative_abundance',ascending=False).index.values)
   # print(good_sp)
    if 's__' in good_sp:
        good_sp.remove('s__')
    good_sp = good_sp[:len(palette)-1]
   # print(np.sort(good_sp))
    for i, sp in enumerate(np.sort(good_sp)[::-1]):
        if sp == 's__':
            continue
        cmap_dict[f'{family}-{sp}']=palette[i]
        
    cmap_dict[f'{family}-s__'] = palette[-1]
    return cmap_dict,good_sp[:len(palette)-1]


def get_cmap_dict_linear(rel_abundance, family, primary_color, cmap_dict = {}):
    rel_abundance_f = rel_abundance.loc[rel_abundance['family'] == family,:]
    good_sp = rel_abundance_f.groupby(['species']).max().sort_values(by='relative_abundance',ascending=False)

    good_sp = list(good_sp.loc[good_sp['relative_abundance']>.01,:].index.values)
    
    if 's__' in good_sp:
        good_sp.remove('s__')
    
    print(len(good_sp))
    if len(good_sp) == 0:
        cmap_dict[f'{family}-s__'] = primary_color
        return cmap_dict,good_sp 
   # print(good_sp)
    palette = bokeh.palettes.varying_alpha_palette(primary_color, len(good_sp)+1,
                                                  100, 255)[::-1]
   # print(np.sort(good_sp))
    for i, sp in enumerate(np.sort(good_sp)):
        if sp == 's__':
            continue
        cmap_dict[f'{family}-{sp}']=palette[i+1]
        
    cmap_dict[f'{family}-s__'] = palette[0]
    return cmap_dict,good_sp


cmap_dict,good_sp= get_cmap_dict(df_abundance_melted_coal, 'f__Bacteroidaceae', bokeh.palettes.PuRd[9])


cmap_dict = {}
good_sp=[]
for family in list(family_colors.keys()):
    cmap_dict,good_sp_f = get_cmap_dict_linear(df_abundance_melted_coal, family, family_colors[family],
                             cmap_dict = cmap_dict)
    good_sp = good_sp + good_sp_f
    
good_fam = list(family_colors.keys())
# Out:
# 15
# 4
# 1
# 10
# 4
# 2
# 3
# 16
# 4
# 0

# %%
cmap_dict_color_blind = {'f__Bacteroidaceae-s__Bacteroides caccae': '#aa4499f5',
 'f__Bacteroidaceae-s__Bacteroides cellulosilyticus': '#aa4499ea',
 'f__Bacteroidaceae-s__Bacteroides eggerthii': '#aa4499e0',
 'f__Bacteroidaceae-s__Bacteroides faecis': '#aa4499d6',
 'f__Bacteroidaceae-s__Bacteroides fragilis': '#aa4499cb',
 'f__Bacteroidaceae-s__Bacteroides intestinalis': '#aa4499c1',
 'f__Bacteroidaceae-s__Bacteroides ovatus': '#aa4499b7',
 'f__Bacteroidaceae-s__Bacteroides salyersiae': '#aa4499ac',
 'f__Bacteroidaceae-s__Bacteroides sp002491635': '#aa4499a2',
 'f__Bacteroidaceae-s__Bacteroides stercoris': '#aa449998',
 'f__Bacteroidaceae-s__Bacteroides thetaiotaomicron': '#aa44998d',
 'f__Bacteroidaceae-s__Bacteroides uniformis': '#aa449983',
 'f__Bacteroidaceae-s__Bacteroides xylanisolvens': '#aa449979',
 'f__Bacteroidaceae-s__Bacteroides_B dorei': '#aa44996e',
 'f__Bacteroidaceae-s__Bacteroides_B massiliensis': '#aa449964',
 'f__Bacteroidaceae-s__': '#aa4499',
 'f__Enterobacteriaceae-s__Escherichia coli_D': '#332288cb',
 'f__Enterobacteriaceae-s__Escherichia fergusonii': '#33228898',
 'f__Enterobacteriaceae-s__Escherichia sp000208585': '#33228864',
 'f__Enterobacteriaceae-s__': '#332288',
 'f__Porphyromonadaceae-s__Porphyromonas somerae': '#ddcc7764',
 'f__Porphyromonadaceae-s__': '#ddcc77',
 'f__Oscillospiraceae-s__ER4 sp000765235': '#117733f0',
 'f__Oscillospiraceae-s__Flavonifractor plautii': '#117733e0',
 'f__Oscillospiraceae-s__Flavonifractor sp900199495': '#117733d1',
 'f__Oscillospiraceae-s__Intestinimonas butyriciproducens': '#117733c1',
 'f__Oscillospiraceae-s__Lawsonibacter asaccharolyticus': '#117733b2',
 'f__Oscillospiraceae-s__Lawsonibacter sp000177015': '#117733a2',
 'f__Oscillospiraceae-s__Lawsonibacter sp900066645': '#11773392',
 'f__Oscillospiraceae-s__Oscillibacter sp001916835': '#11773383',
 'f__Oscillospiraceae-s__Oscillibacter sp900066435': '#11773374',
 'f__Oscillospiraceae-s__Ruminiclostridium_C sp000435295': '#11773364',
 'f__Oscillospiraceae-s__': '#117733',
 'f__Peptoniphilaceae-s__Peptoniphilus_A harei': '#88cceed8',
 'f__Peptoniphilaceae-s__Peptoniphilus_A harei_A': '#88cceeb2',
 'f__Peptoniphilaceae-s__Peptoniphilus_A lacrimalis': '#88ccee8b',
 'f__Peptoniphilaceae-s__Peptoniphilus_B sp000478985': '#88ccee64',
 'f__Peptoniphilaceae-s__': '#88ccee',
 'f__Tannerellaceae-s__Parabacteroides distasonis': '#882255b2',
 'f__Tannerellaceae-s__Parabacteroides merdae': '#88225564',
 'f__Tannerellaceae-s__': '#882255',
 'f__Enterococcaceae-s__Enterococcus faecalis': '#44aa99cb',
 'f__Enterococcaceae-s__Enterococcus_B faecium': '#44aa9998',
 'f__Enterococcaceae-s__Enterococcus_B faecium_B': '#44aa9964',
 'f__Enterococcaceae-s__': '#44aa99',
 'f__Lachnospiraceae-s__Anaerostipes hadrus': '#cc6677f5',
 'f__Lachnospiraceae-s__Bariatricus massiliensis': '#cc6677ec',
 'f__Lachnospiraceae-s__Blautia_A hydrogenotrophica': '#cc6677e2',
 'f__Lachnospiraceae-s__CAG-81 sp900066055': '#cc6677d8',
 'f__Lachnospiraceae-s__CAG-81 sp900066535': '#cc6677cf',
 'f__Lachnospiraceae-s__Clostridium_M bolteae': '#cc6677c5',
 'f__Lachnospiraceae-s__Clostridium_M citroniae': '#cc6677bb',
 'f__Lachnospiraceae-s__Clostridium_Q symbiosum': '#cc6677b2',
 'f__Lachnospiraceae-s__Coprococcus_A catus': '#cc6677a8',
 'f__Lachnospiraceae-s__Coprococcus_B comes': '#cc66779e',
 'f__Lachnospiraceae-s__Dorea formicigenerans': '#cc667794',
 'f__Lachnospiraceae-s__Dorea longicatena_B': '#cc66778b',
 'f__Lachnospiraceae-s__Eisenbergiella sp900066775': '#cc667781',
 'f__Lachnospiraceae-s__Fusicatenibacter saccharivorans': '#cc667777',
 'f__Lachnospiraceae-s__Hungatella hathewayi': '#cc66776e',
 'f__Lachnospiraceae-s__Ruminococcus_A sp003011855': '#cc667764',
 'f__Lachnospiraceae-s__': '#cc6677',
 'f__Veillonellaceae-s__Veillonella atypica': '#999933cb',
 'f__Veillonellaceae-s__Veillonella parvula': '#99993398',
 'f__Veillonellaceae-s__Veillonella parvula_A': '#99993364',
 'f__Veillonellaceae-s__': '#999933',
 'f_other-s__': '#DDDDDD'}

# %%
all_e003 = pd.read_csv('assembly_sp_data.csv').drop(columns='Unnamed: 0')
cmap_dict_old = {'s__Bacteroides thetaiotaomicron': '#1f77b4',
 's__Bacteroides uniformis': '#aec7e8',
 's__Escherichia coli_D': '#ff7f0e',
 's__Porphyromonas somerae': '#ffbb78',
 's__Bacteroides stercoris': '#2ca02c',
 's__Peptoniphilus_A harei_A': '#98df8a',
 's__Agathobacter rectalis': '#d62728',
 's__Flavonifractor plautii': '#ff9896',
 's__Parabacteroides distasonis': '#9467bd',
 's__Bacteroides_B dorei': '#c5b0d5',
 's__Enterococcus_B faecium_B': '#8c564b',
 's__Enterococcus_B durans': '#c49c94',
 's__Lawsonibacter asaccharolyticus': '#e377c2',
 's__Enterococcus faecalis': '#f7b6d2',
 's__Peptoniphilus_A lacrimalis': '#7f7f7f',
 's__Veillonella parvula': '#c7c7c7',
 's__Blautia_A wexlerae': '#bcbd22',
 's__Ruminococcus_E bromii_B': '#dbdb8d',
 's__Veillonella parvula_A': '#17becf',
 's__': '#9edae5'}

# %%
def make_stacked_bar_plot_family_sp(rel_abundance, cmap_dict, good_sp, good_fam,show_legend=False):
    rel_abundance_adjust = rel_abundance.copy()
    rel_abundance_adjust.loc[~rel_abundance_adjust['family'].isin(good_fam),'family'] = 'f_other'
    rel_abundance_adjust.loc[~rel_abundance_adjust['species'].isin(good_sp),'species'] = 's__'
    rel_abundance_adjust.loc[rel_abundance_adjust['family']=='f_other','species'] = 's__'
    rel_abundance_adjust['family_sp'] = rel_abundance_adjust['family'] + '-' + rel_abundance_adjust['species']
    rel_abundance_adjust_gr = rel_abundance_adjust.groupby(['sample','passage','family_sp']).sum().reset_index()
    val = rel_abundance_adjust_gr.loc[rel_abundance_adjust_gr['family_sp'] != 'f_other-s__','relative_abundance'].sum()
    rel_abundance_adjust_gr.loc[rel_abundance_adjust_gr['family_sp'] == 'f_other-s__', 'relative_abundance'] = 1- val 
    
    rel_abundance_adjust_gr = rel_abundance_adjust_gr.sort_values(by='family_sp')
    rel_abundance_adjust = rel_abundance_adjust.sort_values(by='family_sp')
    rel_abundance_adjust['passage'] = rel_abundance_adjust['passage'].astype(str)
    bars = hv.Bars(rel_abundance_adjust, kdims=['passage',hv.Dimension('family_sp',range=(0,1))],
               vdims = ['relative_abundance'])

    bars.opts(width=200,height = 300, ).opts(stacked=True, xrotation = 0,cmap = cmap_dict,
                                            show_legend=show_legend,
                                            xlabel='Passage', ylabel='Rel. Abundance',
                                            ylim=(0, 1.))


    #bars = hv.render(bars) 
    #bars.y_range = bokeh.models.Range1d(0, 1)
    return bars



def make_stacked_bar_plot_family_sp_mult_passages(rel_abundance, cmap_dict, good_sp, 
                                                  good_fam,show_legend=False,
                                                 passages=[0,3,5]):
    rel_abundance_adjust = rel_abundance.copy()
    all_passages = []
    for passage in passages:
        rel_abundance_adjust = rel_abundance.loc[rel_abundance['passage'] == passage,:]
        if len(rel_abundance_adjust) == 0:
            continue 
        rel_abundance_adjust.loc[~rel_abundance_adjust['family'].isin(good_fam),'family'] = 'f_other'
        rel_abundance_adjust.loc[~rel_abundance_adjust['species'].isin(good_sp),'species'] = 's__'
        rel_abundance_adjust.loc[rel_abundance_adjust['family']=='f_other','species'] = 's__'
        rel_abundance_adjust['family_sp'] = rel_abundance_adjust['family'] + '-' + rel_abundance_adjust['species']
        rel_abundance_adjust_gr = rel_abundance_adjust.groupby(['sample','passage','family_sp']).sum().reset_index()
        val = rel_abundance_adjust_gr.loc[rel_abundance_adjust_gr['family_sp'] != 'f_other-s__','relative_abundance'].sum()
        rel_abundance_adjust_gr.loc[rel_abundance_adjust_gr['family_sp'] == 'f_other-s__', 'relative_abundance'] = 1- val 
        
        rel_abundance_adjust_gr = rel_abundance_adjust_gr.sort_values(by='family_sp')
        rel_abundance_adjust = rel_abundance_adjust.sort_values(by='family_sp')
        rel_abundance_adjust['passage'] = rel_abundance_adjust['passage'].astype(str)
        all_passages.append(rel_abundance_adjust)
        
    bars = hv.Bars(pd.concat(all_passages), kdims=['passage',hv.Dimension('family_sp',range=(0,1))],
               vdims = ['relative_abundance'])

    bars.opts(width=200,height = 200, ).opts(stacked=True, xrotation = 0,cmap = cmap_dict,
                                            show_legend=show_legend,
                                            xlabel='Passage', ylabel='Rel. Abundance',
                                            ylim=(0, 1.))


    #bars = hv.render(bars) 
    #bars.y_range = bokeh.models.Range1d(0, 1)
    return bars

# %%
all_e003['comm'].unique()
all_e003 = all_e003.sort_values(by='comm')
all_e003 = all_e003.sort_values(by='media')
all_e003 = all_e003.sort_values(by='subject')
allbars = []
all_e003_AA = all_e003.loc[all_e003['subject'] == 'AF',:]
for mesocosm in all_e003_AA['mesocosm'].unique():
    if 'fecal' in mesocosm:
        continue 
    df_mesocosm = all_e003.loc[all_e003['mesocosm'] == mesocosm,:].sort_values(by='passage')
    subject = mesocosm.split('-')[1]
    fecal_df = all_e003.loc[all_e003['mesocosm'] == f'fecal-{subject}-fecal',:]
  #  barsfecal = make_stacked_bar_plot_family_sp(fecal_df, cmap_dict, good_sp, good_fam,)
    full_df = pd.concat([fecal_df , df_mesocosm])
# make_stacked_bar_plot_family(rel_abundance, cmap_dict,  good_fam,
    bars =  make_stacked_bar_plot_family(full_df, family_colors_colorblind,  good_fam,show_legend=True)
    bars.opts(title='-'.join(mesocosm.split('-')[1:]))
  #  bars.legend.visible=True
    allbars.append(bars)

# %%
family_colors_colorblind = {'f__Bacteroidaceae': '#AA4499',
 'f__Enterobacteriaceae': '#332288',
 'f__Porphyromonadaceae': '#DDCC77',
 'f__Oscillospiraceae': '#117733',
 'f__Peptoniphilaceae': '#88CCEE',
 'f__Tannerellaceae': '#882255',
 'f__Enterococcaceae': '#44AA99',
 'f__Lachnospiraceae': '#CC6677',
 'f__Veillonellaceae': '#999933',
 'f_other': '#DDDDDD'}

# %%
good_spb = ['s__Bacteroides thetaiotaomicron']

# %%
all_e003.columns.values
# Out:
# array(['species_id', 'sample', 'relative_abundance', 'Lineage', 'species',
#        'genus', 'family', 'phyla', 'exp_type', 'media', 'passage', 'comm',
#        'subject', 'mesocosm', 'type_mesocosm'], dtype=object)

# %%
all_e003['comm'].unique()
all_e003 = all_e003.sort_values(by='comm')
all_e003 = all_e003.sort_values(by='media')
all_e003 = all_e003.sort_values(by='subject')

all_e003_AA = all_e003.loc[all_e003['comm'].isin(['B2','B3','B4','B5',
                                                  'B8','B9','B10','B11']),:]

#all_e003_AA = all_e003_AA.sort_values(by='media')
#all_e003_AA = all_e003_AA.sort_values(by='subject')
allbars = []
for mesocosm in all_e003_AA['mesocosm'].unique():
    print(mesocosm)
    if 'fecal' in mesocosm:
        continue 
    df_mesocosm = all_e003.loc[all_e003['mesocosm'] == mesocosm,:].sort_values(by='passage')
    subject = mesocosm.split('-')[1]
    fecal_df = all_e003.loc[all_e003['mesocosm'] == f'fecal-{subject}-fecal',:]
  #  barsfecal = make_stacked_bar_plot_family_sp(fecal_df, cmap_dict, good_sp, good_fam,)
    full_df = pd.concat([fecal_df , df_mesocosm])

    bars = make_stacked_bar_plot_family_sp_mult_passages(full_df, cmap_dict, good_sp, good_fam,show_legend=False)
    bars.opts(title='-'.join(mesocosm.split('-')[1:]))
   # bars.opts(title=mesocosm)
    allbars.append(bars)
# Out:
# B8-AA-mGAM
# B2-AA-mBHI
# B3-AC/PP-mBHI
# B9-AC/PP-mGAM
# B10-AE-mGAM
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_49889/2444564485.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rel_abundance_adjust['family_sp'] = rel_abundance_adjust['family'] + '-' + rel_abundance_adjust['species']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_49889/2444564485.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
allbars[1]+allbars[2]+allbars[5] + allbars[7] +allbars[0]+allbars[3]+allbars[4] + allbars[6]
# Out:
# :Layout
#    .Bars.I    :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.II   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.III  :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.IV   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.V    :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VI   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VII  :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VIII :Bars   [passage,family_sp]   (relative_abundance)

# %%
all_e003['comm'].unique()
all_e003 = all_e003.sort_values(by='comm')
all_e003 = all_e003.sort_values(by='media')
all_e003 = all_e003.sort_values(by='subject')

all_e003_AA = all_e003.loc[all_e003['comm'].isin(['C2','C3','C4','C5',
                                                  'C8','C9','C10','C11']),:]

#all_e003_AA = all_e003_AA.sort_values(by='media')
#all_e003_AA = all_e003_AA.sort_values(by='subject')
allbars2 = []
for mesocosm in all_e003_AA['mesocosm'].unique():
    print(mesocosm)
    if 'fecal' in mesocosm:
        continue 
    df_mesocosm = all_e003.loc[all_e003['mesocosm'] == mesocosm,:].sort_values(by='passage')
    subject = mesocosm.split('-')[1]
    fecal_df = all_e003.loc[all_e003['mesocosm'] == f'fecal-{subject}-fecal',:]
  #  barsfecal = make_stacked_bar_plot_family_sp(fecal_df, cmap_dict, good_sp, good_fam,)
    full_df = pd.concat([fecal_df , df_mesocosm])

    bars = make_stacked_bar_plot_family_sp_mult_passages(full_df, cmap_dict, good_sp, good_fam,show_legend=False)
    bars.opts(title='-'.join(mesocosm.split('-')[1:]))
   # bars.opts(title=mesocosm)
    allbars2.append(bars)
# Out:
# C8-AA-mGAM
# C2-AA-mBHI
# C9-AC/PP-mGAM
# C3-AC/PP-mBHI
# C10-AE-mGAM
# C4-AE-mBHI
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_49889/2444564485.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rel_abundance_adjust['family_sp'] = rel_abundance_adjust['family'] + '-' + rel_abundance_adjust['species']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_49889/2444564485.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
allbars[1]+allbars[2]+allbars[5] + allbars[7] +allbars[0]+allbars[3]+allbars[4] + allbars[6]
# Out:
# :Layout
#    .Bars.I    :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.II   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.III  :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.IV   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.V    :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VI   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VII  :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VIII :Bars   [passage,family_sp]   (relative_abundance)

# %%
allbars2[7]+ allbars2[1]+allbars2[2]+allbars2[5] + allbars2[7] +allbars2[0]+allbars2[3]+allbars2[4] + allbars2[6]
# Out:
# :Layout
#    .Bars.I    :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.II   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.III  :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.IV   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.V    :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VI   :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VII  :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.VIII :Bars   [passage,family_sp]   (relative_abundance)
#    .Bars.IX   :Bars   [passage,family_sp]   (relative_abundance)

# %%
all_e003['counts']=1
all_e003_good = all_e003.loc[all_e003['relative_abundance']>1e-3,:]
all_e003_alpha = all_e003_good.groupby(['sample','exp_type','passage','media',
                                   'comm','subject','mesocosm','type_mesocosm']).sum().reset_index()

all_e003_alpha = all_e003_alpha.loc[all_e003_alpha['passage'] !=2,:]
p = iqplot.strip(all_e003_alpha.sort_values(by='passage'), q= 'counts', 
                  color_column = 'media',q_axis = 'y',
                 width=250,
                 height=300,
                  palette = [bokeh.palettes.Set2[8][-2],bokeh.palettes.Set2[8][1],bokeh.palettes.Set2[8][0],
                             ],
         
                 cats = 'passage', jitter=True,)# marker_kwargs = dict(alpha=.5))

#p.xaxis.major_label_orientation = 1
#p.xaxis.major_label_orientation = -np.pi
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.y_range = bokeh.models.Range1d(0,150)
#p.legend.location='right'
p.legend.visible=False
p.yaxis.axis_label = 'Species Diversity'
p.xaxis.axis_label = 'Passage'
bokeh.io.show(p)
# Out:
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/iqplot/cat.py:173: UserWarning: `jitter` is deprecated. Use spread='jitter'.
#   warnings.warn("`jitter` is deprecated. Use spread='jitter'.")
# /Users/sophiewalton/miniconda3/envs/bokeh_update/lib/python3.13/site-packages/iqplot/cat.py:175: UserWarning: `jitter` is deprecated. Use spread='jitter'.
#   warnings.warn("`jitter` is deprecated. Use spread='jitter'.")
#   <div id="ef27d662-2ba3-4370-8ee3-98e7883bc900" data-root-id="68829eca-df8c-4935-96ef-68b41e30f96b" style="display: contents;"></div>

# %%
df_abundance_melted = pd.melt(df_abundance, 
                                  var_name = 'sample', 
                                  id_vars='species_id',
                                  value_name = 'relative_abundance')


df_abundance_melted = transform_df(df_abundance_melted)
df_abundance_melted['relative_abundance'] = df_abundance_melted['relative_abundance'].astype(float)
#df_abundance_melted = df_abundance_melted.loc[df_abundance_melted['relative_abundance']>1e-3,:]
df_abundance_melted.head()
# Out:
#    species_id                       sample  relative_abundance  \
# 0      102506  C12-e003Coalescence-mBHI-p3               0.187
# 1      102320  C12-e003Coalescence-mBHI-p3               0.121
# 2      100099  C12-e003Coalescence-mBHI-p3               0.119
# 3      100196  C12-e003Coalescence-mBHI-p3               0.123
# 4      101346  C12-e003Coalescence-mBHI-p3               0.038
#
#                                              Lineage  \
# 0  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 1  d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...
# 2  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# 3  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 4  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                            species              genus                 family  \
# 0            s__Escherichia coli_D     g__Escherichia  f__Enterobacteriaceae
# 1      s__Enterococcus_B faecium_B  g__Enterococcus_B     f__Enterococcaceae
# ...

# %%
e003_metadata = pd.read_csv('e003_metadata_cultures_round2.csv').drop(columns = 'Unnamed: 0')
df_abundance_melted_coal = df_abundance_melted.loc[df_abundance_melted['sample'].isin(e003_metadata['sample'].values),:]
def get_meso(x):
   # print(x)
    try:
        e003_metadata.loc[e003_metadata['sample'] == x,'mesocosm']
    except:
        return np.nan
df_abundance_melted_coal['mesocosm'] = df_abundance_melted_coal['sample'].transform(get_meso)
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_96841/1228051373.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abundance_melted_coal['mesocosm'] = df_abundance_melted_coal['sample'].transform(get_meso)

# %%
e003_metadata = pd.read_csv('e003_metadata_cultures_round2.csv').drop(columns = 'Unnamed: 0')
df_abundance_melted_coal = df_abundance_melted.loc[df_abundance_melted['sample'].isin(e003_metadata['sample'].values),:]
df_abundance_melted_coal['mesocosm'] = df_abundance_melted_coal['sample'].transform(lambda x: \
                                                                                    e003_metadata.loc[e003_metadata['sample'] == x,'mesocosm'].values[0])

df_abundance_melted_coal['passage'] = df_abundance_melted_coal['sample'].transform(lambda x: \
                                                                                   e003_metadata.loc[e003_metadata['sample'] == x,'passage'].values[0])
df_abundance_melted_coal['inoculumn_sample'] = df_abundance_melted_coal['sample'].transform(lambda x: \
                                                                                            e003_metadata.loc[e003_metadata['sample'] == x,'inoculumn_sample'].values[0]) 
df_abundance_melted_coal['type_mesocosm'] = df_abundance_melted_coal['sample'].transform(lambda x: \
                                                                                         e003_metadata.loc[e003_metadata['sample'] == x,'type_mesocosm'].values[0])
# Out:
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_96841/2247626426.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abundance_melted_coal['mesocosm'] = df_abundance_melted_coal['sample'].transform(lambda x: \
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_96841/2247626426.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abundance_melted_coal['passage'] = df_abundance_melted_coal['sample'].transform(lambda x: \
# ...

# %%
#df_abundance_melted_coal.to_csv('coal_sp_abundance.csv')

# %%
df_abundance_melted_coal=pd.read_csv('coal_sp_abundance.csv')

# %%
all_e003['comm'].unique()
df_abundance_melted_coal = df_abundance_melted_coal.sort_values(by='passage')
#e003_metadata_AA_AE = e003_metadata.loc[e003_metadata['parent_subjects'].isin(['AA-AE','AE-AA']),:]
e003_metadata_AA_AE = e003_metadata.loc[e003_metadata['type_mesocosm'] == 'AE-AF-mBHI-mBHI',:]
allbars = []
for mesocosm in e003_metadata_AA_AE['mesocosm'].unique():

    df_mesocosm = df_abundance_melted_coal.loc[df_abundance_melted_coal['mesocosm'] == mesocosm,:].sort_values(by='passage')
   # subject = mesocosm.split('-')[1]
    if len(df_mesocosm) == 0:
        print(mesocosm)
        continue
    #print(subject, mesocosm,len(df_mesocosm))
    print(df_mesocosm['inoculumn_sample'].unique())
    in_sample = df_mesocosm['inoculumn_sample'].unique()[0]
    in_df = df_abundance_melted_coal.loc[df_abundance_melted_coal['sample'] == in_sample,:]
    full_df = pd.concat([in_df, df_mesocosm])

    bars = make_stacked_bar_plot_family_sp_mult_passages(full_df.loc[full_df['species_id'] == 101346,:], cmap_dict, good_sp, good_fam,show_legend=False,
                                                        passages=[0,3,5,7])
    bars.opts(title='-'.join(mesocosm.split('-')[1:]))
    allbars.append(bars)
# Out:
# ['D4-e003Coalescence-Inoculumn-mBHI']
# ['C5-e003Coalescence-mBHI-inoculumn-redo']
# ['C5-e003Coalescence-mBHI-inoculumn-redo']
# ['D4-e003Coalescence-Inoculumn-mBHI']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_96841/2369162344.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rel_abundance_adjust['family_sp'] = rel_abundance_adjust['family'] + '-' + rel_abundance_adjust['species']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_96841/2369162344.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
allbars[0]
# Out:
# :Bars   [passage,family_sp]   (relative_abundance)

# %%
def make_alpha_abund_mult_passages_fecal(rel_abundance,cmap,show_legend=False,
                                                ):
    rel_abundance_adjust = rel_abundance.copy()
    rel_abundance_adjust  = rel_abundance_adjust.loc[rel_abundance_adjust['relative_abundance']>1e-4,:]
    rel_abundance_adjust['counts'] = 1 
    rel_abundance_adjust = rel_abundance_adjust.groupby(['sample','passage','mesocosm',]).sum().reset_index()
   
    p = bokeh.plotting.figure(height = 200, width = 400)
    for mesocosm in rel_abundance_adjust['mesocosm'].unique():
        subject = mesocosm.split('-')[1]
        media = mesocosm.split('-')[2]
      #  if media == 'fecal':
       #     continue
        
        in_df = rel_abundance_adjust.loc[rel_abundance_adjust['mesocosm'] == f'fecal-{subject}-fecal',:]

        
        meso_df = rel_abundance_adjust.loc[rel_abundance_adjust['mesocosm'] == mesocosm,:]
        meso_df = pd.concat([in_df, meso_df])
        meso_df = meso_df.sort_values(by='passage')
        p.line(meso_df['passage'].values, meso_df['counts'].values,color=cmap[media])
        p.scatter(meso_df['passage'].values, meso_df['counts'].values,color=cmap[media] )

    p.yaxis.axis_label = f'Number of species'
    p.xaxis.axis_label = 'Passage'
   
    p.y_range = bokeh.models.Range1d(0,190)

    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    return p

# %%
cmap2 = {'mBHI':bokeh.palettes.Set2[8][1],
         'mGAM':bokeh.palettes.Set2[8][0],
        'fecal': bokeh.palettes.Set2[8][-2]}

# %%
p = make_alpha_abund_mult_passages(all_e003,cmap2)

# %%
p.y_range= bokeh.models.Range1d(0,190)
bokeh.io.show(p)
# Out:
#   <div id="db81a795-dee7-4b6d-9851-f28e1da3fe75" data-root-id="f76dc363-01e1-4a51-adac-5b9500c559ba" style="display: contents;"></div>

# %%
def make_alpha_abund_mult_passages_coal(rel_abundance,cmap,show_legend=False,
                                                ):
    rel_abundance_adjust = rel_abundance.copy()
    rel_abundance_adjust  = rel_abundance_adjust.loc[rel_abundance_adjust['relative_abundance']>1e-4,:]
    rel_abundance_adjust['counts'] = 1 
    rel_abundance_adjust = rel_abundance_adjust.groupby(['sample','passage','mesocosm','inoculumn_sample']).sum().reset_index()
   
    p = bokeh.plotting.figure(height = 200, width = 400)
    for mesocosm in rel_abundance_adjust['mesocosm'].unique():
     #   subject = mesocosm.split('-')[1]
        env = '-'.join(mesocosm.split('-')[3:])
        in_sample = rel_abundance_adjust.loc[rel_abundance_adjust['mesocosm'] == mesocosm,'inoculumn_sample'].values[0]
      #  if media == 'fecal':
       #     continue
        
        in_df = rel_abundance_adjust.loc[rel_abundance_adjust['sample'] == in_sample,:]
        if len(in_df) == 0:
            print(mesocosm, in_sample)
        meso_df = rel_abundance_adjust.loc[rel_abundance_adjust['mesocosm'] == mesocosm,:]
        meso_df = pd.concat([in_df, meso_df])
        meso_df = meso_df.sort_values(by='passage')
        p.line(meso_df['passage'].values, meso_df['counts'].values,color=cmap[env])
        p.scatter(meso_df['passage'].values, meso_df['counts'].values,color=cmap[env] )

    p.yaxis.axis_label = f'Number of species'
    p.xaxis.axis_label = 'Passage'
   
    p.y_range = bokeh.models.Range1d(0,100)

    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    return p

# %%
cmap = {'mBHI-mBHI': bokeh.palettes.colorblind['Colorblind'][7][-1],
        'mBHI-mGAM': bokeh.palettes.colorblind['Colorblind'][7][-3],
        'mGAM-mBHI': bokeh.palettes.colorblind['Colorblind'][7][-2],
        'mGAM-mGAM': bokeh.palettes.colorblind['Colorblind'][7][-4]}
p = make_alpha_abund_mult_passages_coal(df_abundance_melted_coal,cmap)

# %%
bokeh.io.show(p)
# Out:
#   <div id="c95f9a07-0292-4064-adea-86189ccf0acc" data-root-id="679555e4-2fa4-43c9-b281-e7b721b62109" style="display: contents;"></div>
