# %%
import pandas as pd
import numpy as np
import os
import itertools as it
from snp_analysis_tools_sherlock import *
from coalescence_analysis_tools import *
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='843c9978-88fe-491d-9533-682444eb5a47'>
#   <div id="e23f79db-4ca1-4341-8725-de6c1785d43e" data-root-id="843c9978-88fe-491d-9533-682444eb5a47" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/mergev4/species/species_relative_abundance.tsv'
df_abundance = pd.read_csv(fname, delimiter = '\t', low_memory=False)
df_abundance
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_metadata = transform_df(df_metadata)
#df_abundance_melted = pd.melt(df_abundance, 
 #                                 var_name = 'sample', 
  #                                id_vars='species_id',
   #                               value_name = 'relative_abundance')


#df_abundance_melted = transform_df(df_abundance_melted)
df_abundance_melted= pd.read_csv('all_abundances_melted.csv', )

# %%
BE=df_abundance_melted.loc[df_abundance_melted['sample']=='BF-Fecal',:].sum()

# %%
BE=df_abundance_melted.loc[df_abundance_melted['sample']=='e004-inoculumn-fecal-BE',:]

BEgood = BE.loc[BE['relative_abundance']>1e-2,:].sort_values(by='relative_abundance',ascending=False)
print(np.sum(BEgood['relative_abundance'].values))
len(BEgood['family'].unique())
BEgood  = BEgood.groupby('family').sum().reset_index()
BEgood=BEgood.sort_values(by='relative_abundance',ascending=False)
len(BEgood)
# Out:
# 0.0
# 0

# %%
BE=df_abundance_melted.loc[df_abundance_melted['sample']=='e004-inoculumn-fecal-BE',:]
BE.to_csv('BE_rel_abundance_with_zeros.csv',index=False)

# %%
BE.loc[BE['family']=='f__Bacteroidaceae',:].sort_values(by='relative_abundance',ascending=False)[:10]
# Out:
# Empty DataFrame
# Columns: [species_id, sample, relative_abundance, Lineage, species, genus, family, phyla]
# Index: []

# %%
fams = BEgood['family'].unique()
cmap_family = {}
for i,fam in enumerate(fams):
    cmap_family[fam]=bokeh.palettes.Set3[12][i]
cmap_family['f__other'] ='#d9d9d9'

# %%
len(BEg)

# %%
def ecdf_transform(data):
    return 1- data.rank(method="first") / len(data)
BEg = BE.loc[BE['relative_abundance']>1e-4,:].sort_values(by='relative_abundance',ascending=False)
BEg.loc[:, "rel abun ECDF"] = BEg[
    "relative_abundance"
].transform(ecdf_transform)

p1=hv.Scatter(
    data=BEg,
    kdims='relative_abundance',
    vdims=[('rel abun ECDF', 'ECDF'), ],
).opts(width=200,height=200, color= 'grey',xlabel='Relative Abundance',
       logx=True,xlim=(4e-4,2e-1),
      ylabel='1-P(f>x)')
p1

# %%
BEplot = BEplot.groupby(['relative_abundance','sample','species_id']).sum().reset_index()

# %%
def adjust_df(meso_df):
    for sample in meso_df['sample'].unique():
        full= meso_df.loc[meso_df['sample']==sample,'relative_abundance'].sum()

        meso_df.loc[meso_df['sample']==sample,'relative_abundance']=  meso_df.loc[meso_df['sample']==sample,'relative_abundance']/full
        #print(full,meso_df.loc[meso_df['sample']==sample,'relative_abundance'].sum())
    return meso_df
good_families = list(cmap_family.keys())
good_families
BEplot = BE.copy()
#BEplot.loc[BEplot['relative_abundance']<1e-2,'family']='f__other'
BEplot.loc[~BEplot['family'].isin(good_families),'family_plot']='f__other'
#BEplot.loc[BEplot['relative_abundance']<1e-2,'species_id']=-1
BEplot = BEplot.groupby(['family','sample','species_id']).sum().reset_index()

print(np.sum(BEplot['relative_abundance'].values))
#print(df_meso['family'])
BEplot= adjust_df(BEplot)
#print(df_meso['family'])
BEplot['family_plot']=BEplot['family'].copy()

BEplot.loc[~BEplot['family'].isin(good_families),'family_plot']='f__other'
BEplot=BEplot.sort_values(by='family_plot')

bars2 = hv.Bars(BEplot, kdims=['sample', 'species_id',],
               vdims = ['relative_abundance','family_plot',])

bars2=bars2.opts(width=400, height=400).opts(stacked=True,#alpha='relative_abundance',
                                      color='family_plot',
                                      cmap=cmap_family,
                                      alpha=1.,
                                             bar_width = 2,
                                      xlabel=None,
                                      ylabel='Relative Abundance',
                                        show_legend=True,legend_position='right',
                                         )#.sort(by='passage_plot')

bars2

# %%
def adjust_df(meso_df):
    for sample in meso_df['sample'].unique():
        full= meso_df.loc[meso_df['sample']==sample,'relative_abundance'].sum()

        meso_df.loc[meso_df['sample']==sample,'relative_abundance']=  meso_df.loc[meso_df['sample']==sample,'relative_abundance']/full
        #print(full,meso_df.loc[meso_df['sample']==sample,'relative_abundance'].sum())
    return meso_df
good_families = list(cmap_family.keys())
good_families
BEplot = BE.copy()
BEplot.loc[BEplot['relative_abundance']<1e-2,'family']='f__other'
BEplot.loc[BEplot['relative_abundance']<1e-2,'species_id']=-1
BEplot.loc[BEplot['relative_abundance']<1e-2,'relative_abundance']=0
BEplot = BEplot.groupby(['family','sample','species_id']).sum().reset_index()

print(np.sum(BEplot['relative_abundance'].values))
#print(df_meso['family'])


BEplot= adjust_df(BEplot)
#print(df_meso['family'])
BEplot['family_plot']=BEplot['family'].copy()

BEplot.loc[~BEplot['family'].isin(good_families),'family_plot']='f__other'
BEplot=BEplot.sort_values(by='family_plot')

bars2 = hv.Bars(BEplot, kdims=['sample', 'species_id',],
               vdims = ['relative_abundance','family_plot',])

bars2=bars2.opts(width=400, height=400).opts(stacked=True,#alpha='relative_abundance',
                                      color='family_plot',
                                      cmap=cmap_family,
                                      alpha=1.,
                                             bar_width = 2,
                                      xlabel=None,
                                      ylabel='Relative Abundance',
                                        show_legend=True,legend_position='right',
                                         )#.sort(by='passage_plot')

bars2

# %%
fnames = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/calculateDiversityDepthv3/*/*_diversity_df1.csv')
dfs = []

for fname in fnames:
    df = pd.read_csv(fname).rename(columns={'0':'div'})
    sp = int(fname.split('/')[-2])
    df['species_id']=sp
    df['sp_name']= df_metadata.loc[df_metadata['species_id']==sp,'species'].values[0]
    dfs.append(df)
all_df= pd.concat(dfs)
all_df_BF = all_df.loc[all_df['Unnamed: 0']=='e004-inoculumn-fecal-BE',:]
all_df_BF.columns.values

# %%
all_df_BF.loc[:, "div ECDF"] = all_df_BF[
    'div'
].transform(ecdf_transform)

p1=hv.Scatter(
    data=all_df_BF,
    kdims='div',
    vdims=[('div ECDF', 'ECDF'), ],
).opts(width=200,height=200, color= 'black',xlabel='SNP Diversity',
       logx=True,
      ylabel='1-P(f>x)')
p1 = hv.render(p1)
p1.ray(x = 1e-3,y=-1,angle=np.pi/2,color='grey',)
bokeh.io.show(p1)

# %%
len(all_df_BF.loc[all_df_BF['div']>1e-3,:])

# %%
all_df_BF.loc[all_df_BF['div']<1e-3,'sp_name'].unique()

# %%
df_abundance_melted= pd.read_csv('all_abundances_melted.csv', )
df_abundance_melted

# %%
df_abundance_melted_samples = df_abundance_melted[['sample']]
df_abundance_melted_samples['e004']=df_abundance_melted_samples['sample'].transform(lambda x: 'e004' in x)
df_abundance_melted_samples=df_abundance_melted_samples.loc[df_abundance_melted_samples['e004'],:]
df_abundance_melted_samples['well']=df_abundance_melted_samples['sample'].transform(lambda x: x.split('-')[0])
df_abundance_melted_samples['passage']=df_abundance_melted_samples['sample'].transform(lambda x: x.split('-')[-1][-1])
df_abundance_melted_samples['column']=df_abundance_melted_samples['well'].transform(lambda x: x[-1])
df_abundance_melted_samplesBE=df_abundance_melted_samples.loc[df_abundance_melted_samples['column']=='5',:]
df_abundance_melted_samplesBE['media']=df_abundance_melted_samplesBE['sample'].transform(lambda x: x.split('-')[-2])
df_abundance_melted_samplesBE['passage']=df_abundance_melted_samplesBE['passage'].astype(int)
good_samples =['B5-e004Assembly-mBHI-p3', 'B5-e004Assembly-mBHI-p7',
       'G5-e004Assembly-epsilon-p3', 'C5-e004Assembly-mBHI-p3',
       'E5-e004Assembly-mGAM-p5', 'D5-e004Assembly-mGAM-p5',
       'F5-e004Assembly-epsilon-p5', 'E5-e004Assembly-mGAM-p7',
       'D5-e004Assembly-mGAM-p7', 'D5-e004Assembly-mGAM-p3',
       'F5-e004Assembly-epsilon-p3', 'E5-e004Assembly-mGAM-p3',
       'C5-e004Assembly-mBHI-p7', 'G5-e004Assembly-epsilon-p5',
       'B5-e004Assembly-mBHI-p5', 'G5-e004Assembly-epsilon-p7','e004-inoculumn-fecal-BE']

# %%
df_abundance_melted['e004']=''
df_abundance_melted['well']=''
df_abundance_melted['passage']=''
df_abundance_melted['column']=''
df_abundance_melted['media']=''
df_abundance_melted_samples = df_abundance_melted.loc[df_abundance_melted['sample'].isin(good_samples),:]

df_abundance_melted_samples['well']=df_abundance_melted_samples['sample'].transform(lambda x: x.split('-')[0])
df_abundance_melted_samples['passage']=df_abundance_melted_samples['sample'].transform(lambda x: x.split('-')[-1][-1])
df_abundance_melted_samples['column']=df_abundance_melted_samples['well'].transform(lambda x: x[-1])
df_abundance_melted_samples['media']=df_abundance_melted_samples['sample'].transform(lambda x: x.split('-')[-2])
df_abundance_melted_samples.loc[df_abundance_melted_samples['sample']=='e004-inoculumn-fecal-BE','well']='fecal'
df_abundance_melted_samples.loc[df_abundance_melted_samples['sample']=='e004-inoculumn-fecal-BE','column']='fecal'
df_abundance_melted_samples.loc[df_abundance_melted_samples['sample']=='e004-inoculumn-fecal-BE','media']='fecal'
df_abundance_melted_samples.loc[df_abundance_melted_samples['sample']=='e004-inoculumn-fecal-BE','passage']=0
df_abundance_melted_samples['passage']=df_abundance_melted_samples['passage'].astype(int)
#df_abundance_melted_samplesBE['passage']=df_abundance_melted_samplesBE['passage'].astype(int)

# %%
df_abundance_melted_samples

# %%
df_meso_alts=df_abundance_melted_samples.groupby(['sample','well','media','column','passage']).sum().reset_index()
df_meso_alts['relative_abundance']=1-df_meso_alts['relative_abundance'].sum()
df_meso_alts=df_meso_alts.loc[df_meso_alts['relative_abundance']>0,:]
df_meso_alts['genus']='g__missing'
df_meso_alts['family']='f__missing'
df_meso_alts['phyla']='p__missing'
df_meso_alts['species']='s__missing'
df_meso_alts['Lineage']='missing'
df_meso_alts['species_id']=0
df_meso_alts# = pd.concat([df_abundance,df_meso_alts])

# %%
def adjust_df(meso_df):
    for sample in meso_df['sample'].unique():
        full= meso_df.loc[meso_df['sample']==sample,'relative_abundance'].sum()
        print(sample,full)
        meso_df.loc[meso_df['sample']==sample,'relative_abundance']=  meso_df.loc[meso_df['sample']==sample,'relative_abundance']/full
        print(full,meso_df.loc[meso_df['sample']==sample,'relative_abundance'].sum())
    return meso_df

# %%
df_meso

# %%
well = 'C5'

df_meso=df_abundance_melted_samples.loc[df_abundance_melted_samples['well']==well,:]
in_sample =df_abundance_melted_samples.loc[df_abundance_melted_samples['sample']=='e004-inoculumn-fecal-BE',:]
df_meso = pd.concat([df_meso,in_sample])
df_meso['family_sp']=df_meso['family']+ '-' + df_meso['species']
df_meso['passage'].unique()
#df_meso['species_id']=df_meso['species_id'].astype(str)
df_meso['passage_plot']=df_meso['passage'].astype(str)
#df_meso=df_meso.sort_values(by='passage_plot')
df_meso['is_important']=0.1
df_meso.loc[df_meso['species_id']==101346,'is_important']=1.
#df_meso=df_meso.loc[df_meso['sample']!='Assembly-G12-fecal-AA-fecal-0_S703',:]
cmap_family= {'f__Bacteroidaceae': '#8dd3c7',
 'f__Enterobacteriaceae': '#ffffb3',
 'f__Porphyromonadaceae': '#bebada',
 'f__Peptoniphilaceae': '#fb8072',
 'f__Oscillospiraceae': '#80b1d3',
 'f__Enterococcaceae': '#fdb462',
 'f__Tannerellaceae': '#b3de69',
 'f__Lachnospiraceae': '#fccde5',
 'f__Veillonellaceae': '#bc80bd',
 'f__Peptostreptococcaceae': '#ccebc5',
 'f__Acidaminococcaceae': '#ffed6f',
 'f__other': '#d9d9d9'}
good_families = list(cmap_family.keys())
good_families

df_meso.loc[df_meso['relative_abundance']<1e-2,'relative_abundance']=0
#print(df_meso['family'])
df_meso = adjust_df(df_meso)
#print(df_meso['family'])
df_meso['family_plot']=df_meso['family'].copy()

df_meso.loc[~df_meso['family'].isin(good_families),'family_plot']='f__other'
df_meso=df_meso.sort_values(by='family_plot')
#df_mesog=df_meso#.loc[df_meso['is_important']==1.,:]
df_meso_small =df_meso.loc[df_meso['passage'].isin([0,1,2,3,4,5,6,7]),:].sort_values(by='family_plot')
bars2 = hv.Bars(df_meso_small, kdims=[hv.Dimension('passage', values=[0,1,2,3,4,5,6,7]), 'species_id',],
               vdims = ['relative_abundance','family_plot',])

bars2=bars2.opts(width=600, height=400).opts(stacked=True,#alpha='relative_abundance',
                                      color='family_plot',
                                      cmap=cmap_family,
                                      alpha=1.,
                                             title = 'BE in mBHI r2',
                                             bar_width = 2,
                                      xlabel='Passage',
                                      ylabel='Relative Abundance',
                                        show_legend=True,legend_position='right',
                                         )#.sort(by='passage_plot')

bars2
