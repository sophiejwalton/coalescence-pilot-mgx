# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control
#from bokeh.models import FixedTicker, FuncTickFormatter 
from scipy.stats import chi2

#from bokeh.io import output_notebook

from snp_analysis_tools_sherlock import *
from plot_tools import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1c76b33b-590c-4dd7-a495-bf38906f199a'>
#   <div id="b7244666-5553-415a-97b2-2723dc96c0c9" data-root-id="1c76b33b-590c-4dd7-a495-bf38906f199a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b1e94103-1cdf-455d-b694-d7cb3366f26e":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1c76b33b-590c-4dd7-a495-bf38906f199a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"f694054a-ef53-40c5-a613-a93959c4b0b9","attributes":{"plot_id":"1c76b33b-590c-4dd7-a495-bf38906f199a","comm_id":"4321570d108a41ef90c077a458d2973f","client_comm_id":"9c1cda87b4a24ccca7c4bd101f6f9a76"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"b1e94103-1cdf-455d-b694-d7cb3366f26e","roots":{"1c76b33b-590c-4dd7-a495-bf38906f199a":"b7244666-5553-415a-97b2-2723dc96c0c9"},"root_ids":["1c76b33b-590c-4dd7-a495-bf38906f199a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_metadata  =transform_df(df_metadata)
df_metadata.loc[df_metadata['species_id']==101349,:]
# Out:
#       species_id    representative MGnify_accession  species_closest  \
# 1348      101349  GUT_GENOME096096  MGYG-HGUT-01349         102640.0
#
#       ani_closest  gtpro_kmer_counts  phyeco_marker_counts  phyeco_pass_ratio  \
# 1348      94.0625            55924.0                  15.0                1.0
#
#       pangene_counts  genome_counts  ...     N50  GC_content  Completeness  \
# 1348          100370            789  ...  257597       38.67         100.0
#
#       Contamination                                            Lineage  \
# 1348            0.0  d__Bacteria;p__Firmicutes_C;c__Negativicutes;o...
#
#       Continent                   species           genus              family  \
# 1348        NaN  s__Veillonella parvula_A  g__Veillonella  f__Veillonellaceae
#
#                 phyla
# 1348  p__Firmicutes_C
#
# [1 rows x 23 columns]

# %%
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',

            
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
            
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
            
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',

            
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
            
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
            
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
            
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
            
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',

            
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI',]

# %%
def get_pred_sel(ts,sel_coeff, start_value,):
    pred=np.exp(ts*sel_coeff)
    pred = pred*start_value/(1 - start_value + start_value*pred)
    return pred

# %%
def get_preds_for_plottingv2(sp,ino,type_meso, t0,t1):

    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
    print(fname1)
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parent1_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    freq1 = pd.read_csv(fname1)
    df_both = get_both_dfs(fname1)
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['total_shift']<.1,:]
    

    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()


   # print('bef',np.max(df_both_meta_good['actual_med1']- df_both_meta_good['boot_med1']))
    df_both_meta_good.loc[df_both_meta_good['boot_med1']<1e-3,'boot_med1']=1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med1']>1-1e-3,'boot_med1']=1-1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med2']<1e-3,'boot_med2']=1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med1']>1-1e-3,'boot_med1']=1-1e-3
    
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med1']/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med1']/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])
   # print(df_both_meta_good['boot_med1'])
    df_both_meta_good.loc[df_both_meta_good['boot_med1']<1e-3,'boot_med1']=1e-3
    df_both_meta_good.loc[df_both_meta_good['boot_med1']>1-1e-3,'boot_med1']=1-1e-3

    sel_stuff['type_mesocosm']=sel_stuff['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:]))
    sel_stuff['species']=sp
    sel_stuff['inoculumn']=ino
    sel_stuff = sel_stuff.loc[sel_stuff['type_mesocosm']==type_meso,:]
    sel_stuff['start_val']=np.nan
    sel_stuff['t1_val']=np.nan
    
    if len(sel_stuff)==0:
        return [],[],[],[]
    good_mesos = []
    for meso in sel_stuff['mesocosm'].unique():
    
        sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'late_sel_med']
        start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1']
        if len(start_val)>0:
            sel_stuff.loc[sel_stuff['mesocosm']==meso,'start_val'] = start_val.values[0]
        passages = list(df_both_meta_good.loc[df_both_meta_good['mesocosm']==meso,'passage'].values)
        if len(np.intersect1d([1,2,6,7],passages))==4:
            good_mesos.append(meso)
    ts=np.arange(9)
    #print(start_values)
    sel_stuff=sel_stuff.loc[~sel_stuff['start_val'].isna(),:]
    sel_stuff = sel_stuff.loc[sel_stuff['mesocosm'].isin(good_mesos),:]
    if len(sel_stuff)==0:
        return [],[],[],[]
    sel_stuff_med = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).median(numeric_only=True)
    
   #print(sel_stuff_med)
    pred_values = get_pred_sel(ts-t1,sel_stuff_med['early_sel_med'].values[0], sel_stuff_med['start_val'].values[0])
    pred_values_logit = np.log(pred_values/(1-pred_values))
    sel_coeffs = sel_stuff['early_sel_med'].values
    print(len(sel_stuff))
    start_values = sel_stuff['start_val'].values
    print('starts',start_values)
    print(sel_coeffs)
    pred_values_t7=get_pred_sel(7-t1,sel_coeffs, start_values,)
    argmax_7 =np.argmax(pred_values_t7) 
    argmin_7 =np.argmin(pred_values_t7) 

    ts=np.arange(9)
    pred_valuesmax = get_pred_sel(ts-t1,sel_coeffs[argmax_7], start_values[argmax_7],)
    pred_values_logitmax = np.log(pred_valuesmax/(1-pred_valuesmax))

    pred_valuesmin = get_pred_sel(ts-t1,sel_coeffs[argmin_7], start_values[argmin_7],)
    pred_values_logitmin = np.log(pred_valuesmin/(1-pred_valuesmin))
  #  print('potatoes',sel_stuff_meso.loc[(sel_stuff_meso['passage1']==t0)*(sel_stuff_meso['passage2']==t1),'start_value1'].values)
    
        
    return ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax

# %%
import os
inos=['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]

#inos = ['AA-AF-mGAM']
1#inos = ['AE-AF-mBHI']
species = [102438,100196, 100099, 100146, 101346, 102506, 102478]
species = [102438,100196, 100099, 100146, 101346, 102506, 102478,102358,101294]
species = [102438]
species = ['100146', '101059', '100910', '102478', '102438', '100196',
       '103117', '103656', '102544', '102506', '101346', '100099',
       '101400', '101294']

species
t0=1
t1=2
inos = ['AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI','AE-AF-mGAM',]
#inos = ['AE-AF-mBHI',]
species = [102438]
for sp in species:
    plots_all=[]
    for ino in inos:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{sp}/{ino}_parent1_info.csv'
        if f'{sp}-{ino}' in bad_inos:
            continue
        if not os.path.isfile(fname):
            print('oo')
            continue
        psstrain,type_mesos = make_logit_plot(sp, ino,
                                       colorby='const',logit=True,
                                        )
      #  print(psstrain)
        for i in range(len(psstrain)):
            p1 = psstrain[i]
            meso = type_mesos[i]
            med1=meso.split('-')[-2]
            med2 = meso.split('-')[-1]
            ino1 = f'{sp}-{med1}-{med2}'
            p1.legend.visible=False
            ts,pred_values_logit, pred_values_logitmin, pred_values_logitmax = get_preds_for_plottingv2(sp,ino,meso, t0,t1)
            if len(pred_values_logit)>0:
                p1.line(ts,pred_values_logit,color='grey')
                p1.line(ts,pred_values_logitmin,color='grey',line_dash='dashed')
                p1.line(ts,pred_values_logitmax,color='grey',line_dash='dashed')
                p1.yaxis.axis_label_text_font_style = 'normal'
                p1.xaxis.axis_label_text_font_style = 'normal'
                bokeh.io.show(p1)
                p1.output_backend='svg'
                export_plot_pdf(p1,f'time_varying_plotv2_{sp}_{ino}-{med2}-{t0}_{t1}')
# Out:
# bef 0.0004999999999999866
# aft 0.0004482724667423249
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# 2
# starts [0.03670514 0.02397325]
# [-2.63625724 -3.23923649]
#   <div id="fc81452d-375c-46e0-adbd-77e0aece138c" data-root-id="db59628c-5e85-427d-aff7-c82ec635b270" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# 4
# starts [0.04444444 0.05364372 0.02110553 0.06983806]
# [-2.35585756 -2.47988999 -3.00188175 -2.23325496]
#   <div id="e55e442d-d8b4-46c0-bba1-66ebbc92f0c8" data-root-id="12861cd1-2cc5-4bc0-a3c5-272614e1421b" style="display: contents;"></div>
# bef 1.8693514640800643e-05
# aft 1.8561649535137753e-05
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AE-mGAM_1_2_6_7_parent1_info_shift.csv
# 3
# starts [0.04563895 0.09285714 0.09929078]
# [-0.29018886 -0.29945239  0.34134939]
#   <div id="c68a8c72-4891-4a6e-ab20-e16eba80e4cd" data-root-id="ced5e9ce-a46a-40a8-980b-2771476f406b" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AE-mGAM_1_2_6_7_parent1_info_shift.csv
# 4
# starts [0.00400802 0.00501002 0.00800801 0.00201929]
# [-1.8162006  -1.71189753 -1.20110492 -2.70415499]
#   <div id="a7fde9e5-96d3-4f92-ab58-8829f9cb233f" data-root-id="5dcd7e2a-69d4-43a1-a09a-7d01f8e7867b" style="display: contents;"></div>
# bef 0.006999999999999895
# aft 0.003809689673563932
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AE-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# 2
# starts [0.20449898 0.38461538]
# [-1.68467355 -0.67008796]
#   <div id="cddbf686-f1c1-4f43-a8ba-35bcff9825e2" data-root-id="73ef2304-ca44-432f-977e-4aaf15db8f44" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AE-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# 4
# starts [0.76078029 0.74564103 0.7807377  0.64906832]
# [1.08356866 0.77125735 1.11029255 0.10571444]
#   <div id="e5307125-7bea-46d1-9eea-ab8e43d37eea" data-root-id="7cea4c86-69bf-43a7-b501-08fe4da0ccde" style="display: contents;"></div>
# bef 3.221053770289736e-05
# aft 3.1500749025543257e-05
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# 1
# starts [0.0317123]
# [-2.03531884]
#   <div id="d802abe6-e288-4098-8c01-a90148c80f5a" data-root-id="4b4a326c-d672-42c5-90e5-87fe931121fb" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AF-mBHI_1_2_6_7_parent1_info_shift.csv
# 1
# starts [0.00701403]
# [-2.4130895]
#   <div id="e089efaf-ff81-4349-83a4-24ae15584cf1" data-root-id="bdf664f7-98ac-47e2-bf06-d30d9034ae1f" style="display: contents;"></div>
# bef 1.8567834931600136e-05
# aft 1.7775265413952357e-05
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AE-mBHI_1_2_6_7_parent1_info_shift.csv
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AA-AE-mBHI_1_2_6_7_parent1_info_shift.csv
# 1
# starts [0.001]
# [-3.13086888]
#   <div id="e867561f-378b-4827-9bbd-fb52103edaed" data-root-id="3d26c3cf-4fd9-4c96-8f64-e2cfd6d16516" style="display: contents;"></div>
# bef 0.0010000000000000009
# aft 0.0005127975505121452
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AE-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# 2
# starts [0.93333333 0.66873065]
# [ 0.45521195 -1.2292795 ]
#   <div id="b9ee58ab-76af-4981-98a7-61edd0c89756" data-root-id="e8680dc1-a9ea-429e-844a-2f3defc4839d" style="display: contents;"></div>
# /Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/102438/AE-AF-mGAM_1_2_6_7_parent1_info_shift.csv
# 3
# starts [0.93346774 0.95674044 0.89756592]
# [ 0.02372414  0.59610052 -0.33315223]
#   <div id="d61d481d-f05a-479f-bc59-9e7982d8156e" data-root-id="698162f1-8777-4e4b-a40c-e0aae54c5a8f" style="display: contents;"></div>

# %%
species = 101346
inoculumn = 'AE-AF-mBHI'
t0=1
t1=2
fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
df = pd.read_csv(fname1)
df.columns.values
# Out:
# array(['Unnamed: 0', 'mesocosms', 'diff7_med', 'diff7_lower',
#        'diff7_upper', 'pred_7_upper', 'pred_7_lower', 'pred7_med',
#        'as_extreme7', 'act7_upper', 'act_7_lower', 'act_7_med',
#        'early_sel_upper', 'early_sel_lower', 'early_sel_med',
#        'late_sel_upper', 'late_sel_lower', 'late_sel_med',
#        'sample_early1', 'sample_early2', 'sample_late1', 'sample_late2'],
#       dtype=object)

# %%
def get_selection_stuff_time_vary(species,inoculumn,t0,t1,thresh=1e-3):
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
 #   print(fname1)
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parent1_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    freq1 = pd.read_csv(fname1)
    df_both = get_both_dfs(fname1)
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['total_shift']<.1,:]
    

    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()


   # print('bef',np.max(df_both_meta_good['actual_med1']- df_both_meta_good['boot_med1']))
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med1']/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med1']/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])
    sel_stuff['type_mesocosm']=sel_stuff['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:]))
    sel_stuff['species']=species
    sel_stuff['inoculumn']=inoculumn
   # sel_stuff = sel_stuff.loc[sel_stuff['type_mesocosm']==type_meso,:]
    sel_stuff['start_val']=np.nan
    sel_stuff['t1_val']=np.nan
    
    if len(sel_stuff)==0:
        return [],[]
    good_mesos = []
    for meso in sel_stuff['mesocosm'].unique():
    
        sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'early_sel_med']
        start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1']
        if len(start_val)>0:
            sel_stuff.loc[sel_stuff['mesocosm']==meso,'start_val'] = start_val.values[0]
        passages = list(df_both_meta_good.loc[df_both_meta_good['mesocosm']==meso,'passage'].values)
        if len(np.intersect1d([1,2,6,7],passages))==4:
            good_mesos.append(meso)
    ts=np.arange(9)
    
    #print(start_values)
    sel_stuff=sel_stuff.loc[~sel_stuff['start_val'].isna(),:]
    sel_stuff = sel_stuff.loc[sel_stuff['mesocosm'].isin(good_mesos),:]
    sel_stuff.loc[sel_stuff['start_val']<=1e-3,'late_sel_med']=sel_stuff.loc[sel_stuff['start_val']<=1e-3,'early_sel_med']
    sel_stuff.loc[sel_stuff['start_val']>=1-1e-3,'late_sel_med']=sel_stuff.loc[sel_stuff['start_val']>=1-1e-3,'early_sel_med']
    if len(sel_stuff)==0:
        return [],[]
    sel_stuff_meso_meds = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).median(numeric_only=True)
    sel_stuff_meso_maxs= sel_stuff.groupby(['type_mesocosm','species','inoculumn']).max(numeric_only=True)
    
    sel_stuff_meso_mins = sel_stuff.groupby(['type_mesocosm','species','inoculumn']).min(numeric_only=True)
   # print(species, sel_stuff_meso_meds.columns.values)
    for column in ['early_sel_med','act_7_med','pred7_med','late_sel_med']:
        sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'max_{column}']=sel_stuff_meso_maxs.loc[sel_stuff_meso_meds.index.values,column]
        sel_stuff_meso_meds.loc[sel_stuff_meso_meds.index.values,f'min_{column}']=sel_stuff_meso_mins.loc[sel_stuff_meso_meds.index.values,column]
    return sel_stuff_meso_meds,sel_stuff

# %%
def get_pred_sel(ts,sel_coeff, start_value,):
    pred=np.exp(ts*sel_coeff)
  #  print(pred)
    pred = pred*start_value/(1 - start_value + start_value*pred)
    
    return pred

# %%
def get_selection_stuff_time_vary_all_times(species,inoculumn,t0,t1,thresh=1e-3):
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
   # fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{species}/{inoculumn}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
    sel_stuff = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
 #   print(fname1)
   # fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parentboth_info.csv'
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{sp}/{ino}_parent1_info.csv'
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    df_both = pd.read_csv(fname1)
    df_both = get_both_dfs(fname1)
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['total_shift']<.1,:]


    df_both_meta_good = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]], axis=1).reset_index()
    df_both_meta_good['actual_med1']=df_both_meta_good['actual_med1']/(df_both_meta_good['actual_med1']+df_both_meta_good['actual_med2'])
    df_both_meta_good['boot_med1']=df_both_meta_good['boot_med1']/(df_both_meta_good['boot_med1']+df_both_meta_good['boot_med2'])
    
    sel_stuff['type_mesocosm']=sel_stuff['mesocosm'].transform(lambda x: '-'.join(x.split('-')[1:]))
 
    sel_stuff['species']=species
    sel_stuff['inoculumn']=inoculumn
   # sel_stuff = sel_stuff.loc[sel_stuff['type_mesocosm']==type_meso,:]
    sel_stuff['start_val']=np.nan
    sel_stuff['t1_val']=np.nan
    df_both_meta_good['pred_val_sel_12']=np.nan
    df_both_meta_good['sel_12']=np.nan
    
    if len(sel_stuff)==0:
        return [],[]
    big_dfs = []
    for sample in df_both_meta_good['sample'].unique():
        meso = df_both_meta_good.loc[df_both_meta_good['sample']==sample,'mesocosm'].values[0]
        passage = df_both_meta_good.loc[df_both_meta_good['sample']==sample,'passage'].values[0]
     #   print(sel_stuff['mesocosm'])
      #  print(meso)
        sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'early_sel_med']
        if len(sel_coeff)>0:
            sel_coeff = sel_stuff.loc[sel_stuff['mesocosm']==meso,'early_sel_med'].values[0]
        start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1']
        
        if len(start_val)>0:
            start_val = df_both_meta_good.loc[(df_both_meta_good['mesocosm']==meso)*(df_both_meta_good['passage']==t1),'boot_med1'].values[0]
        t = passage-t1
        
        
        pred = get_pred_sel(t,sel_coeff, start_val)
       # print('passage',start_val)
      #  print('pred',pred)
    #    print(pred,sel_coeff,start_val,passage, t)
       # print('pred',pred)
        df_both_meta_good.loc[df_both_meta_good['sample']==sample,'pred_val_sel_12']=pred
        df_both_meta_good.loc[df_both_meta_good['sample']==sample,'sel_12']=sel_coeff
    ts=np.arange(9)
    
    return sel_stuff,df_both_meta_good

# %%
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
len(np.unique(species_list))
# Out:
# 137

# %%
all_dfs=[]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
t0 = 1
t1 = 2
big_dfs = []
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']

for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
        if f'{sp}-{ino}' in bad_inos:
            continue 
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
        if os.path.exists(fname):
           # df,_= get_selection_stuff_time_vary(sp,ino,t0,t1,thresh=1e-3)
            df,df2=get_selection_stuff_time_vary_all_times(sp,ino,t0,t1,thresh=1e-3)
          #  df2['species_id']==sp
            
            if len(df)>0:
                df2['species_id']=sp
                big_dfs.append(df2.reset_index())
            
big_df=pd.concat(big_dfs).reset_index()
len(big_df['species_id'].unique())
big_df['species-type_meso']=big_df['species_id'].astype(str)+'-'+big_df['type_mesocosm'].astype(str)
big_df['species-mesocosm']=big_df['species_id'].astype(str)+'-'+big_df['mesocosm'].astype(str)
big_df = big_df.loc[~big_df['pred_val_sel_12'].isna(),:]
big_df_good=big_df.loc[(big_df['pred_val_sel_12']>1e-2)*(big_df['pred_val_sel_12']<1-1e-2),:]
#big_df = big_df.set_index('species-type_meso')
len(big_df['species_id'].unique())
# Out:
# 10

# %%
len(species_list)
# Out:
# 137

# %%
big_df = big_df.loc[~big_df['pred_val_sel_12'].isna(),:]
thresh=5e-3
big_df_good=big_df.loc[(big_df['pred_val_sel_12']>=thresh)*(big_df['pred_val_sel_12']<=1-thresh),:]
big_df_good=big_df_good.loc[big_df_good['passage']>2,:]
#print(len(big_df_good))

big_df_good['counts']=1
print('good',len(big_df_good))
big_df_good_pol = big_df_good#.groupby(['species-type_meso','passage']).median(numeric_only=True).copy().reset_index()
#print(big_df_good_pol['sel_12']>0,)
#big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.0,'pred_val_sel_12']
big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'boot_med1']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'boot_med1']
big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']

#big_df_good_pol.loc[big_df_good_pol['sel_12']>0,'boot_med1']=1-big_df_good_pol.loc[big_df_good_pol['sel_12']>.0,'boot_med1']
#big_df_good_pol.loc[big_df_good_pol['sel_12']>0,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['sel_12']>0,'pred_val_sel_12']


print(len(big_df_good_pol))
b=big_df_good.groupby(['species-mesocosm']).median(numeric_only=True)
len(b)
# Out:
# good 185
# 185
# 68

# %%
sp_mesos=[]

passages=[]
preds=[]
acts=[]
column='species-mesocosm'
for sp_meso in big_df_good_pol[column].unique():
    sp_thing=big_df_good_pol.loc[big_df_good_pol[column]==sp_meso,:]
    
    max_passage = sp_thing['passage'].max()
    sp_thing = sp_thing.loc[sp_thing['passage']==max_passage,:]
    pred_val = sp_thing['pred_val_sel_12'].values[0]
    act_val = sp_thing['boot_med1'].values[0]
    sp_mesos.append(sp_meso)
    passages.append(max_passage)
    preds.append(pred_val)
    acts.append(act_val)
df = pd.DataFrame(data={'sp_mesos':sp_mesos,'passage':passages,'pred':preds,'act':acts})
#df

# %%
df['het_act']=df['act']*(1.-df['act'])
df['het_pred']=df['pred']*(1.-df['pred'])
df['passage']=df['passage'].astype(str)
df=df.sort_values(by='passage')
p = hv.Points(df,vdims=['het_act',hv.Dimension('passage',values=['3','4','5','6','7',])],kdims = ['het_pred','het_act']).opts(size=10,color='passage',line_color='black',
                                                                                                                              cmap = [bokeh.palettes.Pastel1[5][0],
                                                                                                                                      bokeh.palettes.Pastel1[5][-1],
                                                                                                                                      bokeh.palettes.Pastel1[5][2],
                                                                                                                                      bokeh.palettes.Pastel1[5][1],
                                                                                                                                       bokeh.palettes.Pastel1[5][3],],
                                                                                                                              colorbar=True,width=400,
                                                                     )
p = hv.render(p)
points = np.linspace(-1,2)
p.x_range=bokeh.models.Range1d(-.005,.255)
p.y_range=bokeh.models.Range1d(-.005,.255)
p.legend.location='right'
p.line(points,points,color='grey',line_width=2)
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
export_plot_pdf(p,'het')
bokeh.io.show(p)
# Out:
#   <div id="f4168fa7-6a30-4933-b384-d1913d07ab31" data-root-id="29c87fef-21ee-4dc3-97a3-a395b91878a4" style="display: contents;"></div>

# %%
df['sp_type_meso']=df['sp_mesos'].transform(lambda x: '-'.join([x.split('-')[0]]+x.split('-')[2:]))
df.loc[df['sp_type_meso']=='100099-AA-AE-mGAM-mGAM',:]
# Out:
#                       sp_mesos passage      pred       act   het_act  \
# 48   100099-C8-AA-AE-mGAM-mGAM       3  0.011622  0.075605  0.069889
# 51   100099-G8-AA-AE-mGAM-mGAM       3  0.009048  0.073589  0.068173
# 45  100099-A10-AA-AE-mGAM-mGAM       4  0.007656  0.069959  0.065065
# 50  100099-E10-AA-AE-mGAM-mGAM       5  0.006785  0.131712  0.114364
#
#     het_pred            sp_type_meso
# 48  0.011487  100099-AA-AE-mGAM-mGAM
# 51  0.008966  100099-AA-AE-mGAM-mGAM
# 45  0.007598  100099-AA-AE-mGAM-mGAM
# 50  0.006739  100099-AA-AE-mGAM-mGAM

# %%
df['het_act']=df['act']*(1.-df['act'])
df['het_pred']=df['pred']*(1.-df['pred'])
df['passage']=df['passage'].astype(str)
df=df.sort_values(by='passage')
p = hv.Points(df,vdims=['het_act',hv.Dimension('passage',values=['3','4','5','6','7',])],kdims = ['het_pred','het_act']).opts(size=10,color='passage',line_color='black',
                                                                                                                              cmap = [bokeh.palettes.Pastel1[5][0],
                                                                                                                                      bokeh.palettes.Pastel1[5][-1],
                                                                                                                                      bokeh.palettes.Pastel1[5][2],
                                                                                                                                      bokeh.palettes.Pastel1[5][1],
                                                                                                                                       bokeh.palettes.Pastel1[5][3],],
                                                                                                                              colorbar=True,width=400,
                                                                     )
p = hv.render(p)
points = np.linspace(-1,2)
p.legend.location='right'
p.x_range=bokeh.models.Range1d(-.005,.255)
p.y_range=bokeh.models.Range1d(-.005,.255)
p.line(points,points,color='grey',line_width=2)
#p.legend.visible=False
p.xaxis.major_label_text_font_size='15px'
p.yaxis.major_label_text_font_size='15px'
export_plot_pdf(p,'het')
bokeh.io.show(p)
# Out:
#   <div id="c3d9b328-f5c3-4826-885d-b7a978278c5f" data-root-id="9616c57b-6d53-4645-8a33-84056bbc4147" style="display: contents;"></div>

# %%
df.loc[df['het_pred']>df['het_act'],:]
# Out:
#                   sp_mesos passage      pred       act   het_act  het_pred
# 7   100099-AE-AF-mGAM-mBHI       7  0.391558  0.052261  0.049530  0.238240
# 18  102438-AA-AE-mGAM-mBHI       7  0.022390  0.007107  0.007056  0.021889
# 15  101294-AE-AF-mBHI-mGAM       7  0.051755  0.005163  0.005137  0.049077
# 13  100910-AA-AE-mBHI-mGAM       7  0.112576  0.999859  0.000141  0.099903

# %%
len(df)
# Out:
# 28

# %%
p = np.random.choice([0,1],size=(28,10000))
b=p.sum(axis=0)
np.percentile(b,99.5)
# Out:
# np.float64(21.0)

# %%
big_df_good_pol = big_df_good.copy()
#print(big_df_good_pol['sel_12']>0,)
#big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>0,'pred_val_sel_12']
big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'boot_med1']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'boot_med1']
big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']=1-big_df_good_pol.loc[big_df_good_pol['pred_val_sel_12']>.5,'pred_val_sel_12']

print(len(big_df_good_pol))
b=big_df_good_pol.groupby(['species-type_meso']).median(numeric_only=True)

p = hv.Points(big_df_good_pol,vdims=['boot_med1'],kdims = ['pred_val_sel_12','boot_med1'])
p = hv.render(p)
points = np.linspace(-1,2)
p.line(points,points)
bokeh.io.show(p)
# Out:
# 151
#   <div id="ed43de09-99be-4620-94b4-b29f6f8a9641" data-root-id="5fde536c-b3c7-4ff8-a991-25e8192dc220" style="display: contents;"></div>

# %%
def make_big_plot(meds,logit_scale=False,sel_range = (-.5,.5),line=True,width=400):
    if logit_scale:
        meds = meds.copy()
        for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med','pred7_med']:
            meds[freq_column]=np.log(meds[freq_column]/(1-meds[freq_column]))

         #   'early_sel_med','act_7_med','pred7_med','late_sel_med'
    scatter = hv.Scatter(meds, kdims =  'pred7_med', vdims=['act_7_med',hv.Dimension('early_sel_med',range=sel_range)]).opts(#size=4, 
                                                                                        alpha = 1.0, color = 'early_sel_med',#height=700,
                                                                                           width = width,line_color='black',
                                                                                                      
                                                                                      cmap = 'Magma',
                                                                                                            colorbar=True, 
                                                                                                  # logx=True, logy=True,
                                                                                                    legend_position='right',
                                                                                                        size=10,
                                                                                         )
    seg = hv.Segments(meds, ['pred7_med', 
                             'min_act_7_med', 
                             'pred7_med', 'max_act_7_med', ]).opts(color='black',alpha=.2)
    
    seg2 = hv.Segments(meds, ['min_pred7_med', 
                             'act_7_med', 
                             'max_pred7_med', 'act_7_med', ]).opts(color='black',alpha=.2)

    exps_adjust = np.array([.001,.01,.1,.5,.9,.99,.999])
    lins_adjust = np.log(exps_adjust/(1-exps_adjust))
    #exps_adjust = exps_adjust[::2]
   # lins_adjust = lins_adjust[::2]
    if logit_scale:
        scatter.opts(xticks=[(lins_adjust[i], exps_adjust[i]) for i in range(len(lins_adjust))],
                 yticks=[(lins_adjust[i], exps_adjust[i]) for i in range(len(lins_adjust))]
                )
    
    ticks = np.linspace(sel_range[0],sel_range[1],6)
    labels = [str(tick) for tick in ticks]
   # if sel_range[0]!=0:
    labels[0] = '<' + labels[0]
   # if sel_range[-1]!= 0:
    labels[-1] = '>' + labels[-1]

    #labels[-1] = '>' + labels[-1]
    print(labels)
  #  labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    
    # Apply colorbar customization
    scatter.opts(
        colorbar=True,
        colorbar_opts={
            'major_label_overrides': dict(zip(ticks, labels))
        }
    )

    scatter = hv.render(scatter*seg*seg2)
    if line:
        if logit_scale:
            scatter.line(np.linspace(-8,8), np.linspace(-8,8),color = 'black', )
        else:
            scatter.line(np.linspace(1e-20,1), np.linspace(1e-20,1),color = 'black', )
        
    scatter.legend.visible = True
    scatter.xaxis.axis_label = 'Predicted final frequency'
    scatter.yaxis.axis_label = 'Actual final frequency'
    #bokeh.io.show(scatter)
    return scatter,meds

# %%
def polarize(df,positive=False):
    to_polarize = df.loc[df['pred7_med']>.5,:].index.values
    if positive:
        to_polarize = df.loc[df['pred7_med']<.5,:].index.values
    print(to_polarize)
    for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med',]:
        df.loc[to_polarize,freq_column]= 1- df.loc[to_polarize,freq_column]
    for sel_column in ['early_sel_med','max_early_sel_med','min_early_sel_med',
                      'late_sel_med','max_late_sel_med','min_late_sel_med',]:
        df.loc[to_polarize,sel_column]= -df.loc[to_polarize,sel_column]
    print(df.loc[to_polarize,'pred7_med'])
    df.loc[to_polarize,'pred7_med']=1-df.loc[to_polarize,'pred7_med']
    return df


def adjust(df,thresh=1e-3):
   # to_polarize = df.loc[df['pred_p7s']>.5,:].index.values
    for freq_column in ['act_7_med', 'min_act_7_med',  'max_act_7_med', 'min_pred7_med','max_pred7_med','pred7_med']:
        df.loc[df[freq_column]>1-thresh,freq_column]= 1-thresh
        df.loc[df[freq_column]<thresh,freq_column]= thresh
    return df

# %%
all_dfs=[]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
t0 = 1
t1 = 2
big_dfs = []
bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']
for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
        if f'{sp}-{ino}' in bad_inos:
            continue 
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_shift_self_test_mod_shift/{sp}/{ino}_{str(t0)}_{str(t1)}_6_7_parent1_info_shift.csv'
        if os.path.exists(fname):
            df,_= get_selection_stuff_time_vary(sp,ino,t0,t1,thresh=1e-3)
            #df,df2=get_selection_stuff_time_vary_all_times(sp,ino,t0,t1,thresh=1e-3)
          #  df2['species_id']==sp
            
            if len(df)>0:
                df['species_id']=sp
                big_dfs.append(df.reset_index())
            
big_df=pd.concat(big_dfs).reset_index()
len(big_df['species_id'].unique())
big_df['species-type_meso']=big_df['species_id'].astype(str)+'-'+big_df['type_mesocosm'].astype(str)
#big_df['species-mesocosm']=big_df['species_id'].astype(str)+'-'+big_df['mesocosm'].astype(str)
#big_df = big_df.loc[~big_df['pred_val_sel_12'].isna(),:]
#big_df_good=big_df.loc[(big_df['pred_val_sel_12']>1e-2)*(big_df['pred_val_sel_12']<1-1e-2),:]
#big_df = big_df.set_index('species-type_meso')
len(big_df['species_id'].unique())
# Out:
# 11

# %%
            
big_df=pd.concat(big_dfs).reset_index()
len(big_df['species_id'].unique())
big_df['species-type_meso']=big_df['species_id'].astype(str)+'-'+big_df['type_mesocosm'].astype(str)
big_df = big_df.set_index('species-type_meso')
big_df.head()
pol = polarize(big_df,positive=True)
pol = adjust(pol)
# Out:
# ['100146-AA-AE-mGAM-mBHI' '100146-AA-AF-mGAM-mGAM'
#  '102438-AA-AE-mBHI-mGAM' '102438-AA-AF-mBHI-mBHI'
#  '102438-AA-AF-mBHI-mGAM' '102438-AE-AF-mBHI-mBHI'
#  '102438-AA-AE-mGAM-mBHI' '102438-AA-AE-mGAM-mGAM'
#  '102438-AA-AF-mGAM-mBHI' '102438-AA-AF-mGAM-mGAM'
#  '102438-AE-AF-mGAM-mBHI' '100196-AA-AE-mBHI-mGAM'
#  '100196-AA-AF-mGAM-mGAM' '102506-AA-AF-mGAM-mBHI'
#  '102506-AA-AF-mGAM-mGAM' '101346-AA-AF-mGAM-mGAM'
#  '100099-AA-AE-mBHI-mBHI' '100099-AA-AE-mBHI-mGAM'
#  '100099-AA-AF-mBHI-mBHI' '100099-AA-AF-mBHI-mGAM'
#  '100099-AE-AF-mBHI-mBHI' '100099-AE-AF-mBHI-mGAM'
#  '100099-AA-AE-mGAM-mGAM' '100099-AA-AF-mGAM-mBHI'
#  '100099-AA-AF-mGAM-mGAM' '100099-AE-AF-mGAM-mBHI'
#  '101294-AE-AF-mBHI-mGAM' '101294-AA-AE-mGAM-mGAM'
#  '101294-AA-AF-mGAM-mGAM']
# species-type_meso
# 100146-AA-AE-mGAM-mBHI    3.392826e-06
# 100146-AA-AF-mGAM-mGAM    4.881343e-15
# 102438-AA-AE-mBHI-mGAM    1.591619e-10
# 102438-AA-AF-mBHI-mBHI    1.263791e-06
# 102438-AA-AF-mBHI-mGAM    4.065061e-08
# 102438-AE-AF-mBHI-mBHI    1.103148e-02
# 102438-AA-AE-mGAM-mBHI    2.223953e-02
# 102438-AA-AE-mGAM-mGAM    7.116606e-07
# 102438-AA-AF-mGAM-mBHI    3.720995e-08
# 102438-AA-AF-mGAM-mGAM    2.949577e-07
# 102438-AE-AF-mGAM-mBHI    4.985084e-01
# 100196-AA-AE-mBHI-mGAM    8.861110e-04
# 100196-AA-AF-mGAM-mGAM    3.226409e-07
# 102506-AA-AF-mGAM-mBHI    6.159110e-04
# 102506-AA-AF-mGAM-mGAM    7.143977e-05
# 101346-AA-AF-mGAM-mGAM    3.098858e-07
# 100099-AA-AE-mBHI-mBHI    2.334749e-07
# 100099-AA-AE-mBHI-mGAM    7.750429e-07
# 100099-AA-AF-mBHI-mBHI    7.299593e-04
# 100099-AA-AF-mBHI-mGAM    1.563034e-06
# 100099-AE-AF-mBHI-mBHI    3.228213e-05
# 100099-AE-AF-mBHI-mGAM    5.925187e-05
# 100099-AA-AE-mGAM-mGAM    2.488562e-04
# 100099-AA-AF-mGAM-mBHI    2.647757e-12
# 100099-AA-AF-mGAM-mGAM    1.286096e-06
# 100099-AE-AF-mGAM-mBHI    6.382418e-07
# 101294-AE-AF-mBHI-mGAM    5.107743e-02
# 101294-AA-AE-mGAM-mGAM    1.136840e-09
# 101294-AA-AF-mGAM-mGAM    2.113908e-03
# Name: pred7_med, dtype: float64

# %%
pol.loc[pol['species_id']=='103656',:]
# Out:
#                         index    type_mesocosm species   inoculumn  \
# species-type_meso
# 103656-AA-AE-mGAM-mGAM      0  AA-AE-mGAM-mGAM  103656  AA-AE-mGAM
# 103656-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  103656  AA-AF-mGAM
#
#                         Unnamed: 0  diff7_med  diff7_lower  diff7_upper  \
# species-type_meso
# 103656-AA-AE-mGAM-mGAM         0.5        NaN          NaN          NaN
# 103656-AA-AF-mGAM-mGAM         1.0        NaN          NaN          NaN
#
#                         pred_7_upper  pred_7_lower  ...  t1_val  \
# species-type_meso                                   ...
# 103656-AA-AE-mGAM-mGAM           NaN           NaN  ...     NaN
# 103656-AA-AF-mGAM-mGAM           NaN           NaN  ...     NaN
#
#                         max_early_sel_med  min_early_sel_med  max_act_7_med  \
# species-type_meso
# 103656-AA-AE-mGAM-mGAM                NaN                NaN            NaN
# 103656-AA-AF-mGAM-mGAM                NaN                NaN            NaN
#
#                         min_act_7_med  max_pred7_med  min_pred7_med  \
# species-type_meso
# 103656-AA-AE-mGAM-mGAM            NaN            NaN            NaN
# 103656-AA-AF-mGAM-mGAM            NaN            NaN            NaN
#
#                         max_late_sel_med  min_late_sel_med  species_id
# species-type_meso
# 103656-AA-AE-mGAM-mGAM               NaN               NaN      103656
# 103656-AA-AF-mGAM-mGAM               NaN               NaN      103656
#
# [2 rows x 36 columns]

# %%
b=pol.loc[pol['pred7_med']<1e-1,:]
print(len(b))
b=b.loc[b['act_7_med']>1e-1,:]
print(len(b))
# Out:
# 0
# 0

# %%
b=pol.loc[(pol['act_7_med']>=1-5*1e-3),:]
b
# Out:
#                         index    type_mesocosm species   inoculumn  \
# species-type_meso
# 102478-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  102478  AA-AF-mGAM
# 102438-AA-AE-mBHI-mGAM      0  AA-AE-mBHI-mGAM  102438  AA-AE-mBHI
# 102438-AA-AF-mBHI-mGAM      1  AA-AF-mBHI-mGAM  102438  AA-AF-mBHI
# 102438-AA-AE-mGAM-mGAM      1  AA-AE-mGAM-mGAM  102438  AA-AE-mGAM
# 100196-AA-AE-mBHI-mGAM      0  AA-AE-mBHI-mGAM  100196  AA-AE-mBHI
# 102506-AA-AF-mGAM-mGAM      1  AA-AF-mGAM-mGAM  102506  AA-AF-mGAM
# 100099-AA-AE-mBHI-mBHI      0  AA-AE-mBHI-mBHI  100099  AA-AE-mBHI
# 100099-AA-AE-mBHI-mGAM      1  AA-AE-mBHI-mGAM  100099  AA-AE-mBHI
# 100099-AA-AF-mBHI-mGAM      1  AA-AF-mBHI-mGAM  100099  AA-AF-mBHI
# 100099-AE-AF-mBHI-mBHI      0  AE-AF-mBHI-mBHI  100099  AE-AF-mBHI
# 101294-AA-AE-mGAM-mGAM      0  AA-AE-mGAM-mGAM  101294  AA-AE-mGAM
# 101294-AE-AF-mGAM-mBHI      0  AE-AF-mGAM-mBHI  101294  AE-AF-mGAM
#
#                         Unnamed: 0     diff7_med   diff7_lower  diff7_upper  \
# species-type_meso
# 102478-AA-AF-mGAM-mGAM         2.5  1.354857e-03  8.721106e-04     0.001889
# 102438-AA-AE-mBHI-mGAM         0.0  0.000000e+00  0.000000e+00     0.000000
# 102438-AA-AF-mBHI-mGAM         2.0 -3.065594e-04 -4.575413e-04    -0.000154
# 102438-AA-AE-mGAM-mGAM         4.5  0.000000e+00  0.000000e+00     0.000000
# 100196-AA-AE-mBHI-mGAM         1.5 -5.493896e-05 -5.555556e-05    -0.000054
# 102506-AA-AF-mGAM-mGAM         3.5 -4.368116e-04 -6.039184e-04    -0.000262
# 100099-AA-AE-mBHI-mBHI         0.0  0.000000e+00  0.000000e+00     0.000000
# 100099-AA-AE-mBHI-mGAM         2.0  0.000000e+00 -8.687682e-09     0.000000
# 100099-AA-AF-mBHI-mGAM         3.0 -2.437243e-04 -3.745137e-04    -0.000116
# 100099-AE-AF-mBHI-mBHI         2.5 -1.360348e-03 -1.571766e-03    -0.001164
# 101294-AA-AE-mGAM-mGAM         0.5 -2.603822e-07 -9.246605e-07     0.000000
# 101294-AE-AF-mGAM-mBHI         1.0  1.770596e-03  9.879628e-04     0.002711
#
#                         pred_7_upper  pred_7_lower  ...  t1_val  \
# species-type_meso                                   ...
# 102478-AA-AF-mGAM-mGAM  1.000000e+00  1.000000e+00  ...     NaN
# 102438-AA-AE-mBHI-mGAM  2.721752e-10  3.723138e-11  ...     NaN
# 102438-AA-AF-mBHI-mGAM  9.519752e-08  2.070103e-09  ...     NaN
# 102438-AA-AE-mGAM-mGAM  1.551011e-06  5.860975e-07  ...     NaN
# 100196-AA-AE-mBHI-mGAM  9.006157e-04  6.836100e-04  ...     NaN
# 102506-AA-AF-mGAM-mGAM  8.679191e-05  5.840693e-05  ...     NaN
# 100099-AA-AE-mBHI-mBHI  3.034476e-07  1.540481e-07  ...     NaN
# 100099-AA-AE-mBHI-mGAM  1.039771e-06  6.579899e-07  ...     NaN
# 100099-AA-AF-mBHI-mGAM  2.757576e-06  8.980805e-07  ...     NaN
# 100099-AE-AF-mBHI-mBHI  3.655260e-05  2.288442e-05  ...     NaN
# 101294-AA-AE-mGAM-mGAM  5.141795e-09  1.878120e-10  ...     NaN
# 101294-AE-AF-mGAM-mBHI  9.999952e-01  9.999888e-01  ...     NaN
#
#                         max_early_sel_med  min_early_sel_med  max_act_7_med  \
# species-type_meso
# 102478-AA-AF-mGAM-mGAM           4.780776           2.385141       0.999000
# 102438-AA-AE-mBHI-mGAM           3.130869           3.130869       0.999000
# 102438-AA-AF-mBHI-mGAM           2.413089           2.413089       0.998693
# 102438-AA-AE-mGAM-mGAM           1.201105           2.704155       0.998999
# 100196-AA-AE-mBHI-mGAM           0.019659           0.036068       0.998890
# 102506-AA-AF-mGAM-mGAM           1.131330           1.880615       0.998178
# 100099-AA-AE-mBHI-mBHI           2.345639           2.345639       0.999000
# 100099-AA-AE-mBHI-mGAM           1.908134           3.064204       0.999000
# 100099-AA-AF-mBHI-mGAM           1.885562           1.885562       0.998756
# 100099-AE-AF-mBHI-mBHI           1.378578           3.037295       0.975928
# 101294-AA-AE-mGAM-mGAM           2.839561           3.241507       0.998999
# 101294-AE-AF-mGAM-mBHI           1.908730           1.908730       0.997229
#
#                         min_act_7_med  max_pred7_med  min_pred7_med  \
# species-type_meso
# 102478-AA-AF-mGAM-mGAM       0.991984          0.999          0.999
# 102438-AA-AE-mBHI-mGAM       0.999000          0.999          0.999
# 102438-AA-AF-mBHI-mGAM       0.998693          0.999          0.999
# 102438-AA-AE-mGAM-mGAM       0.999000          0.999          0.999
# 100196-AA-AE-mBHI-mGAM       0.999000          0.999          0.999
# 102506-AA-AF-mGAM-mGAM       0.999000          0.999          0.999
# 100099-AA-AE-mBHI-mBHI       0.999000          0.999          0.999
# 100099-AA-AE-mBHI-mGAM       0.999000          0.999          0.999
# 100099-AA-AF-mBHI-mGAM       0.998756          0.999          0.999
# 100099-AE-AF-mBHI-mBHI       0.998900          0.999          0.999
# 101294-AA-AE-mGAM-mGAM       0.999000          0.999          0.999
# 101294-AE-AF-mGAM-mBHI       0.997229          0.999          0.999
#
#                         max_late_sel_med  min_late_sel_med  species_id
# species-type_meso
# 102478-AA-AF-mGAM-mGAM          1.668171         -1.123854      102478
# 102438-AA-AE-mBHI-mGAM          3.130869          3.130869      102438
# 102438-AA-AF-mBHI-mGAM         -0.267704         -0.267704      102438
# 102438-AA-AE-mGAM-mGAM         -0.001002          2.316698      102438
# 100196-AA-AE-mBHI-mGAM          0.019659          0.036068      100196
# 102506-AA-AF-mGAM-mGAM          0.226344          1.482348      102506
# 100099-AA-AE-mBHI-mBHI          0.355340          0.355340      100099
# 100099-AA-AE-mBHI-mGAM         -0.000000          0.243877      100099
# 100099-AA-AF-mBHI-mGAM         -0.218354         -0.218354      100099
# 100099-AE-AF-mBHI-mBHI         -2.269325          0.939547      100099
# 101294-AA-AE-mGAM-mGAM         -0.000521          1.221231      101294
# 101294-AE-AF-mGAM-mBHI          0.143854          0.143854      101294
#
# [12 rows x 36 columns]

# %%
p,_ = make_big_plot(pol,sel_range = (-2,0),logit_scale=False)
p.x_range = bokeh.models.Range1d(-.05,.5)
#p.y_range = bokeh.models.Range1d(-.05,1.05)
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,f'time_varying_{str(t0)}_{str(t1)}_freq')
# Out:
# ['<-2.0', '-1.6', '-1.2', '-0.7999999999999998', '-0.3999999999999999', '>0.0']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_83054/292325157.py:61: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   scatter.legend.visible = True
#   <div id="c33cd14d-2f59-4dd9-a0a7-1e8fa052f465" data-root-id="0ed7532c-79a4-4045-917c-2841436ca6ce" style="display: contents;"></div>

# %%
p,_ = make_big_plot(pol.loc[pol['pred7_med']<1e-1,:],sel_range = (-4.0,0),width=400,logit_scale=True)
p.x_range = bokeh.models.Range1d(-8.,-2)
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,'time_varying_01_freq_inset')
# Out:
# ['<-4.0', '-3.2', '-2.4', '-1.5999999999999996', '-0.7999999999999998', '>0.0']
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_83054/292325157.py:61: UserWarning:
# You are attempting to set `plot.legend.visible` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   scatter.legend.visible = True
#   <div id="c797f292-edf3-44a2-aa9a-69699c84a9e3" data-root-id="2ff630a7-2755-418e-87e0-54a2be1469fe" style="display: contents;"></div>

# %%
from holoviews.operation import histogram
def make_big_plot_sel(meds,line=True,width=400):
    scatter = hv.Scatter(meds.sort_values(by='act_7_med'), kdims =  'early_sel_med', vdims=['late_sel_med',hv.Dimension('act_7_med',range=(0,1))]).opts(#size=4, 
                                                                                        alpha = 1.0,  xlim=(-1,7), ylim=(-7,7),height=300,width=300,
                                                                                           line_color='black',color=bokeh.palettes.Set2[3][-1],
                                                                                                      
                                                                                     # cmap = 'Magma',
                                                                                                          #  colorbar=True, 
                                                                                                  # logx=True, logy=True,
                                                                                                    legend_position='right',
                                                                                                        size=10,
        
                                                                                         )
    seg = hv.Segments(meds, ['early_sel_med', 
                             'min_late_sel_med', 
                             'early_sel_med', 'max_late_sel_med', ]).opts(color='black',alpha=.2,)#backend_opts={'plot.output_backend':'svg'})
    
    seg2 = hv.Segments(meds, ['min_early_sel_med', 
                             'late_sel_med', 
                             'max_early_sel_med', 'late_sel_med', ]).opts(color='black',alpha=.2,)#backend_opts={'plot.output_backend':'svg'})
    
    ticks = np.linspace(0,1,6)
    labels = [str(tick) for tick in ticks]
   # if sel_range[0]!=0:
    labels[0] = '<' + labels[0]
   # if sel_range[-1]!= 0:
    labels[-1] = '>' + labels[-1]

    #labels[-1] = '>' + labels[-1]
    print(labels)
  #  labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    
    # Apply colorbar customization
    scatter.opts(
        colorbar=True,
        #\colorbar_opts={
      #      'major_label_overrides': dict(zip(ticks, labels))
      #  }
    )
  #  [(i,i) for i in np.linspace(-10,10)]
    p = hv.Curve([(i,i) for i in np.linspace(-7,7)]).opts(line_color='grey',xlim=(-1,7),
                                                         ylim=(-7,7), )#backend_opts={'plot.output_backend':'svg'})

    scatter=scatter#.hist(dimension=['early_sel_med','late_sel_med'],).opts(opts.Histogram(color=bokeh.palettes.Set2[3][-1]),)
                                                                         # backend_opts={'plot.output_backend':'svg'})
    scatter = scatter*seg*seg2*p
 #   scatter = (scatter) << yhist.opts(width=300) << xhist.opts(height=300)
   # scatter = hv.render(scatter*seg*seg2*p, kwargs=dict(fmt='svg'))
#    scatter.line(np.linspace(-10,10), np.linspace(-10,10),color = 'black', )
        
   # scatter.legend.visible = True
 #   scatter.yaxis.axis_label = 'Sel 6-7'
    #bokeh.io.show(scatter)
    return scatter

# %%
bokeh.io.show(p, )
bokeh.io.export_svg(p,filename="plots/plot.svg")
# Out:
#   <div id="b4883b2d-bc82-4831-beb9-f001c83c793c" data-root-id="2ff630a7-2755-418e-87e0-54a2be1469fe" style="display: contents;"></div>
# ['plots/plot.svg']

# %%
pol
# Out:
#                         index    type_mesocosm species   inoculumn  \
# species-type_meso
# 100146-AA-AE-mGAM-mBHI      0  AA-AE-mGAM-mBHI  100146  AA-AE-mGAM
# 100146-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  100146  AA-AF-mGAM
# 100146-AE-AF-mGAM-mBHI      0  AE-AF-mGAM-mBHI  100146  AE-AF-mGAM
# 101059-AA-AF-mBHI-mBHI      0  AA-AF-mBHI-mBHI  101059  AA-AF-mBHI
# 101059-AA-AF-mBHI-mGAM      1  AA-AF-mBHI-mGAM  101059  AA-AF-mBHI
# 100910-AA-AE-mBHI-mBHI      0  AA-AE-mBHI-mBHI  100910  AA-AE-mBHI
# 102478-AA-AE-mGAM-mBHI      0  AA-AE-mGAM-mBHI  102478  AA-AE-mGAM
# 102478-AA-AE-mGAM-mGAM      1  AA-AE-mGAM-mGAM  102478  AA-AE-mGAM
# 102478-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  102478  AA-AF-mGAM
# 102478-AE-AF-mGAM-mBHI      0  AE-AF-mGAM-mBHI  102478  AE-AF-mGAM
# 102438-AA-AE-mBHI-mGAM      0  AA-AE-mBHI-mGAM  102438  AA-AE-mBHI
# 102438-AA-AF-mBHI-mBHI      0  AA-AF-mBHI-mBHI  102438  AA-AF-mBHI
# 102438-AA-AF-mBHI-mGAM      1  AA-AF-mBHI-mGAM  102438  AA-AF-mBHI
# 102438-AE-AF-mBHI-mBHI      0  AE-AF-mBHI-mBHI  102438  AE-AF-mBHI
# 102438-AE-AF-mBHI-mGAM      1  AE-AF-mBHI-mGAM  102438  AE-AF-mBHI
# 102438-AA-AE-mGAM-mBHI      0  AA-AE-mGAM-mBHI  102438  AA-AE-mGAM
# 102438-AA-AE-mGAM-mGAM      1  AA-AE-mGAM-mGAM  102438  AA-AE-mGAM
# 102438-AA-AF-mGAM-mBHI      0  AA-AF-mGAM-mBHI  102438  AA-AF-mGAM
# 102438-AA-AF-mGAM-mGAM      1  AA-AF-mGAM-mGAM  102438  AA-AF-mGAM
# 102438-AE-AF-mGAM-mBHI      0  AE-AF-mGAM-mBHI  102438  AE-AF-mGAM
# 102438-AE-AF-mGAM-mGAM      1  AE-AF-mGAM-mGAM  102438  AE-AF-mGAM
# 100196-AA-AE-mBHI-mGAM      0  AA-AE-mBHI-mGAM  100196  AA-AE-mBHI
# 100196-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  100196  AA-AF-mGAM
# 103656-AA-AE-mGAM-mGAM      0  AA-AE-mGAM-mGAM  103656  AA-AE-mGAM
# 103656-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  103656  AA-AF-mGAM
# 102506-AA-AF-mGAM-mBHI      0  AA-AF-mGAM-mBHI  102506  AA-AF-mGAM
# 102506-AA-AF-mGAM-mGAM      1  AA-AF-mGAM-mGAM  102506  AA-AF-mGAM
# 101346-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  101346  AA-AF-mGAM
# 100099-AA-AE-mBHI-mBHI      0  AA-AE-mBHI-mBHI  100099  AA-AE-mBHI
# 100099-AA-AE-mBHI-mGAM      1  AA-AE-mBHI-mGAM  100099  AA-AE-mBHI
# 100099-AA-AF-mBHI-mBHI      0  AA-AF-mBHI-mBHI  100099  AA-AF-mBHI
# 100099-AA-AF-mBHI-mGAM      1  AA-AF-mBHI-mGAM  100099  AA-AF-mBHI
# 100099-AE-AF-mBHI-mBHI      0  AE-AF-mBHI-mBHI  100099  AE-AF-mBHI
# 100099-AE-AF-mBHI-mGAM      1  AE-AF-mBHI-mGAM  100099  AE-AF-mBHI
# 100099-AA-AE-mGAM-mBHI      0  AA-AE-mGAM-mBHI  100099  AA-AE-mGAM
# 100099-AA-AE-mGAM-mGAM      1  AA-AE-mGAM-mGAM  100099  AA-AE-mGAM
# 100099-AA-AF-mGAM-mBHI      0  AA-AF-mGAM-mBHI  100099  AA-AF-mGAM
# 100099-AA-AF-mGAM-mGAM      1  AA-AF-mGAM-mGAM  100099  AA-AF-mGAM
# 100099-AE-AF-mGAM-mBHI      0  AE-AF-mGAM-mBHI  100099  AE-AF-mGAM
# 100099-AE-AF-mGAM-mGAM      1  AE-AF-mGAM-mGAM  100099  AE-AF-mGAM
# 101294-AE-AF-mBHI-mGAM      0  AE-AF-mBHI-mGAM  101294  AE-AF-mBHI
# 101294-AA-AE-mGAM-mGAM      0  AA-AE-mGAM-mGAM  101294  AA-AE-mGAM
# 101294-AA-AF-mGAM-mGAM      0  AA-AF-mGAM-mGAM  101294  AA-AF-mGAM
# 101294-AE-AF-mGAM-mBHI      0  AE-AF-mGAM-mBHI  101294  AE-AF-mGAM
# 101294-AE-AF-mGAM-mGAM      1  AE-AF-mGAM-mGAM  101294  AE-AF-mGAM
#
#                         Unnamed: 0     diff7_med   diff7_lower  diff7_upper  \
# species-type_meso
# 100146-AA-AE-mGAM-mBHI         1.5 -5.410998e-01 -5.447099e-01    -0.529888
# 100146-AA-AF-mGAM-mGAM         2.0 -4.679944e-03 -5.808086e-03    -0.003702
# 100146-AE-AF-mGAM-mBHI         1.0  2.899986e-01  2.860866e-01     0.293289
# 101059-AA-AF-mBHI-mBHI         1.5           NaN           NaN          NaN
# 101059-AA-AF-mBHI-mGAM         4.0           NaN           NaN          NaN
# 100910-AA-AE-mBHI-mBHI         0.0  7.071717e-02  6.862664e-02     0.074303
# 102478-AA-AE-mGAM-mBHI         1.5           NaN           NaN          NaN
# 102478-AA-AE-mGAM-mGAM         3.0           NaN           NaN          NaN
# 102478-AA-AF-mGAM-mGAM         2.5  1.354857e-03  8.721106e-04     0.001889
# 102478-AE-AF-mGAM-mBHI         0.0           NaN           NaN          NaN
# 102438-AA-AE-mBHI-mGAM         0.0  0.000000e+00  0.000000e+00     0.000000
# 102438-AA-AF-mBHI-mBHI         1.0 -5.660216e-03 -6.557391e-03    -0.004801
# 102438-AA-AF-mBHI-mGAM         2.0 -3.065594e-04 -4.575413e-04    -0.000154
# 102438-AE-AF-mBHI-mBHI         0.5 -4.363594e-01 -4.436462e-01    -0.425531
# 102438-AE-AF-mBHI-mGAM         3.5  5.372445e-01  5.341983e-01     0.540316
# 102438-AA-AE-mGAM-mBHI         2.0  1.697939e-02  1.057023e-02     0.022078
# 102438-AA-AE-mGAM-mGAM         4.5  0.000000e+00  0.000000e+00     0.000000
# 102438-AA-AF-mGAM-mBHI         3.5 -6.968437e-02 -7.117652e-02    -0.067296
# 102438-AA-AF-mGAM-mGAM         3.5 -8.657989e-02 -8.751536e-02    -0.081951
# 102438-AE-AF-mGAM-mBHI         1.0  2.146201e-02  1.698427e-02     0.025021
# 102438-AE-AF-mGAM-mGAM         3.0  2.240815e-03  1.099698e-03     0.003277
# 100196-AA-AE-mBHI-mGAM         1.5 -5.493896e-05 -5.555556e-05    -0.000054
# 100196-AA-AF-mGAM-mGAM         3.5 -1.316865e-01 -1.328670e-01    -0.130284
# 103656-AA-AE-mGAM-mGAM         0.5           NaN           NaN          NaN
# 103656-AA-AF-mGAM-mGAM         1.0           NaN           NaN          NaN
# 102506-AA-AF-mGAM-mBHI         3.5 -1.529187e-02 -1.580862e-02    -0.014241
# 102506-AA-AF-mGAM-mGAM         3.5 -4.368116e-04 -6.039184e-04    -0.000262
# 101346-AA-AF-mGAM-mGAM         2.0 -1.727411e-02 -1.926342e-02    -0.015277
# 100099-AA-AE-mBHI-mBHI         0.0  0.000000e+00  0.000000e+00     0.000000
# 100099-AA-AE-mBHI-mGAM         2.0  0.000000e+00 -8.687682e-09     0.000000
# 100099-AA-AF-mBHI-mBHI         1.5 -2.899058e-02 -3.137393e-02    -0.026968
# 100099-AA-AF-mBHI-mGAM         3.0 -2.437243e-04 -3.745137e-04    -0.000116
# 100099-AE-AF-mBHI-mBHI         2.5 -1.360348e-03 -1.571766e-03    -0.001164
# 100099-AE-AF-mBHI-mGAM         4.5 -7.905511e-02 -8.088634e-02    -0.076458
# 100099-AA-AE-mGAM-mBHI         2.5  4.885003e-01  4.755307e-01     0.504421
# 100099-AA-AE-mGAM-mGAM         5.5 -6.949222e-02 -7.119703e-02    -0.068262
# 100099-AA-AF-mGAM-mBHI         3.5 -6.535176e-03 -6.542254e-03    -0.006039
# 100099-AA-AF-mGAM-mGAM         3.5 -6.547275e-02 -6.778005e-02    -0.064013
# 100099-AE-AF-mGAM-mBHI         2.0 -2.073422e-03 -2.312167e-03    -0.001845
# 100099-AE-AF-mGAM-mGAM         4.0  1.786954e-01  1.773181e-01     0.180542
# 101294-AE-AF-mBHI-mGAM         1.5  4.520840e-02  2.024308e-02     0.078938
# 101294-AA-AE-mGAM-mGAM         0.5 -2.603822e-07 -9.246605e-07     0.000000
# 101294-AA-AF-mGAM-mGAM         1.5 -7.144247e-02 -7.765354e-02    -0.061820
# 101294-AE-AF-mGAM-mBHI         1.0  1.770596e-03  9.879628e-04     0.002711
# 101294-AE-AF-mGAM-mGAM         0.0  5.224064e-02  4.426371e-03     0.124583
#
#                         pred_7_upper  pred_7_lower  ...  t1_val  \
# species-type_meso                                   ...
# 100146-AA-AE-mGAM-mBHI  4.189340e-06  2.849576e-06  ...     NaN
# 100146-AA-AF-mGAM-mGAM  1.522294e-14  1.397497e-15  ...     NaN
# 100146-AE-AF-mGAM-mBHI  9.991126e-01  9.978233e-01  ...     NaN
# 101059-AA-AF-mBHI-mBHI           NaN           NaN  ...     NaN
# 101059-AA-AF-mBHI-mGAM           NaN           NaN  ...     NaN
# 100910-AA-AE-mBHI-mBHI  9.999985e-01  9.999972e-01  ...     NaN
# 102478-AA-AE-mGAM-mBHI           NaN           NaN  ...     NaN
# 102478-AA-AE-mGAM-mGAM           NaN           NaN  ...     NaN
# 102478-AA-AF-mGAM-mGAM  1.000000e+00  1.000000e+00  ...     NaN
# 102478-AE-AF-mGAM-mBHI           NaN           NaN  ...     NaN
# 102438-AA-AE-mBHI-mGAM  2.721752e-10  3.723138e-11  ...     NaN
# 102438-AA-AF-mBHI-mBHI  7.278534e-06  6.623014e-07  ...     NaN
# 102438-AA-AF-mBHI-mGAM  9.519752e-08  2.070103e-09  ...     NaN
# 102438-AE-AF-mBHI-mBHI  1.683201e-02  8.866175e-03  ...     NaN
# 102438-AE-AF-mBHI-mGAM  9.961860e-01  9.952405e-01  ...     NaN
# 102438-AA-AE-mGAM-mBHI  2.742542e-02  1.595093e-02  ...     NaN
# 102438-AA-AE-mGAM-mGAM  1.551011e-06  5.860975e-07  ...     NaN
# 102438-AA-AF-mGAM-mBHI  6.550018e-08  1.950410e-08  ...     NaN
# 102438-AA-AF-mGAM-mGAM  4.195465e-07  2.045844e-07  ...     NaN
# 102438-AE-AF-mGAM-mBHI  4.997905e-01  4.957643e-01  ...     NaN
# 102438-AE-AF-mGAM-mGAM  9.574759e-01  9.072694e-01  ...     NaN
# 100196-AA-AE-mBHI-mGAM  9.006157e-04  6.836100e-04  ...     NaN
# 100196-AA-AF-mGAM-mGAM  3.508844e-07  2.965478e-07  ...     NaN
# 103656-AA-AE-mGAM-mGAM           NaN           NaN  ...     NaN
# 103656-AA-AF-mGAM-mGAM           NaN           NaN  ...     NaN
# 102506-AA-AF-mGAM-mBHI  8.015585e-04  4.789525e-04  ...     NaN
# 102506-AA-AF-mGAM-mGAM  8.679191e-05  5.840693e-05  ...     NaN
# 101346-AA-AF-mGAM-mGAM  3.594110e-07  2.689883e-07  ...     NaN
# 100099-AA-AE-mBHI-mBHI  3.034476e-07  1.540481e-07  ...     NaN
# 100099-AA-AE-mBHI-mGAM  1.039771e-06  6.579899e-07  ...     NaN
# 100099-AA-AF-mBHI-mBHI  1.752537e-03  1.742710e-04  ...     NaN
# 100099-AA-AF-mBHI-mGAM  2.757576e-06  8.980805e-07  ...     NaN
# 100099-AE-AF-mBHI-mBHI  3.655260e-05  2.288442e-05  ...     NaN
# 100099-AE-AF-mBHI-mGAM  6.754640e-05  3.918625e-05  ...     NaN
# 100099-AA-AE-mGAM-mBHI  9.387803e-01  9.283079e-01  ...     NaN
# 100099-AA-AE-mGAM-mGAM  3.089172e-04  2.127386e-04  ...     NaN
# 100099-AA-AF-mGAM-mBHI  4.941466e-12  1.346251e-12  ...     NaN
# 100099-AA-AF-mGAM-mGAM  1.482644e-06  1.122429e-06  ...     NaN
# 100099-AE-AF-mGAM-mBHI  8.039244e-07  5.780194e-07  ...     NaN
# 100099-AE-AF-mGAM-mGAM  9.996351e-01  9.995539e-01  ...     NaN
# 101294-AE-AF-mBHI-mGAM  8.467154e-02  3.003017e-02  ...     NaN
# 101294-AA-AE-mGAM-mGAM  5.141795e-09  1.878120e-10  ...     NaN
# 101294-AA-AF-mGAM-mGAM  3.082582e-03  1.407408e-03  ...     NaN
# 101294-AE-AF-mGAM-mBHI  9.999952e-01  9.999888e-01  ...     NaN
# 101294-AE-AF-mGAM-mGAM  9.446323e-01  8.253647e-01  ...     NaN
#
#                         max_early_sel_med  min_early_sel_med  max_act_7_med  \
# species-type_meso
# 100146-AA-AE-mGAM-mBHI           1.744257           3.854358       0.204499
# 100146-AA-AF-mGAM-mGAM           5.241445           7.176380       0.993456
# 100146-AE-AF-mGAM-mBHI           4.071997           1.055020       0.773469
# 101059-AA-AF-mBHI-mBHI                NaN                NaN            NaN
# 101059-AA-AF-mBHI-mGAM                NaN                NaN            NaN
# 100910-AA-AE-mBHI-mBHI           2.184529           2.184529       0.928283
# 102478-AA-AE-mGAM-mBHI                NaN                NaN            NaN
# 102478-AA-AE-mGAM-mGAM                NaN                NaN            NaN
# 102478-AA-AF-mGAM-mGAM           4.780776           2.385141       0.999000
# 102478-AE-AF-mGAM-mBHI                NaN                NaN            NaN
# 102438-AA-AE-mBHI-mGAM           3.130869           3.130869       0.999000
# 102438-AA-AF-mBHI-mBHI           2.035319           2.035319       0.993340
# 102438-AA-AF-mBHI-mGAM           2.413089           2.413089       0.998693
# 102438-AE-AF-mBHI-mBHI           0.670088           1.684674       0.439099
# 102438-AE-AF-mBHI-mGAM           1.110293           0.105714       0.502028
# 102438-AA-AE-mGAM-mBHI          -0.341349           0.299452       0.984730
# 102438-AA-AE-mGAM-mGAM           1.201105           2.704155       0.998999
# 102438-AA-AF-mGAM-mBHI           2.636257           3.239236       0.913177
# 102438-AA-AF-mGAM-mGAM           2.233255           3.001882       0.886965
# 102438-AE-AF-mGAM-mBHI          -0.455212           1.229280       0.281443
# 102438-AE-AF-mGAM-mGAM           0.596101          -0.333152       0.995430
# 100196-AA-AE-mBHI-mGAM           0.019659           0.036068       0.998890
# 100196-AA-AF-mGAM-mGAM           2.502992           3.843851       0.735692
# 103656-AA-AE-mGAM-mGAM                NaN                NaN            NaN
# 103656-AA-AF-mGAM-mGAM                NaN                NaN            NaN
# 102506-AA-AF-mGAM-mBHI           0.877539           1.103347       0.976386
# 102506-AA-AF-mGAM-mGAM           1.131330           1.880615       0.998178
# 101346-AA-AF-mGAM-mGAM           2.656169           3.015944       0.945973
# 100099-AA-AE-mBHI-mBHI           2.345639           2.345639       0.999000
# 100099-AA-AE-mBHI-mGAM           1.908134           3.064204       0.999000
# 100099-AA-AF-mBHI-mBHI           0.698996           1.211222       0.951299
# 100099-AA-AF-mBHI-mGAM           1.885562           1.885562       0.998756
# 100099-AE-AF-mBHI-mBHI           1.378578           3.037295       0.975928
# 100099-AE-AF-mBHI-mGAM           0.833341           1.698723       0.831653
# 100099-AA-AE-mGAM-mBHI           1.105181           0.605445       0.632653
# 100099-AA-AE-mGAM-mGAM           0.802742           1.355586       0.906977
# 100099-AA-AF-mGAM-mBHI           4.138852           4.297992       0.985930
# 100099-AA-AF-mGAM-mGAM           2.076909           2.958442       0.906061
# 100099-AE-AF-mGAM-mBHI           0.227704           2.560420       0.947739
# 100099-AE-AF-mGAM-mGAM           1.075956           0.915434       0.898888
# 101294-AE-AF-mBHI-mGAM           0.159210           0.691985       0.989648
# 101294-AA-AE-mGAM-mGAM           2.839561           3.241507       0.998999
# 101294-AA-AF-mGAM-mGAM           0.259339           1.293964       0.863959
# 101294-AE-AF-mGAM-mBHI           1.908730           1.908730       0.997229
# 101294-AE-AF-mGAM-mGAM           0.298591           0.298591       0.818826
#
#                         min_act_7_med  max_pred7_med  min_pred7_med  \
# species-type_meso
# 100146-AA-AE-mGAM-mBHI       0.701826       0.999000       0.999000
# 100146-AA-AF-mGAM-mGAM       0.999000       0.999000       0.999000
# 100146-AE-AF-mGAM-mBHI       0.612870       0.999000       0.992144
# 101059-AA-AF-mBHI-mBHI            NaN            NaN            NaN
# 101059-AA-AF-mBHI-mGAM            NaN            NaN            NaN
# 100910-AA-AE-mBHI-mBHI       0.928283       0.999000       0.999000
# 102478-AA-AE-mGAM-mBHI            NaN            NaN            NaN
# 102478-AA-AE-mGAM-mGAM            NaN            NaN            NaN
# 102478-AA-AF-mGAM-mGAM       0.991984       0.999000       0.999000
# 102478-AE-AF-mGAM-mBHI            NaN            NaN            NaN
# 102438-AA-AE-mBHI-mGAM       0.999000       0.999000       0.999000
# 102438-AA-AF-mBHI-mBHI       0.993340       0.999000       0.999000
# 102438-AA-AF-mBHI-mGAM       0.998693       0.999000       0.999000
# 102438-AE-AF-mBHI-mBHI       0.667000       0.977993       0.999000
# 102438-AE-AF-mBHI-mGAM       0.290456       0.998918       0.758002
# 102438-AA-AE-mGAM-mBHI       0.994746       0.617318       0.988917
# 102438-AA-AE-mGAM-mGAM       0.999000       0.999000       0.999000
# 102438-AA-AF-mGAM-mBHI       0.945455       0.999000       0.999000
# 102438-AA-AF-mGAM-mGAM       0.941355       0.999000       0.999000
# 102438-AE-AF-mGAM-mBHI       0.764842       0.007274       0.995710
# 102438-AE-AF-mGAM-mGAM       0.356540       0.997708       0.623642
# 100196-AA-AE-mBHI-mGAM       0.999000       0.999000       0.999000
# 100196-AA-AF-mGAM-mGAM       0.998935       0.999000       0.999000
# 103656-AA-AE-mGAM-mGAM            NaN            NaN            NaN
# 103656-AA-AF-mGAM-mGAM            NaN            NaN            NaN
# 102506-AA-AF-mGAM-mBHI       0.990973       0.998989       0.999000
# 102506-AA-AF-mGAM-mGAM       0.999000       0.999000       0.999000
# 101346-AA-AF-mGAM-mGAM       0.986855       0.999000       0.999000
# 100099-AA-AE-mBHI-mBHI       0.999000       0.999000       0.999000
# 100099-AA-AE-mBHI-mGAM       0.999000       0.999000       0.999000
# 100099-AA-AF-mBHI-mBHI       0.988051       0.998611       0.999000
# 100099-AA-AF-mBHI-mGAM       0.998756       0.999000       0.999000
# 100099-AE-AF-mBHI-mBHI       0.998900       0.999000       0.999000
# 100099-AE-AF-mBHI-mGAM       0.981982       0.996423       0.999000
# 100099-AA-AE-mGAM-mBHI       0.330266       0.986139       0.793113
# 100099-AA-AE-mGAM-mGAM       0.933401       0.998629       0.999000
# 100099-AA-AF-mGAM-mBHI       0.999000       0.999000       0.999000
# 100099-AA-AF-mGAM-mGAM       0.953676       0.999000       0.999000
# 100099-AE-AF-mGAM-mBHI       0.996927       0.608077       0.999000
# 100099-AE-AF-mGAM-mGAM       0.430328       0.999000       0.999000
# 101294-AE-AF-mBHI-mGAM       0.999000       0.545517       0.963126
# 101294-AA-AE-mGAM-mGAM       0.999000       0.999000       0.999000
# 101294-AA-AF-mGAM-mGAM       0.946667       0.955567       0.999000
# 101294-AE-AF-mGAM-mBHI       0.997229       0.999000       0.999000
# 101294-AE-AF-mGAM-mGAM       0.818826       0.870661       0.870661
#
#                         max_late_sel_med  min_late_sel_med  species_id
# species-type_meso
# 100146-AA-AE-mGAM-mBHI         -0.756514          0.352602      100146
# 100146-AA-AF-mGAM-mGAM         -1.846620         -0.000000      100146
# 100146-AE-AF-mGAM-mBHI          0.239881         -0.349112      100146
# 101059-AA-AF-mBHI-mBHI               NaN               NaN      101059
# 101059-AA-AF-mBHI-mGAM               NaN               NaN      101059
# 100910-AA-AE-mBHI-mBHI         -0.933855         -0.933855      100910
# 102478-AA-AE-mGAM-mBHI               NaN               NaN      102478
# 102478-AA-AE-mGAM-mGAM               NaN               NaN      102478
# 102478-AA-AF-mGAM-mGAM          1.668171         -1.123854      102478
# 102478-AE-AF-mGAM-mBHI               NaN               NaN      102478
# 102438-AA-AE-mBHI-mGAM          3.130869          3.130869      102438
# 102438-AA-AF-mBHI-mBHI          0.887146          0.887146      102438
# 102438-AA-AF-mBHI-mGAM         -0.267704         -0.267704      102438
# 102438-AE-AF-mBHI-mBHI         -0.043279          0.310595      102438
# 102438-AE-AF-mBHI-mGAM          0.726726         -1.038364      102438
# 102438-AA-AE-mGAM-mBHI         -0.125007          0.490207      102438
# 102438-AA-AE-mGAM-mGAM         -0.001002          2.316698      102438
# 102438-AA-AF-mGAM-mBHI          0.147020          0.242572      102438
# 102438-AA-AF-mGAM-mGAM         -0.962342          0.111289      102438
# 102438-AE-AF-mGAM-mBHI         -0.939154          0.217808      102438
# 102438-AE-AF-mGAM-mGAM          1.584807          0.186311      102438
# 100196-AA-AE-mBHI-mGAM          0.019659          0.036068      100196
# 100196-AA-AF-mGAM-mGAM         -1.594447          1.107069      100196
# 103656-AA-AE-mGAM-mGAM               NaN               NaN      103656
# 103656-AA-AF-mGAM-mGAM               NaN               NaN      103656
# 102506-AA-AF-mGAM-mBHI         -0.977450         -0.254346      102506
# 102506-AA-AF-mGAM-mGAM          0.226344          1.482348      102506
# 101346-AA-AF-mGAM-mGAM         -0.548061          1.640683      101346
# 100099-AA-AE-mBHI-mBHI          0.355340          0.355340      100099
# 100099-AA-AE-mBHI-mGAM         -0.000000          0.243877      100099
# 100099-AA-AF-mBHI-mBHI         -1.441618         -0.391570      100099
# 100099-AA-AF-mBHI-mGAM         -0.218354         -0.218354      100099
# 100099-AE-AF-mBHI-mBHI         -2.269325          0.939547      100099
# 100099-AE-AF-mBHI-mGAM         -0.485637          0.379994      100099
# 100099-AA-AE-mGAM-mBHI          0.692719         -0.385111      100099
# 100099-AA-AE-mGAM-mGAM         -0.390777          0.903949      100099
# 100099-AA-AF-mGAM-mBHI         -2.657240         -0.000000      100099
# 100099-AA-AF-mGAM-mGAM         -0.464417          0.813122      100099
# 100099-AE-AF-mGAM-mBHI         -0.772272          0.828073      100099
# 100099-AE-AF-mGAM-mGAM          0.919143          0.041832      100099
# 101294-AE-AF-mBHI-mGAM          1.255149          2.594439      101294
# 101294-AA-AE-mGAM-mGAM         -0.000521          1.221231      101294
# 101294-AA-AF-mGAM-mGAM         -0.041002          0.423379      101294
# 101294-AE-AF-mGAM-mBHI          0.143854          0.143854      101294
# 101294-AE-AF-mGAM-mGAM         -0.060793         -0.060793      101294
#
# [45 rows x 36 columns]

# %%
pol.loc['102438-AE-AF-mBHI-mGAM',:]
# Out:
# index                              1
# type_mesocosm        AE-AF-mBHI-mGAM
# species                       102438
# inoculumn                 AE-AF-mBHI
# Unnamed: 0                       3.5
# diff7_med                   0.537244
# diff7_lower                 0.534198
# diff7_upper                 0.540316
# pred_7_upper                0.996186
# pred_7_lower                 0.99524
# pred7_med                    0.99572
# as_extreme7                      0.0
# act7_upper                  0.385175
# act_7_lower                  0.37881
# act_7_med                   0.381835
# early_sel_upper             0.948843
# early_sel_lower             0.906107
# early_sel_med               0.927413
# late_sel_upper             -0.636507
# late_sel_lower             -0.689621
# late_sel_med                 -0.6636
# sample_early1                    1.0
# sample_early2                    2.0
# sample_late1                     6.0
# sample_late2                     7.0
# start_val                   0.753211
# t1_val                           NaN
# max_early_sel_med           1.110293
# min_early_sel_med           0.105714
# max_act_7_med               0.502028
# min_act_7_med               0.290456
# max_pred7_med               0.998918
# min_pred7_med               0.758002
# max_late_sel_med            0.726726
# min_late_sel_med           -1.038364
# species_id                    102438
# Name: 102438-AE-AF-mBHI-mGAM, dtype: object

# %%
pol.loc[pol[
p = make_big_plot_sel(pol,)
p= hv.render(p)
p.output_backend='svg'
bokeh.io.show(p)
export_plot_pdf(p,'1_2_scatter')
# Out:
#   Cell In[34], line 1
#     pol.loc[pol[
#                ^
# SyntaxError: '[' was never closed

# %%
renderer = hv.renderer('bokeh')
renderer

# %%
len(data)

# %%
np.random.seed(1)
data = np.random.randn(10000)
data = pol.loc[~pol['early_sel_med'].isna(),'early_sel_med']
frequencies, edges = np.histogram(data)
print(f'Values: {frequencies.shape[0]}, Edges: {edges.shape[0]}')
p=hv.Histogram((edges, frequencies)).opts(width=300,height=120,color=bokeh.palettes.Set2[3][-1])
p = hv.render(p)
p.yaxis.axis_label_text_font_style='normal'
p.x_range = bokeh.models.Range1d(-1,7)
#p.yaxis.visible=False
p.output_backend='svg'
export_plot_pdf(p,'early_sel')

# %%
np.random.seed(1)
data = np.random.randn(10000)
data = pol.loc[~pol['late_sel_med'].isna(),'late_sel_med']
frequencies, edges = np.histogram(data)
print(f'Values: {frequencies.shape[0]}, Edges: {edges.shape[0]}')
p=hv.Histogram((edges, frequencies)).opts(width=300,height=120,color=bokeh.palettes.Set2[3][-1])
p = hv.render(p)
p.yaxis.axis_label_text_font_style='normal'
p.x_range = bokeh.models.Range1d(-7,7)
#p.yaxis.visible=False
p.output_backend='svg'
export_plot_pdf(p,'late_sel')

# %%
b=pol.loc[pol['pred7_med']>=1-1e-3,:]
len(b)/len(pol)

# %%
np.random.seed(1)
data = np.random.randn(10000)
data = pol.loc[~pol['pred7_med'].isna(),'pred7_med']
frequencies, edges = np.histogram(data)
print(f'Values: {frequencies.shape[0]}, Edges: {edges.shape[0]}')
p=hv.Histogram((edges, frequencies)).opts(width=300,height=120,color=bokeh.palettes.Set2[3][-1])
p = hv.render(p)
p.yaxis.axis_label_text_font_style='normal'
p.yaxis.visible=False
p.output_backend='svg'
export_plot_pdf(p,'pred7_med')

# %%
pol.columns.values

# %%
np.random.seed(1)
data = np.random.randn(10000)
data = pol.loc[~pol['act_7_med'].isna(),'act_7_med']
frequencies, edges = np.histogram(data)
print(f'Values: {frequencies.shape[0]}, Edges: {edges.shape[0]}')
p=hv.Histogram((edges, frequencies)).opts(width=300,height=120,color=bokeh.palettes.Set2[3][-1])
p = hv.render(p)
p.yaxis.axis_label_text_font_style='normal'
p.yaxis.visible=False
p.output_backend='svg'
export_plot_pdf(p,'act_med')

# %%
np.random.seed(1)
data = np.random.randn(10000)
data = pol.loc[~pol['late_sel_med'].isna(),'late_sel_med']
frequencies, edges = np.histogram(data)
print(f'Values: {frequencies.shape[0]}, Edges: {edges.shape[0]}')
p=hv.Histogram((edges, frequencies)).opts(width=300,height=120,xlim=(-5,5))
p
