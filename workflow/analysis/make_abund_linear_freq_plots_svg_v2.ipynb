# %%
import pandas as pd
import numpy as np
from scipy.stats import false_discovery_control
#from bokeh.models import FixedTicker, FuncTickFormatter 
from scipy.stats import chi2

#from bokeh.io import output_notebook

from snp_analysis_tools_sherlock import *
from plot_tools import *
from scipy.stats import binom
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot
from glob import glob
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d7ea29ad-bc3e-4fe4-95a3-5066da23dafb'>
#   <div id="f70de620-a843-4d53-bd06-98f1ee124aaa" data-root-id="d7ea29ad-bc3e-4fe4-95a3-5066da23dafb" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df_abundance = pd.read_csv('e003_coalescence_metadata_round4_abundances.csv')#.drop(columns='Unnamed: 0')

# %%
df_coal = pd.read_csv('e003_coalescence_metadata_round4_good.csv')
abundance_df = pd.read_csv('e003_coalescence_metadata_round4_abundances.csv')
df_coal['replicate']=np.nan
for type_mesocosm in df_coal['type_mesocosm'].unique():
    rep = 0
    for mesocosm in df_coal.loc[df_coal['type_mesocosm']==type_mesocosm,'mesocosm'].unique():
        abundance_df.loc[abundance_df['mesocosm']==mesocosm,'replicate'] = rep 
        df_coal.loc[df_coal['mesocosm']==mesocosm,'replicate']=rep
        rep = rep+1
df_coal.loc[df_coal['is_inoculumn'],'replicate']=0
abundance_df.loc[abundance_df['is_inoculumn'],'replicate'] = 0. 
df_abundance.to_csv('e003_coalescence_metadata_round4_abundances.csv',index=False)
df_coal.to_csv('e003_coalescence_metadata_round4_good.csv',index=False)

# %%
import os

bad_inos = ['100146-AA-AF-mBHI',
 '100146-AE-AF-mBHI',
 '102478-AA-AF-mBHI',
 '102478-AE-AF-mBHI',
 '100196-AA-AF-mBHI',
 '100196-AE-AF-mBHI',
 '100196-AA-AE-mGAM',
 '100196-AE-AF-mGAM',
 '102544-AA-AF-mBHI',
 '102544-AE-AF-mBHI',
 '101349-AA-AF-mBHI',
 '101349-AE-AF-mBHI',
 '102506-AA-AE-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AF-mBHI',
 '102506-AE-AF-mBHI',
 '102506-AA-AE-mGAM',
 '102506-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AF-mBHI',
 '101346-AE-AF-mBHI',
 '101346-AA-AE-mGAM',
 '101346-AE-AF-mGAM',
 '101346-AA-AE-mBHI',
 '101346-AA-AF-mBHI',
 '100120-AA-AF-mBHI',
 '100120-AE-AF-mBHI',
 '102327-AA-AF-mBHI',
 '102327-AE-AF-mBHI']
bads_bads = ['101346-AE-AF-mBHI','101346-AA-AF-mBHI', '101346-AA-AE-mBHI', '102506-AE-AF-mBHI']
#inos = ['AE-AF-mGAM']

inos=['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
inos = ['AE-AF-mGAM','AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
#inos = ['AE-AF-mGAM']
#inos = ['AE-AF-mBHI']
species = [102438,100196, 100099, 100146, 101346, 102506, 102478]
species = [102438,100196, 100099, 100146, 102506, 102478,101294]
species = [102438]
inos = ['AE-AF-mGAM']
for sp in species:
    plots_all=[]
    for ino in inos:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{sp}/{ino}_parent1_info.csv'
        if not os.path.isfile(fname):
            continue
        if f'{sp}-{ino}' in bads_bads:
            continue
                    
     #   print(sp,ino)
        #outputs=make_logit_plot_with_preds(sp, ino,1,2)
        
        #parent_subject1, parent_subject2, media = ino.split('-')
        psab,psstrain,type_mesos = make_plain_linear_plot_abundance(df_abundance.loc[df_abundance['inoculumn']==ino,:],sp, ino,
                                       colorby='const',
                                        )
      #  psab,psstrain = make_plain_linear_plot(sp, ino,same_plots=True)

        for i in range(len(psstrain)):
            p1 = psab[i]
            p2 = psstrain[i]
            media = type_mesos[i]
            sub1 = media.split('-')[0]
            media=media.split('-')[-1]
          #  p2.yaxis.axis_label=f'Freq {ino.split('-')[0]} vs. {ino.split('-')[1]}'
           # p2.title.text=''
          #  p1.title.text = 'Species Relative Abundance'
           # p1.xaxis.axis_label=''
            p1.legend.visible=False
            p2.legend.visible=False
            p2.height=300
            p2.width=500
            
            p1.y_range = bokeh.models.Range1d(0,.2)
            p1.xaxis.ticker.desired_num_ticks = 10
           # p1.height=160
            p1.output_backend = "svg"
            p2.output_backend = "svg"
            fname_prefix1 = f'{sp}_{ino}_linear_{media}_sp_abun'
            fname_prefix2 = f'{sp}_{ino}_linear_{media}_strain_abun'
            
            
            
            
            
            
            p1.yaxis.axis_label = 'Sp Abun'
            p2.yaxis.axis_label_text_font_style = 'normal'
            p2.xaxis.axis_label_text_font_style = 'normal'
            p1.yaxis.axis_label_text_font_style = 'normal'
            p1.xaxis.axis_label_text_font_style = 'normal'
          #  p2.yaxis.axis_label_text_font_size = '22px'
           # p2.xaxis.axis_label_text_font_size = '22px'

        #    p2.yaxis.major_label_text_font_size = '15px'
         #   p2.xaxis.major_label_text_font_size = '15px'

           # p1.yaxis.major_label_text_font_size = '15px'
            #p1.xaxis.major_label_text_font_size = '15px'
            #p1.yaxis.axis_label_text_font_size = '22px'
            #p1.xaxis.axis_label_text_font_size = '22px'
            p1.height=160
            export_plot_pdf(p1, fname_prefix1)
           # p1.height=100
            p2.yaxis.minor_tick_line_color= None
            export_plot_pdf(p2, fname_prefix2)
            bokeh.io.show(p2)
            p1.xaxis.visible=False
            grid = bokeh.layouts.gridplot([p1,p2],ncols=1)
            fname_prefix = f'{sp}_{ino}_{media}_sp_strain_abun'

            plot_fname_svg=f'plots/{fname_prefix}.svg'
            plot_fname_pdf=f'plots/{fname_prefix}.pdf'
            bokeh.io.export_svg(grid,filename=plot_fname_svg)
            convert_scripts = f'rsvg-convert -f pdf -o {plot_fname_pdf} {plot_fname_svg}' 
            
            os.system(convert_scripts)
          #  export_grid_pdf(grid, fname_prefix)
# Out:
#   <div id="adbb832f-3250-417b-998c-6d479554a45a" data-root-id="8f6e2718-5b66-4ca0-90fd-5cb5c2091df7" style="display: contents;"></div>
#   <div id="b58cced5-64b1-4e6b-8088-b3d4e70e0885" data-root-id="434ce784-ba46-4d8d-852d-467bc14ac212" style="display: contents;"></div>

# %%
import os
inos=['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
inos = ['AE-AF-mGAM','AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
#inos = ['AA-AF-mGAM']
#inos = ['AE-AF-mBHI']
species = [102438,100196, 100099, 100146, 101346, 102506, 102478]
species = [102438,100196, 100099, 100146, 101346, 102506, 102478,102358,101294]
species = [102506,100099,101294]
species = ['100146', '101059', '100910', '102478', '102438', '100196',
       '103117', '103656', '102544', '102506', '101346', '100099',
       '101400', '101294']
#species=[101294]
sp_inos = ['100099-AE-AF-mBHI', '101294-AA-AF-mGAM', '101294-AE-AF-mGAM',
       '100099-AA-AF-mGAM', '100099-AE-AF-mGAM', '102478-AA-AF-mGAM',
       '101346-AA-AF-mGAM', '100099-AA-AE-mGAM', '100146-AE-AF-mGAM']
species = [101294,101346,100099,102478,101346,100146,]
name_dic = {'100099':'Flavonifractor plautii',
            '100146':'Dorea formicigenerans',
            '100196': 'Bacteroides thetaiotaomicron',
            '101294': 'Parasutterella excrementihominis',
            '101346': 'Bacteroides uniformis',
            '102438': 'Parabacteroides distasonis',
            '102478': 'Bacteroides dorei',
            '102506': 'Escherichia coli',
            '103656': 'Acutalibacteraceae sp'}
          
inos = ['AE-AF-mGAM','AA-AF-mGAM','AA-AE-mGAM']+['AE-AF-mBHI','AA-AF-mBHI','AA-AE-mBHI',]
to_plot =['100099-AE-AF-mBHI', '101294-AA-AF-mGAM', '101294-AE-AF-mGAM',
       '100099-AA-AF-mGAM', '100099-AE-AF-mGAM', '100146-AA-AE-mGAM',
       '102478-AA-AF-mGAM', '101346-AA-AF-mGAM', '100099-AA-AE-mGAM',
       '100146-AE-AF-mGAM']
for sp in species:
    plots_all=[]
    for ino in inos:
        fname = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{sp}/{ino}_parent1_info.csv'
        if not os.path.isfile(fname):
            continue
        if f'{sp}-{ino}' in bad_inos:
            continue
        if f'{sp}-{ino}' not in to_plot:
            continue
    #    if f'{sp}-{ino}' not in sp_inos:
     #       continue
                    
     #   print(sp,ino)
        #outputs=make_logit_plot_with_preds(sp, ino,1,2)
        
        #parent_subject1, parent_subject2, media = ino.split('-')
        psab,psstrain,type_mesos = make_plain_linear_plot_abundance(df_abundance.loc[df_abundance['inoculumn']==ino,:],sp, ino,
                                       colorby='media',markers='none',same_plots = True,useboth=True,
                                                                    
                                        )
      #  psab,psstrain = make_plain_linear_plot(sp, ino,same_plots=True)

        for i in range(len(psstrain)):
        
            p1 = psab[i]
            p2 = psstrain[i]
            media = type_mesos[i]
            sub1 = media.split('-')[0]
            media=media.split('-')[-1]
          #  p2.yaxis.axis_label=f'Freq {ino.split('-')[0]} vs. {ino.split('-')[1]}'
           # p2.title.text=''
          #  p1.title.text = 'Species Relative Abundance'
           # p1.xaxis.axis_label=''
            p1.legend.visible=False
            p2.legend.visible=False

            p1.output_backend = "svg"
            p2.output_backend = "svg"
            fname_prefix1 = f'{sp}_{ino}_linear_both_sp_abun'
            fname_prefix2 = f'{sp}_{ino}_linear_both_strain_abun'
            p2.yaxis.axis_label_text_font_style = 'normal'
            p2.xaxis.axis_label_text_font_style = 'normal'
            p2.title.text = name_dic[str(sp)]
            p2.title.text_font_style='italic'
            p2.title.text_font_size='22px'
           # bokeh.io.show(p2)
         #   export_plot_pdf(p1, fname_prefix1)
          #  bokeh.io.show(p2)
            export_plot_pdf(p2, f'plots_media/{fname_prefix2}')
           # p1.xaxis.visible=False

           # grid = bokeh.layouts.gridplot([p1,p2],ncols=1)
            #fname_prefix = f'{sp}_{ino}_both_sp_strain_abun'

          #  plot_fname_svg=f'plots/{fname_prefix}_both.svg'
           # plot_fname_pdf=f'plots/{fname_prefix}_both.pdf'
            #bokeh.io.export_svg(grid,filename=plot_fname_svg)
          #  convert_scripts = f'rsvg-convert -f pdf -o {plot_fname_pdf} {plot_fname_svg}' 
           # os.system(convert_scripts)
          #  export_grid_pdf(grid, fname_prefix)

# %%
bokeh.io.show(psstrain[0])
# Out:
#   <div id="c0713a21-c74c-4cde-90f3-9aff4d2c1ab4" data-root-id="d716ba78-e00c-4255-bbe6-81845eb4956b" style="display: contents;"></div>
