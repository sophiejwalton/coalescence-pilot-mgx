# %%
import pandas as pd
import numpy as np
import os
import itertools as it
from snp_analysis_tools_sherlock import *
from coalescence_analysis_tools import *
from plot_tools import *
import iqplot
import bokeh.plotting
import bokeh.io
import holoviews as hv
from holoviews import dim, opts
import bokeh.models
from bokeh.layouts import gridplot

hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='5deeb358-0b12-46b6-a2ec-5a943c9d0776'>
#   <div id="f3437bcd-46d2-439e-a18b-2879f157718b" data-root-id="5deeb358-0b12-46b6-a2ec-5a943c9d0776" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6200fcfa-d4c6-41a5-bf2e-11451634abeb":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"5deeb358-0b12-46b6-a2ec-5a943c9d0776"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"409e7f13-425a-461a-94c1-3f8c5aab28a1","attributes":{"plot_id":"5deeb358-0b12-46b6-a2ec-5a943c9d0776","comm_id":"2f6da7b6a9c944b8ab2a447467104d94","client_comm_id":"053fff731cc648c8a4b105b6e0beac57"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"6200fcfa-d4c6-41a5-bf2e-11451634abeb","roots":{"5deeb358-0b12-46b6-a2ec-5a943c9d0776":"f3437bcd-46d2-439e-a18b-2879f157718b"},"root_ids":["5deeb358-0b12-46b6-a2ec-5a943c9d0776"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
fname = '~/git/coalescence-pilot-mgx/workflow/out/midas2_output/old_species/species/metadata.tsv'
df_metadata= pd.read_csv(fname, delimiter = '\t')
df_metadata

def transform_df(df_abundance):
    df_abundance['Lineage'] = df_abundance['species_id'].transform(lambda x: df_metadata.loc[df_metadata['species_id'] == x,'Lineage'].values[0])
    df_abundance['species'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-1])
    df_abundance['genus'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-2])
    df_abundance['family'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[-3])
    df_abundance['phyla'] = df_abundance['Lineage'].transform(lambda x: x.split(';')[1])
    return df_abundance

df_metadata  =transform_df(df_metadata)
df_metadata
# Out:
#       species_id    representative MGnify_accession  species_closest  \
# 0         100001  GUT_GENOME000001  MGYG-HGUT-00001         100049.0
# 1         100002  GUT_GENOME000004  MGYG-HGUT-00002         100201.0
# 2         100003  GUT_GENOME000008  MGYG-HGUT-00003         103279.0
# 3         100004  GUT_GENOME000010  MGYG-HGUT-00004         103876.0
# 4         100005  GUT_GENOME000017  MGYG-HGUT-00005         101623.0
# ...          ...               ...              ...              ...
# 4639      104640  GUT_GENOME286389  MGYG-HGUT-04640         103346.0
# 4640      104641  GUT_GENOME286625  MGYG-HGUT-04641              NaN
# 4641      104642  GUT_GENOME286704  MGYG-HGUT-04642         104273.0
# 4642      104643  GUT_GENOME286769  MGYG-HGUT-04643         100646.0
# 4643      104644  GUT_GENOME286887  MGYG-HGUT-04644         101057.0
#
#       ani_closest  gtpro_kmer_counts  phyeco_marker_counts  phyeco_pass_ratio  \
# 0        83.35600                NaN                  15.0                1.0
# 1        84.86955            29822.0                  15.0                1.0
# 2        93.41555             1115.0                  15.0                1.0
# 3        78.17620                NaN                  15.0                1.0
# 4        85.84275                NaN                  15.0                1.0
# ...           ...                ...                   ...                ...
# 4639     90.06215                NaN                  13.0                1.0
# 4640          NaN                NaN                  12.0                1.0
# 4641     79.50010                NaN                  15.0                1.0
# 4642     79.02775            89795.0                  15.0                1.0
# 4643     79.53465           114400.0                  15.0                1.0
#
#       pangene_counts  genome_counts  ...     N50  GC_content  Completeness  \
# 0               4893              4  ...   47258       28.26         98.59
# 1             147601            358  ...  109266       42.60         99.37
# 2             113409           1178  ...  158570       58.52        100.00
# 3              12599             24  ...   90296       54.19         98.66
# 4               5488              2  ...  350032       28.59         99.30
# ...              ...            ...  ...     ...         ...           ...
# 4639            7938             11  ...   11755       51.72         84.97
# 4640            1451              1  ...   17325       62.69         68.94
# 4641            8769             30  ...  153485       38.81         93.29
# 4642           40134            246  ...  433108       41.96         97.99
# 4643           45432             64  ...   14090       57.36         93.96
#
#       Contamination                                            Lineage  \
# 0              0.70  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__P...
# 1              0.00  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__L...
# 2              0.00  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 3              0.22  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# 4              0.00  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__P...
# ...             ...                                                ...
# 4639           0.35  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 4640           0.00  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 4641           0.00  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__L...
# 4642           0.00  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
# 4643           0.67  d__Bacteria;p__Firmicutes_A;c__Clostridia;o__O...
#
#       Continent                           species                genus  \
# 0        Europe                               s__     g__GCA-900066495
# 1        Europe          s__Blautia_A sp900066165         g__Blautia_A
# 2        Europe               s__Alistipes shahii         g__Alistipes
# 3        Europe      s__Anaerotruncus colihominis     g__Anaerotruncus
# 4        Europe  s__Terrisporobacter glycolicus_A  g__Terrisporobacter
# ...         ...                               ...                  ...
# 4639     Europe                               s__        g__Prevotella
# 4640     Europe                               s__        g__Sutterella
# 4641     Europe                               s__                  g__
# 4642     Europe      s__Eubacterium_R sp003526845     g__Eubacterium_R
# 4643     Europe                               s__  g__Negativibacillus
#
#                         family              phyla
# 0     f__Peptostreptococcaceae    p__Firmicutes_A
# 1           f__Lachnospiraceae    p__Firmicutes_A
# 2             f__Rikenellaceae    p__Bacteroidota
# 3           f__Ruminococcaceae    p__Firmicutes_A
# 4     f__Peptostreptococcaceae    p__Firmicutes_A
# ...                        ...                ...
# 4639         f__Bacteroidaceae    p__Bacteroidota
# 4640       f__Burkholderiaceae  p__Proteobacteria
# 4641                       f__    p__Firmicutes_A
# 4642     f__Acutalibacteraceae    p__Firmicutes_A
# 4643        f__Ruminococcaceae    p__Firmicutes_A
#
# [4644 rows x 23 columns]

# %%
def get_sel_stuff(species,inoculumn, polarize=True, sel_period=(1,3)):
    fname1 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{species}/{inoculumn}_parent1_info.csv'
    fname2 = f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{species}/{inoculumn}_parent2_info.csv'
    sel_stuff1 = pd.read_csv(fname1).rename(columns={'mesocosms':'mesocosm'})
    sel_stuff2 = pd.read_csv(fname2).rename(columns={'mesocosms':'mesocosm'})
    
    fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{species}/{inoculumn}_parent1_info.csv'
    fname2=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3/{species}/{inoculumn}_parent1_info.csv'
    freq1 = pd.read_csv(fname1)
    freq2=pd.read_csv(fname2)
    df_both = get_both_dfs(fname1)
    e003_metadata = pd.read_csv('e003_coalescence_metadata_round4_good.csv').set_index('sample')
    df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
    df_both=df_both.loc[df_both['total_shift']<.1,:]

    df_both_meta = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]],
                                         axis=1).reset_index()
    sel_stuff1=sel_stuff1.loc[sel_stuff1['sample1'].isin(df_both_meta['sample'].unique())*sel_stuff1['sample2'].isin(df_both_meta['sample'].unique()),:]
    sel_stuff1=sel_stuff1.loc[(sel_stuff1['passage1']==sel_period[0])*(sel_stuff1['passage2']==sel_period[1]),:]
    sel_stuff2=sel_stuff2.loc[sel_stuff2['sample1'].isin(df_both_meta['sample'].unique())*sel_stuff2['sample2'].isin(df_both_meta['sample'].unique()),:]
    sel_stuff2=sel_stuff2.loc[(sel_stuff2['passage1']==sel_period[0])*(sel_stuff2['passage2']==sel_period[1]),:]
    
    df_both_meta_pfinal = df_both_meta.loc[df_both_meta['passage']== 7,:].set_index('mesocosm')
    df_both_meta_p_pol = df_both_meta.loc[df_both_meta['passage']== 0,:].set_index('mesocosm')
    df_both_meta_p_polgr=df_both_meta_p_pol.groupby(['type_mesocosm']).median(numeric_only=True).reset_index()
    to_repol = df_both_meta_p_polgr['actual_med1']>.5
    if len(to_repol) <1:
        return pd.DataFrame()
#    print(to_repol)
    to_repol=to_repol[0]
  #  print(to_repol)
    
    sel_stuff1=sel_stuff1.set_index('mesocosm')
    sel_stuff2=sel_stuff2.set_index('mesocosm')

    good_mesos = np.intersect1d(sel_stuff1.index.values,df_both_meta_pfinal.index.values)
    sel_stuff1=sel_stuff1.loc[good_mesos,:]
    sel_stuff2=sel_stuff2.loc[good_mesos,:]
    df_both_meta_pfinal=df_both_meta_pfinal.loc[good_mesos,:]

    df_both_meta_pfinal['plot_freq_act']=df_both_meta_pfinal['actual_med1']
    if to_repol:
        df_both_meta_pfinal['plot_freq_act']=df_both_meta_pfinal['actual_med2']
    df_both_meta_pfinal=df_both_meta_pfinal.loc[sel_stuff1.index.values,:]
    
    df_both_meta_pinitial=df_both_meta.loc[df_both_meta['passage']== sel_period[1],:].set_index('mesocosm')
    df_both_meta_piniall_dfs_p7tial=df_both_meta_pinitial.loc[good_mesos,:]

    df_both_meta_pfinal['sel_coeff'] = np.nan 
    df_both_meta_pfinal=df_both_meta_pfinal.loc[sel_stuff1.index.values,:]
    df_both_meta_pfinal['sel_coeff']= sel_stuff1['sel_med']
    df_both_meta_pfinal['plot_freq_initial'] = df_both_meta_pinitial['actual_med1']
    if to_repol:
        df_both_meta_pfinal=df_both_meta_pfinal.loc[sel_stuff2.index.values,:]
        df_both_meta_pfinal['sel_coeff']= sel_stuff2['sel_med']
        df_both_meta_pfinal['plot_freq_initial'] = df_both_meta_pinitial['actual_med2']


    df_both_meta_pfinal['dt'] = 7-sel_period[1]
    df_both_meta_pfinal['plot_pred']= np.exp(df_both_meta_pfinal['dt']*df_both_meta_pfinal['sel_coeff'])
    df_both_meta_pfinal['plot_pred']=df_both_meta_pfinal['plot_pred']*df_both_meta_pfinal['plot_freq_initial']/(\
            1-df_both_meta_pfinal['plot_freq_initial']+df_both_meta_pfinal['plot_freq_initial']*df_both_meta_pfinal['plot_pred'])

    
    return df_both_meta_pfinal

# %%
all_dfs=[]
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
     #   try:
        if os.path.exists(f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_sel_bootstrapv3/{sp}/{ino}_parent1_info.csv'):
            df=get_sel_stuff(sp,ino, sel_period=(0,7)).reset_index()
       # except:
        #    continue
            df['species_id']=sp
            if len(df)>0:
                all_dfs.append(df)
all_dfs=pd.concat(all_dfs)
all_dfs['species-type_meso']=all_dfs['species_id'].astype(str)+'-'+all_dfs['type_mesocosm']
all_dfs_gr=all_dfs.groupby(['species-type_meso']).median(numeric_only=True).reset_index()

all_dfs['species-ino']=all_dfs['species_id'].astype(str) +'-'+ all_dfs['inoculumn'].astype(str)
all_dfs = all_dfs.loc[~all_dfs['species-ino'].isin(bad_inos),:]
all_dfs
# Out:
#                mesocosm                                      sample  \
# 0   A10-AA-AE-mGAM-mBHI                 A10-e003Coalescence-mBHI-p7
# 1   A10-AA-AE-mGAM-mGAM                 A10-e003Coalescence-mGAM-p7
# 2    C8-AA-AE-mGAM-mBHI                  C8-e003Coalescence-mBHI-p7
# 3    C8-AA-AE-mGAM-mGAM                  C8-e003Coalescence-mGAM-p7
# 4   E10-AA-AE-mGAM-mBHI           E100-e003Coalescence-mBHI-p7_S103
# ..                  ...                                         ...
# 0   C11-AE-AF-mGAM-mBHI  Coalescence-A10-C11-AE-AF-mGAM-mBHI-7_S629
# 1   C11-AE-AF-mGAM-mGAM                 C11-e003Coalescence-mGAM-p7
# 2   D10-AE-AF-mGAM-mGAM                 D10-e003Coalescence-mGAM-p7
# 3   G11-AE-AF-mGAM-mBHI           G111-e003Coalescence-mBHI-p7_S128
# 4   H10-AE-AF-mGAM-mBHI           H100-e003Coalescence-mBHI-p7_S139
#
#     boot_med1  boot_low1  boot_high1  actual_med1  conf_int1  boot_med2  \
# 0    0.500000   0.500000    0.500000     0.500000   0.000000   0.500000
# 1    0.004959   0.004294    0.005655     0.004957   0.001361   0.994580
# 2    0.294000   0.286000    0.300000     0.294000   0.014000   0.692000
# 3    0.100000   0.091000    0.105000     0.100000   0.014000   0.889000
# 4    0.778000   0.769000    0.778000     0.778000   0.009000   0.200000
# ..        ...        ...         ...          ...        ...        ...
# 0    0.997163   0.996603    0.997659     0.997157   0.001056   0.001202
# 1    0.806000   0.800000    0.810000     0.806000   0.010000   0.179000
# 2    0.833000   0.829000    0.833000     0.833000   0.004000   0.146000
# 3    0.997702   0.996778    0.998516     0.997699   0.001738   0.001186
# 4    0.995920   0.995245    0.996567     0.995921   0.001322   0.002787
#
#     boot_low2  boot_high2  ...      mesocosm-passage  replicate plot_freq_act  \
# 0    0.500000    0.500000  ...  A10-AA-AE-mGAM-mBHI7        2.0      0.500000
# 1    0.994023    0.995069  ...  A10-AA-AE-mGAM-mGAM7        2.0      0.004957
# 2    0.690000    0.700000  ...   C8-AA-AE-mGAM-mBHI7        0.0      0.294000
# 3    0.889000    0.900000  ...   C8-AA-AE-mGAM-mGAM7        0.0      0.100000
# 4    0.192000    0.200000  ...  E10-AA-AE-mGAM-mBHI7        1.0      0.778000
# ..        ...         ...  ...                   ...        ...           ...
# 0    0.000895    0.001539  ...  C11-AE-AF-mGAM-mBHI7        0.0      0.997157
# 1    0.174000    0.182000  ...  C11-AE-AF-mGAM-mGAM7        0.0      0.806000
# 2    0.142000    0.149000  ...  D10-AE-AF-mGAM-mGAM7        3.0      0.833000
# 3    0.000593    0.001873  ...  G11-AE-AF-mGAM-mBHI7        1.0      0.997699
# 4    0.002325    0.003307  ...  H10-AE-AF-mGAM-mBHI7        2.0      0.995921
#
#    sel_coeff  plot_freq_initial  dt  plot_pred  species_id  \
# 0        NaN           0.500000   0        NaN      100146
# 1        NaN           0.004957   0        NaN      100146
# 2        NaN           0.294000   0        NaN      100146
# 3        NaN           0.100000   0        NaN      100146
# 4        NaN           0.778000   0        NaN      100146
# ..       ...                ...  ..        ...         ...
# 0   1.033376           0.997157   0   0.997157      101294
# 1   0.253167           0.806000   0   0.806000      101294
# 2   0.287501           0.833000   0   0.833000      101294
# 3   1.033376           0.997699   0   0.997699      101294
# 4   1.044603           0.995921   0   0.995921      101294
#
#          species-type_meso        species-ino
# 0   100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
# 1   100146-AA-AE-mGAM-mGAM  100146-AA-AE-mGAM
# 2   100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
# 3   100146-AA-AE-mGAM-mGAM  100146-AA-AE-mGAM
# 4   100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
# ..                     ...                ...
# 0   101294-AE-AF-mGAM-mBHI  101294-AE-AF-mGAM
# 1   101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 2   101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 3   101294-AE-AF-mGAM-mBHI  101294-AE-AF-mGAM
# 4   101294-AE-AF-mGAM-mBHI  101294-AE-AF-mGAM
#
# [158 rows x 44 columns]

# %%
all_dfs_gr['sel_coeff_abs']=all_dfs_gr['sel_coeff'].abs()
good_sel = all_dfs_gr['sel_coeff']
good_sel = good_sel[~np.isnan(good_sel)]
frequencies, edges = np.histogram(good_sel,bins=20)
#print('Values: %s, Edges: %s' % (frequencies.shape[0], edges.shape[0]))
hv.Histogram((edges, frequencies)).opts(width=500, height=200, xlabel='Sel Coefficient Passages 0-7', 
                                        ylabel='Counts',fill_color= bokeh.palettes.Bright[6][1]
                                       )
# Out:
# :Histogram   [x]   (Frequency)

# %%
def get_both_dfs(fname):
    #print(fname)
    df1 = pd.read_csv(fname).drop(columns='Unnamed: 0').set_index('sample')
    df2 = pd.read_csv(fname.split('parent1_info.csv')[0] + 'parent2_info.csv').drop(columns='Unnamed: 0').set_index('sample')
    df2['conf_int'] = df2['boot_high']-df2['boot_low']
    
    df1['conf_int'] = df1['boot_high']-df1['boot_low']
    df_both = pd.concat([df1.rename(columns = {'boot_med':'boot_med1', 'boot_low':'boot_low1', 'boot_high':'boot_high1',
       'actual_med':'actual_med1', 'conf_int':'conf_int1'}),
                         df2.rename(columns = {'boot_med':'boot_med2', 'boot_low':'boot_low2', 'boot_high':'boot_high2',
       'actual_med':'actual_med2', 'conf_int':'conf_int2'})],axis=1)
    
    df_both['species'] = fname.split('/')[-2]
    df_both['fname'] = fname
   # print('-'.join(fname1.split('/')[-1].split('-')[:-1]))
   # parent_media = 
    
    df_both['subjects_measured'] = '-'.join(fname.split('/')[-1].split('-')[:-1])
    df_both['in_measured'] = '-'.join(fname.split('/')[-1].split('_')[:-2])
    df_both['total_shift'] = np.abs(1-(df_both['actual_med1'] + df_both['actual_med2']))
    df_both['total_shift12'] = np.abs(1-(df_both['boot_low1'] + df_both['boot_high2']))
    df_both['total_shift21'] = np.abs(1-(df_both['boot_low2'] + df_both['boot_high1']))
    df_both['total_shift_max'] = df_both['total_shift21']
    df_both.loc[df_both['total_shift_max']<df_both['total_shift12'],'total_shift_max'] = df_both.loc[df_both['total_shift_max']<df_both['total_shift12'],'total_shift12']

    return df_both

# %%
all_dfs=[]
species_list = glob('/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/*/')
species_list =[sp.split('/')[-2] for sp in species_list]
e003_metadata = pd.read_csv('e003_coalescence_metadata_round4.csv').set_index('sample')

for sp in species_list:
    for ino in ['AA-AE-mBHI','AA-AF-mBHI','AE-AF-mBHI',
                'AA-AE-mGAM','AA-AF-mGAM','AE-AF-mGAM',]:
     #   try:
        fname1=f'/Users/sophiewalton/git/coalescence-pilot-mgx/workflow/report/track_snpsv2_ALL_bootstrapv3_both/{sp}/{ino}_parentboth_info.csv'
        if os.path.exists(fname1):
            
            df_both=pd.read_csv(fname1).set_index('sample')
            df_both = df_both.loc[np.intersect1d(df_both.index.values,e003_metadata.index.values),:]
            df_both_meta = pd.concat([df_both,e003_metadata.loc[np.intersect1d(df_both.index.values,
                                                                                   e003_metadata.index.values),:]],
                                         axis=1).reset_index()
       # except:
        #    continue
            df_both_meta['species_id']=sp
            df_both_meta['diff_from_in']=df_both_meta['actual_med']
          #  df_both_meta['diff_from_in2']=df_both_meta['actual_med2']
            in_samples = df_both_meta['inoculumn_sample'].unique()
            if len(in_samples) != len(df_both_meta.loc[df_both_meta['sample'].isin(in_samples),'actual_med']):
                continue
            
            for in_sample in df_both_meta['inoculumn_sample'].unique():
                
                with_in_sample = df_both_meta.loc[df_both_meta['inoculumn_sample']==in_sample,'sample'].values
                in1_val=df_both_meta.loc[df_both_meta['sample']==in_sample,'actual_med'].values[0]
                df_both_meta.loc[df_both_meta['sample'].isin(with_in_sample),'diff_from_in']= \
                    df_both_meta.loc[df_both_meta['sample'].isin(with_in_sample),'diff_from_in'] - in1_val
                
              
            all_dfs.append(df_both_meta)
all_dfs=pd.concat(all_dfs)
all_dfs['species-type_meso']=all_dfs['species_id'].astype(str)+'-'+all_dfs['type_mesocosm']
all_dfs['species-ino']=all_dfs['species_id'].astype(str) +'-'+ all_dfs['inoculumn'].astype(str)
all_dfs = all_dfs.loc[~all_dfs['species-ino'].isin(bad_inos),:]
print(len(all_dfs))
#all_dfs.loc[all_dfs['passage']>0,'species-type_meso'].unique()
df_coal = pd.read_csv('num_sites_stuff_coal.csv')
df_coal['species-sample']=df_coal['species_id'].astype(str)+'-'+df_coal['sample'].astype(str)
all_dfs['species-sample'] = all_dfs['species_id'].astype(str)+'-'+ all_dfs['sample'].astype(str)
df_coalbad = df_coal.loc[df_coal['frac_sites']<.5,:]
print(len(np.intersect1d(all_dfs['species-sample'].values, df_coalbad['species-sample'].values)))
all_dfs=all_dfs.loc[all_dfs['shifts_med']<.1,:]
np.intersect1d(all_dfs['species-sample'].values, df_coalbad['species-sample'].values)
# Out:
# 1354
# 10
# array(['100099-A5-e003Coalescence-mBHI-p3',
#        '101294-D4-e003Coalescence-Inoculumn-mGAM',
#        '101294-D_D5_D8_AA_AF_mGAM_mBHI_6_S329',
#        '101294-E10-e003Coalescence-mGAM-p1_S832',
#        '101294-G111-e003Coalescence-mBHI-p7_S128',
#        '102438-C2-e003Coalescence-mBHI-p3',
#        '102438-D4-e003Coalescence-mBHI-p3',
#        '103117-D_E12_E11_AF_AA_mGAM_mGAM_4_S348',
#        '103656-D_H11_H10_AE_AF_mGAM_mGAM_4_S383'], dtype=object)

# %%
all_dfs.loc[all_dfs['species-sample'].isin(df_coalbad['species-sample'].values),:]
# Out:
#                                sample  Unnamed: 0  boot_med  boot_low  \
# 14         C2-e003Coalescence-mBHI-p3          14  0.023232  0.021531
# 26         D4-e003Coalescence-mBHI-p3          26  0.400000  0.396406
# 12   D_E12_E11_AF_AA_mGAM_mGAM_4_S348          12  0.002523  0.001817
# 12   D_H11_H10_AE_AF_mGAM_mGAM_4_S383          12  0.127291  0.125000
# 3          A5-e003Coalescence-mBHI-p3           3  0.024027  0.022348
# 23   E10-e003Coalescence-mGAM-p1_S832          23  0.046930  0.041829
# 29     D_D5_D8_AA_AF_mGAM_mBHI_6_S329          29  0.999000  0.999000
# 24  D4-e003Coalescence-Inoculumn-mGAM          24  0.444444  0.418410
# 34  G111-e003Coalescence-mBHI-p7_S128          34  0.998813  0.998202
#
#     boot_high  actual_med  shifts_low  shifts_high  shifts_med comm  ...  \
# 14   0.025018    0.023225    0.002179     0.006478    0.004285   C2  ...
# 26   0.411946    0.400000    0.000000     0.029000    0.000000   D4  ...
# 12   0.003289    0.002527    0.000346     0.002762    0.001560  E11  ...
# 12   0.127291    0.127291    0.000000     0.018000    0.018000  H10  ...
# 3    0.025672    0.024004    0.001912     0.007059    0.004464   A5  ...
# 23   0.052509    0.046904   -0.004417     0.045164    0.005410  E10  ...
# 29   0.999000    0.999873    0.000000     0.000000    0.000000   H8  ...
# 24   0.444444    0.444444    0.029000     0.100000    0.100000   D4  ...
# 34   0.998999    0.998811   -0.000018     0.002210    0.001089  G11  ...
#
#    passage    type_mesocosm   redo  counts       mesocosm-passage species_id  \
# 14       3  AA-AE-mBHI-mBHI  False       1    C2-AA-AE-mBHI-mBHI3     102438
# 26       3  AE-AF-mBHI-mBHI  False       1    D4-AE-AF-mBHI-mBHI3     102438
# 12       4  AA-AF-mGAM-mGAM  False       1  E11-AA-AF-mGAM-mGAM-4     103117
# 12       4  AE-AF-mGAM-mGAM  False       1  H10-AE-AF-mGAM-mGAM-4     103656
# 3        3  AA-AF-mBHI-mBHI  False       1    A5-AA-AF-mBHI-mBHI3     100099
# 23       1  AA-AE-mGAM-mGAM  False       1   E10-AA-AE-mGAM-mGAM1     101294
# 29       6  AA-AF-mGAM-mBHI  False       1   D8-AA-AF-mGAM-mBHI-6     101294
# 24       0  AE-AF-mGAM-mGAM  False       1    D4-AE-AF-mGAM-mGAM0     101294
# 34       7  AE-AF-mGAM-mBHI  False       1   G11-AE-AF-mGAM-mBHI7     101294
#
#    diff_from_in       species-type_meso        species-ino  \
# 14    -0.540878  102438-AA-AE-mBHI-mBHI  102438-AA-AE-mBHI
# 26    -0.051745  102438-AE-AF-mBHI-mBHI  102438-AE-AF-mBHI
# 12    -0.537430  103117-AA-AF-mGAM-mGAM  103117-AA-AF-mGAM
# 12    -0.472709  103656-AE-AF-mGAM-mGAM  103656-AE-AF-mGAM
# 3     -0.233728  100099-AA-AF-mBHI-mBHI  100099-AA-AF-mBHI
# 23    -0.403044  101294-AA-AE-mGAM-mGAM  101294-AA-AE-mGAM
# 29     0.670339  101294-AA-AF-mGAM-mBHI  101294-AA-AF-mGAM
# 24     0.000000  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 34     0.572431  101294-AE-AF-mGAM-mBHI  101294-AE-AF-mGAM
#
#                               species-sample
# 14         102438-C2-e003Coalescence-mBHI-p3
# 26         102438-D4-e003Coalescence-mBHI-p3
# 12   103117-D_E12_E11_AF_AA_mGAM_mGAM_4_S348
# 12   103656-D_H11_H10_AE_AF_mGAM_mGAM_4_S383
# 3          100099-A5-e003Coalescence-mBHI-p3
# 23   101294-E10-e003Coalescence-mGAM-p1_S832
# 29     101294-D_D5_D8_AA_AF_mGAM_mBHI_6_S329
# 24  101294-D4-e003Coalescence-Inoculumn-mGAM
# 34  101294-G111-e003Coalescence-mBHI-p7_S128
#
# [9 rows x 28 columns]

# %%
10/1300
df_coalbad.loc[df_coalbad['species-sample'].isin(all_dfs['species-sample'].values),:]
# Out:
#        Unnamed: 0                             sample  depth  num_int_sites  \
# 3670         5644         D4-e003Coalescence-mBHI-p3    5.0         9335.0
# 3687         5662         C2-e003Coalescence-mBHI-p3    5.0         7381.0
# 5269         7920   D_E12_E11_AF_AA_mGAM_mGAM_4_S348    5.0          399.0
# 5618         8502   D_H11_H10_AE_AF_mGAM_mGAM_4_S383    5.0         5710.0
# 10024       15640         A5-e003Coalescence-mBHI-p3    5.0         4495.0
# 11602       18035     D_D5_D8_AA_AF_mGAM_mBHI_6_S329    5.0          362.0
# 11736       18188  G111-e003Coalescence-mBHI-p7_S128    5.0          960.0
# 11774       18237  D4-e003Coalescence-Inoculumn-mGAM    5.0         4695.0
# 11794       18266   E10-e003Coalescence-mGAM-p1_S832    5.0         2153.0
#
#        diversity  species_id                           species      sites  \
# 3670    0.005024      102438        Parabacteroides distasonis  1858072.0
# 3687    0.003864      102438        Parabacteroides distasonis  1909953.0
# 5269    0.000847      103117             Peptoniphilus_A harei   470850.0
# 5618    0.005770      103656               UBA1417 sp003531055   989558.0
# 10024   0.002884      100099            Flavonifractor plautii  1558390.0
# 11602   0.000369      101294  Parasutterella excrementihominis   982055.0
# 11736   0.000953      101294  Parasutterella excrementihominis  1007412.0
# 11774   0.004508      101294  Parasutterella excrementihominis  1041430.0
# 11794   0.002171      101294  Parasutterella excrementihominis   991921.0
#
#        frac_sites  frac_sites ECDF  passage parent_subjects    type_mesocosm  \
# 3670     0.462313         0.985816        3           AE-AF  AE-AF-mBHI-mBHI
# 3687     0.475221         0.981921        3           AA-AE  AA-AE-mBHI-mBHI
# 5269     0.473412         0.982560        4           AA-AF  AA-AF-mGAM-mGAM
# 5618     0.481919         0.979014        4           AE-AF  AE-AF-mGAM-mGAM
# 10024    0.469866         0.983374        3           AA-AF  AA-AF-mBHI-mBHI
# 11602    0.465023         0.985118        6           AA-AF  AA-AF-mGAM-mBHI
# 11736    0.477030         0.981281        7           AE-AF  AE-AF-mGAM-mBHI
# 11774    0.493138         0.972271        0           AE-AF  AE-AF-mGAM-mGAM
# 11794    0.469695         0.983548        1           AA-AE  AA-AE-mGAM-mGAM
#
#                   mesocosm        sp-type_mesocosm  \
# 3670    D4-AE-AF-mBHI-mBHI  102438-AE-AF-mBHI-mBHI
# 3687    C2-AA-AE-mBHI-mBHI  102438-AA-AE-mBHI-mBHI
# 5269   E11-AA-AF-mGAM-mGAM  103117-AA-AF-mGAM-mGAM
# 5618   H10-AE-AF-mGAM-mGAM  103656-AE-AF-mGAM-mGAM
# 10024   A5-AA-AF-mBHI-mBHI  100099-AA-AF-mBHI-mBHI
# 11602   H8-AA-AF-mGAM-mBHI  101294-AA-AF-mGAM-mBHI
# 11736  G11-AE-AF-mGAM-mBHI  101294-AE-AF-mGAM-mBHI
# 11774   D4-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM-mGAM
# 11794  E10-AA-AE-mGAM-mGAM  101294-AA-AE-mGAM-mGAM
#
#                       sp-mesocosm                            species-sample
# 3670    102438-D4-AE-AF-mBHI-mBHI         102438-D4-e003Coalescence-mBHI-p3
# 3687    102438-C2-AA-AE-mBHI-mBHI         102438-C2-e003Coalescence-mBHI-p3
# 5269   103117-E11-AA-AF-mGAM-mGAM   103117-D_E12_E11_AF_AA_mGAM_mGAM_4_S348
# 5618   103656-H10-AE-AF-mGAM-mGAM   103656-D_H11_H10_AE_AF_mGAM_mGAM_4_S383
# 10024   100099-A5-AA-AF-mBHI-mBHI         100099-A5-e003Coalescence-mBHI-p3
# 11602   101294-H8-AA-AF-mGAM-mBHI     101294-D_D5_D8_AA_AF_mGAM_mBHI_6_S329
# 11736  101294-G11-AE-AF-mGAM-mBHI  101294-G111-e003Coalescence-mBHI-p7_S128
# 11774   101294-D4-AE-AF-mGAM-mGAM  101294-D4-e003Coalescence-Inoculumn-mGAM
# 11794  101294-E10-AA-AE-mGAM-mGAM   101294-E10-e003Coalescence-mGAM-p1_S832

# %%
all_dfs['species-meso'] = all_dfs['species_id'].astype(str)+'-'+all_dfs['mesocosm'].astype(str)
all_dfs['species-type_meso'] = all_dfs['species_id'].astype(str)+'-'+all_dfs['type_mesocosm'].astype(str)
all_dfs.loc[all_dfs['species-type_meso']=='101294-AE-AF-mGAM-mGAM',:]
# Out:
#                                sample  Unnamed: 0  boot_med  boot_low  \
# 1      A_G8_C11_AF_AE_mGAM_mGAM_2_S80           1  0.599790  0.596013
# 5    B_G12_C11_AF_AE_mGAM_mGAM_4_S180           5  0.800000  0.800000
# 6     B_G8_G11_AF_AE_mGAM_mGAM_2_S176           6  0.581590  0.576166
# 7     B_H7_H10_AE_AF_mGAM_mGAM_2_S187           7  0.593555  0.588054
# 9    C11-e003Coalescence-mGAM-p1_S778           9  0.529661  0.500000
# 10        C11-e003Coalescence-mGAM-p3          10  0.744637  0.741344
# 11        C11-e003Coalescence-mGAM-p5          11  0.746707  0.745158
# 12        C11-e003Coalescence-mGAM-p7          12  0.818642  0.815598
# 13  C5-e003Coalescence-Inoculumn-mGAM          13  0.426011  0.422131
# 16    C_G8_C11_AF_AE_mGAM_mGAM_6_S272          16  0.827301  0.827301
# 17    C_H7_D10_AE_AF_mGAM_mGAM_6_S283          17  0.887424  0.885396
# 20   D10-e003Coalescence-mGAM-p1_S771          20  0.505699  0.502070
# 21        D10-e003Coalescence-mGAM-p3          21  0.614271  0.608025
# 22        D10-e003Coalescence-mGAM-p5          22  0.839450  0.836401
# 23        D10-e003Coalescence-mGAM-p7          23  0.850868  0.848110
# 24  D4-e003Coalescence-Inoculumn-mGAM          24  0.444444  0.418410
# 30   D_G12_G11_AF_AE_mGAM_mGAM_4_S372          30  0.792181  0.789959
# 31    D_G8_C11_AF_AE_mGAM_mGAM_6_S368          31  0.840447  0.838415
# 32   G11-e003Coalescence-mGAM-p1_S842          32  0.486653  0.482937
# 35  G111-e003Coalescence-mGAM-p3_S180          35  0.757292  0.752083
# 36   G111-e003Coalescence-mGAM-p5_S80          36  0.780231  0.775595
# 38   H10-e003Coalescence-mGAM-p1_S835          38  0.489074  0.482937
#
#     boot_high  actual_med  shifts_low  shifts_high  shifts_med comm  ...  \
# 1    0.604603    0.600418    0.036000     0.051000       0.044  C11  ...
# 5    0.827301    0.800000    0.000000     0.033000       0.000  C11  ...
# 6    0.587117    0.581590    0.035000     0.055000       0.044  G11  ...
# 7    0.596891    0.593555    0.028975     0.044000       0.038  H10  ...
# 9    0.538213    0.529661    0.000000     0.101000       0.056  C11  ...
# 10   0.747692    0.744637    0.016000     0.026000       0.021  C11  ...
# 11   0.754892    0.745677    0.011000     0.029000       0.019  C11  ...
# 12   0.822811    0.818274    0.010000     0.024025       0.016  C11  ...
# 13   0.429735    0.426380    0.015000     0.030000       0.023   C5  ...
# 16   0.835073    0.827301    0.033000     0.042000       0.033  C11  ...
# 17   0.889343    0.887424    0.012000     0.019000       0.015  D10  ...
# 20   0.508808    0.505711    0.031000     0.043000       0.037  D10  ...
# 21   0.618857    0.615385    0.019000     0.039025       0.025  D10  ...
# 22   0.842857    0.839468    0.014000     0.028000       0.021  D10  ...
# 23   0.854082    0.850868    0.018000     0.028000       0.022  D10  ...
# 24   0.444444    0.444444    0.029000     0.100000       0.100   D4  ...
# 30   0.794450    0.792395    0.022000     0.031000       0.026  G11  ...
# 31   0.843177    0.840447    0.013000     0.021000       0.017  G11  ...
# 32   0.493776    0.486125    0.022000     0.042000       0.028  G11  ...
# 35   0.762055    0.757292    0.031000     0.047000       0.038  G11  ...
# 36   0.784902    0.778008    0.024000     0.042000       0.036  G11  ...
# 38   0.493750    0.489051    0.025000     0.047000       0.039  H10  ...
#
#       type_mesocosm   redo counts       mesocosm-passage species_id  \
# 1   AE-AF-mGAM-mGAM  False      1  C11-AE-AF-mGAM-mGAM-2     101294
# 5   AE-AF-mGAM-mGAM  False      1  C11-AE-AF-mGAM-mGAM-4     101294
# 6   AE-AF-mGAM-mGAM  False      1  G11-AE-AF-mGAM-mGAM-2     101294
# 7   AE-AF-mGAM-mGAM  False      1  H10-AE-AF-mGAM-mGAM-2     101294
# 9   AE-AF-mGAM-mGAM  False      1   C11-AE-AF-mGAM-mGAM1     101294
# 10  AE-AF-mGAM-mGAM  False      1   C11-AE-AF-mGAM-mGAM3     101294
# 11  AE-AF-mGAM-mGAM  False      1   C11-AE-AF-mGAM-mGAM5     101294
# 12  AE-AF-mGAM-mGAM  False      1   C11-AE-AF-mGAM-mGAM7     101294
# 13  AE-AF-mGAM-mGAM  False      1    C5-AE-AF-mGAM-mGAM0     101294
# 16  AE-AF-mGAM-mGAM  False      1  C11-AE-AF-mGAM-mGAM-6     101294
# 17  AE-AF-mGAM-mGAM  False      1  D10-AE-AF-mGAM-mGAM-6     101294
# 20  AE-AF-mGAM-mGAM  False      1   D10-AE-AF-mGAM-mGAM1     101294
# 21  AE-AF-mGAM-mGAM  False      1   D10-AE-AF-mGAM-mGAM3     101294
# 22  AE-AF-mGAM-mGAM  False      1   D10-AE-AF-mGAM-mGAM5     101294
# 23  AE-AF-mGAM-mGAM  False      1   D10-AE-AF-mGAM-mGAM7     101294
# 24  AE-AF-mGAM-mGAM  False      1    D4-AE-AF-mGAM-mGAM0     101294
# 30  AE-AF-mGAM-mGAM  False      1  G11-AE-AF-mGAM-mGAM-4     101294
# 31  AE-AF-mGAM-mGAM  False      1  C11-AE-AF-mGAM-mGAM-6     101294
# 32  AE-AF-mGAM-mGAM  False      1   G11-AE-AF-mGAM-mGAM1     101294
# 35  AE-AF-mGAM-mGAM  False      1   G11-AE-AF-mGAM-mGAM3     101294
# 36  AE-AF-mGAM-mGAM  False      1   G11-AE-AF-mGAM-mGAM5     101294
# 38  AE-AF-mGAM-mGAM  False      1   H10-AE-AF-mGAM-mGAM1     101294
#
#    diff_from_in       species-type_meso        species-ino  \
# 1      0.174038  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 5      0.373620  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 6      0.155210  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 7      0.149111  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 9      0.103281  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 10     0.318257  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 11     0.319296  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 12     0.391894  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 13     0.000000  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 16     0.400921  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 17     0.442979  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 20     0.061267  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 21     0.170940  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 22     0.395024  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 23     0.406424  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 24     0.000000  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 30     0.366014  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 31     0.414067  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 32     0.059745  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 35     0.330911  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 36     0.351628  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
# 38     0.044607  101294-AE-AF-mGAM-mGAM  101294-AE-AF-mGAM
#
#                               species-sample                species-meso
# 1      101294-A_G8_C11_AF_AE_mGAM_mGAM_2_S80  101294-C11-AE-AF-mGAM-mGAM
# 5    101294-B_G12_C11_AF_AE_mGAM_mGAM_4_S180  101294-C11-AE-AF-mGAM-mGAM
# 6     101294-B_G8_G11_AF_AE_mGAM_mGAM_2_S176  101294-G11-AE-AF-mGAM-mGAM
# 7     101294-B_H7_H10_AE_AF_mGAM_mGAM_2_S187  101294-H10-AE-AF-mGAM-mGAM
# 9    101294-C11-e003Coalescence-mGAM-p1_S778  101294-C11-AE-AF-mGAM-mGAM
# 10        101294-C11-e003Coalescence-mGAM-p3  101294-C11-AE-AF-mGAM-mGAM
# 11        101294-C11-e003Coalescence-mGAM-p5  101294-C11-AE-AF-mGAM-mGAM
# 12        101294-C11-e003Coalescence-mGAM-p7  101294-C11-AE-AF-mGAM-mGAM
# 13  101294-C5-e003Coalescence-Inoculumn-mGAM   101294-C5-AE-AF-mGAM-mGAM
# 16    101294-C_G8_C11_AF_AE_mGAM_mGAM_6_S272  101294-C11-AE-AF-mGAM-mGAM
# 17    101294-C_H7_D10_AE_AF_mGAM_mGAM_6_S283  101294-D10-AE-AF-mGAM-mGAM
# 20   101294-D10-e003Coalescence-mGAM-p1_S771  101294-D10-AE-AF-mGAM-mGAM
# 21        101294-D10-e003Coalescence-mGAM-p3  101294-D10-AE-AF-mGAM-mGAM
# 22        101294-D10-e003Coalescence-mGAM-p5  101294-D10-AE-AF-mGAM-mGAM
# 23        101294-D10-e003Coalescence-mGAM-p7  101294-D10-AE-AF-mGAM-mGAM
# 24  101294-D4-e003Coalescence-Inoculumn-mGAM   101294-D4-AE-AF-mGAM-mGAM
# 30   101294-D_G12_G11_AF_AE_mGAM_mGAM_4_S372  101294-G11-AE-AF-mGAM-mGAM
# 31    101294-D_G8_C11_AF_AE_mGAM_mGAM_6_S368  101294-G11-AE-AF-mGAM-mGAM
# 32   101294-G11-e003Coalescence-mGAM-p1_S842  101294-G11-AE-AF-mGAM-mGAM
# 35  101294-G111-e003Coalescence-mGAM-p3_S180  101294-G11-AE-AF-mGAM-mGAM
# 36   101294-G111-e003Coalescence-mGAM-p5_S80  101294-G11-AE-AF-mGAM-mGAM
# 38   101294-H10-e003Coalescence-mGAM-p1_S835  101294-H10-AE-AF-mGAM-mGAM
#
# [22 rows x 29 columns]

# %%
all_dfs['species-mesocosm']=all_dfs['species_id'].astype(str) + '-' + all_dfs['mesocosm'].astype(str)
all_dfs7 = all_dfs.loc[all_dfs['passage']==7,:]
all_dfs0 = all_dfs.loc[all_dfs['passage']==0,:]
all_dfs7['passage_0'] = np.nan
all_dfs7['sp_ino']=all_dfs7['species_id'].astype(str)+'-'+all_dfs7['inoculumn_sample']
all_dfs0['sp_ino']=all_dfs0['species_id'].astype(str)+'-'+all_dfs0['inoculumn_sample']
for spin in all_dfs7['sp_ino'].unique():
    in_sample = '-'.join(spin.split('-')[1:])
    all_dfs0_good=all_dfs0.loc[all_dfs0['sp_ino']==spin,:]
    all_dfs0_good=all_dfs0_good.loc[all_dfs0_good['sample']==in_sample,'actual_med'].values
    if len(all_dfs0_good)==0:
        continue
    all_dfs7.loc[all_dfs7['sp_ino']==spin,'passage_0']=all_dfs0_good[0]

# %%
all_dfs7 = all_dfs7.loc[~all_dfs7['passage_0'].isna(),:]
all_dfs7p = all_dfs7.copy()
all_dfs7p.loc[all_dfs7p['passage_0']>.5,'actual_med1']=1.-all_dfs7p.loc[all_dfs7p['passage_0']>.5,'actual_med']
all_dfs7p.loc[all_dfs7p['passage_0']>.5,'passage_0']=1.-all_dfs7p.loc[all_dfs7p['passage_0']>.5,'passage_0']
all_dfs7p.head()
# Out:
#                                sample  Unnamed: 0  boot_med  boot_low  \
# 2         A10-e003Coalescence-mBHI-p7           2  0.500000  0.500000
# 4         A10-e003Coalescence-mGAM-p7           4  0.004968  0.004296
# 18         C8-e003Coalescence-mBHI-p7          18  0.298174  0.290061
# 19         C8-e003Coalescence-mGAM-p7          19  0.101112  0.092292
# 41  E100-e003Coalescence-mBHI-p7_S103          41  0.795501  0.793602
#
#     boot_high  actual_med  shifts_low  shifts_high  shifts_med comm  ...  \
# 2    0.500000    0.500000    0.000000     0.000000    0.000000  A10  ...
# 4    0.005644    0.004960   -0.000421     0.001404    0.000512  A10  ...
# 18   0.302419    0.298174    0.000000     0.022000    0.010000   C8  ...
# 19   0.105634    0.101112    0.000000     0.020000    0.011000   C8  ...
# 41   0.800412    0.795501    0.022000     0.032000    0.022000  E10  ...
#
#    species_id diff_from_in       species-type_meso        species-ino  \
# 2      100146     0.365248  100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
# 4      100146    -0.129792  100146-AA-AE-mGAM-mGAM  100146-AA-AE-mGAM
# 18     100146     0.220710  100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
# 19     100146     0.023647  100146-AA-AE-mGAM-mGAM  100146-AA-AE-mGAM
# 41     100146     0.660749  100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
#
#                               species-sample                species-meso  \
# 2         100146-A10-e003Coalescence-mBHI-p7  100146-A10-AA-AE-mGAM-mBHI
# 4         100146-A10-e003Coalescence-mGAM-p7  100146-A10-AA-AE-mGAM-mGAM
# 18         100146-C8-e003Coalescence-mBHI-p7   100146-C8-AA-AE-mGAM-mBHI
# 19         100146-C8-e003Coalescence-mGAM-p7   100146-C8-AA-AE-mGAM-mGAM
# 41  100146-E100-e003Coalescence-mBHI-p7_S103  100146-E10-AA-AE-mGAM-mBHI
#
#               species-mesocosm passage_0  \
# 2   100146-A10-AA-AE-mGAM-mBHI  0.134752
# 4   100146-A10-AA-AE-mGAM-mGAM  0.134752
# 18   100146-C8-AA-AE-mGAM-mBHI  0.077465
# 19   100146-C8-AA-AE-mGAM-mGAM  0.077465
# 41  100146-E10-AA-AE-mGAM-mBHI  0.134752
#
#                                       sp_ino actual_med1
# 2   100146-A4-e003Coalescence-Inoculumn-mGAM         NaN
# 4   100146-A4-e003Coalescence-Inoculumn-mGAM         NaN
# 18  100146-C2-e003Coalescence-Inoculumn-mGAM         NaN
# 19  100146-C2-e003Coalescence-Inoculumn-mGAM         NaN
# 41  100146-A4-e003Coalescence-Inoculumn-mGAM         NaN
#
# [5 rows x 33 columns]

# %%
all_dfs7p['passage'] = all_dfs7p['passage'].astype(str)

p1 = hv.Points(all_dfs7p,vdims = ['passage_0','actual_med1'],
              kdims = [hv.Dimension('passage',values = ['0','7']),'actual_med']).opts(jitter = .1, size=4,
                                                      color = 'passage_0',
                                                      show_legend=False,
                                                      xlabel='Passage',cmap = 'Magma',
                                                                                       
                                                      
                                                      #cmap = bokeh.palettes.
                                                      alpha = .5)
all_dfs7p0=all_dfs7p.copy()
all_dfs7p0['passage']='0'
all_dfs7p0['actual_med1']=all_dfs7p0['passage_0'].copy()
p2= hv.Points(all_dfs7p0,vdims = ['passage_0','actual_med1'],
              kdims = [hv.Dimension('passage',values = ['0','7']),'actual_med']).opts(jitter = .1, size=4,
                                                      color = 'passage_0',
                                                      show_legend=False,
                                                      xlabel='Passage',ylabel = 'Strain Frequency',
                                                                                       
                                                
                                                      cmap = 'Magma',
                                                      alpha = .5)
p = hv.Scatter(all_dfs7p, vdims = ['inoculumn','passage_0'],
               kdims = ['passage_0','actual_med'],).opts(color='inoculumn', size=6,
                                                          xlabel='Freq Passage 0',
                                                          ylabel = 'Freq Passage 7',
                                                          width = 600,alpha=.5,
                                                          cmap = bokeh.palettes.Bright[6],
                                                          line_color='black',legend_position='right',)

from scipy.stats import pearsonr
print(pearsonr(all_dfs7p['passage_0'].values,all_dfs7p['actual_med'].values))
good_ones = all_dfs7p.loc[all_dfs7p['passage_0']>.3,:]
print(pearsonr(good_ones['passage_0'].values,good_ones['actual_med'].values))
good_ones = all_dfs7p.loc[all_dfs7p['passage_0']<.3,:]
print(pearsonr(good_ones['passage_0'].values,good_ones['actual_med'].values))
p=hv.render(p)
p.xaxis.axis_label_text_font_style = 'normal'
p.yaxis.axis_label_text_font_style = 'normal'
p.xaxis.axis_label_text_font_size = '22px'
p.yaxis.axis_label_text_font_size = '22px'

p.xaxis.major_label_text_font_size = '20px'
p.yaxis.major_label_text_font_size = '20px'
bokeh.io.show(p)
p.output_backend='svg'
export_plot_pdf(p,'07corr')
# Out:
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# PearsonRResult(statistic=np.float64(0.12859598729493357), pvalue=np.float64(0.10291902156348709))
# PearsonRResult(statistic=np.float64(-0.03720798436765696), pvalue=np.float64(0.6791382109717946))
# PearsonRResult(statistic=np.float64(-0.10920166186586709), pvalue=np.float64(0.5260893724245521))
#   <div id="ce344a29-6bc8-4ba3-aaf6-30c5fd85bb87" data-root-id="2d4b1e42-a1a6-4c85-9dcf-c368bc89482a" style="display: contents;"></div>

# %%
for ino in all_dfs7p['inoculumn'].unique():
    good_ones = all_dfs7p.loc[all_dfs7p['inoculumn']==ino,]
    print(ino, pearsonr(good_ones['passage_0'].values,good_ones['actual_med1'].values))
    if len(good_ones.loc[good_ones['passage_0']<.1, 'passage_0'].values)>0:
        print(ino,  'small',pearsonr(good_ones.loc[good_ones['passage_0']<.1, 'passage_0'].values, 
                             good_ones.loc[good_ones['passage_0']<.1, 'actual_med1'].values))
    if len(good_ones.loc[good_ones['passage_0']>.1, 'passage_0'].values):
        print(ino, 'big',  pearsonr(good_ones.loc[good_ones['passage_0']>.1, 'passage_0'].values,
                                    good_ones.loc[good_ones['passage_0']>.1, 'actual_med1'].values))
# Out:
# AA-AE-mGAM PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AE-mGAM small PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AE-mGAM big PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AF-mGAM PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AF-mGAM big PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AE-AF-mGAM PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AE-AF-mGAM big PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AF-mBHI PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AF-mBHI big PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AE-mBHI PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AE-mBHI small PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AA-AE-mBHI big PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AE-AF-mBHI PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# AE-AF-mBHI big PearsonRResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# /var/folders/m8/d6y7bwh127db53wc5fyr9w6c0000gn/T/ipykernel_2005/1465569792.py:5: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   print(ino,  'small',pearsonr(good_ones.loc[good_ones['passage_0']<.1, 'passage_0'].values,

# %%
#all_dfs=all_dfs.loc[all_dfs['total_shift']<.1,:]
all_dfs.loc[all_dfs['passage']>0,'species-type_meso'].unique()
df_coal = pd.read_csv('num_sites_stuff_coal.csv')
df_coal['species-sample']=df_coal['species_id'].astype(str)+'-'+df_coal['sample'].astype(str)
all_dfs['species-sample'] = all_dfs['species_id'].astype(str)+'-'+ all_dfs['sample'].astype(str)
df_coalbad = df_coal.loc[df_coal['frac_sites']<.45,:]
all_dfs.head()
# Out:
#                              sample  Unnamed: 0  boot_med  boot_low  \
# 0  A10-e003Coalescence-mBHI-p1_S764           0  0.617920  0.615385
# 1       A10-e003Coalescence-mBHI-p5           1  0.411946  0.411946
# 2       A10-e003Coalescence-mBHI-p7           2  0.500000  0.500000
# 3       A10-e003Coalescence-mGAM-p3           3  0.127291  0.126008
# 4       A10-e003Coalescence-mGAM-p7           4  0.004968  0.004296
#
#    boot_high  actual_med  shifts_low  shifts_high  shifts_med comm  ...  \
# 0   0.620513    0.618219    0.019000     0.029000    0.024000  A10  ...
# 1   0.422998    0.411946    0.012000     0.044000    0.029000  A10  ...
# 2   0.500000    0.500000    0.000000     0.000000    0.000000  A10  ...
# 3   0.134343    0.127291    0.000000     0.018000    0.018000  A10  ...
# 4   0.005644    0.004960   -0.000421     0.001404    0.000512  A10  ...
#
#     redo counts      mesocosm-passage  species_id diff_from_in  \
# 0  False      1  A10-AA-AE-mGAM-mBHI1      100146     0.483467
# 1  False      1  A10-AA-AE-mGAM-mBHI5      100146     0.277195
# 2  False      1  A10-AA-AE-mGAM-mBHI7      100146     0.365248
# 3  False      1  A10-AA-AE-mGAM-mGAM3      100146    -0.007461
# 4  False      1  A10-AA-AE-mGAM-mGAM7      100146    -0.129792
#
#         species-type_meso        species-ino  \
# 0  100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
# 1  100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
# 2  100146-AA-AE-mGAM-mBHI  100146-AA-AE-mGAM
# 3  100146-AA-AE-mGAM-mGAM  100146-AA-AE-mGAM
# 4  100146-AA-AE-mGAM-mGAM  100146-AA-AE-mGAM
#
#                             species-sample                species-meso  \
# 0  100146-A10-e003Coalescence-mBHI-p1_S764  100146-A10-AA-AE-mGAM-mBHI
# 1       100146-A10-e003Coalescence-mBHI-p5  100146-A10-AA-AE-mGAM-mBHI
# 2       100146-A10-e003Coalescence-mBHI-p7  100146-A10-AA-AE-mGAM-mBHI
# 3       100146-A10-e003Coalescence-mGAM-p3  100146-A10-AA-AE-mGAM-mGAM
# 4       100146-A10-e003Coalescence-mGAM-p7  100146-A10-AA-AE-mGAM-mGAM
#
#              species-mesocosm
# 0  100146-A10-AA-AE-mGAM-mBHI
# 1  100146-A10-AA-AE-mGAM-mBHI
# 2  100146-A10-AA-AE-mGAM-mBHI
# 3  100146-A10-AA-AE-mGAM-mGAM
# 4  100146-A10-AA-AE-mGAM-mGAM
#
# [5 rows x 30 columns]

# %%
all_dfs=all_dfs.loc[all_dfs['shifts_med']<.1,:]
print(len(all_dfs['species_id'].unique()))
print(len(all_dfs.loc[all_dfs['passage']>0,'species-type_meso'].unique()))
all_dfsgood = all_dfs.loc[~all_dfs['species-sample'].isin(df_coalbad['species-sample']),:]
print(len(all_dfsgood['species_id'].unique()))
print(len(all_dfsgood.loc[all_dfsgood['passage']>0,'species-type_meso'].unique()))
all_dfs_p7 = all_dfs.loc[all_dfs['passage']==7,:]
all_dfs_p7['diff_from_in_abs']=all_dfs_p7['diff_from_in'].abs()
all_dfs_gr=all_dfs_p7.groupby(['species-type_meso']).median(numeric_only=True).reset_index()
all_dfs_gr['diff_from_in_abs']=all_dfs_gr['diff_from_in'].abs()
frequencies, edges = np.histogram(all_dfs_p7['diff_from_in_abs'],bins=20)
#print('Values: %s, Edges: %s' % (frequencies.shape[0], edges.shape[0]))
hv.Histogram((edges, frequencies)).opts(width=400, height=200, xlabel='|Absolute Frequency Shift|', 
                                        ylabel='Counts',fill_color= bokeh.palettes.Bright[6][1]
                                       )
# Out:
# 13
# 61
# 13
# 61
# :Histogram   [x]   (Frequency)

# %%
all_dfs=all_dfs.loc[all_dfs['shifts_med']<.1,:]
all_dfs_p7 = all_dfs.loc[all_dfs['passage']==7,:]
all_dfs_p7  = all_dfs_p7.loc[~all_dfs_p7['species-sample'].isin(df_coalbad['species-sample']),:]
all_dfs_p7['dir']=all_dfs_p7['diff_from_in']>0
all_dfs_p7['counts']=1
all_dfs_p7_gr=all_dfs_p7.groupby(['species-type_meso','species_id']).sum(numeric_only=True)
all_dfs_p7_gr['frac_one']=all_dfs_p7_gr['dir']/all_dfs_p7_gr['counts']
all_dfs_p7_gr['dir_adjust'] = all_dfs_p7_gr['frac_one']<.5
all_dfs_p7_gr['counts_major']=all_dfs_p7_gr['dir']
all_dfs_p7_gr['counts_opp'] = all_dfs_p7_gr['counts']-all_dfs_p7_gr['dir']
all_dfs_p7_gr.loc[all_dfs_p7_gr['dir_adjust'],'counts_major']=all_dfs_p7_gr['counts_opp'].astype(int)

all_dfs_p7_gr['all_one_dir']=all_dfs_p7_gr['counts_major']==all_dfs_p7_gr['counts']
all_dfs_p7_gr['counts_major'].min()
all_dfs_p7_gr=all_dfs_p7_gr.loc[all_dfs_p7_gr['counts']>1,:]
len(all_dfs_p7_gr.reset_index()['species_id'].unique())
print(len(all_dfs['species-type_meso'].unique()))
print(len(all_dfs['species_id'].unique()))
print(len(all_dfs_p7['species-type_meso'].unique()))
# Out:
# 61
# 13
# 51

# %%
np.setdiff1d(all_dfs['species-type_meso'].unique(),np.array(['100146-AA-AE-mGAM-mBHI', '100146-AA-AF-mGAM-mBHI',
       '100146-AA-AF-mGAM-mGAM', '100146-AE-AF-mGAM-mBHI',
       '101059-AA-AF-mBHI-mBHI', '101059-AA-AF-mBHI-mGAM',
       '100910-AA-AE-mBHI-mBHI', '100910-AA-AE-mBHI-mGAM',
       '102478-AA-AF-mGAM-mBHI', '102478-AA-AF-mGAM-mGAM',
       '102438-AA-AE-mBHI-mGAM', '102438-AA-AF-mBHI-mBHI',
       '102438-AA-AF-mBHI-mGAM', '102438-AE-AF-mBHI-mBHI',
       '102438-AE-AF-mBHI-mGAM', '102438-AA-AE-mGAM-mBHI',
       '102438-AA-AE-mGAM-mGAM', '102438-AA-AF-mGAM-mBHI',
       '102438-AA-AF-mGAM-mGAM', '102438-AE-AF-mGAM-mGAM',
       '102438-AE-AF-mGAM-mBHI', '100196-AA-AE-mBHI-mGAM',
       '100196-AA-AF-mGAM-mGAM', '103656-AA-AE-mGAM-mGAM',
       '103656-AA-AF-mGAM-mGAM', '103656-AE-AF-mGAM-mGAM',
       '102506-AA-AF-mGAM-mBHI', '102506-AA-AF-mGAM-mGAM',
       '101346-AA-AF-mGAM-mGAM', '100099-AA-AE-mBHI-mBHI',
       '100099-AA-AE-mBHI-mGAM', '100099-AA-AF-mBHI-mBHI',
       '100099-AA-AF-mBHI-mGAM', '100099-AE-AF-mBHI-mBHI',
       '100099-AE-AF-mBHI-mGAM', '100099-AA-AE-mGAM-mBHI',
       '100099-AA-AE-mGAM-mGAM', '100099-AA-AF-mGAM-mBHI',
       '100099-AA-AF-mGAM-mGAM', '100099-AE-AF-mGAM-mGAM',
       '100099-AE-AF-mGAM-mBHI', '101400-AA-AF-mBHI-mBHI',
       '101294-AE-AF-mBHI-mGAM', '101294-AA-AE-mGAM-mGAM',
       '101294-AA-AF-mGAM-mGAM', '101294-AE-AF-mGAM-mGAM',
       '101294-AE-AF-mGAM-mBHI']))
# Out:
# array(['100146-AA-AE-mGAM-mGAM', '100146-AE-AF-mGAM-mGAM',
#        '100196-AA-AE-mBHI-mBHI', '100196-AA-AF-mGAM-mBHI',
#        '101294-AA-AE-mGAM-mBHI', '101294-AA-AF-mGAM-mBHI',
#        '101294-AE-AF-mBHI-mBHI', '101346-AA-AF-mGAM-mBHI',
#        '102438-AA-AE-mBHI-mBHI', '102544-AA-AE-mBHI-mBHI',
#        '102544-AA-AE-mBHI-mGAM', '103117-AA-AF-mGAM-mBHI',
#        '103117-AA-AF-mGAM-mGAM', '103656-AA-AF-mGAM-mBHI',
#        '103656-AE-AF-mGAM-mBHI'], dtype=object)

# %%
all_dfs.loc[all_dfs['species-type_meso']=='101294-AE-AF-mBHI-mBHI','passage']
# Out:
# 0     2
# 6     0
# 15    0
# Name: passage, dtype: int64

# %%
len(all_dfs.loc[all_dfs['passage']>0,'species-type_meso'].unique())
# Out:
# 61

# %%
all_dfs['species-type_meso']
# Out:
# 0     100146-AA-AE-mGAM-mBHI
# 1     100146-AA-AE-mGAM-mBHI
# 2     100146-AA-AE-mGAM-mBHI
# 3     100146-AA-AE-mGAM-mGAM
# 4     100146-AA-AE-mGAM-mGAM
#                ...
# 36    101294-AE-AF-mGAM-mGAM
# 37    101294-AE-AF-mGAM-mBHI
# 38    101294-AE-AF-mGAM-mGAM
# 39    101294-AE-AF-mGAM-mBHI
# 40    101294-AE-AF-mGAM-mBHI
# Name: species-type_meso, Length: 1285, dtype: object

# %%
np.intersect1d(all_dfs_p7['species-sample'].values, df_coalbad['species-sample'].values)
# Out:
# array([], dtype=object)

# %%
counts_34 = all_dfs_p7_gr.loc[all_dfs_p7_gr['counts']>2,:]
cons = len(counts_34.loc[counts_34['all_one_dir'],:])
trials_4 = len(counts_34.loc[counts_34['counts']==4,:])
trials_3 = len(counts_34.loc[counts_34['counts']==3,:])

# %%
def get_bs_reps_all_4s(n_trials,n_bs_trials=10000):
    bs_reps = np.zeros(n_bs_trials)
    bs_reps1=  np.zeros(n_bs_trials)
    bs_reps2 = np.zeros(n_bs_trials)
    for n in range(n_bs_trials):
        rep = np.random.binomial(4,1/2,size=n_trials)
        bs_reps[n]=np.sum(rep==4)+np.sum(rep==0)
        bs_reps1[n]=np.sum(rep==3)+np.sum(rep==1)
        bs_reps2[n]=np.sum(rep==2)
    return bs_reps, bs_reps1,bs_reps2

def get_bs_reps_4s_3s(n_trials4, n_trials3, n_bs_trials=10000):
    bs_reps = np.zeros(n_bs_trials)
    for n in range(n_bs_trials):
        rep4 = np.random.binomial(4,1/2,size=n_trials4)
        rep3=np.random.binomial(3,1/2,size=n_trials3)
        bs_reps[n]=np.sum(rep4==4)+np.sum(rep4==0)+np.sum(rep3==3)+np.sum(rep3==0)
    return bs_reps

# %%
b34=get_bs_reps_4s_3s(trials_4, trials_3, n_bs_trials=100000)/(trials_4+trials_3)
b34
# Out:
# array([0.16216216, 0.10810811, 0.13513514, ..., 0.13513514, 0.18918919,
#        0.13513514], shape=(100000,))

# %%
cons
# Out:
# 29

# %%
(trials_4+trials_3)
# Out:
# 37

# %%
dfgood = pd.DataFrame(data = {'Data': ['Data','Null Dist'], 'Vals': [cons/(trials_4+trials_3), np.median(b34)]})
p = hv.Bars(dfgood.sort_values(by='Data',ascending=True), kdims = ['Data'],vdims = ['Vals']).opts(ylim=(0,1),fill_color='Data',
                                                                                  cmap = [bokeh.palettes.Vibrant[4][-1], 'grey',],
                                                                                   alpha = .5,
                                                                                                   height=400,
                                                                                                   width=250,
                                                                                   bar_width = .5,show_legend=False)

low = np.median(b34)-np.percentile(b34, 2.5)
upp = np.percentile(b34, 97.5) - np.median(b34)
print(upp)
print(low)
print(np.median(b34))
p=hv.render(p)
from bokeh.models import ColumnDataSource, Whisker
source = ColumnDataSource(data=dict(base=['Null Dist'], upper=[np.percentile(b34, 97.5)], lower=[np.percentile(b34, 2.5)]))
error = Whisker(base="base", upper="upper", lower="lower", source=source,
                level="annotation", line_width=2)

p.add_layout(error)
p.output_backend='svg'
p.yaxis.major_label_text_font_size='18px'
p.xaxis.major_label_text_font_size='18px'
p.xaxis.axis_label=None
bokeh.io.show(p)
export_plot_pdf(p,'sim_vs_null_repro')
# Out:
# 0.10810810810810811
# 0.10810810810810811
# 0.16216216216216217
#   <div id="b4cf4b78-6e67-4432-8742-be54a1fddd95" data-root-id="d93d5170-6669-465d-a257-7cbe5b26d468" style="display: contents;"></div>

# %%
trials4 = counts_34.loc[counts_34['counts']==4,:]
trials4_3s = trials4.loc[(trials4['counts_major']==4)+(trials4['counts_major']==0),:]
len(trials4)
# Out:
# 27

# %%
['Data','Null']*3
# Out:
# ['Data', 'Null', 'Data', 'Null', 'Data', 'Null']

# %%
b, b1,b2=get_bs_reps_all_4s(27,n_bs_trials=100000)
trials_4 = len(counts_34.loc[counts_34['counts']==4,:])
trials_4
counts_34.loc[counts_34['counts']==4,:]


dfgood = pd.DataFrame(data = {'Data': ['Data','Null Dist'], 'Vals': [cons/(trials_4+trials_3), np.median(b34)]})
dfgood =pd.DataFrame(data = {'Data2':['Data 2 vs 2','Null 2 vs 2', 
                                    'Data 3 vs 1','Null 3 vs 1',
                                    'Data 4 vs 0','Null 4 vs 0'],
                             'Data':['Data','Null','Data','Null','Data','Null',],
                             'Compare':[3,3.25,2,2.25,1,1.25],
                             'Vals': [2/27, np.median(b2)/27,
                                      6/27,np.median(b1)/27,
                                      19/27, np.median(b)/27,]})
                                      
                             
 #values =[ 'Data 4 vs 0','Null 4 vs 0', 'Data 3 vs 1','Null 3 vs 1', 'Data 2 vs 2','Null 2 vs 2']                            
p = hv.Bars(dfgood, kdims = ['Compare'],vdims = ['Vals','Data']).opts(ylim=(0,1),fill_color='Data',
                                                                                  cmap = [bokeh.palettes.Vibrant[4][-1], 'grey'],
                                                                                   alpha = .5,
                                                                                                   height=200,
                                                                                                   width=400,
                                                                                   bar_width = 1,show_legend=True)

p=hv.render(p)
source = ColumnDataSource(data=dict(base=[3.25,2.25,1.25 ], upper=[np.percentile(b2/27, 97.5),
                                                                  np.percentile(b1/27, 97.5),
                                                                 np.percentile(b/27, 97.5)], 
                                    lower=[np.percentile(b2/27, 2.5),
                                   np.percentile(b1/27, 2.5),
                                          np.percentile(b/27, 2.5)]))
error = Whisker(base="base", upper="upper", lower="lower", source=source,
                level="annotation", line_width=2)

p.add_layout(error)

p.output_backend='svg'
p.yaxis.major_label_text_font_size='15px'
p.xaxis.major_label_text_font_size='15px'
p.xaxis.minor_tick_line_color= None
p.xaxis.major_tick_line_color= None
p.xaxis.axis_label=None
p.legend.visible=False
bokeh.io.show(p)
export_plot_pdf(p,'sim_vs_null_repro_only_4s')
# Out:
#   <div id="b2110195-42e9-4350-8d3d-13088477f06a" data-root-id="2dcd1856-9903-483d-bb55-6368a1b6c85e" style="display: contents;"></div>

# %%
19/27
# Out:
# 0.7037037037037037

# %%
p.output_backend='svg'
p.yaxis.major_label_text_font_size='15px'
p.xaxis.major_label_text_font_size='15px'
p.xaxis.axis_label=None
bokeh.io.show(p)
export_plot_pdf(p,'sim_vs_null_repro_only_4s')
# Out:
#   <div id="e36eefce-f8b2-42af-8e17-ae96e31d73eb" data-root-id="2dcd1856-9903-483d-bb55-6368a1b6c85e" style="display: contents;"></div>
